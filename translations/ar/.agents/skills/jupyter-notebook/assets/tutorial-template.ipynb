# %% [markdown]
# # دليل: TITLE
#
# الجمهور:
# - صف من هذا موجه إليه.
#
# المتطلبات المسبقة:
# - اذكر المفاهيم أو الإعدادات المطلوبة.
#
# أهداف التعلم:
# - عند الانتهاء، سيتمكن القارئ من...

# %% [markdown]
# ## الخطوط العريضة
#
# 1. الإعداد
# 2. مثال عملي بسيط
# 3. الاختلافات والمزالق
# 4. تمارين

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## الخطوة 1 - ابدأ بمثال صغير
#
# اشرح ما تفعله الخلية التالية بلغة بسيطة.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## تمارين
#
# - جرّب إدخالًا مختلفًا.
# - تنبّأ بالمخرجات قبل تشغيل الشيفرة.
# - اذكر خطأً شائعًا واحدًا وكيفية إصلاحه.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# إخلاء المسؤولية:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة الآلية Co-op Translator (https://github.com/Azure/co-op-translator). بينما نسعى لتحقيق الدقة، يُرجى العلم أن الترجمات الآلية قد تحتوي على أخطاء أو عدم دقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر المعتمد. للمعلومات الحرجة، يُنصح بالاستعانة بترجمة مهنية بشرية. نحن غير مسؤولين عن أي سوء فهم أو تفسير خاطئ ينشأ عن استخدام هذه الترجمة.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
