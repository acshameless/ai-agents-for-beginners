# %% [markdown]
# # 🔍 RAG المؤسساتي مع Microsoft Foundry (.NET)
#
# ## 📋 أهداف التعلم
#
# توضح هذه المذكرة كيفية بناء أنظمة التوليد المعزز بالاسترجاع (RAG) بمستوى مؤسسي باستخدام إطار عمل Microsoft Agent في .NET مع Microsoft Foundry. ستتعلم كيفية إنشاء وكلاء جاهزين للإنتاج يمكنهم البحث عبر الوثائق وتقديم إجابات دقيقة وواعية للسياق مع مستويات أمان وقابلية توسيع على مستوى المؤسسة.
#
# **قدرات RAG المؤسساتي التي ستبنيها:**
# - 📚 **ذكاء المستندات**: معالجة متقدمة للمستندات باستخدام خدمات Azure AI
# - 🔍 **البحث الدلالي**: بحث شعاعي عالي الأداء مع ميزات مؤسسية
# - 🛡️ **تكامل الأمان**: تحكم بالوصول قائم على الأدوار وأنماط حماية البيانات
# - 🏢 **هندسة قابلة للتوسع**: أنظمة RAG جاهزة للإنتاج مع المراقبة
#
# ## 🎯 هندسة RAG المؤسساتي
#
# ### المكونات الأساسية للمؤسسة
# - **Microsoft Foundry**: منصة ذكاء اصطناعي مُدارة للمؤسسات مع الأمان والامتثال
# - **Persistent Agents**: وكلاء بحالة مع سجل المحادثة وإدارة السياق
# - **Vector Store Management**: فهرسة واسترجاع مستندات بمستوى مؤسسي
# - **Identity Integration**: مصادقة Azure AD والتحكم في الوصول قائمًا على الأدوار
#
# ### فوائد .NET للمؤسسات
# - **Type Safety**: التحقق أثناء التجميع لعمليات RAG وهياكل البيانات
# - **Async Performance**: معالجة مستندات وعمليات بحث غير حابسة
# - **Memory Management**: استخدام موارد فعال لمجموعات المستندات الكبيرة
# - **Integration Patterns**: تكامل أصلي مع خدمات Azure باستخدام حقن التبعيات
#
# ## 🏗️ الهندسة التقنية
#
# ### خط أنابيب RAG للمؤسسة
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### المكونات الأساسية لـ .NET
# - **Azure.AI.Agents.Persistent**: إدارة الوكلاء للمؤسسات مع حفظ الحالة
# - **Azure.Identity**: مصادقة متكاملة للوصول الآمن إلى خدمات Azure
# - **Microsoft.Agents.AI.AzureAI**: تنفيذ إطار عمل الوكلاء محسّن لـ Azure
# - **System.Linq.Async**: عمليات LINQ غير متزامنة عالية الأداء
#
# ## 🔧 ميزات وفوائد المؤسسة
#
# ### الأمان والامتثال
# - **Azure AD Integration**: إدارة هوية ومصادقة للمؤسسات
# - **Role-Based Access**: أذونات دقيقة للوصول إلى المستندات والعمليات
# - **Data Protection**: التشفير أثناء التخزين والنقل للمستندات الحساسة
# - **Audit Logging**: تتبع نشاط شامل لمتطلبات الامتثال
#
# ### الأداء وقابلية التوسع
# - **Connection Pooling**: إدارة فعالة لاتصالات خدمات Azure
# - **Async Processing**: عمليات غير حابسة لسيناريوهات ذات إنتاجية عالية
# - **Caching Strategies**: تخزين مؤقت ذكي للمستندات التي يتم الوصول إليها بكثرة
# - **Load Balancing**: معالجة موزعة للنشر على نطاق واسع
#
# ### الإدارة والمراقبة
# - **Health Checks**: مراقبة مدمجة لمكونات نظام RAG
# - **Performance Metrics**: تحليلات مفصلة حول جودة البحث وأوقات الاستجابة
# - **Error Handling**: إدارة شاملة للاستثناءات مع سياسات إعادة المحاولة
# - **Configuration Management**: إعدادات مخصصة للبيئة مع التحقق من الصحة
#
# ## ⚙️ المتطلبات والإعداد
#
# **بيئة التطوير:**
# - .NET 9.0 SDK أو أعلى
# - Visual Studio 2022 أو VS Code مع امتداد C#
# - اشتراك Azure مع وصول إلى AI Foundry
#
# **حزم NuGet المطلوبة:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **إعداد مصادقة Azure:**
# ```bash
# # تثبيت Azure CLI وتسجيل الدخول
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **تكوين البيئة (ملف .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 أنماط RAG للمؤسسات
#
# ### أنماط إدارة المستندات
# - **Bulk Upload**: معالجة فعالة لمجموعات المستندات الكبيرة
# - **Incremental Updates**: إضافة وتعديل المستندات في الوقت الحقيقي
# - **Version Control**: إصدار المستندات وتتبع التغييرات
# - **Metadata Management**: سمات غنية للمستندات وتصنيف
#
# ### أنماط البحث والاسترجاع
# - **Hybrid Search**: دمج البحث الدلالي وبالكلمات المفتاحية للحصول على أفضل النتائج
# - **Faceted Search**: تصفية وتصنيف متعدد الأبعاد
# - **Relevance Tuning**: ضبط الصلة بخوارزميات تصنيف مخصصة لاحتياجات المجال
# - **Result Ranking**: ترتيب متقدم مع تكامل منطق الأعمال
#
# ### أنماط الأمان
# - **Document-Level Security**: تحكم وصول دقيق على مستوى المستند
# - **Data Classification**: تصنيف البيانات ووضع تسميات الحساسية والحماية تلقائيًا
# - **Audit Trails**: تسجيل شامل لكل عمليات RAG
# - **Privacy Protection**: اكتشاف المعلومات الشخصية وإمكانيات إخفائها/حجبها
#
# ## 🔒 ميزات أمان المؤسسة
#
# ### المصادقة والتفويض
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### حماية البيانات
# - **Encryption**: تشفير شامل من الطرف إلى الطرف للمستندات وفهارس البحث
# - **Access Controls**: التكامل مع Azure AD لأذونات المستخدمين والمجموعات
# - **Data Residency**: ضوابط موقع البيانات الجغرافية للامتثال
# - **Backup & Recovery**: إمكانيات النسخ الاحتياطي والاستعادة الآلية والتعافي من الكوارث
#
# ## 📈 تحسين الأداء
#
# ### أنماط المعالجة غير المتزامنة
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### إدارة الذاكرة
# - **Streaming Processing**: معالجة المستندات الكبيرة دون مشاكل في الذاكرة
# - **Resource Pooling**: إعادة استخدام فعالة للموارد المكلفة
# - **Garbage Collection**: أنماط تخصيص ذاكرة مُحسّنة
# - **Connection Management**: دورة حياة اتصال مناسبة لخدمات Azure
#
# ### استراتيجيات التخزين المؤقت
# - **Query Caching**: تخزين مؤقت للبحث الذي يُنفَّذ بشكل متكرر
# - **Document Caching**: تخزين مؤقت في الذاكرة للمستندات الساخنة
# - **Index Caching**: تخزين مؤقت مُحسن لفهرس المتجهات
# - **Result Caching**: تخزين مؤقت ذكي للاستجابات المُولَّدة
#
# ## 📊 حالات استخدام المؤسسة
#
# ### إدارة المعرفة
# - **Corporate Wiki**: بحث ذكي عبر قواعد معرفة الشركة
# - **Policy & Procedures**: إرشاد تلقائي للامتثال والإجراءات
# - **Training Materials**: مساعدة ذكية في التعلم والتطوير
# - **Research Databases**: أنظمة تحليل الأوراق الأكاديمية والبحثية
#
# ### دعم العملاء
# - **Support Knowledge Base**: ردود خدمة عملاء آلية
# - **Product Documentation**: استرجاع ذكي لمعلومات المنتج
# - **Troubleshooting Guides**: مساعدة سياقية لحل المشكلات
# - **FAQ Systems**: توليد ديناميكي للأسئلة الشائعة من مجموعات المستندات
#
# ### الامتثال التنظيمي
# - **Legal Document Analysis**: ذكاء المستندات القانونية والعقود
# - **Compliance Monitoring**: فحص امتثال تنظيمي آلي
# - **Risk Assessment**: تحليل المخاطر وإعداد تقارير مستندة إلى الوثائق
# - **Audit Support**: اكتشاف ذكي للمستندات للمراجعات والتدقيق
#
# ## 🚀 النشر في الإنتاج
#
# ### المراقبة والرصد
# - **Application Insights**: قياس بيانات تفصيلية ومراقبة الأداء
# - **Custom Metrics**: تتبع مؤشرات الأداء الرئيسية الخاصة بالأعمال والتنبيه
# - **Distributed Tracing**: تتبع الطلبات من الطرف إلى الطرف عبر الخدمات
# - **Health Dashboards**: تصوّر صحة النظام والأداء في الوقت الحقيقي
#
# ### قابلية التوسع والموثوقية
# - **Auto-Scaling**: مقياس تلقائي بناءً على الحمل ومقاييس الأداء
# - **High Availability**: نشر متعدد المناطق مع قدرات التحويل عند الفشل
# - **Load Testing**: تحقق من الأداء تحت ظروف حمل مؤسسية
# - **Disaster Recovery**: إجراءات النسخ الاحتياطي والاستعادة الآلية
#
# هل أنت مستعد لبناء أنظمة RAG بمستوى مؤسسي قادرة على التعامل مع المستندات الحساسة على نطاق واسع؟ دعونا نصمم أنظمة معرفة ذكية للمؤسسات! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **إخلاء المسؤولية**:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة الآلية [Co-op Translator](https://github.com/Azure/co-op-translator). بينما نسعى لتحقيق الدقة، يرجى ملاحظة أن الترجمات الآلية قد تحتوي على أخطاء أو معلومات غير دقيقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر الموثوق به. للمعلومات الحرجة، يُنصح بالاستعانة بترجمة بشرية محترفة. نحن غير مسؤولين عن أي سوء فهم أو تفسير خاطئ ينشأ عن استخدام هذه الترجمة.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
