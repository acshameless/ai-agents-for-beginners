# %% [markdown]
# # Урок: ЗАГЛАВИЕ
#
# Аудитория:
# - Опишете за кого е предназначено.
#
# Изисквания:
# - Избройте необходимите концепции или настройки.
#
# Учебни цели:
# - До края, читателят ще може...

# %% [markdown]
# ## План
#
# 1. Настройка
# 2. Минимален работещ пример
# 3. Вариации и подводни камъни
# 4. Упражнения

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Стъпка 1 - Започнете с малък пример
#
# Обяснете с прости думи какво прави следващата клетка.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Упражнения
#
# - Опитайте с друг вход.
# - Предскажете изхода преди да стартирате кода.
# - Отбележете една често срещана грешка и как да я поправите.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Отказ от отговорност:
# Този документ е преведен с помощта на AI преводаческа услуга Co-op Translator (https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля, имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на оригиналния му език трябва да се счита за авторитетен източник. За важна информация се препоръчва професионален превод, извършен от човек. Не носим отговорност за каквито и да е недоразумения или погрешни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
