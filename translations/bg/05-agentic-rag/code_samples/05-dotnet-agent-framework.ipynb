# %% [markdown]
# # 🔍 RAG за предприятия с Microsoft Foundry (.NET)
#
# ## 📋 Цели на обучението
#
# Този записник демонстрира как да се изградят корпоративни системи Retrieval-Augmented Generation (RAG) с Microsoft Agent Framework в .NET и Microsoft Foundry. Ще научите как да създавате готови за продукция агенти, които могат да търсят в документи и да предоставят точни, контекстно-осъзнати отговори с корпоративна защита и мащабируемост.
#
# **Възможности на корпоративния RAG, които ще изградите:**
# - 📚 **Document Intelligence**: Разширена обработка на документи с услугите Azure AI
# - 🔍 **Semantic Search**: Високопроизводително векторно търсене с корпоративни функции
# - 🛡️ **Security Integration**: Ролево базиран достъп и модели за защита на данните
# - 🏢 **Scalable Architecture**: RAG системи, готови за продукция, с наблюдение
#
# ## 🎯 Архитектура на корпоративния RAG
#
# ### Основни корпоративни компоненти
# - **Microsoft Foundry**: Управлявана корпоративна AI платформа със защита и съответствие
# - **Persistent Agents**: Агенти със състояние, с история на разговорите и управление на контекста
# - **Vector Store Management**: Корпоративно индексиране и извличане на документи
# - **Identity Integration**: Azure AD удостоверяване и контрол на достъпа на базата на роли
#
# ### Предимства на .NET за предприятията
# - **Type Safety**: Проверка по време на компилация за RAG операции и структури от данни
# - **Async Performance**: Неблокираща обработка на документи и операции за търсене
# - **Memory Management**: Ефективно използване на ресурсите за големи колекции от документи
# - **Integration Patterns**: Нативна интеграция с услуги на Azure чрез инжектиране на зависимости
#
# ## 🏗️ Техническа архитектура
#
# ### Конвейер на корпоративния RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основни .NET компоненти
# - **Azure.AI.Agents.Persistent**: Управление на корпоративни агенти с постоянство на състоянието
# - **Azure.Identity**: Интегрирано удостоверяване за сигурен достъп до услуги на Azure
# - **Microsoft.Agents.AI.AzureAI**: Реализация на агентна рамка, оптимизирана за Azure
# - **System.Linq.Async**: Високопроизводителни асинхронни LINQ операции
#
# ## 🔧 Корпоративни функции и ползи
#
# ### Сигурност и съответствие
# - **Azure AD Integration**: Управление на корпоративната идентичност и удостоверяване
# - **Role-Based Access**: Фино настроени разрешения за достъп до документи и операции
# - **Data Protection**: Криптиране в покой и при транзит за чувствителни документи
# - **Audit Logging**: Всеобхватно проследяване на дейностите за изискванията за съответствие
#
# ### Производителност и мащабируемост
# - **Connection Pooling**: Ефективно управление на връзките към услуги на Azure
# - **Async Processing**: Неблокиращи операции за сценарии с висок пропуск
# - **Caching Strategies**: Интелигентно кеширане за често използвани документи
# - **Load Balancing**: Разпределена обработка за внедрявания в голям мащаб
#
# ### Управление и наблюдение
# - **Health Checks**: Вградено наблюдение на компонентите на RAG системата
# - **Performance Metrics**: Подробна аналитика за качеството на търсене и времена за отговор
# - **Error Handling**: Всеобхватно управление на изключения с политики за повторен опит
# - **Configuration Management**: Настройки, специфични за средата, с валидиране
#
# ## ⚙️ Предварителни изисквания и настройка
#
# **Среда за разработка:**
# - .NET 9.0 SDK или по-нова версия
# - Visual Studio 2022 или VS Code с разширение C#
# - Абонамент в Azure с достъп до AI Foundry
#
# **Необходими NuGet пакети:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Настройка на удостоверяване в Azure:**
# ```bash
# # Инсталирайте Azure CLI и се удостоверете
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфигурация на средата (файл .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Модели на корпоративния RAG
#
# ### Модели за управление на документи
# - **Bulk Upload**: Ефективна обработка на големи колекции от документи
# - **Incremental Updates**: Добавяне и модифициране на документи в реално време
# - **Version Control**: Версиониране на документи и проследяване на промените
# - **Metadata Management**: Богати атрибути на документите и таксономия
#
# ### Модели за търсене и извличане
# - **Hybrid Search**: Комбиниране на семантично и ключово търсене за оптимални резултати
# - **Faceted Search**: Многоизмерно филтриране и категоризиране
# - **Relevance Tuning**: Персонализирани алгоритми за оценяване за домейн-специфични изисквания
# - **Result Ranking**: Разширено ранжиране с интеграция на бизнес логика
#
# ### Модели за сигурност
# - **Document-Level Security**: Фино настройван контрол на достъпа по документ
# - **Data Classification**: Автоматично маркиране на чувствителността и защита
# - **Audit Trails**: Всеобхватно логване на всички RAG операции
# - **Privacy Protection**: Възможности за откриване и скриване на PII
#
# ## 🔒 Функции за корпоративна сигурност
#
# ### Удостоверяване и авторизация
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Защита на данните
# - **Encryption**: Криптиране от край до край за документи и индекси за търсене
# - **Access Controls**: Интеграция с Azure AD за разрешения на потребители и групи
# - **Data Residency**: Контрол на географското местоположение на данните за съответствие
# - **Backup & Recovery**: Автоматизирани възможности за архивиране и възстановяване при бедствия
#
# ## 📈 Оптимизация на производителността
#
# ### Модели за асинхронна обработка
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управление на паметта
# - **Streaming Processing**: Обработка на големи документи без проблеми с паметта
# - **Resource Pooling**: Ефективно повторно използване на скъпи ресурси
# - **Garbage Collection**: Оптимизирани модели за разпределение на паметта
# - **Connection Management**: Правилен жизнен цикъл на връзките към услуги на Azure
#
# ### Стратегии за кеширане
# - **Query Caching**: Кеширане на често изпълнявани заявки за търсене
# - **Document Caching**: Кеширане в паметта за често използвани документи
# - **Index Caching**: Оптимизирано кеширане на векторни индекси
# - **Result Caching**: Интелигентно кеширане на генерираните отговори
#
# ## 📊 Корпоративни случаи на използване
#
# ### Управление на знанията
# - **Corporate Wiki**: Интелигентно търсене в базите знания на компанията
# - **Policy & Procedures**: Автоматизирано съответствие и насоки за процедури
# - **Training Materials**: Интелигентна помощ за обучение и развитие
# - **Research Databases**: Системи за анализ на академични и научни статии
#
# ### Поддръжка на клиенти
# - **Support Knowledge Base**: Автоматизирани отговори за обслужване на клиенти
# - **Product Documentation**: Интелигентно извличане на информация за продукти
# - **Troubleshooting Guides**: Контекстуална помощ за решаване на проблеми
# - **FAQ Systems**: Динамично генериране на ЧЗВ от колекции от документи
#
# ### Регулаторно съответствие
# - **Legal Document Analysis**: Интелигентност при договори и правни документи
# - **Compliance Monitoring**: Автоматизирана проверка за регулаторно съответствие
# - **Risk Assessment**: Анализ и отчитане на рискове на базата на документи
# - **Audit Support**: Интелигентно откриване на документи за одити
#
# ## 🚀 Внедряване в продукция
#
# ### Мониторинг и наблюдаемост
# - **Application Insights**: Подробна телеметрия и мониторинг на производителността
# - **Custom Metrics**: Проследяване и алармиране на бизнес-специфични KPI
# - **Distributed Tracing**: Край-до-край проследяване на заявки между услуги
# - **Health Dashboards**: Визуализация в реално време за състоянието и производителността на системата
#
# ### Мащабируемост и надеждност
# - **Auto-Scaling**: Автоматично мащабиране базирано на натоварване и метрики за производителност
# - **High Availability**: Внедряване в няколко региона с възможности за превключване при повреда
# - **Load Testing**: Валидация на производителността при корпоративни натоварвания
# - **Disaster Recovery**: Автоматизирани процедури за архивиране и възстановяване
#
# Готови ли сте да изградите корпоративни RAG системи, които могат да обработват чувствителни документи в голям мащаб? Нека проектираме интелигентни системи за управление на знания за предприятията! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Отказ от отговорност:
# Този документ е преведен с помощта на AI преводаческа услуга Co-op Translator (https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, имайте предвид, че автоматичните преводи могат да съдържат грешки или неточности. Оригиналният документ на съответния език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Не носим отговорност за никакви недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
