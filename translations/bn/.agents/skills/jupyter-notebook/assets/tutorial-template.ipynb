# %% [markdown]
# # টিউটোরিয়াল: TITLE
#
# লক্ষ্য শ্রোতা:
# - এটি কার জন্য তা বর্ণনা করুন।
#
# প্রয়োজনীয়তা:
# - প্রয়োজনীয় ধারণা বা সেটআপগুলি তালিকাভুক্ত করুন।
#
# শিখার লক্ষ্য:
# - শেষ পর্যন্ত, পাঠক ... করতে পারবে।

# %% [markdown]
# ## রূপরেখা
#
# 1. সেটআপ
# 2. একটি ন্যূনতম কার্যকর উদাহরণ
# 3. বিভিন্নতা এবং ফাঁদ
# 4. অনুশীলন

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## ধাপ 1 - একটি ছোট উদাহরণ দিয়ে শুরু করুন
#
# পরের সেলটি কী করে তা সহজ ভাষায় ব্যাখ্যা করুন।

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## অনুশীলন
#
# - ভিন্ন ইনপুট চেষ্টা করুন.
# - কোড চালানোর আগে আউটপুট অনুমান করুন.
# - একটি সাধারণ ভুল এবং এটি কীভাবে ঠিক করবেন তা উল্লেখ করুন.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# দায়মুক্তি:
# এই নথিটি AI অনুবাদ পরিষেবা Co‑op Translator (https://github.com/Azure/co-op-translator) ব্যবহার করে অনূদিত হয়েছে। আমরা যথাসাধ্য সঠিকতা নিশ্চিত করার চেষ্টা করি, তবু অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা ভুল থাকতে পারে। মূল নথিটি তার নিজ ভাষায় প্রামাণিক উৎস হিসেবে বিবেচনা করা উচিত। গুরুত্বপূর্ণ তথ্যের জন্য পেশাদার মানব অনুবাদ গ্রহণ করা উচিৎ। এই অনুবাদ ব্যবহারের ফলে যে কোনো ভুল বোঝাবুঝি বা ভুল ব্যাখ্যার জন্য আমরা দায়ী নই।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
