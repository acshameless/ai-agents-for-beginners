# %% [markdown]
# # 🔍 Enterprise RAG with Microsoft Foundry (.NET)
#
# ## 📋 শেখার উদ্দেশ্য
#
# এই নোটবুকটি দেখায় কিভাবে Microsoft Foundry ব্যবহার করে .NET-এ Microsoft Agent Framework দিয়ে এন্টারপ্রাইজ-গ্রেড Retrieval-Augmented Generation (RAG) সিস্টেম নির্মাণ করতে হয়। আপনি শিখবেন কীভাবে প্রোডাকশন-রেডি এজেন্ট তৈরি করতে হয় যা ডকুমেন্টগুলোর মধ্যে সার্চ করতে পারে এবং এন্টারপ্রাইজ সিকিউরিটি ও স্কেলেবিলিটির সঙ্গে নির্ভুল, প্রসঙ্গ-জ্ঞানসম্পন্ন উত্তর প্রদান করে।
#
# **আপনি যে এন্টারপ্রাইজ RAG ক্ষমতাসমূহ নির্মাণ করবেন:**
# - 📚 **Document Intelligence**: Azure AI সার্ভিসসমূহের সাথে উন্নত ডকুমেন্ট প্রসেসিং
# - 🔍 **Semantic Search**: এন্টারপ্রাইজ বৈশিষ্ট্যসহ উচ্চ-দক্ষতা ভেক্টর সার্চ
# - 🛡️ **Security Integration**: রোল-ভিত্তিক এক্সেস এবং ডেটা সুরক্ষা প্যাটার্ন
# - 🏢 **Scalable Architecture**: মনিটরিংসহ প্রোডাকশন-রেডি RAG সিস্টেম
#
# ## 🎯 এন্টারপ্রাইজ RAG আর্কিটেকচার
#
# ### মূল এন্টারপ্রাইজ উপাদান
# - **Microsoft Foundry**: নিরাপত্তা ও কমপ্লায়েন্সসহ ম্যানেজড এন্টারপ্রাইজ AI প্ল্যাটফর্ম
# - **Persistent Agents**: সংলাপ ইতিহাস এবং প্রসঙ্গ ব্যবস্থাপনাসহ স্টেটফুল এজেন্ট
# - **Vector Store Management**: এন্টারপ্রাইজ-গ্রেড ডকুমেন্ট ইনডেক্সিং ও রিট্রিভাল
# - **Identity Integration**: Azure AD authentication এবং রোল-ভিত্তিক অ্যাকসেস কনট্রোল
#
# ### .NET এন্টারপ্রাইজ সুবিধাসমূহ
# - **Type Safety**: RAG অপারেশন ও ডাটা স্ট্রাকচারের জন্য কম্পাইল-টাইম যাচাইকরণ
# - **Async Performance**: নন-ব্লকিং ডকুমেন্ট প্রসেসিং এবং সার্চ অপারেশন
# - **Memory Management**: বড় ডকুমেন্ট কালেকশনের জন্য দক্ষ রিসোর্স ব্যবহার
# - **Integration Patterns**: ডিপেন্ডেন্সি ইনজেকশনসহ নেটিভ Azure সার্ভিস ইন্টিগ্রেশন প্যাটার্ন
#
# ## 🏗️ টেকনিক্যাল আর্কিটেকচার
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Core .NET Components
# - **Azure.AI.Agents.Persistent**: স্টেট পারসিস্টেন্সসহ এন্টারপ্রাইজ এজেন্ট ম্যানেজমেন্ট
# - **Azure.Identity**: নিরাপদ Azure সার্ভিস অ্যাক্সেসের জন্য ইন্টিগ্রেটেড অথেনটিকেশন
# - **Microsoft.Agents.AI.AzureAI**: Azure-অপ্টিমাইজড এজেন্ট ফ্রেমওয়ার্ক ইমপ্লিমেন্টেশন
# - **System.Linq.Async**: উচ্চ-দক্ষতা অ্যাসিঙ্ক্রোনাস LINQ অপারেশন
#
# ## 🔧 এন্টারপ্রাইজ ফিচার ও সুবিধাসমূহ
#
# ### নিরাপত্তা ও কমপ্লায়েন্স
# - **Azure AD Integration**: এন্টারপ্রাইজ আইডেন্টিটি ম্যানেজমেন্ট এবং অথেনটিকেশন
# - **Role-Based Access**: ডকুমেন্ট অ্যাক্সেস এবং অপারেশনের জন্য সূক্ষ্ম অনুমতি
# - **Data Protection**: সংবেদনশীল ডকুমেন্টগুলোর জন্য রেস্ট ও ট্রানজিট-এ এনক্রিপশন
# - **Audit Logging**: কমপ্লায়েন্স প্রয়োজনীয়তার জন্য বিস্তৃত কার্যকলাপ ট্র্যাকিং
#
# ### পারফরম্যান্স ও স্কেলেবিলিটি
# - **Connection Pooling**: দক্ষ Azure সার্ভিস সংযোগ ম্যানেজমেন্ট
# - **Async Processing**: উচ্চ-থ্রুপুট পরিস্থিতির জন্য নন-ব্লকিং অপারেশন
# - **Caching Strategies**: বারবার অ্যাক্সেস করা ডকুমেন্টগুলোর জন্য বুদ্ধিমান ক্যাশিং
# - **Load Balancing**: বড়-স্কেলের ডিপ্লয়মেন্টের জন্য ডিস্ট্রিবিউটেড প্রসেসিং
#
# ### ম্যানেজমেন্ট ও মনিটরিং
# - **Health Checks**: RAG সিস্টেম উপাদানগুলোর জন্য বিল্ট-ইন মনিটরিং
# - **Performance Metrics**: সার্চ কোয়ালিটি এবং রেসপন্স টাইমের বিস্তৃত অ্যানালিটিক্স
# - **Error Handling**: রিট্রাই পলিসিসহ বিস্তৃত এক্সসেপশন ম্যানেজমেন্ট
# - **Configuration Management**: ভ্যালিডেশনের সঙ্গে পরিবেশ-নির্দিষ্ট সেটিংস
#
# ## ⚙️ প্রয়োজনীয়তা ও সেটআপ
#
# **Development Environment:**
# - .NET 9.0 SDK or higher
# - Visual Studio 2022 or VS Code with C# extension
# - Azure subscription with AI Foundry access
#
# **Required NuGet Packages:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure Authentication Setup:**
# ```bash
# # Azure CLI ইনস্টল করুন এবং প্রমাণীকরণ করুন
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Environment Configuration (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 এন্টারপ্রাইজ RAG প্যাটার্নস
#
# ### Document Management Patterns
# - **Bulk Upload**: বড় ডকুমেন্ট কালেকশনের কার্যকর প্রসেসিং
# - **Incremental Updates**: রিয়েল-টাইম ডকুমেন্ট যোগ ও পরিবর্তন
# - **Version Control**: ডকুমেন্ট ভার্সনিং এবং পরিবর্তন ট্র্যাকিং
# - **Metadata Management**: সমৃদ্ধ ডকুমেন্ট অ্যাট্রিবিউট ও ট্যাক্সোনমি
#
# ### Search & Retrieval Patterns
# - **Hybrid Search**: সর্বোত্তম ফলাফলের জন্য সেম্যান্টিক ও কিওয়ার্ড সার্চের সমন্বয়
# - **Faceted Search**: বহুমাত্রিক ফিল্টারিং ও শ্রেণীবিভাগ
# - **Relevance Tuning**: ডোমেইন-নির্দিষ্ট দরকার অনুযায়ী কাস্টম স্কোরিং অ্যালগরিদম
# - **Result Ranking**: ব্যবসায়িক লজিক ইন্টিগ্রেশনের সঙ্গে উন্নত র‍্যাঙ্কিং
#
# ### Security Patterns
# - **Document-Level Security**: প্রতিটি ডকুমেন্টের জন্য সূক্ষ্ম-গ্র্যানুলার অ্যাক্সেস কন্ট্রোল
# - **Data Classification**: স্বয়ংক্রিয় সেন্সিটিভিটি লেবেলিং ও প্রোটেকশন
# - **Audit Trails**: সমস্ত RAG অপারেশনের বিস্তৃত লগিং
# - **Privacy Protection**: PII সনাক্তকরণ ও রেডাকশন সক্ষমতা
#
# ## 🔒 এন্টারপ্রাইজ নিরাপত্তা বৈশিষ্ট্য
#
# ### Authentication & Authorization
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Data Protection
# - **Encryption**: ডকুমেন্ট এবং সার্চ ইনডেক্সগুলোর জন্য এন্ড-টু-এন্ড এনক্রিপশন
# - **Access Controls**: ইউজার এবং গ্রুপ পারমিশনের জন্য Azure AD ইন্টিগ্রেশন
# - **Data Residency**: কমপ্লায়েন্সের জন্য ভৌগোলিক ডেটা অবস্থান নিয়ন্ত্রণ
# - **Backup & Recovery**: অটোমেটেড ব্যাকআপ এবং ডিজাস্টার রিকভারি সক্ষমতা
#
# ## 📈 পারফরম্যান্স অপ্টিমাইজেশন
#
# ### Async Processing Patterns
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Memory Management
# - **Streaming Processing**: বড় ডকুমেন্টগুলি মেমোরি সমস্যা ছাড়াই হ্যান্ডল করা
# - **Resource Pooling**: ব্যয়বহুল রিসোর্সগুলোর কার্যকর পুনরায় ব্যবহার
# - **Garbage Collection**: অপ্টিমাইজড মেমোরি অ্যলোকেশন প্যাটার্ন
# - **Connection Management**: Proper Azure সার্ভিস সংযোগ লাইফসাইকেল
#
# ### Caching Strategies
# - **Query Caching**: ঘনঘন নির্বাহিত সার্চগুলোর ক্যাশিং
# - **Document Caching**: হট ডকুমেন্টগুলোর জন্য ইন-মেমরি ক্যাশিং
# - **Index Caching**: অপ্টিমাইজড ভেক্টর ইনডেক্স ক্যাশিং
# - **Result Caching**: জেনারেট করা রেসপন্সগুলোর বুদ্ধিমান ক্যাশিং
#
# ## 📊 এন্টারপ্রাইজ ব্যবহার কেসসমূহ
#
# ### Knowledge Management
# - **Corporate Wiki**: কোম্পানির নলেজ বেস জুড়ে ইন্টেলিজেন্ট সার্চ
# - **Policy & Procedures**: স্বয়ংক্রিয় কমপ্লায়েন্স এবং পদ্ধতি নির্দেশনা
# - **Training Materials**: ইন্টেলিজেন্ট শিক্ষণ ও ডেভেলপমেন্ট সহায়তা
# - **Research Databases**: একাডেমিক এবং গবেষণা পেপার বিশ্লেষণ সিস্টেম
#
# ### Customer Support
# - **Support Knowledge Base**: স্বয়ংক্রিয় কাস্টমার সার্ভিস রেসপন্স
# - **Product Documentation**: ইন্টেলিজেন্ট প্রোডাক্ট ইনফরমেশন রিট্রিভাল
# - **Troubleshooting Guides**: প্রসঙ্গভিত্তিক সমস্যা সমাধানের সহায়তা
# - **FAQ Systems**: ডকুমেন্ট কালেকশনের থেকে ডাইনামিক FAQ জেনারেশন
#
# ### Regulatory Compliance
# - **Legal Document Analysis**: কন্ট্রাক্ট ও আইনি ডকুমেন্ট ইন্টেলিজেন্স
# - **Compliance Monitoring**: স্বয়ংক্রিয় নিয়ন্ত্রক কমপ্লায়েন্স চেকিং
# - **Risk Assessment**: ডকুমেন্ট-ভিত্তিক ঝুঁকি বিশ্লেষণ ও রিপোর্টিং
# - **Audit Support**: অডিটের জন্য ইন্টেলিজেন্ট ডকুমেন্ট ডিসকভারি
#
# ## 🚀 প্রোডাকশন ডিপ্লয়মেন্ট
#
# ### Monitoring & Observability
# - **Application Insights**: বিশদ টেলিমেট্রি এবং পারফরম্যান্স মনিটরিং
# - **Custom Metrics**: ব্যবসা-নির্দিষ্ট KPI ট্র্যাকিং এবং অ্যালার্টিং
# - **Distributed Tracing**: সার্ভিসগুলোর মধ্যে এন্ড-টু-এন্ড রিকোয়েস্ট ট্রেকিং
# - **Health Dashboards**: রিয়েল-টাইম সিস্টেম হেলথ এবং পারফরম্যান্স ভিজ্যুয়ালাইজেশন
#
# ### Scalability & Reliability
# - **Auto-Scaling**: লোড এবং পারফরম্যান্স মেট্রিক্সের ওপর ভিত্তি করে অটোম্যাটিক স্কেলিং
# - **High Availability**: ফেইলোভার ক্ষমতাসহ মাল্টি-রিজিয়ন ডিপ্লয়মেন্ট
# - **Load Testing**: এন্টারপ্রাইজ লোড কন্ডিশনের নিচে পারফরম্যান্স ভ্যালিডেশন
# - **Disaster Recovery**: অটোমেটেড ব্যাকআপ এবং রিকভারি প্রোসেস
#
# এনক্রিপশন-সমর্থিত, স্কেলেবল এবং সংবেদনশীল ডকুমেন্ট হ্যান্ডেল করতে সক্ষম এন্টারপ্রাইজ-গ্রেড RAG সিস্টেম তৈরি করতে প্রস্তুত? চলুন এন্টারপ্রাইজের জন্য ইন্টেলিজেন্ট নলেজ সিস্টেম আর্কিটেক্ট করি! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# দায়-অস্বীকৃতি:
# এই দলিলটি AI অনুবাদ সেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনূদিত। আমরা যথাসাধ্য সঠিকতার চেষ্টা করি, তবু স্বয়ংক্রিয় অনুবাদে ভুল বা অসামঞ্জস্য থাকতে পারে। মূল দলিলটি তার মূল ভাষায়ই প্রামাণিক উৎস হিসেবে বিবেচনা করা উচিত। গুরুত্বপূর্ণ তথ্যের জন্য পেশাদার মানব অনুবাদের পরামর্শ দেওয়া হয়। এই অনুবাদ ব্যবহারের ফলে উদ্ভূত কোনো ভুল বোঝাবুঝি বা ভ্রান্ত ব্যাখ্যার জন্য আমরা দায়ী নই।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
