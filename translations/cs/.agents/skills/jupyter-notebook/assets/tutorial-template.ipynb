# %% [markdown]
# # Návod: NÁZEV
#
# Cílová skupina:
# - Popište, pro koho to je.
#
# Předpoklady:
# - Uveďte požadované koncepty nebo nastavení.
#
# Výukové cíle:
# - Na konci bude čtenář schopen...

# %% [markdown]
# ## Osnova
#
# 1. Nastavení
# 2. Minimální funkční příklad
# 3. Variace a úskalí
# 4. Cvičení

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Krok 1 - Začněte s malým příkladem
#
# Vysvětlete, co dělá následující buňka srozumitelně.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Cvičení
#
# - Vyzkoušejte jiný vstup.
# - Před spuštěním kódu předpovězte výstup.
# - Uveďte jednu častou chybu a jak ji opravit.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Prohlášení o vyloučení odpovědnosti**:
# Tento dokument byl přeložen pomocí AI překladatelské služby [Co-op Translator](https://github.com/Azure/co-op-translator). Přestože se snažíme o přesnost, mějte prosím na paměti, že automatické překlady mohou obsahovat chyby nebo nepřesnosti. Původní dokument v jeho originálním jazyce by měl být považován za závazný zdroj. Pro důležité informace doporučujeme profesionální lidský překlad. Nejsme odpovědní za žádná nedorozumění nebo chybné výklady, které mohou vzniknout v důsledku použití tohoto překladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
