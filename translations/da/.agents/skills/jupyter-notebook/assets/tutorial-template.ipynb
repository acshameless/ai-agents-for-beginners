# %% [markdown]
# # Vejledning: TITEL
#
# Målgruppe:
# - Beskriv hvem dette er til.
#
# Forudsætninger:
# - Angiv nødvendige koncepter eller opsætning.
#
# Læringsmål:
# - Når vejledningen er færdig, kan læseren...

# %% [markdown]
# ## Oversigt
#
# 1. Opsætning
# 2. Et minimalt fungerende eksempel
# 3. Variationer og faldgruber
# 4. Øvelser

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Step 1 - Start with a tiny example
#
# Forklar, hvad den næste celle gør i almindeligt sprog.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Øvelser
#
# - Prøv en anden indtastning.
# - Forudsig outputtet, før du kører koden.
# - Bemærk en almindelig fejl og hvordan du retter den.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Ansvarsfraskrivelse:
# Dette dokument er blevet oversat ved hjælp af AI-oversættelsestjenesten [Co-op Translator](https://github.com/Azure/co-op-translator). Selvom vi bestræber os på nøjagtighed, skal du være opmærksom på, at automatiske oversættelser kan indeholde fejl eller unøjagtigheder. Det oprindelige dokument på originalsproget bør betragtes som den autoritative kilde. For kritisk information anbefales en professionel, menneskelig oversættelse. Vi påtager os intet ansvar for eventuelle misforståelser eller fejltolkninger, der måtte opstå som følge af brugen af denne oversættelse.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
