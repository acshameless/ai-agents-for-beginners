# %% [markdown]
# # Tutorial: TITLE
#
# Zielgruppe:
# - Beschreibe, für wen das gedacht ist.
#
# Voraussetzungen:
# - Liste die erforderlichen Konzepte oder die notwendige Einrichtung auf.
#
# Lernziele:
# - Am Ende kann der Leser...

# %% [markdown]
# ## Gliederung
#
# 1. Einrichtung
# 2. Ein minimales funktionierendes Beispiel
# 3. Varianten und Fallstricke
# 4. Übungen

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Schritt 1 - Beginnen Sie mit einem kleinen Beispiel
#
# Erklären Sie in einfacher Sprache, was die nächste Zelle tut.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Übungen
#
# - Probiere eine andere Eingabe.
# - Schätze die Ausgabe, bevor du den Code ausführst.
# - Notiere einen häufigen Fehler und wie man ihn behebt.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Haftungsausschluss:
# Dieses Dokument wurde mit dem KI-Übersetzungsdienst [Co-op Translator](https://github.com/Azure/co-op-translator) übersetzt. Obwohl wir uns um Genauigkeit bemühen, beachten Sie bitte, dass automatisierte Übersetzungen Fehler oder Ungenauigkeiten enthalten können. Das Originaldokument in seiner Ausgangssprache ist als maßgebliche Quelle zu betrachten. Für kritische Informationen wird eine professionelle menschliche Übersetzung empfohlen. Für Missverständnisse oder Fehlinterpretationen, die sich aus der Nutzung dieser Übersetzung ergeben, übernehmen wir keine Haftung.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
