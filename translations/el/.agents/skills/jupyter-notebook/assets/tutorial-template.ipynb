# %% [markdown]
# # Οδηγός: ΤΙΤΛΟΣ
#
# Κοινό:
# - Περιγράψτε για ποιον προορίζεται.
#
# Προαπαιτούμενα:
# - Καταγράψτε απαραίτητες έννοιες ή ρυθμίσεις.
#
# Στόχοι μάθησης:
# - Στο τέλος, ο αναγνώστης θα μπορεί...

# %% [markdown]
# ## Περίγραμμα
#
# 1. Ρύθμιση
# 2. Ένα ελάχιστο λειτουργικό παράδειγμα
# 3. Παραλλαγές και παγίδες
# 4. Ασκήσεις

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Βήμα 1 - Ξεκινήστε με ένα μικρό παράδειγμα
#
# Εξηγήστε με απλά λόγια τι κάνει το επόμενο κελί.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Ασκήσεις
#
# - Δοκιμάστε διαφορετική είσοδο.
# - Προβλέψτε την έξοδο πριν τρέξετε τον κώδικα.
# - Σημειώστε ένα συνηθισμένο λάθος και πώς να το διορθώσετε.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Αποποίηση ευθύνης:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία αυτόματης μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Παρόλο που καταβάλλουμε προσπάθειες για ακρίβεια, παρακαλούμε να λάβετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν σφάλματα ή ανακρίβειες. Το αρχικό έγγραφο στην πρωτότυπη γλώσσα του πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική μετάφραση από ανθρώπινο μεταφραστή. Δεν φέρουμε ευθύνη για οποιεσδήποτε παρανοήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
