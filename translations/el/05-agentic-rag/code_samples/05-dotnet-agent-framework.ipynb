# %% [markdown]
# # 🔍 RAG Επιχειρήσεων με Microsoft Foundry (.NET)
#
# ## 📋 Στόχοι Μάθησης
#
# Αυτό το σημειωματάριο δείχνει πώς να δημιουργήσετε συστήματα Retrieval-Augmented Generation (RAG) επιπέδου επιχείρησης χρησιμοποιώντας το Microsoft Agent Framework σε .NET με Microsoft Foundry. Θα μάθετε να δημιουργείτε πράκτορες έτοιμους για παραγωγή που μπορούν να αναζητούν μέσα σε έγγραφα και να παρέχουν ακριβείς, συμφραζόμενες απαντήσεις με ασφάλεια και κλιμακωσιμότητα επιπέδου επιχείρησης.
#
# **Ικανότητες RAG Επιχείρησης που θα Χτίσετε:**
# - 📚 **Νοημοσύνη Εγγράφων**: Προηγμένη επεξεργασία εγγράφων με υπηρεσίες Azure AI
# - 🔍 **Σηματική Αναζήτηση**: Υψηλής απόδοσης αναζήτηση σε διανυσματικό χώρο με επιχειρησιακά χαρακτηριστικά
# - 🛡️ **Ενσωμάτωση Ασφαλείας**: Πρότυπα έλεγχου ρόλων και προστασίας δεδομένων
# - 🏢 **Κλιμακώσιμη Αρχιτεκτονική**: Συστήματα RAG έτοιμα για παραγωγή με παρακολούθηση
#
# ## 🎯 Αρχιτεκτονική RAG Επιχειρήσεων
#
# ### Κύρια Επιχειρησιακά Συστατικά
# - **Microsoft Foundry**: Διαχειριζόμενη επιχειρησιακή πλατφόρμα AI με ασφάλεια και συμμόρφωση
# - **Persistent Agents**: Επίμονοι πράκτορες με ιστορικό συνομιλίας και διαχείριση συμφραζομένων
# - **Vector Store Management**: Επιχειρησιακή ευρετηρίαση και ανάκτηση εγγράφων
# - **Identity Integration**: Πιστοποίηση Azure AD και έλεγχος πρόσβασης με βάση ρόλους
#
# ### .NET Οφέλη για Επιχειρήσεις
# - **Ασφάλεια Τύπων**: Έλεγχος χρόνου μεταγλώττισης για λειτουργίες RAG και δομές δεδομένων
# - **Ασύγχρονη Απόδοση**: Μη αποκλειστική επεξεργασία εγγράφων και λειτουργίες αναζήτησης
# - **Διαχείριση Μνήμης**: Αποδοτική χρήση πόρων για μεγάλες συλλογές εγγράφων
# - **Πρότυπα Ενσωμάτωσης**: Φυσική ενσωμάτωση υπηρεσιών Azure με dependency injection
#
# ## 🏗️ Τεχνική Αρχιτεκτονική
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Κύρια Συστατικά .NET
# - **Azure.AI.Agents.Persistent**: Διαχείριση επιχειρησιακών πρακτόρων με διατήρηση κατάστασης
# - **Azure.Identity**: Ενσωματωμένη πιστοποίηση για ασφαλή πρόσβαση σε υπηρεσίες Azure
# - **Microsoft.Agents.AI.AzureAI**: Υλοποίηση πλαισίου πρακτόρων βελτιστοποιημένη για Azure
# - **System.Linq.Async**: Υψηλής απόδοσης ασύγχρονες λειτουργίες LINQ
#
# ## 🔧 Χαρακτηριστικά & Οφέλη Επιχειρήσεων
#
# ### Ασφάλεια & Συμμόρφωση
# - **Azure AD Integration**: Επιχειρησιακή διαχείριση ταυτότητας και πιστοποίηση
# - **Role-Based Access**: Λεπτομερής δικαιώματα για πρόσβαση εγγράφων και λειτουργίες
# - **Data Protection**: Κρυπτογράφηση κατά την αποθήκευση και κατά τη μεταφορά για ευαίσθητα έγγραφα
# - **Audit Logging**: Εκτενής καταγραφή δραστηριοτήτων για απαιτήσεις συμμόρφωσης
#
# ### Απόδοση & Κλιμακωσιμότητα
# - **Connection Pooling**: Αποδοτική διαχείριση συνδέσεων υπηρεσιών Azure
# - **Async Processing**: Μη αποκλειστικές λειτουργίες για σενάρια υψηλής διαμέσου
# - **Caching Strategies**: Έξυπνη προσωρινή αποθήκευση για συχνά προσπελάσιμα έγγραφα
# - **Load Balancing**: Κατανεμημένη επεξεργασία για μεγάλης κλίμακας αναπτύξεις
#
# ### Διαχείριση & Παρακολούθηση
# - **Health Checks**: Ένθετη παρακολούθηση για συνιστώσες του συστήματος RAG
# - **Performance Metrics**: Λεπτομερείς αναλύσεις για ποιότητα αναζήτησης και χρόνους απόκρισης
# - **Error Handling**: Ολοκληρωμένη διαχείριση εξαιρέσεων με πολιτικές επανάληψης
# - **Configuration Management**: Ρυθμίσεις ανά περιβάλλον με επικύρωση
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# **Περιβάλλον Ανάπτυξης:**
# - .NET 9.0 SDK ή νεότερο
# - Visual Studio 2022 ή VS Code με επέκταση C#
# - Συνδρομή Azure με πρόσβαση στο AI Foundry
#
# **Απαιτούμενα Πακέτα NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Ρύθμιση Πιστοποίησης Azure:**
# ```bash
# # Εγκαταστήστε το Azure CLI και συνδεθείτε
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Διαμόρφωση Περιβάλλοντος (αρχείο .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Μοντέλα RAG Επιχειρήσεων
#
# ### Πρότυπα Διαχείρισης Εγγράφων
# - **Bulk Upload**: Αποδοτική επεξεργασία μεγάλων συλλογών εγγράφων
# - **Incremental Updates**: Αυξητικές ενημερώσεις και πραγματικός χρόνος προσθήκης εγγράφων
# - **Version Control**: Έκδοση εγγράφων και παρακολούθηση αλλαγών
# - **Metadata Management**: Πλούσια χαρακτηριστικά εγγράφων και ταξονομία
#
# ### Πρότυπα Αναζήτησης & Ανάκτησης
# - **Hybrid Search**: Συνδυασμός σηματικής και λέξεων-κλειδιών για βέλτιστα αποτελέσματα
# - **Faceted Search**: Πολυδιάστατος φιλτραρισμός και κατηγοριοποίηση
# - **Relevance Tuning**: Εξατομικευμένοι αλγόριθμοι βαθμολόγησης για ανάγκες συγκεκριμένου τομέα
# - **Result Ranking**: Προηγμένη κατάταξη με ενσωμάτωση επιχειρηματικής λογικής
#
# ### Πρότυπα Ασφάλειας
# - **Document-Level Security**: Λεπτομερής έλεγχος πρόσβασης ανά έγγραφο
# - **Data Classification**: Αυτόματη επισήμανση ευαισθησίας και προστασία
# - **Audit Trails**: Εκτενής καταγραφή όλων των λειτουργιών RAG
# - **Privacy Protection**: Ανίχνευση PII και δυνατότητες απόκρυψης
#
# ## 🔒 Χαρακτηριστικά Ασφάλειας Επιχειρήσεων
#
# ### Authentication & Authorization
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Προστασία Δεδομένων
# - **Encryption**: Ολοκληρωμένη κρυπτογράφηση για έγγραφα και ευρετήρια αναζήτησης
# - **Access Controls**: Ενσωμάτωση με Azure AD για δικαιώματα χρηστών και ομάδων
# - **Data Residency**: Έλεγχοι γεωγραφικής τοποθεσίας δεδομένων για συμμόρφωση
# - **Backup & Recovery**: Αυτόματη δημιουργία αντιγράφων ασφαλείας και δυνατότητες ανάκτησης καταστροφών
#
# ## 📈 Βελτιστοποίηση Απόδοσης
#
# ### Async Processing Patterns
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Διαχείριση Μνήμης
# - **Streaming Processing**: Διαχείριση μεγάλων εγγράφων χωρίς προβλήματα μνήμης
# - **Resource Pooling**: Αποδοτική επαναχρησιμοποίηση ακριβών πόρων
# - **Garbage Collection**: Βελτιστοποιημένα πρότυπα κατανομής μνήμης
# - **Connection Management**: Ορθή διαχείριση κύκλου ζωής συνδέσεων υπηρεσιών Azure
#
# ### Στρατηγικές Κρυφής Μνήμης
# - **Query Caching**: Cache για συχνά εκτελούμενες αναζητήσεις
# - **Document Caching**: Ενδομνημονική προσωρινή αποθήκευση για "hot" έγγραφα
# - **Index Caching**: Βελτιστοποιημένη προσωρινή αποθήκευση ευρετηρίων διανυσμάτων
# - **Result Caching**: Έξυπνη προσωρινή αποθήκευση παραγόμενων απαντήσεων
#
# ## 📊 Επιχειρησιακές Περιπτώσεις Χρήσης
#
# ### Διαχείριση Γνώσης
# - **Corporate Wiki**: Νοητική αναζήτηση σε εταιρικές βάσεις γνώσης
# - **Policy & Procedures**: Αυτοματοποιημένη καθοδήγηση συμμόρφωσης και διαδικασιών
# - **Training Materials**: Νοητική υποστήριξη μάθησης και ανάπτυξης
# - **Research Databases**: Συστήματα ανάλυσης ακαδημαϊκών και ερευνητικών εργασιών
#
# ### Υποστήριξη Πελατών
# - **Support Knowledge Base**: Αυτοματοποιημένες απαντήσεις εξυπηρέτησης πελατών
# - **Product Documentation**: Νοητική ανάκτηση πληροφοριών προϊόντος
# - **Troubleshooting Guides**: Συμφραζόμενη βοήθεια στην επίλυση προβλημάτων
# - **FAQ Systems**: Δυναμική δημιουργία FAQ από συλλογές εγγράφων
#
# ### Κανονιστική Συμμόρφωση
# - **Legal Document Analysis**: Νοημοσύνη σε συμβάσεις και νομικά έγγραφα
# - **Compliance Monitoring**: Αυτοματοποιημένος έλεγχος κανονιστικής συμμόρφωσης
# - **Risk Assessment**: Ανάλυση κινδύνου βάσει εγγράφων και αναφορές
# - **Audit Support**: Νοητική αναζήτηση εγγράφων για ελέγχους
#
# ## 🚀 Παραγωγική Ανάπτυξη
#
# ### Παρακολούθηση & Παρατηρησιμότητα
# - **Application Insights**: Λεπτομερής τηλεμετρία και παρακολούθηση απόδοσης
# - **Custom Metrics**: Παρακολούθηση KPI επιχειρηματικού χαρακτήρα και ειδοποιήσεις
# - **Distributed Tracing**: End-to-end παρακολούθηση αιτημάτων μεταξύ υπηρεσιών
# - **Health Dashboards**: Οπτικοποίηση σε πραγματικό χρόνο της υγείας και απόδοσης του συστήματος
#
# ### Κλιμακωσιμότητα & Αξιοπιστία
# - **Auto-Scaling**: Αυτόματη κλιμάκωση βάσει φόρτου και μετρικών απόδοσης
# - **High Availability**: Ανάπτυξη σε πολλαπλές περιοχές με δυνατότητες failover
# - **Load Testing**: Επαλήθευση απόδοσης υπό συνθήκες φόρτου επιχείρησης
# - **Disaster Recovery**: Αυτόματες διαδικασίες αντιγράφων ασφαλείας και ανάκτησης
#
# Είστε έτοιμοι να δημιουργήσετε συστήματα RAG επιπέδου επιχείρησης που μπορούν να χειριστούν ευαίσθητα έγγραφα σε κλίμακα; Ας αρχιτεκτονήσουμε έξυπνα συστήματα γνώσης για την επιχείρηση! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Αποποίηση ευθυνών:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να λάβετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν σφάλματα ή ανακρίβειες. Το πρωτότυπο έγγραφο στην αρχική του γλώσσα πρέπει να θεωρείται η επίσημη πηγή. Για κρίσιμες πληροφορίες συνιστάται επαγγελματική μετάφραση από ανθρώπινο μεταφραστή. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
