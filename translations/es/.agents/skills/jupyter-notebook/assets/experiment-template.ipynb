# %% [markdown]
# # Experimento: TITLE
#
# Objetivo:
# - Indica la pregunta que quieres responder.
# - Define los criterios de éxito.

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## Plan
#
# - Hipótesis:
# - Variables a explorar:
# - Métricas a registrar:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## Resultados
#
# - Observaciones clave:
# - Sorpresas o modos de falla:
# - Decisión: continuar, pivotar o detener:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## Próximos pasos
#
# - Qué probar a continuación:
# - Qué documentar en otro lugar (PRD, notas, incidencia):

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Descargo de responsabilidad:
# Este documento ha sido traducido mediante el servicio de traducción por IA [Co-op Translator](https://github.com/Azure/co-op-translator). Aunque nos esforzamos por la exactitud, tenga en cuenta que las traducciones automáticas pueden contener errores o inexactitudes. El documento original en su idioma original debe considerarse la fuente autorizada. Para información crítica, se recomienda una traducción profesional realizada por un traductor humano. No nos hacemos responsables de cualquier malentendido o interpretación errónea que pueda derivarse del uso de esta traducción.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
