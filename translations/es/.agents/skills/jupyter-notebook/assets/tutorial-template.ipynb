# %% [markdown]
# # Tutorial: TITLE
#
# Audiencia:
# - Describe a quién va dirigido.
#
# Requisitos previos:
# - Enumera los conceptos o la configuración requeridos.
#
# Objetivos de aprendizaje:
# - Al final, el lector podrá...

# %% [markdown]
# ## Esquema
#
# 1. Configuración
# 2. Un ejemplo mínimo y funcional
# 3. Variaciones y errores comunes
# 4. Ejercicios

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Paso 1 - Comienza con un pequeño ejemplo
#
# Explica en lenguaje sencillo qué hace la siguiente celda.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Ejercicios
#
# - Prueba una entrada diferente.
# - Predice la salida antes de ejecutar el código.
# - Anota un error común y cómo corregirlo.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Aviso legal:
# Este documento ha sido traducido utilizando el servicio de traducción automática [Co-op Translator](https://github.com/Azure/co-op-translator). Si bien nos esforzamos por la precisión, tenga en cuenta que las traducciones automatizadas pueden contener errores o inexactitudes. El documento original en su idioma nativo debe considerarse la fuente autorizada. Para información crítica, se recomienda una traducción profesional realizada por un traductor humano. No nos hacemos responsables de malentendidos o interpretaciones erróneas que puedan derivarse del uso de esta traducción.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
