# %% [markdown]
# ## **Näited: Mitme tehisintellekti agendid hotelli broneerimiseks**
#
# Tänapäeva kiires maailmas hõlmab ärireisi planeerimine rohkem kui vaid lennupileti ja hotellitoa broneerimist. See nõuab koordineerimist ja tõhusust, mida võib olla keeruline saavutada. Siin tulevad mängu mitme tehisintellekti agendid, kes muudavad selle, kuidas me haldame oma reisinõudeid.
#
# Kujutage ette, et teil on käepärast meeskond intelligentseid agente, kes töötavad koos, et teie reisi iga aspekti täpselt ja lihtsalt korraldada. Meie arenenud tehisintellekti tehnoloogial baseerudes oleme loonud spetsialiseeritud agente broneerimisteenuste ja reisiplaani koostamiseks, tagamaks sujuva ja stressivaba reisikogemuse.
#
# See on lihtne stsenaarium. Ärireisi planeerimisel tuleb konsulteerida ärireiside agendiga, et saada lennupiletite infot, hotelli infot jne. AI agentide kaudu saame luua broneerimisteenuste agente ja reisiplaani koostamise agente, kes teevad koostööd ja parandavad intellekti taset.

# %% [markdown]
# # Initializeeri Azure AI Agendi teenus ja saa konfiguratsiooniteave **.env** failist
#
# ### **.env**
#
# Loo .env fail
#
# **.env** sisaldab Azure AI Agendi teenuse ühendusstringi, AOAI poolt kasutatavat mudelit ning vastavat Google API Search teenuse API-d, ENDPOINT-i jne.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Sinu Azure AI Agendi teenuse mudeli kasutuselevõtu nimi"
#
# [**NOTE**] Sul on vaja mudelit, millel on 100 000 määramislimiit (sõnnakesi minutis) ja 600 määramislimiit (päringut minutis).
#
#   Mudelit saad Microsoft Foundry - Model and Endpoint alt.
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Sinu Azure AI Agendi teenuse projekti ühendusstring"
#
#   Projekti ühendusstringi leiad oma projekti ülevaatest AI Foundry portaali ekraanil.
#
# - **SERPAPI_SEARCH_API_KEY** = "Sinu SERPAPI Search API VÕTI"
# - **SERPAPI_SEARCH_ENDPOINT** = "Sinu SERPAPI Search Endpoint"
#
# Azure AI Agendi teenuse mudeli kasutuselevõtu nime ja projekti ühendusstringi saamiseks pead Azure AI Agendi teenuse looma. Soovitatav on kasutada [seda malli](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json), et see otse luua (***Märkus:*** Azure AI Agent Service on hetkel piiratud piirkonnas. Soovitatav on tutvuda [sellega](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support), et seada piirkond).
#
# Agendil peab olema juurdepääs SERPAPI-le. Soovitatav on registreeruda [selle lingi kaudu](https://serpapi.com/searches). Pärast registreerumist saad ainulaadse API VÕTI ja ENDPOINT-i.

# %% [markdown]
# # Sisselogimine Azure'i
#
# Nüüd peate Azure'i sisse logima. Avage VScode'is terminal ja käivitage käsk `az login`

# %% [markdown]
# # Setup
#
# Selle märkmiku käivitamiseks peate installima järgmised teegid. Siin on nimekiri nõutavatest teekidest ja vastavad pip install käsud:
#
# azure-identity: Azure autentimiseks.
# requests: HTTP-päringute tegemiseks.
# semantic-kernel: Semantilise tuuma raamistikuks (eeldades, et see on kohandatud või konkreetne teek, peate selle võib-olla installima kindlast allikast või hoidlast).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Selgitus:
# import asyncio: See impordib asyncio mooduli, mis pakub tuge asünkroonseks programmeerimiseks Pythonis. See võimaldab kirjutada kõrvuti töötavaid koodilõike, kasutades async ja await süntaksit.
# from typing import Annotated: See impordib Annotated tüübi typing moodulist. Annotated kasutatakse tüübiviidete metainfo lisamiseks, mis võib olla kasulik erinevatel eesmärkidel nagu valideerimine, dokumentatsioon või tööriistad.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Selgitus:
# Kasutades from dotenv import load_dotenv ja load_dotenv(), saate hõlpsasti hallata seadistusi ja tundlikku teavet (näiteks API-võtmeid ja andmebaasi URL-e) .env-failis, hoides need eraldi teie lähtekoodist ning muutes teie rakenduse turvalisemaks ja lihtsamini seadistatavaks.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Selgitus:
#
# Import-lause: from azure.identity.aio import DefaultAzureCredential: See impordib DefaultAzureCredential klassi moodulist azure.identity.aio. Moodulinime aio osa tähistab, et see on mõeldud asünkroonsete operatsioonide jaoks.
#
# DefaultAzureCredentiali eesmärk: DefaultAzureCredential klass on osa Azure SDK-st Pythonile. See pakub vaikimisi viisi Azure teenustega autentimiseks. See üritab autentida mitme meetodi abil kindlas järjekorras, näiteks keskkonnamuutujad, hallatud identiteet ja Azure CLI mandaadid.
#
# Asünkroonsed operatsioonid: aio moodul näitab, et DefaultAzureCredential klass toetab asünkroonseid operatsioone. See tähendab, et seda saab kasutada koos asyncio-ga mitteblokeerivate autentimistaotluste tegemiseks.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Selgitus:
# Imporditakse erinevaid mooduleid ja klasse paketist semantic_kernel. Siin on iga impordi kirjeldus:
#
# AgentGroupChat paketist semantic_kernel.agents: See klass haldab funktsionaalsust, mis on seotud AI-agentide grupivestlusega. AzureAIAgent ja AzureAIAgentSettings paketist semantic_kernel.agents.azure_ai
#
# AzureAIAgent: Seda klassi kasutatakse AI-agentide loomiseks ja haldamiseks, kes kasutavad Azure AI teenuseid.
#
# AzureAIAgentSettings: Seda klassi kasutatakse AzureAIAgent seadistuste konfigureerimiseks. TerminationStrategy paketist semantic_kernel.agents.strategies.termination.termination_strategy:
#
# See klass määratleb strateegiad AI-agentide täitmise lõpetamiseks teatud tingimustel. ChatMessageContent paketist semantic_kernel.contents.chat_message_content:
#
# See klass haldab vestlus sõnumite sisu.
# AuthorRole paketist semantic_kernel.contents.utils.author_role:
#
# See klass määratleb erinevad autori rollid vestlus sõnumite kontekstis.
#
# kernel_function paketist semantic_kernel.functions.kernel_function_decorator: Seda dekoratiivset kasutatakse tuumikfunktsioonide määratlemiseks, mis on funktsioonid, mida saab täita semantic_kernel raamistikus.
# Need impordid seadistavad vajalikud komponendid AI-agentide loomiseks ja haldamiseks, kes saavad suhelda grupivestluse keskkonnas, näiteks hotellibroneeringute või sarnaste ülesannete jaoks.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Selgitus:
# Järgmisena impordime klassi CodeInterpreterTool moodulist azure.ai.projects.models.
#
# CodeInterpreterTool: See klass on osa Azure AI SDK-st ja seda kasutatakse koodi tõlgendamiseks ning käivitamiseks AI projektide kontekstis. See pakub funktsionaalsusi koodilõikude jooksutamiseks, koodi analüüsimiseks või koodi täitmise integreerimiseks AI töövoogudes.
# See import seab üles vajaliku komponendi CodeInterpreterTool kasutamiseks sinu projektis, mis võib olla kasulik ülesannete puhul, mis hõlmavad koodi dünaamilist tõlgendamist ja täitmist.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Selgitus:
# ApprovalTerminationStrategy klass pakub spetsiifilist strateegiat tehisintellekti agendi töö lõpetamiseks. Agent lõpetab tegevuse, kui tema suhtlusajaloo viimane sõnum sisaldab sõna "saved". See võib olla kasulik olukordades, kus agendi ülesanne loetakse lõpetatuks kohe, kui ta saab kinnituse millegi "salvestamise" kohta. Määra suhtlusmeetod. Pärast broneerimiskava salvestamist saab agent peatada, kui ta saab salvestamise signaali.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Selgitus:
#
# Koodirida initialiseib AzureAIAgentSettings objekti vaikeseadistustega või eelmääratletud seadistustega, kutsudes välja create() meetodi. Seda seadistusobjekti (ai_agent_settings) saab seejärel kasutada AzureAIAgent eksemplari seadistamiseks ja haldamiseks.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Selgitus:
# Impordides requests'i teegi saad hõlpsasti teha HTTP-päringuid ja suhelda veebiteenustega oma Pythoni koodis.

# %%
import requests

# %% [markdown]
# # Selgitus:
# See on muutuja, mis salvestab API võtit SERP-i (otsingumootori tulemuste lehe) API teenusele juurdepääsuks. API võti on unikaalne identifikaator, mida kasutatakse päringute autentimiseks, mis on seotud teie kontoga.
#
# 'GOOGLE_SEARCH_API_KEY': See on kohatäitja string. Peate asendama ''GOOGLE_SEARCH_API_KEY' oma tegeliku SERP API võtmega.
#
# Eesmärk: Selle rea eesmärk on salvestada API võti muutujasse, et seda saaks kasutada päringute autentimiseks SERP API teenusele. API võtit on vaja teenusele juurdepääsuks ja otsingute tegemiseks.
#
# Kuidas saada SERP API võti: SERP API võtme saamiseks järgige neid üldiseid samme aadressil https://serpapi.com (täpsed sammud võivad erineda sõltuvalt kasutatavast SERP API teenusest):
#
# Valige SERP API teenus: Saadaval on mitmeid SERP API teenuseid, nagu SerpAPI, Google Custom Search JSON API ja teised. Valige see, mis vastab kõige paremini teie vajadustele.
#
# Registreeruge kontole:
#
# Minge valitud SERP API teenuse veebisaidile https://www.serpapi.com ja registreeruge kontole. Võib-olla peate esitama mõningaid põhiteadmisi ja kinnitama oma e-posti aadressi.
#
# Looge API võti:
#
# Pärast registreerumist logige sisse oma kontole ja liikuge API jaotisse või juhtpaneelile. Otsige valikut uue API võtme loomiseks või genereerimiseks.
# Kopeerige API võti:
#
# Kui API võti on genereeritud, kopeerige see. Seda võtit kasutatakse teie päringute autentimiseks SERP API teenusele.
# Asendage kohatäitja:
#
# Asendage kohatäitja oma .env failis

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Selgitus:
# BookingPlugin klass pakub meetodeid hotellide ja lendude broneerimiseks, kasutades Serpapi.com Google Search API-t. See koostab vajalikud parameetrid, saadab API päringud ja töötleb vastuseid, et tagastada asjakohane broneerimisteave. API võtit (SERPAPI_SEARCH_API_KEY) ja lõpp-punkti (SERPAPI_SEARCH_ENDPOINT) kasutatakse Google Search API-ga autentimiseks ja päringute saatmiseks.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Selgitus:
# SavePlugin klass pakub meetodit saving_plan, et salvestada reisiplaane, kasutades Azure AI teenuseid. See seab üles Azure'i volitused, loob AI agendi, töötleb kasutajasisendeid reisiplaani sisu genereerimiseks ja salvestamiseks ning haldab faili salvestamise ja koristamise toiminguid. Meetod tagastab õnnestunud lõpetamise korral "Saved".

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # Selgitus:
# See kood seab üles Azure AI agendid lendude ja hotellide broneerimiseks ning reisiplaanide salvestamiseks kasutaja sisendite põhjal. See kasutab Azure'i volitusi agentide loomiseks ja konfigureerimiseks, töötleb kasutaja sisendeid grupivestluse kaudu ning tagab korraliku puhastamise pärast ülesannete lõpetamist. Agendid kasutavad oma ülesannete täitmiseks konkreetseid pluginaid (BookingPlugin ja SavePlugin).

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastutusest loobumine**:
# See dokument on tõlgitud kasutades tehisintellektil põhinevat tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi püüame tagada täpsust, tuleb arvestada, et automaatsed tõlked võivad sisaldada vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleb pidada autoriteetseks allikaks. Tähtsa teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta käesoleva tõlke kasutamisest tekkida võivate arusaamatuste või valesti mõistmiste eest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
