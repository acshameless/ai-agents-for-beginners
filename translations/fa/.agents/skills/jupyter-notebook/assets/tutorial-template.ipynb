# %% [markdown]
# # آموزش: TITLE
#
# مخاطب:
# - مشخص کنید برای چه افرادی مناسب است.
#
# پیش‌نیازها:
# - مفاهیم یا تنظیمات لازم را فهرست کنید.
#
# اهداف یادگیری:
# - در پایان، خواننده می‌تواند...

# %% [markdown]
# ## نمای کلی
#
# 1. راه‌اندازی
# 2. یک مثال کاری حداقلی
# 3. تنوع‌ها و موارد مشکل‌زا
# 4. تمرین‌ها

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## مرحله 1 - با یک مثال خیلی کوچک شروع کنید
#
# به زبان ساده توضیح دهید که سلول بعدی چه کاری انجام می‌دهد.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## تمرین‌ها
#
# - یک ورودی متفاوت امتحان کنید.
# - خروجی را قبل از اجرای کد پیش‌بینی کنید.
# - یک اشتباه رایج را ذکر کنید و نحوه رفع آن را توضیح دهید.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# سلب مسئولیت:
# این سند با استفاده از سرویس ترجمهٔ هوش مصنوعی Co-op Translator (https://github.com/Azure/co-op-translator) ترجمه شده است. در حالی که ما سعی در دقت داریم، لطفاً توجه داشته باشید که ترجمه‌های خودکار ممکن است دارای خطاها یا نادرستی‌هایی باشند. سند اصلی به زبان مبدأ باید به‌عنوان منبع معتبر در نظر گرفته شود. برای اطلاعات حیاتی، استفاده از ترجمهٔ حرفه‌ای انسانی توصیه می‌شود. ما در قبال هرگونه سوءتفاهم یا برداشت نادرستی که از استفاده از این ترجمه به‌وجود آید مسئولیتی نداریم.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
