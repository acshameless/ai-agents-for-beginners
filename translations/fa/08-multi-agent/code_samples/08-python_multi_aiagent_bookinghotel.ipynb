# %% [markdown]
# ## **نمونه‌ها: عوامل چندهوش مصنوعی برای رزرو هتل**
#
# در دنیای پرسرعت امروز، برنامه‌ریزی یک سفر کاری فراتر از رزرو پرواز و اتاق هتل است. این کار نیازمند سطحی از هماهنگی و کارایی است که دستیابی به آن می‌تواند چالش‌برانگیز باشد. اینجاست که عوامل چندهوش مصنوعی وارد عمل می‌شوند و نحوه مدیریت نیازهای سفر ما را متحول می‌کنند.
#
# تصور کنید تیمی از عوامل هوشمند در اختیار دارید که با هم همکاری می‌کنند تا هر جنبه‌ای از سفر شما را با دقت و سهولت مدیریت کنند. با فناوری پیشرفته هوش مصنوعی ما، عوامل تخصصی برای خدمات رزرو و ترتیب دادن برنامه سفر ایجاد کرده‌ایم که تجربه سفر بی‌وقفه و عاری از استرس را تضمین می‌کنند.
#
# این یک سناریوی پایه است. هنگام برنامه‌ریزی یک سفر کاری، نیاز به مشورت با یک مأمور سفر کاری برای دریافت اطلاعات بلیط هواپیما، اطلاعات هتل و غیره داریم. از طریق عوامل هوش مصنوعی، می‌توانیم عواملی برای خدمات رزرو و عواملی برای ترتیب دادن برنامه سفر ایجاد کنیم تا با همکاری هم سطح هوشمندی را ارتقاء دهند.

# %% [markdown]
# # راه‌اندازی سرویس Azure AI Agent و دریافت اطلاعات پیکربندی از **.env**
#
# ### **.env**
#
# یک فایل .env بسازید
#
# **.env** حاوی رشته اتصال سرویس Azure AI Agent، مدلی که توسط AOAI استفاده می‌شود، و سرویس API جستجوی گوگل مربوطه، ENDPOINT و غیره است.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "نام استقرار مدل سرویس Azure AI Agent شما"
#
# [**توجه**] شما به مدلی با محدودیت نرخ ۱۰۰,۰۰۰ (توکن در دقیقه) و محدودیت نرخ ۶۰۰ (درخواست در دقیقه) نیاز دارید
#
#   می‌توانید مدل را در Microsoft Foundry - Model and Endpoint دریافت کنید.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "رشته اتصال پروژه سرویس Azure AI Agent شما"
#
#   می‌توانید رشته اتصال پروژه را در صفحه نمای کلی پروژه خود در پرتال AI Foundry دریافت کنید.
#
# - **SERPAPI_SEARCH_API_KEY** = "کلید API جستجوی SERPAPI شما"
# - **SERPAPI_SEARCH_ENDPOINT** = "نقطه انتهایی جستجوی SERPAPI شما"
#
# برای به‌دست آوردن نام استقرار مدل و رشته اتصال پروژه سرویس Azure AI Agent، نیاز دارید سرویس Azure AI Agent را ایجاد کنید. توصیه می‌شود از [این قالب](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) برای ایجاد مستقیم آن استفاده کنید （***توجه:*** سرویس Azure AI Agent در حال حاضر در منطقه‌ای محدود تنظیم شده است. توصیه می‌شود به [این لینک](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) مراجعه کنید تا منطقه را تنظیم کنید)
#
# عامل نیاز دارد به SERPAPI دسترسی داشته باشد. پیشنهاد می‌شود با استفاده از [این لینک](https://serpapi.com/searches) ثبت‌نام کنید. پس از ثبت‌نام، می‌توانید یک کلید API یکتا و نقطه انتهایی دریافت کنید.

# %% [markdown]
# # ورود به Azure
#
# اکنون باید وارد Azure شوید. یک ترمینال در VScode باز کنید و دستور `az login` را اجرا کنید.

# %% [markdown]
# # تنظیمات
#
# برای اجرای این نوت‌بوک، باید کتابخانه‌های زیر را نصب کنید. در اینجا فهرستی از کتابخانه‌های مورد نیاز و دستورات نصب pip مربوط به آن‌ها آمده است:
#
# azure-identity: برای احراز هویت Azure.
# requests: برای ایجاد درخواست‌های HTTP.
# semantic-kernel: برای چارچوب semantic kernel (با فرض اینکه این یک کتابخانه سفارشی یا خاص است، ممکن است نیاز باشد آن را از منبع یا مخزن خاصی نصب کنید).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # توضیح:
# import asyncio: این ماژول asyncio را وارد می‌کند که پشتیبانی از برنامه‌نویسی ناهمگام در پایتون را فراهم می‌کند. این امکان را به شما می‌دهد که کد همزمان با استفاده از نحو async و await بنویسید.
# from typing import Annotated: این نوع Annotated را از ماژول typing وارد می‌کند. Annotated برای افزودن فراداده به نشانه‌های نوع استفاده می‌شود که می‌تواند برای اهداف مختلفی مانند اعتبارسنجی، مستندسازی یا ابزارسازی مفید باشد.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # توضیح:
# با استفاده از from dotenv import load_dotenv و load_dotenv()، می‌توانید به‌راحتی تنظیمات پیکربندی و اطلاعات حساس (مانند کلیدهای API و آدرس‌های پایگاه داده) را در یک فایل .env مدیریت کنید، آنها را از کد منبع خود جدا نگه دارید و برنامه‌تان را امن‌تر و پیکربندی آن را آسان‌تر کنید.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # توضیح:
#
# عبارت واردات: from azure.identity.aio import DefaultAzureCredential: این عبارت کلاس DefaultAzureCredential را از ماژول azure.identity.aio وارد می‌کند. بخش aio از نام ماژول نشان می‌دهد که برای عملیات غیرهمزمان طراحی شده است.
#
# هدف از DefaultAzureCredential: کلاس DefaultAzureCredential بخشی از Azure SDK برای پایتون است. این کلاس روشی پیش‌فرض برای احراز هویت با سرویس‌های Azure فراهم می‌کند. این کلاس تلاش می‌کند با استفاده از چندین روش به ترتیب خاصی احراز هویت کند، مانند متغیرهای محیطی، شناسه مدیریت‌شده، و اعتبارنامه‌های Azure CLI.
#
# عملیات غیرهمزمان: ماژول aio نشان می‌دهد که کلاس DefaultAzureCredential از عملیات غیرهمزمان پشتیبانی می‌کند. این به این معنی است که می‌توانید از آن همراه با asyncio برای انجام درخواست‌های احراز هویت غیرمسدودکننده استفاده کنید.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # توضیح:
# واردات ماژول‌ها و کلاس‌های مختلف از بسته semantic_kernel. شرح هر واردات به صورت زیر است:
#
# AgentGroupChat از semantic_kernel.agents: این کلاس مربوط به عملکردهای مرتبط با چت گروهی برای عامل‌های هوش مصنوعی است. AzureAIAgent و AzureAIAgentSettings از semantic_kernel.agents.azure_ai
#
# AzureAIAgent: این کلاس برای ایجاد و مدیریت عامل‌های هوش مصنوعی که از خدمات Azure AI استفاده می‌کنند کاربرد دارد.
#
# AzureAIAgentSettings: این کلاس برای پیکربندی تنظیمات AzureAIAgent استفاده می‌شود. TerminationStrategy از semantic_kernel.agents.strategies.termination.termination_strategy:
#
# این کلاس استراتژی‌هایی برای خاتمه اجرای عامل‌های هوش مصنوعی در شرایط خاص تعریف می‌کند. ChatMessageContent از semantic_kernel.contents.chat_message_content:
#
# این کلاس برای مدیریت محتوای پیام‌های چت استفاده می‌شود.
# AuthorRole از semantic_kernel.contents.utils.author_role:
#
# این کلاس نقش‌های مختلف نویسندگان را در زمینه پیام‌های چت تعریف می‌کند.
#
# kernel_function از semantic_kernel.functions.kernel_function_decorator: این دکوراتور برای تعریف توابع هسته استفاده می‌شود، که توابعی هستند که می‌توانند در چارچوب semantic kernel اجرا شوند.
# این واردات اجزای لازم برای ایجاد و مدیریت عامل‌های هوش مصنوعی که می‌توانند در محیط چت گروهی تعامل داشته باشند، ممکن است برای کارهایی مانند رزرو هتل یا فعالیت‌های مشابه را فراهم می‌کنند.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # توضیح:
# گام بعدی وارد کردن کلاس CodeInterpreterTool از ماژول azure.ai.projects.models است.
#
# CodeInterpreterTool: این کلاس بخشی از کیت توسعه Azure AI است و برای تفسیر و اجرای کد در چارچوب پروژه‌های هوش مصنوعی استفاده می‌شود. این کلاس امکاناتی برای اجرای قطعات کد، تحلیل کد، یا ادغام اجرای کد در جریان‌های کاری هوش مصنوعی فراهم می‌کند.
# این واردسازی، جزء ضروری برای استفاده از CodeInterpreterTool در پروژه شما را تنظیم می‌کند، که ممکن است برای کارهایی که شامل تفسیر و اجرای پویا کد هستند مفید باشد.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # توضیح:
# کلاس ApprovalTerminationStrategy یک استراتژی مشخص برای خاتمه عملیات یک عامل هوش مصنوعی فراهم می‌کند. عامل زمانی خاتمه می‌یابد که آخرین پیام در تاریخچه تعامل آن شامل کلمه "saved" باشد. این می‌تواند در سناریوهایی مفید باشد که وظیفه عامل پس از دریافت تأیید اینکه چیزی "ذخیره شده" کامل تلقی می‌شود.
# روش تعامل را تعریف کنید. پس از ذخیره برنامه رزرو، می‌توان آن را هنگام دریافت سیگنال ذخیره شده متوقف کرد.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # توضیح:
#
# خط کد یک شیء AzureAIAgentSettings را با تنظیمات پیش‌فرض یا از پیش تعریف‌شده با فراخوانی متد create() مقداردهی اولیه می‌کند. سپس این شیء تنظیمات (ai_agent_settings) می‌تواند برای پیکربندی و مدیریت یک نمونه AzureAIAgent مورد استفاده قرار گیرد.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # توضیح:
# با وارد کردن کتابخانه requests، می‌توانید به‌راحتی درخواست‌های HTTP ارسال کرده و با سرویس‌های وب در کد پایتون خود تعامل داشته باشید.

# %%
import requests

# %% [markdown]
# # توضیح:
# این یک متغیر است که کلید API برای دسترسی به سرویس API صفحه نتایج موتور جستجو (SERP) را ذخیره می‌کند. کلید API یک شناسه یکتا است که برای احراز هویت درخواست‌های مرتبط با حساب شما استفاده می‌شود.
#
# 'GOOGLE_SEARCH_API_KEY': این یک رشته جایگزین است. شما باید ''GOOGLE_SEARCH_API_KEY' را با کلید API واقعی SERP خود جایگزین کنید.
#
# هدف: هدف این خط ذخیره کلید API در یک متغیر است تا بتوان از آن برای احراز هویت درخواست‌ها به سرویس API SERP استفاده کرد. کلید API برای دسترسی به سرویس و انجام جستجوها لازم است.
#
# چگونه یک کلید API برای SERP دریافت کنیم: برای دریافت کلید API SERP، مراحل کلی زیر را در https://serpapi.com دنبال کنید (مراحل دقیق ممکن است بسته به سرویس API SERP خاصی که استفاده می‌کنید متفاوت باشد):
#
# انتخاب یک سرویس API SERP: چندین سرویس API SERP موجود است، مانند SerpAPI، Google Custom Search JSON API و غیره. آن سرویسی که بهترین نیازهای شما را برآورده می‌کند انتخاب کنید.
#
# ثبت نام برای حساب کاربری:
#
# به وبسایت سرویس API SERP انتخاب شده به آدرس https://www.serpapi.com بروید و ثبت نام کنید. ممکن است نیاز باشد اطلاعات پایه‌ای را ارائه داده و ایمیل خود را تأیید کنید.
#
# ایجاد کلید API:
#
# پس از ثبت نام، وارد حساب خود شوید و به بخش API یا داشبورد مراجعه کنید. به دنبال گزینه‌ای برای ایجاد یا تولید کلید جدید API باشید.
# کپی کلید API:
#
# وقتی کلید API ایجاد شد، آن را کپی کنید. این کلید برای احراز هویت درخواست‌های شما به سرویس API SERP استفاده خواهد شد.
# جایگزینی جایگزین:
#
# مقدار جایگزین را در فایل .env خود جایگزین کنید

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # توضیح:
# کلاس BookingPlugin متدهایی برای رزرو هتل‌ها و پروازها با استفاده از API جستجوی گوگل Serpapi.com ارائه می‌دهد. این کلاس پارامترهای لازم را می‌سازد، درخواست‌های API را ارسال می‌کند و پاسخ‌ها را پردازش می‌کند تا اطلاعات مربوط به رزرو را بازگرداند. کلید API (SERPAPI_SEARCH_API_KEY) و نقطه انتهایی (SERPAPI_SEARCH_ENDPOINT) برای احراز هویت و ارسال درخواست‌ها به API جستجوی گوگل استفاده می‌شوند.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # توضیح:
# کلاس SavePlugin متدی به نام saving_plan ارائه می‌دهد که برای ذخیره برنامه‌های سفر با استفاده از سرویس‌های هوش مصنوعی Azure استفاده می‌شود. این متد اعتبارنامه‌های Azure را تنظیم می‌کند، یک عامل هوش مصنوعی ایجاد می‌کند، ورودی‌های کاربر را پردازش می‌کند تا محتوای برنامه سفر را تولید و ذخیره کند، و عملیات ذخیره فایل و پاکسازی را مدیریت می‌کند. این متد در پایان با موفقیت، عبارت «Saved» را بازمی‌گرداند.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # توضیح:
# این کد نمایندگان هوش مصنوعی آزور را برای مدیریت رزرو پروازها و هتل‌ها و ذخیره برنامه‌های سفر بر اساس ورودی‌های کاربر تنظیم می‌کند. این کد از مدارک آزور برای ایجاد و پیکربندی نمایندگان استفاده می‌کند، ورودی‌های کاربر را از طریق چت گروهی پردازش می‌کند و پس از اتمام وظایف، پاک‌سازی مناسب را تضمین می‌کند. نمایندگان از افزونه‌های خاص (BookingPlugin و SavePlugin) برای انجام کارهای مربوطه استفاده می‌کنند.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **توضیح مهم**:
# این سند با استفاده از سرویس ترجمه‌ای هوش مصنوعی [Co-op Translator](https://github.com/Azure/co-op-translator) ترجمه شده است. در حالی که ما تلاش می‌کنیم دقت را حفظ کنیم، لطفاً توجه داشته باشید که ترجمه‌های خودکار ممکن است حاوی اشتباهات یا نادرستی‌هایی باشند. سند اصلی به زبان بومی خود، منبع معتبر و قابل اتکا است. برای اطلاعات حیاتی، توصیه می‌شود از ترجمه حرفه‌ای انسانی استفاده شود. ما در قبال هرگونه سوء تفاهم یا برداشت نادرست ناشی از استفاده این ترجمه مسئولیتی نداریم.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
