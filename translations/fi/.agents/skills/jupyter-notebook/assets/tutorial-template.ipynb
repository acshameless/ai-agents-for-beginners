# %% [markdown]
# # Opas: TITLE
#
# Kohdeyleisö:
# - Kuvaile, kenelle tämä on tarkoitettu.
#
# Esivaatimukset:
# - Luettele vaadittavat käsitteet tai asetukset.
#
# Oppimistavoitteet:
# - Lopuksi lukija osaa...

# %% [markdown]
# ## Rakenne
#
# 1. Asennus
# 2. Minimaalinen toimiva esimerkki
# 3. Vaihtoehdot ja sudenkuopat
# 4. Harjoitukset

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Vaihe 1 - Aloita pienellä esimerkillä
#
# Selitä, mitä seuraava solu tekee selkokielellä.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Harjoitukset
#
# - Kokeile eri syötettä.
# - Ennusta tulos ennen koodin suorittamista.
# - Mainitse yksi yleinen virhe ja miten se korjataan.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Vastuuvapauslauseke:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, huomioithan, että automaattiset käännökset voivat sisältää virheitä tai epätarkkuuksia. Alkuperäistä asiakirjaa sen alkuperäisellä kielellä tulee pitää määräyksenmukaisena lähteenä. Tärkeiden tietojen osalta suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai virhetulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
