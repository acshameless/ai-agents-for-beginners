# %% [markdown]
# ## **Näytteet: Moni-AI-agentit hotellin varaamiseen**
#
# Nykypäivän vauhdikkaassa maailmassa liikematkan suunnittelu ei tarkoita pelkästään lennon ja hotellihuoneen varaamista. Se vaatii tason koordinointia ja tehokkuutta, jonka saavuttaminen voi olla haastavaa. Tässä kohtaa moni-AI-agentit tulevat kuvaan, mullistaen tapamme hallita matkatarpeitamme.
#
# Kuvittele, että sinulla on käytössäsi älykkäiden agenttien tiimi, joka työskentelee yhdessä hoitaakseen matkasi kaikki osa-alueet tarkasti ja vaivattomasti. Edistyneen tekoälyteknologiamme avulla olemme luoneet erikoistuneita agentteja varauspalveluita ja matkasuunnitelman järjestämistä varten, varmistaen saumattoman ja stressittömän matkaelämyksen.
#
# Tämä on perusskenaario. Liikematkaa suunniteltaessa meidän täytyy neuvotella liikematka-agentin kanssa saadaksemme lentolippujen tiedot, hotellitiedot jne. Tekoälyagenttien avulla voimme rakentaa varauspalvelujen agentteja ja matkasuunnitelman järjestämisen agentteja tekemään yhteistyötä ja parantamaan älykkyystasoa.

# %% [markdown]
# # Alusta Azure AI Agent -palvelu ja hae määritystiedot **.env**-tiedostosta
#
# ### **.env**
#
# Luo .env-tiedosto
#
# **.env** sisältää Azure AI Agent -palvelun yhteysmerkkijonon, AOAI:n käyttämän mallin sekä vastaavan Google API Search -palvelun API-avaimen, PÄÄTEOSOITTEEN jne.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Azure AI Agent -palvelun mallin käyttöönoton nimi"
#
# [**HUOMAUTUS**] Tarvitset mallin, jolla on 100 000 rajaus (tokenia minuutissa) ja 600 rajaus (pyyntöä minuutissa).
#
#   Mallin saat Microsoft Foundry - Model and Endpoint -kohdasta.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Azure AI Agent -palvelun projektin yhteysmerkkijono"
#
#   Projektin yhteysmerkkijonon löydät projektisi yleiskatsauksesta AI Foundry -portaalin näytöltä.
#
# - **SERPAPI_SEARCH_API_KEY** = "SERPAPI-hakuluvan API-AVAIN"
# - **SERPAPI_SEARCH_ENDPOINT** = "SERPAPI Search Päätepiste"
#
# Azure AI Agent -palvelun malli Käyttöönoton nimi ja projektin yhteysmerkkijono löytyvät, kun luot Azure AI Agent -palvelun. Suositellaan käyttämään [tätä mallia](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) suoraan sen luomiseen  (***Huom:*** Azure AI Agent -palvelu on tällä hetkellä käytettävissä rajoitetuilla alueilla. Suositellaan tutustumaan [tähän linkkiin](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) asetuksen alueen määrittämiseksi)
#
# Agentin tulee käyttää SERPAPI-palvelua. Rekisteröityminen suositellaan tehtäväksi [tästä linkistä](https://serpapi.com/searches). Rekisteröitymisen jälkeen voit saada yksilöllisen API-AVAIMEN ja PÄÄTEOSOITTEEN.

# %% [markdown]
# # Kirjaudu Azureen
#
# Sinun täytyy nyt kirjautua Azureen. Avaa terminaali VScodessa ja suorita komento `az login`

# %% [markdown]
# # Asennus
#
# Tämän muistikirjan suorittamiseksi sinun tulee asentaa seuraavat kirjastot. Tässä on luettelo vaadituista kirjastoista ja vastaavat pip install -komennot:
#
# azure-identity: Azure-todennusta varten.
# requests: HTTP-pyyntöjen tekemiseen.
# semantic-kernel: Semanttisen kernel-kehyksen käyttöä varten (olettaen, että tämä on oma tai erityinen kirjasto, saatat joutua asentamaan sen tietystä lähteestä tai repositoriosta).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Selitys:
# import asyncio: Tämä tuo asyncio-moduulin, joka tarjoaa tukea asynkroniselle ohjelmoinnille Pythonissa. Sen avulla voit kirjoittaa samanaikaista koodia käyttäen async- ja await-syntaksia.
# from typing import Annotated: Tämä tuo Annotated-tyypin typing-moduulista. Annotatedia käytetään lisäämään metatietoa tyyppivihjeisiin, mikä voi olla hyödyllistä esimerkiksi validoinnissa, dokumentaatiossa tai työkalujen käytössä.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Selitys:
# Käyttämällä from dotenv import load_dotenv ja load_dotenv(), voit helposti hallita konfiguraatioasetuksia ja arkaluonteisia tietoja (kuten API-avaimia ja tietokannan URL-osoitteita) .env-tiedostossa, pitäen ne erillään lähdekoodistasi ja tekemällä sovelluksestasi turvallisemman ja helpommin konfiguroitavan.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Selitys:
#
# Tuontilauseke: from azure.identity.aio import DefaultAzureCredential: Tämä tuo DefaultAzureCredential-luokan azure.identity.aio-moduulista. Moduulin nimen aio-osa tarkoittaa, että se on suunniteltu asynkronisia toimintoja varten.
#
# DefaultAzureCredentialin tarkoitus: DefaultAzureCredential-luokka on osa Azure SDK:ta Pythonille. Se tarjoaa oletustavan todennukseen Azure-palveluissa. Se yrittää todennusta useilla menetelmillä tietyssä järjestyksessä, kuten käyttöympäristömuuttujien, hallitun identiteetin ja Azure CLI -tunnistetietojen avulla.
#
# Asynkroniset toiminnot: aio-moduuli tarkoittaa, että DefaultAzureCredential-luokka tukee asynkronisia toimintoja. Tämä tarkoittaa, että voit käyttää sitä yhdessä asyncio-kirjaston kanssa tehdäksesi ei-estäviä todennuspyyntöjä.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Selitys:
# Tuo erilaisia moduuleja ja luokkia semantic_kernel-paketista. Tässä on erittely kustakin tuonnista:
#
# AgentGroupChat semantic_kernel.agents:ista: Tämä luokka käsittelee ryhmäkeskusteluihin liittyviä toimintoja AI-agenttien osalta. AzureAIAgent ja AzureAIAgentSettings semantic_kernel.agents.azure_ai:sta
#
# AzureAIAgent: Tätä luokkaa käytetään AI-agenttien luomiseen ja hallintaan, jotka hyödyntävät Azure AI -palveluja.
#
# AzureAIAgentSettings: Tätä luokkaa käytetään AzureAIAgentin asetusten määrittämiseen. TerminationStrategy semantic_kernel.agents.strategies.termination.termination_strategy:sta:
#
# Tämä luokka määrittelee strategioita AI-agenttien suorituksen lopettamiseen tietyissä olosuhteissa. ChatMessageContent semantic_kernel.contents.chat_message_content:sta:
#
# Tätä luokkaa käytetään chat-viestien sisällön käsittelyyn. AuthorRole semantic_kernel.contents.utils.author_role:sta:
#
# Tämä luokka määrittelee erilaisia rooleja kirjoittajille chat-viestien yhteydessä.
#
# kernel_function semantic_kernel.functions.kernel_function_decorator:sta: Tätä dekorattoria käytetään kernel-funktioiden määrittelemiseen, eli funktioiden, joita voidaan suorittaa semantic kernel -kehyksessä.
# Nämä tuonnit valmistavat tarvittavat komponentit AI-agenttien luomiseen ja hallintaan, jotka voivat olla vuorovaikutuksessa ryhmäkeskustelussa, esimerkiksi hotellivarauksiin tai vastaaviin tehtäviin.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Explanation:
# Seuraavaksi tuomme CodeInterpreterTool-luokan azure.ai.projects.models-moduulista.
#
# CodeInterpreterTool: Tämä luokka on osa Azure AI SDK:ta ja sitä käytetään koodin tulkitsemiseen ja suorittamiseen tekoälyprojektien yhteydessä. Se tarjoaa toiminnallisuuksia koodinpätkien ajamiseen, koodin analysointiin tai koodin suorituksen integroimiseen tekoälytyönkulkuihin.
# Tämä tuonti asettaa tarvittavan komponentin CodeInterpreterToolin käyttämiseen projektissasi, mikä voi olla hyödyllistä tehtävissä, jotka liittyvät koodin dynaamiseen tulkitsemiseen ja suorittamiseen.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Selitys:
# ApprovalTerminationStrategy-luokka tarjoaa tarkan strategian tekoälyagentin toiminnan lopettamiseksi. Agentti lopettaa, jos sen vuorovaikutushistorian viimeisessä viestissä on sana "saved". Tämä voi olla hyödyllistä tilanteissa, joissa agentin tehtävä katsotaan suoritetuksi, kun se saa vahvistuksen, että jokin on "saved". Määrittele vuorovaikutusmenetelmä. Varaussuunnitelman tallentamisen jälkeen sen voi lopettaa vastaanottaessaan tallennussignaalin.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Selitys:
#
# Koodirivi alustaa AzureAIAgentSettings-olion oletus- tai ennalta määritellyillä asetuksilla kutsumalla create()-metodia. Tätä asetusta sisältävää oliota (ai_agent_settings) voidaan sitten käyttää AzureAIAgent-instanssin konfigurointiin ja hallintaan.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Selitys:
# Tuomalla requests-kirjasto voit helposti tehdä HTTP-pyyntöjä ja olla vuorovaikutuksessa verkkopalveluiden kanssa Python-koodissasi.

# %%
import requests

# %% [markdown]
# # Selitys:
# Tämä on muuttuja, joka tallentaa API-avaimen SERP (hakukoneen tulossivun) API-palvelun käyttöä varten. API-avain on yksilöllinen tunniste, jota käytetään todennukseen tilisi yhteydessä tehtävissä pyynnöissä.
#
# 'GOOGLE_SEARCH_API_KEY': Tämä on paikkamerkkimerkkijono. Sinun tulee korvata ''GOOGLE_SEARCH_API_KEY' omalla SERP API -avaimellasi.
#
# Tarkoitus: Tämän rivin tarkoituksena on tallentaa API-avain muuttujaan, jotta sitä voidaan käyttää todennukseen tehtäessä pyyntöjä SERP API -palveluun. API-avain vaaditaan palveluun pääsyyn ja hakuominaisuuksien käyttämiseen.
#
# Kuinka saada SERP API -avain: Saat SERP API -avaimen noudattamalla yleisiä ohjeita osoitteessa https://serpapi.com (tarkat vaiheet voivat vaihdella käyttämäsi SERP API -palvelun mukaan):
#
# Valitse SERP API -palvelu: Saatavilla on useita SERP API -palveluja, kuten SerpAPI, Google Custom Search JSON API ja muita. Valitse tarpeisiisi parhaiten soveltuva palvelu.
#
# Rekisteröidy tilille:
#
# Mene valitsemasi SERP API -palvelun verkkosivulle https://www.serpapi.com ja rekisteröidy tilille. Sinun on ehkä annettava joitain perustietoja ja vahvistettava sähköpostiosoitteesi.
#
# Luo API-avain:
#
# Rekisteröitymisen jälkeen kirjaudu tilillesi ja siirry API-osioon tai hallintapaneeliin. Etsi vaihtoehto uuden API-avaimen luomiseen tai generointiin.
#
# Kopioi API-avain:
#
# Kun API-avain on luotu, kopioi se. Tätä avainta käytetään pyyntöjen todennukseen SERP API -palvelua käytettäessä.
#
# Korvaa paikkamerkki:
#
# Korvaa paikkamerkki .env-tiedostossasi.

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Selitys:
# BookingPlugin-luokka tarjoaa menetelmiä hotellien ja lentojen varaamiseen Serpapi.com Google Search API:n avulla. Se rakentaa tarvittavat parametrit, lähettää API-pyynnöt ja käsittelee vastaukset palauttaakseen asiaankuuluvaa varausinformaatiota. API-avain (SERPAPI_SEARCH_API_KEY) ja päätepiste (SERPAPI_SEARCH_ENDPOINT) käytetään todennukseen ja pyyntöjen lähettämiseen Google Search API:lle.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Selitys:
# SavePlugin-luokka tarjoaa saving_plan-metodin, jolla voi tallentaa matkasunnitelmia käyttämällä Azure AI -palveluita. Se määrittää Azure-tunnistetiedot, luo AI-agentin, käsittelee käyttäjän syötteitä matkasunnitelman sisällön luomiseksi ja tallentamiseksi sekä hoitaa tiedoston tallennuksen ja siivouksen. Metodi palauttaa "Saved" onnistuneen suorituksen jälkeen.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # Selitys:
# Tämä koodi määrittää Azure AI -agentit käsittelemään lentojen ja hotellien varaamista sekä matkasunnitelmien tallentamista käyttäjän syötteiden perusteella. Se käyttää Azure-tunnistetietoja agenttien luomiseen ja konfigurointiin, käsittelee käyttäjien syötteitä ryhmäkeskustelun kautta ja varmistaa asianmukaisen siivouksen tehtävien päätyttyä. Agentit käyttävät tiettyjä laajennuksia (BookingPlugin ja SavePlugin) suorittaakseen omat tehtävänsä.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, on hyvä tiedostaa, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäistä asiakirjaa sen alkuperäisellä kielellä tulee pitää virallisena lähteenä. Tärkeissä asioissa suosittelemme ammattimaista ihmiskäännöstä. Emme vastaa mahdollisista väärinymmärryksistä tai virhetulkinnoista, jotka johtuvat tämän käännöksen käytöstä.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
