# %% [markdown]
# # Expérience: TITLE
#
# Objectif:
# - Indiquez la question à laquelle vous voulez répondre.
# - Définissez les critères de réussite.

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## Plan
#
# - Hypothèse:
# - Variables à balayer:
# - Métriques à enregistrer:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## Résultats
#
# - Observations clés:
# - Surprises ou modes de défaillance:
# - Décision: continuer, pivoter, ou arrêter:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## Prochaines étapes
#
# - Ce qu'il faut essayer ensuite:
# - Ce qu'il faut documenter ailleurs (PRD, notes, issue):

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Avis de non-responsabilité :
# Ce document a été traduit à l'aide du service de traduction automatique par IA Co-op Translator (https://github.com/Azure/co-op-translator). Bien que nous nous efforcions d'assurer l'exactitude, veuillez noter que les traductions automatisées peuvent contenir des erreurs ou des inexactitudes. Le document original, dans sa langue d'origine, doit être considéré comme la source faisant foi. Pour les informations critiques, il est recommandé de recourir à une traduction professionnelle réalisée par un traducteur humain. Nous ne sommes pas responsables des malentendus ou des interprétations erronées résultant de l'utilisation de cette traduction.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
