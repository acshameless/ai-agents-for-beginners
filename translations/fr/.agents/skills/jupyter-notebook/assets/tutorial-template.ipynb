# %% [markdown]
# # Tutoriel: TITRE
#
# Audience:
# - Décrivez à qui cela s'adresse.
#
# Prérequis:
# - Énumérez les concepts requis ou la configuration.
#
# Objectifs d'apprentissage:
# - À la fin, le lecteur pourra...

# %% [markdown]
# ## Plan
#
# 1. Configuration
# 2. Un exemple minimal fonctionnel
# 3. Variantes et pièges
# 4. Exercices

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Étape 1 - Commencez par un petit exemple
#
# Expliquez en termes simples ce que fait la cellule suivante.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Exercices
#
# - Essayez une entrée différente.
# - Prédisez la sortie avant d'exécuter le code.
# - Notez une erreur courante et comment la corriger.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Clause de non-responsabilité** :
# Ce document a été traduit à l'aide du service de traduction par IA [Co-op Translator](https://github.com/Azure/co-op-translator). Bien que nous nous efforcions d'assurer l'exactitude, veuillez noter que les traductions automatisées peuvent contenir des erreurs ou des inexactitudes. Le document original dans sa langue d'origine doit être considéré comme la source faisant autorité. Pour les informations critiques, il est recommandé de faire appel à un traducteur professionnel. Nous déclinons toute responsabilité en cas de malentendus ou d'interprétations erronées résultant de l'utilisation de cette traduction.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
