# %% [markdown]
# # מדריך: TITLE
#
# קהל יעד:
# - תאר למי זה מיועד.
#
# דרישות מוקדמות:
# - פרט את המושגים או ההגדרות הנדרשים.
#
# מטרות למידה:
# - בסיום, הקורא יוכל...

# %% [markdown]
# ## מתווה
#
# 1. התקנה
# 2. דוגמה מינימלית שעובדת
# 3. שינויים וטעויות נפוצות
# 4. תרגילים

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## שלב 1 - התחילו עם דוגמה קטנה
#
# הסבירו מה התא הבא עושה בשפה פשוטה.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## תרגילים
#
# - נסה קלט שונה.
# - חזה את הפלט לפני הרצת הקוד.
# - ציין טעות נפוצה אחת וכיצד לתקן אותה.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# הצהרת אי-אחריות:
# מסמך זה תורגם באמצעות שירות תרגום מבוסס בינה מלאכותית [Co-op Translator](https://github.com/Azure/co-op-translator). אף שאנו שואפים לדיוק, יש להביא בחשבון כי תרגומים אוטומטיים עלולים להכיל שגיאות או אי-דיוקים. יש לראות במסמך המקורי בשפתו המקורית כמקור הסמכות. עבור מידע חיוני/קריטי מומלץ תרגום מקצועי על ידי מתרגם אנושי. איננו אחראים לכל אי-הבנות או לפרשנויות שגויות הנובעות משימוש בתרגום זה.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
