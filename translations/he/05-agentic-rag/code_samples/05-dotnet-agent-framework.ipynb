# %% [markdown]
# # 🔍 RAG ארגוני עם Microsoft Foundry (.NET)
#
# ## 📋 יעדי הלמידה
#
# מחברת זו ממחישה כיצד לבנות מערכות Retrieval-Augmented Generation (RAG) ברמת ארגון באמצעות Microsoft Agent Framework ב-.NET עם Microsoft Foundry. תלמדו כיצד ליצור סוכנים מוכנים לייצור היכולים לחפש בתוך מסמכים ולספק תשובות מדויקות, מודעות להקשר, עם אבטחה וסקלאביליות ארגוניות.
#
# **יכולות RAG ארגוניות שתבנו:**
# - 📚 **אינטליגנציה למסמכים**: עיבוד מסמכים מתקדם עם שירותי Azure AI
# - 🔍 **חיפוש סמנטי**: חיפוש וקטורי ביצועי גבוה עם תכונות ארגוניות
# - 🛡️ **שילוב אבטחה**: דפוסי גישה מבוססי תפקידים והגנה על נתונים
# - 🏢 **ארכיטקטורה סקלאבילית**: מערכות RAG מוכנות לייצור עם ניטור
#
# ## 🎯 ארכיטקטורת RAG ארגונית
#
# ### רכיבים ארגוניים מרכזיים
# - **Microsoft Foundry**: פלטפורמת AI מנוהלת לארגון עם אבטחה ועמידה בתקנות
# - **Persistent Agents**: סוכנים בעלי מצב עם היסטוריית שיחה וניהול הקשר
# - **Vector Store Management**: אינדקסציה ושליפה של מסמכים ברמת ארגון
# - **Identity Integration**: אימות Azure AD ובקרת גישה מבוססת תפקידים
#
# ### יתרונות .NET לארגון
# - **Type Safety**: אימות בזמן הקומפילציה עבור פעולות RAG ומבני נתונים
# - **Async Performance**: עיבוד מסמכים וחיפושים לא חוסמים
# - **Memory Management**: שימוש יעיל במשאבים לאוסף מסמכים גדול
# - **Integration Patterns**: אינטגרציה מקומית לשירותי Azure עם הזרקת תלויות
#
# ## 🏗️ ארכיטקטורה טכנית
#
# ### צינור RAG ארגוני
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Core .NET Components
# - **Azure.AI.Agents.Persistent**: ניהול סוכנים ארגוני עם שמירת מצב
# - **Azure.Identity**: אימות משולב לגישה בטוחה לשירותי Azure
# - **Microsoft.Agents.AI.AzureAI**: מימוש מסגרות סוכנים מותאמות ל-Azure
# - **System.Linq.Async**: פעולות LINQ אסינכרוניות בעלות ביצועים גבוהים
#
# ## 🔧 תכונות ויתרונות ארגוניים
#
# ### אבטחה ועמידה בתקנות
# - **Azure AD Integration**: ניהול זהויות ואימות ארגוני
# - **Role-Based Access**: הרשאות עדינות לגישה ולפעולות על מסמכים
# - **Data Protection**: הצפנה במנוחה ובמהלך העברה עבור מסמכים רגישים
# - **Audit Logging**: מעקב פעילות מקיף לדרישות עמידה בתקנות
#
# ### ביצועים וסקלאביליות
# - **Connection Pooling**: ניהול חיבורי שירותי Azure בצורה יעילה
# - **Async Processing**: פעולות לא חוסמות לתרחישי תפוקה גבוהה
# - **Caching Strategies**: מטמון חכם למסמכים הנגישים תדיר
# - **Load Balancing**: עיבוד מבוזר לפריסות בקנה מידה גדול
#
# ### ניהול וניטור
# - **Health Checks**: ניטור מובנה לרכיבי מערכת RAG
# - **Performance Metrics**: אנליטיקה מפורטת על איכות החיפוש וזמני תגובה
# - **Error Handling**: ניהול חריגות מקיף עם מדיניות ניסיון חוזר
# - **Configuration Management**: הגדרות מותאמות לסביבות עם אימות
#
# ## ⚙️ דרישות מוקדמות והגדרה
#
# **סביבת פיתוח:**
# - .NET 9.0 SDK or higher
# - Visual Studio 2022 or VS Code with C# extension
# - מנוי Azure עם גישה ל-AI Foundry
#
# **חבילות NuGet דרושות:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **הגדרת אימות Azure:**
# ```bash
# # התקן את ה-Azure CLI והתחבר
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **הגדרת סביבה (קובץ .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 דפוסי RAG ארגוניים
#
# ### דפוסי ניהול מסמכים
# - **Bulk Upload**: עיבוד יעיל של אוספי מסמכים גדולים
# - **Incremental Updates**: הוספה ושינוי מסמכים בזמן אמת
# - **Version Control**: גרסאות מסמכים ומעקב שינויים
# - **Metadata Management**: מאפייני מסמך עשירים וטקסונומיה
#
# ### דפוסי חיפוש ושליפה
# - **Hybrid Search**: שילוב חיפוש סמנטי וחיפוש מילות מפתח לתוצאות מיטביות
# - **Faceted Search**: סינון וריבוי מימדים וקטלוג
# - **Relevance Tuning**: אלגוריתמי דירוג מותאמים לצרכים דומייניים
# - **Result Ranking**: דירוג מתקדם עם אינטגרציה של לוגיקת עסק
#
# ### דפוסי אבטחה
# - **Document-Level Security**: בקרת גישה עדינה לכל מסמך
# - **Data Classification**: תיוג רגישות אוטומטי והגנה
# - **Audit Trails**: יומנים מקיפים של כל פעולות RAG
# - **Privacy Protection**: זיהוי והסתרת PII
#
# ## 🔒 תכונות אבטחה ארגוניות
#
# ### Authentication & Authorization
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### הגנת נתונים
# - **Encryption**: הצפנה מקצה לקצה למסמכים ואינדקסי חיפוש
# - **Access Controls**: אינטגרציה עם Azure AD להרשאות משתמשים וקבוצות
# - **Data Residency**: בקרות על מיקום גאוגרפי של נתונים לצורכי עמידה בתקנות
# - **Backup & Recovery**: גיבוי אוטומטי ויכולות שיקום מאסונות
#
# ## 📈 אופטימיזציה לביצועים
#
# ### דפוסי עיבוד אסינכרוני
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### ניהול זיכרון
# - **Streaming Processing**: טיפול במסמכים גדולים ללא בעיות זיכרון
# - **Resource Pooling**: שימוש יעיל חוזר במשאבים יקרים
# - **Garbage Collection**: דפוסי הקצאת זיכרון מותאמים
# - **Connection Management**: מחזור חיי חיבור נכון לשירותי Azure
#
# ### אסטרטגיות מטמון
# - **Query Caching**: מטמון לשאילתות שנרצתות בתדירות
# - **Document Caching**: מטמון בזיכרון למסמכים חמים
# - **Index Caching**: מטמון אינדקס וקטורי אופטימיזציה
# - **Result Caching**: מטמון חכם של התגובות המופקות
#
# ## 📊 מקרים שימושיים ארגוניים
#
# ### ניהול ידע
# - **Corporate Wiki**: חיפוש אינטליגנטי בבסיסי ידע של החברה
# - **Policy & Procedures**: הדרכה אוטומטית לציות ולהלכים פרוצדורליים
# - **Training Materials**: סיוע חכם בלמידה ופיתוח מקצועי
# - **Research Databases**: מערכות ניתוח מאמרים ופרסומים אקדמיים
#
# ### תמיכת לקוחות
# - **Support Knowledge Base**: תגובות שירות לקוחות אוטומטיות
# - **Product Documentation**: שליפה אינטליגנטית של מידע מוצר
# - **Troubleshooting Guides**: סיוע בהפעלת פתרונות מותאמים להקשר
# - **FAQ Systems**: יצירת שאלות ותשובות דינמית מאוספי מסמכים
#
# ### עמידה ברגולציה
# - **Legal Document Analysis**: אינטיליגנציה על חוזים ומסמכים משפטיים
# - **Compliance Monitoring**: בדיקות ציות רגולטוריות אוטומטיות
# - **Risk Assessment**: ניתוח ודיווח סיכונים מבוססי מסמכים
# - **Audit Support**: גילו מסמכים חכמים לתמיכה בביקורות
#
# ## 🚀 פריסה לייצור
#
# ### ניטור ותצפית
# - **Application Insights**: טלמטריה מפורטת וניטור ביצועים
# - **Custom Metrics**: מעקב והתראה על KPI ספציפיים לעסק
# - **Distributed Tracing**: מעקב בקשת קצה לקצה דרך שירותים
# - **Health Dashboards**: ויזואליזציית בריאות המערכת וביצועים בזמן אמת
#
# ### סקלאביליות ואמינות
# - **Auto-Scaling**: מדרג אוטומטי לפי עומס ומדדי ביצועים
# - **High Availability**: פריסה רב-אזורית עם יכולות failover
# - **Load Testing**: אימות ביצועים תחת עומס ארגוני
# - **Disaster Recovery**: נהלי גיבוי ושיקום אוטומטיים
#
# מוכנים לבנות מערכות RAG ארגוניות היכולות לטפל במסמכים רגישים בקנה מידה? בואו נבנה מערכות ידע חכמות לארגון! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# כתב ויתור:
# מסמך זה תורגם באמצעות שירות תרגום מבוסס בינה מלאכותית Co-op Translator (https://github.com/Azure/co-op-translator). אף שאנו שואפים לדיוק, יש לשים לב כי תרגומים אוטומטיים עלולים להכיל שגיאות או אי-דיוקים. יש להתייחס למסמך המקורי בשפתו כמקור הסמכות. למידע קריטי מומלץ לקבל תרגום מקצועי על ידי מתרגм/ת אנושי/ת. איננו אחראים לכל אי-הבנות או פרשנויות שגויות הנובעות משימוש בתרגום זה.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
