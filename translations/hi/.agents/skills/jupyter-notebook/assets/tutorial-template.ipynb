# %% [markdown]
# # ट्यूटोरियल: TITLE
#
# दर्शक:
# - बताएं कि यह किसके लिए है।
#
# पूर्वापेक्षाएँ:
# - आवश्यक अवधारणाओं या सेटअप की सूची दें।
#
# सीखने के लक्ष्य:
# - अंत तक, पाठक यह कर सकेंगे...

# %% [markdown]
# ## रूपरेखा
#
# 1. सेटअप
# 2. एक न्यूनतम कार्यशील उदाहरण
# 3. विविधताएँ और जाल
# 4. अभ्यास

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## चरण 1 - एक छोटा सा उदाहरण के साथ शुरू करें
#
# स्पष्ट भाषा में बताएं कि अगला सेल क्या करता है।

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## अभ्यास
#
# - एक अलग इनपुट आज़माएं।
# - कोड चलाने से पहले आउटपुट की भविष्यवाणी करें।
# - एक सामान्य गलती और उसे कैसे ठीक करें, नोट करें।

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# अस्वीकरण:
# यह दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके अनुवादित किया गया है। जबकि हम सटीकता के लिए प्रयास करते हैं, कृपया ध्यान दें कि स्वचालित अनुवादों में त्रुटियाँ या असंगतियाँ हो सकती हैं। मूल दस्तावेज़ उसकी मूल भाषा में प्रामाणिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए पेशेवर मानव अनुवाद की सिफारिश की जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफहमी या भ्रामक व्याख्या के लिए हम जिम्मेदार नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
