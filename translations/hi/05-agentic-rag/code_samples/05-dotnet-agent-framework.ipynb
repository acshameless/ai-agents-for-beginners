# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) के साथ एंटरप्राइज़ RAG
#
# ## 📋 सीखने के उद्देश्य
#
# यह नोटबुक दिखाती है कि Microsoft Foundry के साथ .NET में Microsoft Agent Framework का उपयोग करके एंटरप्राइज़-ग्रेड Retrieval-Augmented Generation (RAG) सिस्टम कैसे बनाये जाते हैं। आप ऐसे प्रोडक्शन-रेडी एजेंट बनाना सीखेंगे जो दस्तावेज़ों में खोज कर सकें और एंटरप्राइज़ सुरक्षा और स्केलेबिलिटी के साथ सटीक, संदर्भ-जानकारी वाले उत्तर प्रदान करें।
#
# **आप जो एंटरप्राइज़ RAG क्षमताएँ बनाएंगे:**
# - 📚 **Document Intelligence**: Azure AI services के साथ उन्नत दस्तावेज़ प्रसंस्करण
# - 🔍 **Semantic Search**: एंटरप्राइज़ फ़ीचर के साथ उच्च-प्रदर्शन वेक्टर खोज
# - 🛡️ **Security Integration**: रोल-आधारित एक्सेस और डेटा सुरक्षा पैटर्न
# - 🏢 **Scalable Architecture**: मॉनिटरिंग के साथ प्रोडक्शन-रेडी RAG सिस्टम
#
# ## 🎯 एंटरप्राइज़ RAG आर्किटेक्चर
#
# ### मुख्य एंटरप्राइज़ घटक
# - **Microsoft Foundry**: सुरक्षा और अनुपालन के साथ प्रबंधित एंटरप्राइज़ AI प्लेटफ़ॉर्म
# - **Persistent Agents**: वार्तालाप इतिहास और संदर्भ प्रबंधन के साथ स्थिति बनाए रखने वाले एजेंट
# - **Vector Store Management**: एंटरप्राइज़-ग्रेड दस्तावेज़ इंडेक्सिंग और पुनर्प्राप्ति
# - **Identity Integration**: Azure AD प्रमाणीकरण और रोल-आधारित एक्सेस नियंत्रण
#
# ### .NET एंटरप्राइज़ लाभ
# - **Type Safety**: RAG ऑपरेशंस और डेटा संरचनाओं के लिए कंपाइल-टाइम सत्यापन
# - **Async Performance**: नॉन-ब्लॉकिंग दस्तावेज़ प्रसंस्करण और खोज ऑपरेशंस
# - **Memory Management**: बड़े दस्तावेज़ संग्रहों के लिए कुशल संसाधन उपयोग
# - **Integration Patterns**: डिपेंडेंसी इंजेक्शन के साथ नेटिव Azure सर्विस इंटीग्रेशन
#
# ## 🏗️ तकनीकी आर्किटेक्चर
#
# ### एंटरप्राइज़ RAG पाइपलाइन
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### मुख्य .NET घटक
# - **Azure.AI.Agents.Persistent**: स्थिति स्थायित्व के साथ एंटरप्राइज़ एजेंट प्रबंधन
# - **Azure.Identity**: सुरक्षित Azure सेवा पहुँच के लिए एकीकृत प्रमाणीकरण
# - **Microsoft.Agents.AI.AzureAI**: Azure-ऑप्टिमाइज़्ड एजेंट फ्रेमवर्क इम्प्लीमेंटेशन
# - **System.Linq.Async**: उच्च-प्रदर्शन असिंक्रोनस LINQ ऑपरेशंस
#
# ## 🔧 एंटरप्राइज़ फ़ीचर और लाभ
#
# ### सुरक्षा और अनुपालन
# - **Azure AD Integration**: एंटरप्राइज़ पहचान प्रबंधन और प्रमाणीकरण
# - **Role-Based Access**: दस्तावेज़ पहुँच और ऑपरेशनों के लिए सूक्ष्म-ग्रेन्युल अनुमतियाँ
# - **Data Protection**: संवेदनशील दस्तावेज़ों के लिए रेस्ट और इन-ट्रांज़िट में एन्क्रिप्शन
# - **Audit Logging**: अनुपालन आवश्यकताओं के लिए व्यापक गतिविधि ट्रैकिंग
#
# ### प्रदर्शन और स्केलेबिलिटी
# - **Connection Pooling**: कुशल Azure सेवा कनेक्शन प्रबंधन
# - **Async Processing**: उच्च-थ्रूपुट परिदृश्यों के लिए नॉन-ब्लॉकिंग ऑपरेशंस
# - **Caching Strategies**: बार-बार एक्सेस किए जाने वाले दस्तावेज़ों के लिए इंटेलिजेंट कैशिंग
# - **Load Balancing**: बड़े पैमाने के तैनाती के लिए वितरित प्रसंस्करण
#
# ### प्रबंधन और मॉनिटरिंग
# - **Health Checks**: RAG सिस्टम घटकों के लिए बिल्ट-इन मॉनिटरिंग
# - **Performance Metrics**: खोज गुणवत्ता और प्रतिक्रिया समय पर विस्तृत एनालिटिक्स
# - **Error Handling**: रिट्राय नीतियों के साथ व्यापक अपवाद प्रबंधन
# - **Configuration Management**: पर्यावरण-विशिष्ट सेटिंग्स के साथ सत्यापन
#
# ## ⚙️ आवश्यकताएँ और सेटअप
#
# **डेवलपमेंट वातावरण:**
# - .NET 9.0 SDK या अधिक
# - Visual Studio 2022 या VS Code में C# एक्सटेंशन
# - AI Foundry एक्सेस के साथ Azure सब्सक्रिप्शन
#
# **आवश्यक NuGet पैकेज:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure प्रमाणीकरण सेटअप:**
# ```bash
# # Azure CLI इंस्टॉल करें और प्रमाणीकृत करें
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **पर्यावरण कॉन्फ़िगरेशन (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 एंटरप्राइज़ RAG पैटर्न
#
# ### दस्तावेज़ प्रबंधन पैटर्न
# - **Bulk Upload**: बड़े दस्तावेज़ संग्रहों का कुशल प्रसंस्करण
# - **Incremental Updates**: रियल-टाइम दस्तावेज़ जोड़ और संशोधन
# - **Version Control**: दस्तावेज़ वर्ज़निंग और परिवर्तन ट्रैकिंग
# - **Metadata Management**: समृद्ध दस्तावेज़ गुण और टैक्सोनॉमी
#
# ### खोज और पुनर्प्राप्ति पैटर्न
# - **Hybrid Search**: सर्वोत्तम परिणामों के लिए सिमेंटिक और कीवर्ड खोज का संयोजन
# - **Faceted Search**: मल्टी-डायमेंशनल फ़िल्टरिंग और वर्गीकरण
# - **Relevance Tuning**: डोमेन-विशिष्ट आवश्यकताओं के लिए कस्टम स्कोरिंग एल्गोरिदम
# - **Result Ranking**: व्यवसायिक लॉजिक इंटीग्रेशन के साथ उन्नत रैंकिंग
#
# ### सुरक्षा पैटर्न
# - **Document-Level Security**: प्रति दस्तावेज़ सूक्ष्म-ग्रेन्युल एक्सेस नियंत्रण
# - **Data Classification**: स्वचालित संवेदनशीलता लेबलिंग और सुरक्षा
# - **Audit Trails**: सभी RAG संचालन का व्यापक लॉगिंग
# - **Privacy Protection**: PII पहचान और रिडैक्शन क्षमताएँ
#
# ## 🔒 एंटरप्राइज़ सुरक्षा फ़ीचर
#
# ### प्रमाणीकरण और प्राधिकरण
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### डेटा सुरक्षा
# - **Encryption**: दस्तावेज़ों और खोज सूचकांकों के लिए एंड-टू-एंड एन्क्रिप्शन
# - **Access Controls**: उपयोगकर्ता और समूह अनुमतियों के लिए Azure AD के साथ इंटीग्रेशन
# - **Data Residency**: अनुपालन के लिए भौगोलिक डेटा स्थान नियंत्रण
# - **Backup & Recovery**: स्वचालित बैकअप और डिजास्टर रिकवरी क्षमताएँ
#
# ## 📈 प्रदर्शन अनुकूलन
#
# ### असिंक्रोनस प्रसंस्करण पैटर्न
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### मेमोरी प्रबंधन
# - **Streaming Processing**: बड़े दस्तावेज़ों को मेमोरी समस्याओं के बिना संसाधित करें
# - **Resource Pooling**: महँगे संसाधनों का कुशल पुन:उपयोग
# - **Garbage Collection**: अनुकूलित मेमोरी आवंटन पैटर्न
# - **Connection Management**: उचित Azure सेवा कनेक्शन लाइफसाइकिल
#
# ### कैशिंग रणनीतियाँ
# - **Query Caching**: बार-बार निष्पादित खोजों के लिए कैश
# - **Document Caching**: हॉट दस्तावेज़ों के लिए इन-मेमरी कैशिंग
# - **Index Caching**: अनुकूलित वेक्टर इंडेक्स कैशिंग
# - **Result Caching**: जनरेट किए गए उत्तरों की इंटेलिजेंट कैशिंग
#
# ## 📊 एंटरप्राइज़ उपयोग के मामले
#
# ### ज्ञान प्रबंधन
# - **Corporate Wiki**: कंपनी के ज्ञान बेस में इंटेलिजेंट खोज
# - **Policy & Procedures**: स्वचालित अनुपालन और प्रक्रिया मार्गदर्शन
# - **Training Materials**: इंटेलिजेंट लर्निंग और विकास सहायता
# - **Research Databases**: एकेडेमिक और शोध पत्र विश्लेषण सिस्टम
#
# ### ग्राहक समर्थन
# - **Support Knowledge Base**: स्वचालित ग्राहक सेवा उत्तर
# - **Product Documentation**: इंटेलिजेंट उत्पाद जानकारी पुनर्प्राप्ति
# - **Troubleshooting Guides**: संदर्भात्मक समस्या-समाधान सहायता
# - **FAQ Systems**: दस्तावेज़ संग्रहों से डायनामिक FAQ जनरेशन
#
# ### नियामक अनुपालन
# - **Legal Document Analysis**: कॉन्ट्रैक्ट और कानूनी दस्तावेज़ों की इंटेलिजेंस
# - **Compliance Monitoring**: स्वचालित नियामक अनुपालन जांच
# - **Risk Assessment**: दस्तावेज़-आधारित जोखिम विश्लेषण और रिपोर्टिंग
# - **Audit Support**: ऑडिट के लिए इंटेलिजेंट दस्तावेज़ खोज
#
# ## 🚀 प्रोडक्शन तैनाती
#
# ### मॉनिटरिंग और ऑब्ज़र्वेबिलिटी
# - **Application Insights**: विस्तृत टेलीमेट्री और प्रदर्शन मॉनिटरिंग
# - **Custom Metrics**: व्यवसाय-विशिष्ट KPI ट्रैकिंग और अलर्टिंग
# - **Distributed Tracing**: सेवाओं के पार एंड-टू-एंड अनुरोध ट्रैकिंग
# - **Health Dashboards**: रीयल-टाइम सिस्टम स्वास्थ्य और प्रदर्शन विज़ुअलाइज़ेशन
#
# ### स्केलेबिलिटी और विश्वसनीयता
# - **Auto-Scaling**: लोड और प्रदर्शन मीट्रिक्स के आधार पर स्वत: स्केलिंग
# - **High Availability**: फेलओवर क्षमताओं के साथ मल्टी-रीजन तैनाती
# - **Load Testing**: एंटरप्राइज़ लोड स्थितियों के तहत प्रदर्शन सत्यापन
# - **Disaster Recovery**: स्वचालित बैकअप और रिकवरी प्रक्रियाएँ
#
# क्या आप बड़े पैमाने पर संवेदनशील दस्तावेज़ों को संभालने में सक्षम एंटरप्राइज़-ग्रेड RAG सिस्टम बनाना तैयार हैं? आइए एंटरप्राइज़ के लिए बुद्धिमान ज्ञान सिस्टम आर्किटेक्ट करें! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# अस्वीकरण:
# यह दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके अनुवादित किया गया है। जबकि हम सटीकता के प्रयास में लगे रहते हैं, कृपया ध्यान रखें कि स्वचालित अनुवादों में त्रुटियाँ या अशुद्धियाँ हो सकती हैं। मूल दस्तावेज़ उसकी मूल भाषा में प्रामाणिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए पेशेवर मानव अनुवाद की सलाह दी जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफ़हमी या गलत व्याख्या के लिए हम उत्तरदायी नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
