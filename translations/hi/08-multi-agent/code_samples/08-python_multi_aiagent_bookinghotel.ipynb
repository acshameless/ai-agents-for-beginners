# %% [markdown]
# ## **नमूने: होटल बुकिंग के लिए मल्टी-एआई एजेंट**
#
# आज की तेजी से बढ़ती दुनिया में, एक व्यापार यात्रा की योजना बनाना सिर्फ उड़ान और होटल का कमरा बुक करने से कहीं अधिक है। इसमें एक ऐसा समन्वय और दक्षता स्तर चाहिए जो प्राप्त करना चुनौतीपूर्ण हो सकता है। यहीं मल्टी-एआई एजेंट्स काम आते हैं, जो हमारी यात्रा आवश्यकताओं को प्रबंधित करने के तरीके में क्रांति ला रहे हैं।
#
# कल्पना करें कि आपके पास बुद्धिमान एजेंटों की एक टीम हो, जो मिलकर आपकी यात्रा के हर पहलू को सटीकता और सहजता के साथ संभालती है। हमारी उन्नत एआई तकनीक के साथ, हमने बुकिंग सेवाओं और यात्रा कार्यक्रम व्यवस्था के लिए विशेषज्ञ एजेंट बनाए हैं, जो एक निर्बाध और तनाव-मुक्त यात्रा अनुभव सुनिश्चित करते हैं।
#
# यह एक बुनियादी परिदृश्य है। जब व्यापार यात्रा की योजना बनाते हैं, तो हमें हवाई टिकट की जानकारी, होटल जानकारी आदि प्राप्त करने के लिए एक व्यापार यात्रा एजेंट से परामर्श करना होता है। एआई एजेंट्स के माध्यम से, हम बुकिंग सेवाओं के लिए एजेंट और यात्रा कार्यक्रम व्यवस्था के लिए एजेंट बना सकते हैं जो सहयोग करें और बुद्धिमत्ता के स्तर को बढ़ाएं।

# %% [markdown]
# # Azure AI एजेंट सेवा प्रारंभ करें और **.env** से कॉन्फ़िगरेशन जानकारी प्राप्त करें
#
# ### **.env**
#
# एक .env फ़ाइल बनाएँ
#
# **.env** में Azure AI एजेंट सेवा का कनेक्शन स्ट्रिंग, AOAI द्वारा उपयोग किया जाने वाला मॉडल, और संबंधित Google API Search सेवा API, ENDPOINT, आदि शामिल होते हैं।
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "आपके Azure AI एजेंट सेवा मॉडल का डिप्लॉइमेंट नाम"
#
# [**NOTE**] आपको 100,000 रेट लिमिट (टोकन्स प्रति मिनट) और 600 रेट लिमिट (रिक्वेस्ट प्रति मिनट) वाले मॉडल की आवश्यकता होगी।
#
#   आप Microsoft Foundry - Model and Endpoint में मॉडल प्राप्त कर सकते हैं।
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "आपके Azure AI एजेंट सेवा प्रोजेक्ट का कनेक्शन स्ट्रिंग"
#
#   आप AI ​​Foundry पोर्टल स्क्रीन में अपने प्रोजेक्ट के अवलोकन में प्रोजेक्ट कनेक्शन स्ट्रिंग प्राप्त कर सकते हैं।
#
# - **SERPAPI_SEARCH_API_KEY** = "आपके SERPAPI सर्च API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "आपका SERPAPI सर्च Endpoint"
#
# Azure AI एजेंट सेवा का मॉडल डिप्लॉयमेंट नाम और प्रोजेक्ट कनेक्शन स्ट्रिंग प्राप्त करने के लिए, आपको Azure AI एजेंट सेवा बनानी होगी। इसे सीधे बनाने के लिए [इस टेम्पलेट](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) का उपयोग करने की सिफारिश की जाती है (***नोट:*** Azure AI एजेंट सेवा वर्तमान में सीमित क्षेत्र में सेट है। क्षेत्र सेट करने के लिए आप [इस लिंक](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) को देखें)
#
# एजेंट को SERPAPI तक पहुंच की आवश्यकता होती है। पंजीकरण के लिए [इस लिंक](https://serpapi.com/searches) का उपयोग करना सुझाव दिया जाता है। पंजीकरण के बाद, आप एक अद्वितीय API KEY और ENDPOINT प्राप्त कर सकते हैं।

# %% [markdown]
# # Azure में लॉगिन करें
#
# अब आपको Azure में लॉगिन करने की आवश्यकता है। VScode में एक टर्मिनल खोलें और `az login` कमांड चलाएं।

# %% [markdown]
# # Setup
#
# इस नोटबुक को चलाने के लिए, आपको निम्नलिखित लाइब्रेरीज़ इंस्टॉल करनी होंगी। यहाँ आवश्यक लाइब्रेरीज़ और उनसे संबंधित pip इंस्टॉल कमांड की सूची दी गई है:
#
# azure-identity: Azure प्रमाणीकरण के लिए।
# requests: HTTP अनुरोध करने के लिए।
# semantic-kernel: सेमांटिक कर्नेल फ्रेमवर्क के लिए (मान लेते हैं कि यह कोई कस्टम या विशिष्ट लाइब्रेरी है, आपको इसे किसी विशेष स्रोत या रिपॉजिटरी से इंस्टॉल करना पड़ सकता है)।

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Explanation:
# import asyncio: यह asyncio मॉड्यूल को आयात करता है, जो Python में गैर-सिंक्रोनस प्रोग्रामिंग के लिए समर्थन प्रदान करता है। यह आपको async और await सिंटैक्स का उपयोग करके सहमति वाली कोड लिखने की अनुमति देता है।
# from typing import Annotated: यह typing मॉड्यूल से Annotated टाइप को आयात करता है। Annotated का उपयोग टाइप संकेतों में मेटाडेटा जोड़ने के लिए किया जाता है, जो विभिन्न उद्देश्यों जैसे सत्यापन, दस्तावेज़ीकरण, या टूलिंग के लिए उपयोगी हो सकता है।

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # व्याख्या:
# from dotenv import load_dotenv और load_dotenv() का उपयोग करके, आप आसानी से .env फ़ाइल में कॉन्फ़िगरेशन सेटिंग्स और संवेदनशील जानकारी (जैसे API कुंजी और डेटाबेस URL) को प्रबंधित कर सकते हैं, उन्हें आपके स्रोत कोड से अलग रख सकते हैं और आपके आवेदन को अधिक सुरक्षित और कॉन्फ़िगर करने में आसान बना सकते हैं।

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # व्याख्या:
#
# इम्पोर्ट स्टेटमेंट: from azure.identity.aio import DefaultAzureCredential: यह azure.identity.aio मॉड्यूल से DefaultAzureCredential क्लास को इम्पोर्ट करता है। मॉड्यूल के नाम में aio का अर्थ है कि यह असिंक्रोनस ऑपरेशन्स के लिए डिज़ाइन किया गया है।
#
# DefaultAzureCredential का उद्देश्य: DefaultAzureCredential क्लास Azure SDK for Python का हिस्सा है। यह Azure सेवाओं के साथ प्रमाणीकृत (authenticate) करने का एक डिफ़ॉल्ट तरीका प्रदान करता है। यह कई तरीकों का उपयोग करके एक विशेष क्रम में प्रमाणीकृत करने का प्रयास करता है, जैसे पर्यावरण चर (environment variables), प्रबंधित पहचान (managed identity), और Azure CLI प्रमाणपत्र।
#
# असिंक्रोनस ऑपरेशन्स: aio मॉड्यूल यह इंगित करता है कि DefaultAzureCredential क्लास असिंक्रोनस ऑपरेशन्स का समर्थन करता है। इसका मतलब है कि आप इसे asyncio के साथ उपयोग कर सकते हैं ताकि नॉन-ब्लॉकिंग प्रमाणिकरण अनुरोध किए जा सकें।

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Explanation:
# semantic_kernel पैकेज से विभिन्न मॉड्यूल और क्लासेस का आयात करता है। यहाँ प्रत्येक आयात का विवरण दिया गया है:
#
# semantic_kernel.agents से AgentGroupChat: यह क्लास AI एजेंट्स के लिए समूह चैट से संबंधित कार्यक्षमताओं को संभालती है। semantic_kernel.agents.azure_ai से AzureAIAgent और AzureAIAgentSettings
#
# AzureAIAgent: यह क्लास Azure AI सेवाओं का उपयोग करने वाले AI एजेंट्स को बनाने और प्रबंधित करने के लिए उपयोग की जाती है।
#
# AzureAIAgentSettings: यह क्लास AzureAIAgent के लिए सेटिंग्स को कॉन्फ़िगर करने के लिए उपयोग की जाती है। semantic_kernel.agents.strategies.termination.termination_strategy से TerminationStrategy:
#
# यह क्लास AI एजेंट्स के निष्पादन को कुछ शर्तों में समाप्त करने के लिए रणनीतियों को परिभाषित करती है। semantic_kernel.contents.chat_message_content से ChatMessageContent:
#
# यह क्लास चैट संदेशों की सामग्री को संभालने के लिए उपयोग की जाती है। semantic_kernel.contents.utils.author_role से AuthorRole:
#
# यह क्लास चैट संदेशों के संदर्भ में लेखकों के विभिन्न भूमिकाओं को परिभाषित करती है।
#
# semantic_kernel.functions.kernel_function_decorator से kernel_function: यह डेकोरेटर कर्नेल फ़ंक्शंस को परिभाषित करने के लिए उपयोग किया जाता है, जो ऐसे फ़ंक्शंस होते हैं जिन्हें semantic kernel फ्रेमवर्क के भीतर निष्पादित किया जा सकता है।
# ये आयात आवश्यक घटकों को सेट करते हैं ताकि AI एजेंट्स को बनाया और प्रबंधित किया जा सके जो समूह चैट वातावरण में बातचीत कर सकें, संभवतः होटल बुकिंग या इसी तरह की गतिविधियों जैसे कार्यों के लिए।

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Explanation:
# Next we import the CodeInterpreterTool class from the azure.ai.projects.models module.
#
# CodeInterpreterTool: यह क्लास Azure AI SDK का हिस्सा है और AI प्रोजेक्ट्स के संदर्भ में कोड की व्याख्या और निष्पादन के लिए उपयोग की जाती है। यह कोड स्निपेट्स चलाने, कोड का विश्लेषण करने, या AI वर्कफ़्लोज़ के भीतर कोड निष्पादन को एकीकृत करने की कार्यक्षमताएँ प्रदान करती है।
# यह आयात आपके प्रोजेक्ट में CodeInterpreterTool का उपयोग करने के लिए आवश्यक घटक सेट करता है, जो गतिशील रूप से कोड की व्याख्या और निष्पादित करने वाले कार्यों के लिए उपयोगी हो सकता है।

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Explanation:
# ApprovalTerminationStrategy क्लास AI एजेंट के संचालन को समाप्त करने के लिए एक विशिष्ट रणनीति प्रदान करता है। एजेंट तब समाप्त हो जाएगा जब उसके इंटरैक्शन इतिहास में अंतिम संदेश में "saved" शब्द होगा। यह उन परिदृश्यों में उपयोगी हो सकता है जहां एजेंट का कार्य पूरा माना जाता है जब उसे यह पुष्टिकरण प्राप्त होता है कि कुछ "saved" हो गया है।इंटरैक्शन विधि को परिभाषित करें। आरक्षण योजना सहेजने के बाद, इसे saved सिग्नल प्राप्त होने पर रोका जा सकता है।

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # व्याख्या:
#
# यह कोड लाइन create() मेथड को कॉल करके AzureAIAgentSettings ऑब्जेक्ट को डिफ़ॉल्ट या पूर्वनिर्धारित सेटिंग्स के साथ इनिशियलाइज़ करती है। यह सेटिंग्स ऑब्जेक्ट (ai_agent_settings) तब AzureAIAgent उदाहरण को कॉन्फ़िगर और प्रबंधित करने के लिए उपयोग किया जा सकता है।

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # व्याख्या:
# requests लाइब्रेरी को इम्पोर्ट करके, आप आसानी से HTTP अनुरोध कर सकते हैं और अपने Python कोड में वेब सेवाओं के साथ इंटरैक्ट कर सकते हैं।

# %%
import requests

# %% [markdown]
# # Explanation:
# यह एक वेरिएबल है जो SERP (Search Engine Results Page) API सेवा तक पहुँचने के लिए API कुंजी संग्रहीत करता है। एक API कुंजी एक अद्वितीय पहचानकर्ता है जिसका उपयोग आपके खाते से जुड़े अनुरोधों को प्रमाणित करने के लिए किया जाता है।
#
# 'GOOGLE_SEARCH_API_KEY': यह एक प्लेसहोल्डर स्ट्रिंग है। आपको ''GOOGLE_SEARCH_API_KEY' को अपने वास्तविक SERP API कुंजी से बदलना होगा।
#
# उद्देश्य: इस लाइन का उद्देश्य API कुंजी को एक वेरिएबल में संग्रहीत करना है ताकि इसका उपयोग SERP API सेवा के लिए अनुरोधों को प्रमाणित करने के लिए किया जा सके। सेवा तक पहुँचने और खोजें करने के लिए API कुंजी आवश्यक है।
#
# SERP API कुंजी कैसे प्राप्त करें: SERP API कुंजी प्राप्त करने के लिए, https://serpapi.com पर ये सामान्य चरणों का पालन करें (विशिष्ट SERP API सेवा के आधार पर सटीक चरण भिन्न हो सकते हैं):
#
# SERP API सेवा चुनें: कई SERP API सेवाएं उपलब्ध हैं, जैसे SerpAPI, Google Custom Search JSON API, और अन्य। अपनी आवश्यकताओं के अनुसार सबसे उपयुक्त सेवा चुनें।
#
# खाते के लिए साइन अप करें:
#
# चुनी हुई SERP API सेवा की वेबसाइट https://www.serpapi.com पर जाएं और एक खाता बनाएं। आपको कुछ मूल जानकारी प्रदान करनी पड़ सकती है और अपना ईमेल पता सत्यापित करना पड़ सकता है।
#
# API कुंजी बनाएं:
#
# साइन अप करने के बाद, अपने खाते में लॉग इन करें और API सेक्शन या डैशबोर्ड पर जाएं। नई API कुंजी बनाने या उत्पन्न करने का विकल्प खोजें।
# API कुंजी कॉपी करें:
#
# API कुंजी जनरेट होने के बाद, उसे कॉपी करें। इस कुंजी का उपयोग आपके अनुरोधों को SERP API सेवा के लिए प्रमाणित करने के लिए किया जाएगा।
# प्लेसहोल्डर बदलें:
#
# अपने .env फ़ाइल में प्लेसहोल्डर को बदलें।

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # व्याख्या:
# BookingPlugin क्लास Serpapi.com Google Search API का उपयोग करके होटलों और उड़ानों की बुकिंग के लिए विधियां प्रदान करता है। यह आवश्यक पैरामीटर बनाता है, API अनुरोध भेजता है, और प्रतिक्रिया को संसाधित करता है ताकि संबंधित बुकिंग जानकारी वापस की जा सके। API कुंजी (SERPAPI_SEARCH_API_KEY) और एंडपॉइंट (SERPAPI_SEARCH_ENDPOINT) का उपयोग Google Search API को प्रमाणित करने और अनुरोध भेजने के लिए किया जाता है।

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # व्याख्या:
# SavePlugin क्लास एक मेथड saving_plan प्रदान करता है जो यात्रा योजनाओं को Azure AI सेवाओं का उपयोग करके सहेजता है। यह Azure क्रेडेंशियल्स सेट करता है, एक AI एजेंट बनाता है, उपयोगकर्ता इनपुट को संसाधित करके यात्रा योजना की सामग्री उत्पन्न और सहेजता है, और फ़ाइल सहेजने तथा क्लीनअप ऑपरेशन्स को संभालता है। मेथड सफलतापूर्वक पूरा होने पर "Saved" लौटाता है।

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # व्याख्या:
# यह कोड Azure AI एजेंट्स को सेट करता है ताकि वे उड़ान और होटल की बुकिंग संभाल सकें, और उपयोगकर्ता इनपुट के आधार पर यात्रा योजनाओं को सहेज सकें। यह एजेंट्स बनाने और कॉन्फ़िगर करने के लिए Azure प्रमाणपत्रों का उपयोग करता है, उपयोगकर्ता इनपुट को एक समूह चैट के माध्यम से संसाधित करता है, और कार्य पूरा होने के बाद उचित सफाई सुनिश्चित करता है। एजेंट्स अपने-अपने कार्यों को करने के लिए विशिष्ट प्लगइन्स (BookingPlugin और SavePlugin) का उपयोग करते हैं।

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यह दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके अनूदित किया गया है। जबकि हम सटीकता के लिए प्रयासरत हैं, कृपया ध्यान दें कि स्वचालित अनुवाद में त्रुटियाँ या गलतियाँ हो सकती हैं। मौलिक दस्तावेज़ अपनी मूल भाषा में ही अधिकारिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए, पेशेवर मानव अनुवाद की सलाह दी जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफहमी या गलत व्याख्या के लिए हम उत्तरदायी नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
