# %% [markdown]
# # Vodič: NASLOV
#
# Publika:
# - Opišite za koga je ovo namijenjeno.
#
# Preduvjeti:
# - Nabrojite potrebne koncepte ili postavke.
#
# Ciljevi učenja:
# - Na kraju, čitatelj će moći...

# %% [markdown]
# ## Pregled
#
# 1. Postavljanje
# 2. Minimalan radni primjer
# 3. Varijacije i zamke
# 4. Vježbe

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Korak 1 - Počnite s malim primjerom
#
# Objasnite što sljedeća ćelija radi jednostavnim jezikom.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Vježbe
#
# - Isprobajte drugačiji unos.
# - Predvidite izlaz prije pokretanja koda.
# - Navedite jednu uobičajenu pogrešku i kako je ispraviti.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Izjava o odricanju odgovornosti:
# Ovaj dokument preveden je korištenjem usluge za automatsko prevođenje pomoću umjetne inteligencije [Co-op Translator](https://github.com/Azure/co-op-translator). Iako nastojimo osigurati točnost, imajte na umu da automatski prijevodi mogu sadržavati pogreške ili netočnosti. Izvorni dokument na izvornom jeziku treba smatrati mjerodavnim izvorom. Za kritične informacije preporučuje se profesionalni, ljudski prijevod. Ne snosimo odgovornost za bilo kakve nesporazume ili pogrešne interpretacije koje proizlaze iz korištenja ovog prijevoda.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
