# %% [markdown]
# # Kísérlet: TITLE
#
# Cél:
# - Határozd meg azt a kérdést, amire választ szeretnél kapni.
# - Határozd meg a siker kritériumait.

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## Terv
#
# - Hipotézis:
# - Változók, amelyeken variálunk:
# - Rögzítendő metrikák:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## Eredmények
#
# - Fő megfigyelések:
# - Meglepetések vagy hibamódok:
# - Döntés: folytatás, irányváltás vagy leállás:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## Következő lépések
#
# - Mit próbáljunk ki ezután:
# - Mit dokumentáljunk máshol (PRD, jegyzetek, hibajegy):

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Felelősségkizárás:
# Ez a dokumentum a [Co-op Translator](https://github.com/Azure/co-op-translator) mesterséges intelligencia alapú fordító szolgáltatásával készült. Bár törekszünk a pontosságra, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti dokumentum a saját nyelvén tekintendő irányadónak. Kritikus jelentőségű információk esetén professzionális, emberi fordítást javaslunk. Nem vállalunk felelősséget a fordítás használatából eredő bármilyen félreértésért vagy félreértelmezésért.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
