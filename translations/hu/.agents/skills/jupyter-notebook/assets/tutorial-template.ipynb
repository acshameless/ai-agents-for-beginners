# %% [markdown]
# # Útmutató: TITLE
#
# Célközönség:
# - Írd le, kiknek szól.
#
# Előfeltételek:
# - Sorold fel a szükséges fogalmakat vagy beállításokat.
#
# Tanulási célok:
# - A végére az olvasó képes lesz...

# %% [markdown]
# ## Vázlat
#
# 1. Beállítás
# 2. Egy minimális működő példa
# 3. Változatok és buktatók
# 4. Gyakorlatok

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## 1. lépés - Kezdj egy apró példával
#
# Magyarázd egyszerű, közérthető nyelven, mit csinál a következő cella.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Gyakorlatok
#
# - Próbálj ki egy másik bemenetet.
# - Jósold meg a kimenetet a kód futtatása előtt.
# - Írj le egy gyakori hibát és hogyan javítható.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Felelősségkizárás:
# Ezt a dokumentumot az AI fordítószolgáltatás, a Co-op Translator (https://github.com/Azure/co-op-translator) segítségével fordítottuk. Bár törekszünk a pontosságra, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti nyelvű dokumentum tekintendő mérvadó forrásnak. Kritikus fontosságú információk esetén szakmai, emberi fordítást javaslunk. Nem vállalunk felelősséget a fordítás használatából eredő félreértésekért vagy téves értelmezésekért.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
