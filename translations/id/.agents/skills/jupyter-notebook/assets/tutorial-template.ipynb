# %% [markdown]
# # Tutorial: TITLE
#
# Audiens:
# - Jelaskan untuk siapa ini.
#
# Prasyarat:
# - Cantumkan konsep atau pengaturan yang diperlukan.
#
# Tujuan pembelajaran:
# - Pada akhir, pembaca dapat...

# %% [markdown]
# ## Garis Besar
#
# 1. Penyiapan
# 2. Contoh kerja minimal
# 3. Variasi dan jebakan
# 4. Latihan

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Langkah 1 - Mulai dengan contoh kecil
#
# Jelaskan apa yang dilakukan sel berikutnya dengan bahasa yang sederhana.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Latihan
#
# - Coba input yang berbeda.
# - Prediksi keluaran sebelum menjalankan kode.
# - Catat satu kesalahan umum dan cara memperbaikinya.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Penafian:
# Dokumen ini telah diterjemahkan menggunakan layanan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Meskipun kami berupaya untuk mencapai ketepatan, harap diketahui bahwa terjemahan otomatis dapat mengandung kesalahan atau ketidakakuratan. Dokumen asli dalam bahasa aslinya harus dianggap sebagai sumber yang berwenang. Untuk informasi yang bersifat kritis, disarankan menggunakan terjemahan profesional oleh penerjemah manusia. Kami tidak bertanggung jawab atas kesalahpahaman atau penafsiran yang keliru yang timbul dari penggunaan terjemahan ini.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
