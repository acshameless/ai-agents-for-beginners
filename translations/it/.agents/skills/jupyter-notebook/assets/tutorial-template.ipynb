# %% [markdown]
# # Tutorial: TITLE
#
# Pubblico:
# - Descrivi a chi è rivolto.
#
# Prerequisiti:
# - Elenca i concetti o le impostazioni richiesti.
#
# Obiettivi di apprendimento:
# - Alla fine, il lettore sarà in grado di...

# %% [markdown]
# ## Indice
#
# 1. Configurazione
# 2. Un esempio minimo funzionante
# 3. Variazioni e insidie
# 4. Esercizi

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Passo 1 - Inizia con un piccolo esempio
#
# Spiega in parole semplici cosa fa la cella successiva.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Esercizi
#
# - Prova un input diverso.
# - Predici l'output prima di eseguire il codice.
# - Nota un errore comune e come risolverlo.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Dichiarazione di non responsabilità:
# Questo documento è stato tradotto utilizzando il servizio di traduzione automatica basato su intelligenza artificiale Co-op Translator (https://github.com/Azure/co-op-translator). Pur impegnandoci per garantire l'accuratezza, si prega di notare che le traduzioni automatizzate possono contenere errori o imprecisioni. Il documento originale nella sua lingua madre deve essere considerato la fonte autorevole. Per informazioni critiche si raccomanda una traduzione professionale effettuata da un traduttore umano. Non siamo responsabili per eventuali incomprensioni o interpretazioni errate derivanti dall'uso di questa traduzione.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
