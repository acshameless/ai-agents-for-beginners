# %% [markdown]
# # チュートリアル: TITLE
#
# 対象読者:
# - 誰のためのものかを説明してください。
#
# 前提条件:
# - 必要な概念やセットアップを列挙してください。
#
# 学習目標:
# - 最終的には、読者は...できるようになります。

# %% [markdown]
# ## アウトライン
#
# 1. セットアップ
# 2. 最小限の動作例
# 3. バリエーションと落とし穴
# 4. 演習

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## ステップ 1 - 小さな例から始める
#
# 次のセルが何をするのかを平易な言葉で説明してください。

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## 演習
#
# - 別の入力を試してみてください。
# - コードを実行する前に出力を予測してください。
# - よくある間違いを一つ挙げ、それを修正する方法を説明してください。

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免責事項：
# 本書はAI翻訳サービス「Co-op Translator」(https://github.com/Azure/co-op-translator)を用いて翻訳されました。正確性の確保に努めていますが、自動翻訳には誤りや不正確な表現が含まれる場合があります。原文（原語の文書）を権威ある正本としてご参照ください。重要な情報については、専門の人間による翻訳を推奨します。本翻訳の利用に起因するいかなる誤解や解釈の相違についても、当方は責任を負いかねます。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
