# %% [markdown]
# # 실험: TITLE
#
# 목표:
# - 답하려는 질문을 명시하세요.
# - 성공 기준을 정의하세요.

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## 계획
#
# - 가설:
# - 스윕할 변수:
# - 기록할 지표:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## 결과
#
# - 주요 관찰 사항:
# - 놀라움 또는 실패 모드:
# - 결정: 계속할지, 전환할지, 또는 중단할지:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## 다음 단계
#
# - 다음으로 시도할 것:
# - 다른 곳에 문서화할 항목 (PRD, 노트, 이슈):

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 면책 조항:
# 이 문서는 AI 번역 서비스 [Co-op Translator](https://github.com/Azure/co-op-translator)를 사용하여 번역되었습니다. 정확성을 위해 노력하고 있으나 자동 번역에는 오류나 부정확성이 포함될 수 있음을 유의해 주시기 바랍니다. 중요한 기준은 해당 언어의 원문이며, 원문을 권위 있는 자료로 간주해야 합니다. 중요한 정보의 경우 전문적인 인간 번역을 권장합니다. 본 번역의 사용으로 인해 발생하는 오해나 잘못된 해석에 대해 당사는 책임을 지지 않습니다.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
