# %% [markdown]
# # 튜토리얼: TITLE
#
# 대상:
# - 누구를 위한 것인지 설명하세요.
#
# 사전 요구사항:
# - 필요한 개념 또는 설정을 나열하세요.
#
# 학습 목표:
# - 마지막에는, 독자는 ...할 수 있습니다.

# %% [markdown]
# ## 개요
#
# 1. 설정
# 2. 최소 동작 예제
# 3. 변형 및 주의사항
# 4. 연습 문제

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## 단계 1 - 작은 예제로 시작하기
#
# 다음 셀이 무엇을 하는지 쉬운 말로 설명하세요.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## 연습 문제
#
# - 다른 입력을 시도하세요.
# - 코드를 실행하기 전에 출력 결과를 예측하세요.
# - 흔한 실수 하나와 그것을 고치는 방법을 적으세요.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 면책 고지:
# 이 문서는 AI 번역 서비스 [Co-op Translator](https://github.com/Azure/co-op-translator)를 사용하여 번역되었습니다. 정확성을 위해 노력하고 있으나 자동 번역에는 오류나 부정확성이 포함될 수 있습니다. 원문(원어) 문서를 권위 있는 자료로 간주하시기 바랍니다. 중요한 정보의 경우 전문적인 인간 번역을 권장합니다. 이 번역의 사용으로 인해 발생한 오해나 잘못된 해석에 대해 당사는 책임을 지지 않습니다.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
