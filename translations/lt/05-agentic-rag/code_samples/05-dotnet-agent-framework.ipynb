# %% [markdown]
# # 🔍 Enterprise RAG su Microsoft Foundry (.NET)
#
# ## 📋 Mokymosi tikslai
#
# Ši užrašų knyga (notebook) demonstruoja, kaip kurti įmonės lygio Retrieval-Augmented Generation (RAG) sistemas, naudojant Microsoft Agent Framework .NET ir Microsoft Foundry. Sužinosite, kaip sukurti gamybai paruoštus agentus, kurie gali ieškoti dokumentuose ir pateikti tikslius, kontekstinius atsakymus su įmonės saugumo ir mastelio galimybėmis.
#
# **Enterprise RAG funkcijos, kurias sukursite:**
# - 📚 **Dokumentų intelektas**: Išplėstinis dokumentų apdorojimas su Azure AI paslaugomis
# - 🔍 **Semantinė paieška**: Aukštos našumo vektorinė paieška su įmonės funkcijomis
# - 🛡️ **Saugumo integracija**: Pareigybių pagrindu pagrįstas prieigos ir duomenų apsaugos modelis
# - 🏢 **Mastelio architektūra**: Gamybai paruoštos RAG sistemos su stebėsena
#
# ## 🎯 Enterprise RAG architektūra
#
# ### Pagrindiniai įmonės komponentai
# - **Microsoft Foundry**: Valdoma įmonės AI platforma su saugumu ir atitiktimi
# - **Persistent Agents**: Būsenos saugojimą turintys agentai su pokalbių istorija ir konteksto valdymu
# - **Vector Store Management**: Įmonės lygio dokumentų indeksavimas ir atgavimas
# - **Identity Integration**: Azure AD autentifikacija ir pareigybių pagrindu valdomas prieigos kontrolė
#
# ### .NET įmonės privalumai
# - **Type Safety**: Kompiliavimo metu atliekama RAG operacijų ir duomenų struktūrų validacija
# - **Async Performance**: Neužblokuojantis dokumentų apdorojimas ir paieškos operacijos
# - **Memory Management**: Efektyvus resursų naudojimas didelėms dokumentų kolekcijoms
# - **Integration Patterns**: Vietinė Azure paslaugų integracija su priklausomybių injekcija
#
# ## 🏗️ Techninė architektūra
#
# ### Enterprise RAG pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Pagrindiniai .NET komponentai
# - **Azure.AI.Agents.Persistent**: Įmonės agentų valdymas su būsenos išsaugojimu
# - **Azure.Identity**: Integruota autentifikacija saugiam Azure paslaugų prieigai
# - **Microsoft.Agents.AI.AzureAI**: Azure optimizuota agentų sistemos implementacija
# - **System.Linq.Async**: Aukštos našumo asinchroninės LINQ operacijos
#
# ## 🔧 Įmonės funkcijos ir privalumai
#
# ### Saugumas ir atitiktis
# - **Azure AD Integration**: Įmonės tapatybės valdymas ir autentifikacija
# - **Role-Based Access**: Smulkiagrūdės teisės dokumentų prieigai ir operacijoms
# - **Data Protection**: Šifravimas ramybėje ir perdavimo metu jautriems dokumentams
# - **Audit Logging**: Išsami veiklos sekimo sistema atitikties reikalavimams
#
# ### Našumas ir mastelis
# - **Connection Pooling**: Efektyvus Azure paslaugų ryšių valdymas
# - **Async Processing**: Neužblokuojančios operacijos didelio pralaidumo scenarijams
# - **Caching Strategies**: Protingas talpinimas dažnai naudojamiems dokumentams
# - **Load Balancing**: Išskirstytas apdorojimas didelio masto diegimams
#
# ### Valdymas ir stebėsena
# - **Health Checks**: Integruota RAG sistemos komponentų stebėsena
# - **Performance Metrics**: Išsamūs analizės duomenys apie paieškos kokybę ir atsakymo laikus
# - **Error Handling**: Išsamus klaidų valdymas su pakartotinio bandymo politika
# - **Configuration Management**: Aplinkai specifiniai nustatymai su validacija
#
# ## ⚙️ Išankstiniai reikalavimai ir sąranka
#
# **Vystymo aplinka:**
# - .NET 9.0 SDK arba naujesnė versija
# - Visual Studio 2022 arba VS Code su C# plėtiniais
# - Azure prenumerata su AI Foundry prieiga
#
# **Reikalingi NuGet paketai:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure autentifikacijos nustatymas:**
# ```bash
# # Įdiekite Azure CLI ir autentifikuokitės
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Aplinkos konfigūracija (.env failas):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Enterprise RAG modeliai
#
# ### Dokumentų valdymo modeliai
# - **Bulk Upload**: Efektyvus didelių dokumentų kolekcijų apdorojimas
# - **Incremental Updates**: Dokumentų pridėjimas ir modifikavimas realiu laiku
# - **Version Control**: Dokumentų versijavimas ir pakeitimų sekimas
# - **Metadata Management**: Išsamūs dokumentų atributai ir taksonomija
#
# ### Paieškos ir atkūrimo modeliai
# - **Hybrid Search**: Semantinės ir raktinių žodžių paieškos derinimas optimaliems rezultatams
# - **Faceted Search**: Daugiapakopė filtracija ir kategorizavimas
# - **Relevance Tuning**: Individualūs balavimo algoritmai domeno specifinėms reikmėms
# - **Result Ranking**: Pažangus reitingavimas su verslo logikos integracija
#
# ### Saugumo modeliai
# - **Document-Level Security**: Smulkiagrūdė prieigos kontrolė kiekvienam dokumentui
# - **Data Classification**: Automatinis jautrumo žymėjimas ir apsauga
# - **Audit Trails**: Išsamus visų RAG operacijų žurnalas
# - **Privacy Protection**: PII aptikimas ir redagavimo galimybės
#
# ## 🔒 Enterprise saugumo funkcijos
#
# ### Autentifikacija ir autorizacija
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Duomenų apsauga
# - **Encryption**: Galutinis šifravimas dokumentams ir paieškos indeksams
# - **Access Controls**: Integracija su Azure AD vartotojų ir grupių teisių valdymui
# - **Data Residency**: Geografinės duomenų lokalizacijos kontrolė atitikties reikalavimams
# - **Backup & Recovery**: Automatizuotas atsarginių kopijų darymas ir katastrofų atkūrimo galimybės
#
# ## 📈 Našumo optimizavimas
#
# ### Asinchroninio apdorojimo modeliai
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Atminties valdymas
# - **Streaming Processing**: Didelių dokumentų apdorojimas be atminties problemų
# - **Resource Pooling**: Efektyvus brangių resursų pakartotinis naudojimas
# - **Garbage Collection**: Optimizuoti atminties paskirstymo modeliai
# - **Connection Management**: Tinkamas Azure paslaugų ryšių gyvenimo ciklo valdymas
#
# ### Talpyklos strategijos
# - **Query Caching**: Talpinimas dažnai vykdomoms paieškoms
# - **Document Caching**: Atminties talpykla aktyviems dokumentams
# - **Index Caching**: Optimizuotas vektorinio indekso talpinimas
# - **Result Caching**: Protingas sugeneruotų atsakymų talpinimas
#
# ## 📊 Enterprise taikymo sritys
#
# ### Žinių valdymas
# - **Corporate Wiki**: Intelektuali paieška įmonės žinių bazėse
# - **Policy & Procedures**: Automatizuotas atitikties ir procedūrų konsultavimas
# - **Training Materials**: Intelektuali mokymo ir plėtros pagalba
# - **Research Databases**: Akademinių ir mokslinių darbų analizės sistemos
#
# ### Klientų aptarnavimas
# - **Support Knowledge Base**: Automatizuoti klientų aptarnavimo atsakymai
# - **Product Documentation**: Intelektualus produkto informacijos atgavimas
# - **Troubleshooting Guides**: Kontekstinė problemų sprendimo pagalba
# - **FAQ Systems**: Dinaminis DUK generavimas iš dokumentų kolekcijų
#
# ### Reguliacinė atitiktis
# - **Legal Document Analysis**: Sutarčių ir teisinių dokumentų intelektas
# - **Compliance Monitoring**: Automatizuota reguliacinės atitikties tikrinimas
# - **Risk Assessment**: Dokumentų pagrindu atliekama rizikos analizė ir ataskaitos
# - **Audit Support**: Intelektualus dokumentų paieškos palaikymas audito metu
#
# ## 🚀 Gamybinis diegimas
#
# ### Stebėsena ir matomumas
# - **Application Insights**: Išsami telemetrija ir našumo stebėsena
# - **Custom Metrics**: Verslui specifinių KPI sekimas ir perspėjimai
# - **Distributed Tracing**: Užklausų sekimas per visą paslaugų grandinę
# - **Health Dashboards**: Realaus laiko sistemos sveikatos ir našumo vizualizacija
#
# ### Mastelio keitimas ir patikimumas
# - **Auto-Scaling**: Automatinis skalės keitimas pagal apkrovą ir našumo rodiklius
# - **High Availability**: Daugiaregioninis diegimas su atsarginio veikimo galimybėmis
# - **Load Testing**: Našumo patikra įmonės apkrovos sąlygomis
# - **Disaster Recovery**: Automatizuotos atsarginių kopijų ir atkūrimo procedūros
#
# Pasiruošę sukurti įmonės lygio RAG sistemas, galinčias tvarkyti jautrius dokumentus dideliu mastu? Sukurkime intelektualias žinių sistemas įmonei! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas pasitelkus dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors stengiamės užtikrinti tikslumą, prašome atkreipti dėmesį, kad automatizuoti vertimai gali turėti klaidų arba netikslumų. Originalus dokumentas jo gimtąja kalba turi būti laikomas autoritetingu šaltiniu. Dėl svarbios informacijos rekomenduojama kreiptis dėl profesionalaus žmogaus atlikto vertimo. Mes neatsakome už jokius nesusipratimus ar neteisingus aiškinimus, kylančius dėl šio vertimo naudojimo.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
