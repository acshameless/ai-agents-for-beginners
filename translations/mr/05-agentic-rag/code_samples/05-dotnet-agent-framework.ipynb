# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) सह एंटरप्राइझ RAG
#
# ## 📋 शिकण्याची उद्दिष्टे
#
# हे नोटबुक Microsoft Agent Framework वापरून .NET मध्ये Microsoft Foundry सह एंटरप्राइझ-स्तरीय Retrieval-Augmented Generation (RAG) सिस्टम कशा तयार कराव्यात हे दर्शवते. तुम्ही दस्तऐवजांमधून शोध घेऊ शकणारे आणि एंटरप्राइझ सुरक्षा व विस्तारक्षमता सह अचूक, संदर्भ-सजग प्रतिसाद देणारे उत्पादन-तयार एजंट्स कसे तयार करायचे ते शिकणार आहात.
#
# **तुम्ही तयार कराल अशा एंटरप्राइझ RAG क्षमता:**
# - 📚 **दस्तऐवज बुद्धिमत्ता**: Azure AI सेवांसह प्रगत दस्तऐवज प्रक्रिया
# - 🔍 **सामांतिक शोध**: एंटरप्राइझ वैशिष्ट्यांसह उच्च-कार्यक्षमतेचे व्हेक्टर शोध
# - 🛡️ **सुरक्षा समाकलन**: भूमिकाभारित प्रवेश आणि डेटा संरक्षण नमुने
# - 🏢 **विस्तारक्षम आर्किटेक्चर**: मॉनिटरिंगसह उत्पादन-तयार RAG सिस्टम्स
#
# ## 🎯 एंटरप्राइझ RAG आर्किटेक्चर
#
# ### मुख्य एंटरप्राइझ घटक
# - **Microsoft Foundry**: सुरक्षा आणि अनुपालनासह व्यवस्थापित एंटरप्राइझ AI प्लॅटफॉर्म
# - **Persistent Agents**: संभाषण इतिहास आणि संदर्भ व्यवस्थापन असलेले स्थिती-संग्रहीत एजंट
# - **Vector Store Management**: एंटरप्राइझ-स्तरीय दस्तऐवज निर्देशांक आणि पुनर्प्राप्ती
# - **Identity Integration**: Azure AD प्रमाणीकरण आणि भूमिकाभारित प्रवेश नियंत्रणे
#
# ### .NET एंटरप्राइझ फायदे
# - **Type Safety**: RAG ऑपरेशन्स आणि डेटा संरचनांसाठी कंपाईल-टाइम पडताळणी
# - **Async Performance**: नॉन-ब्लॉकिंग दस्तऐवज प्रक्रिया आणि शोध ऑपरेशन्स
# - **Memory Management**: मोठ्या दस्तऐवज संचांसाठी कार्यक्षम संसाधन वापर
# - **Integration Patterns**: डिपेंडेंसी इंजेक्शनसह नैसर्गिक Azure सेवा समाकलन
#
# ## 🏗️ तांत्रिक आर्किटेक्चर
#
# ### एंटरप्राइझ RAG पाइपलाइन
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### मुख्य .NET घटक
# - **Azure.AI.Agents.Persistent**: राज्य टिकवून ठेवण्यासह एंटरप्राइझ एजंट व्यवस्थापन
# - **Azure.Identity**: सुरक्षित Azure सेवा प्रवेशासाठी एकीकृत प्रमाणीकरण
# - **Microsoft.Agents.AI.AzureAI**: Azure-ऑप्टिमाइझ्ड एजंट फ्रेमवर्कची अंमलबजावणी
# - **System.Linq.Async**: उच्च-कार्यक्षमतेची असिंक्रोनस LINQ ऑपरेशन्स
#
# ## 🔧 एंटरप्राइझ वैशिष्ट्ये आणि फायदे
#
# ### सुरक्षा आणि अनुपालन
# - **Azure AD समाकलन**: एंटरप्राइझ ओळख व्यवस्थापन आणि प्रमाणीकरण
# - **भूमिकाभारित प्रवेश**: दस्तऐवज प्रवेश आणि ऑपरेशन्ससाठी सूक्ष्म परवानग्या
# - **डेटा संरक्षण**: संग्रहित आणि प्रेषित असताना संवेदनशील दस्तऐवजांसाठी एन्क्रिप्शन
# - **ऑडिट लॉगिंग**: अनुपालन गरजांसाठी सर्वसमावेशक क्रियाकलाप ट्रॅकिंग
#
# ### कार्यक्षमता आणि विस्तारक्षमता
# - **कनेक्शन पूलिंग**: Azure सेवा कनेक्शनचे कार्यक्षम व्यवस्थापन
# - **असिंक्रोनस प्रक्रिया**: उच्च-थ्रूपुट परिस्थितींसाठी नॉन-ब्लॉकिंग ऑपरेशन्स
# - **कॅशिंग धोरणे**: वारंवार प्रवेश केलेल्या दस्तऐवजांसाठी बुद्धिमान कॅशिंग
# - **लोड बॅलन्सिंग**: मोठ्या प्रमाणात डिप्लॉयमेंटसाठी वितरित प्रक्रिया
#
# ### व्यवस्थापन आणि मॉनिटरिंग
# - **हेल्थ चेक्स**: RAG सिस्टम घटकांसाठी अंगभूत मॉनिटरिंग
# - **कार्यक्षमता मेट्रिक्स**: शोध गुणवत्ते आणि प्रतिसाद वेळांवर सविस्तर विश्लेषण
# - **एरर हँडलिंग**: पुनर्प्रयत्न धोरणांसह सर्वसमावेशक अपवाद व्यवस्थापन
# - **कॉन्फिगरेशन व्यवस्थापन**: पर्यावरण-विशिष्ट सेटिंग्जसह पडताळणी
#
# ## ⚙️ पूर्वआवश्यकता आणि सेटअप
#
# **विकास वातावरण:**
# - .NET 9.0 SDK किंवा त्याहून वर
# - Visual Studio 2022 किंवा C# विस्तारासह VS Code
# - AI Foundry प्रवेश असलेली Azure सदस्यता
#
# **आवश्यक NuGet पॅकेजेस:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure प्रमाणीकरण सेटअप:**
# ```bash
# # Azure CLI स्थापित करा आणि प्रमाणीकरण करा
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **पर्यावरण कॉन्फिगरेशन (.env फाईल):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 एंटरप्राइझ RAG नमुने
#
# ### दस्तऐवज व्यवस्थापन नमुने
# - **थोक अपलोड**: मोठ्या दस्तऐवज संचांचे कार्यक्षम प्रसंस्करण
# - **क्रमिक अद्यतने**: रिअल-टाइम दस्तऐवज जोडणी आणि बदल
# - **आवृत्ती नियंत्रण**: दस्तऐवज आवृत्तीकरण आणि बदलांचे ट्रॅकिंग
# - **मेटाडेटा व्यवस्थापन**: समृद्ध दस्तऐवज गुणधर्म आणि वर्गीकरण
#
# ### शोध आणि पुनर्प्राप्ती नमुने
# - **हायब्रिड शोध**: सर्वोत्तम निकालांसाठी सामांतिक आणि कीवर्ड शोधाचे संयोजन
# - **फेसेटेड शोध**: बहुआयामी फिल्टरिंग आणि वर्गीकरण
# - **सापेक्षता ट्यूनिंग**: डोमेन-विशिष्ट गरजांसाठी सानुकूल स्कोरिंग अल्गोरिदम
# - **परिणाम रँकिंग**: व्यवसाय लॉजिक समाकलनासह प्रगत रँकिंग
#
# ### सुरक्षा नमुने
# - **दस्तऐवज-स्तरीय सुरक्षा**: प्रत्येक दस्तऐवजासाठी सूक्ष्म प्रवेश नियंत्रण
# - **डेटा वर्गीकरण**: स्वयंचलित संवेदनशीलता लेबलिंग आणि संरक्षण
# - **ऑडिट ट्रेल्स**: सर्व RAG ऑपरेशन्सचे सर्वसमावेशक लॉगिंग
# - **गोपनीयता संरक्षण**: PII शोध आणि खंडन क्षमता
#
# ## 🔒 एंटरप्राइझ सुरक्षा वैशिष्ट्ये
#
# ### प्रमाणीकरण आणि प्राधिकरण
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### डेटा संरक्षण
# - **एन्क्रिप्शन**: दस्तऐवज आणि शोध इंडेक्ससाठी एंड-टू-एंड एन्क्रिप्शन
# - **एक्सेस कंट्रोल्स**: वापरकर्ता आणि गट परवानग्यांसाठी Azure AD सह समाकलन
# - **डेटा रहिवास**: अनुपालनासाठी भौगोलिक डेटा स्थान नियंत्रण
# - **बॅकअप आणि पुनर्प्राप्ती**: स्वयंचलित बॅकअप आणि आपत्ती-पुनर्प्राप्ती क्षमता
#
# ## 📈 कार्यक्षमता ऑप्टिमायझेशन
#
# ### असिंक्रोनस प्रक्रिया नमुने
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### मेमरी व्यवस्थापन
# - **स्ट्रीमिंग प्रक्रिया**: मेमरी समस्यांशिवाय मोठ्या दस्तऐवजांची हाताळणी
# - **संसाधन पूलिंग**: महागड्या संसाधनांचा कार्यक्षम पुनर्वापर
# - **गार्बेज कलेक्शन**: ऑप्टिमाइझ्ड मेमरी वाटप नमुने
# - **कनेक्शन व्यवस्थापन**: योग्य Azure सेवा कनेक्शन लाईफसायकल
#
# ### कॅशिंग धोरणे
# - **क्वेरी कॅशिंग**: वारंवार चालवल्या जाणाऱ्या शोधांचे कॅशिंग
# - **दस्तऐवज कॅशिंग**: हॉट दस्तऐवजांसाठी इन-मेमरी कॅशिंग
# - **इंडेक्स कॅशिंग**: ऑप्टिमाइझ्ड व्हेक्टर इंडेक्स कॅशिंग
# - **परिणाम कॅशिंग**: तयार केलेल्या प्रतिसादांचे बुद्धिमान कॅशिंग
#
# ## 📊 एंटरप्राइझ वापर प्रकरणे
#
# ### ज्ञान व्यवस्थापन
# - **कॉर्पोरेट विकी**: कंपनी ज्ञान बेसवर बुद्धिमान शोध
# - **धोरणे आणि प्रक्रिया**: स्वयंचलित अनुपालन आणि प्रक्रिया मार्गदर्शन
# - **प्रशिक्षण सामग्री**: बुद्धिमान शिक्षण आणि विकास सहाय्य
# - **संशोधन डेटाबेस**: अकादमिक आणि संशोधन पेपर विश्लेषण प्रणाली
#
# ### ग्राहक समर्थन
# - **समर्थन ज्ञान बेस**: स्वयंचलित ग्राहक सेवा प्रतिसाद
# - **उत्पादन दस्तऐवजीकरण**: बुद्धिमान उत्पादन माहिती पुनर्प्राप्ती
# - **ट्रबलशूटिंग मार्गदर्शक**: संदर्भानुसार समस्या सोडवण्याचे सहाय्य
# - **FAQ सिस्टम्स**: दस्तऐवज संचांमधून डायनॅमिक FAQ निर्मिती
#
# ### नियामक अनुपालन
# - **कायदेशीर दस्तऐवज विश्लेषण**: करार आणि कायदेशीर दस्तऐवज बुद्धिमत्ता
# - **अनुपालन मॉनिटरिंग**: स्वयंचलित नियामक अनुपालन तपासणी
# - **धोक्याचे मूल्यांकन**: दस्तऐवज-आधारित जोखीम विश्लेषण आणि अहवाल
# - **ऑडिट समर्थन**: ऑडिटसाठी बुद्धिमान दस्तऐवज शोध
#
# ## 🚀 उत्पादन वितरण
#
# ### मॉनिटरिंग आणि निरीक्षणक्षमता
# - **Application Insights**: सविस्तर टेलिमेट्री आणि कार्यक्षमता मॉनिटरिंग
# - **कस्टम मेट्रिक्स**: व्यवसाय-विशिष्ट KPI ट्रॅकिंग आणि अलर्टिंग
# - **डिस्ट्रिब्यूटेड ट्रेसिंग**: सेवांमध्ये विनंतीचे एंड-टू-एंड ट्रॅकिंग
# - **हेल्थ डॅशबोर्ड**: रिअल-टाइम सिस्टम आरोग्य आणि कार्यक्षमता दृश्य
#
# ### विस्तारक्षमता आणि विश्वसनीयता
# - **ऑटो-स्केलिंग**: लोड आणि कार्यक्षमता मेट्रिक्सवर आधारित स्वयंचलित स्केलिंग
# - **उच्च उपलब्धता**: फेलओव्हर क्षमता असह बहु-क्षेत्रीय डिप्लॉयमेंट
# - **लोड टेस्टिंग**: एंटरप्राइझ लोड परिस्थितींमध्ये कार्यक्षमता सत्यापन
# - **आपत्ती पुनर्प्राप्ती**: स्वयंचलित बॅकअप आणि पुनर्प्राप्ती प्रक्रिया
#
# सुविधेनुसार संवेदनशील दस्तऐवज मोठ्या प्रमाणात हाताळू शकणारी एंटरप्राइझ-स्तरीय RAG सिस्टम्स तयार करण्यास तयार आहात का? चला एंटरप्राइझसाठी बुद्धिमान ज्ञान प्रणाली रचूया! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# अस्वीकरण:
# हे दस्तऐवज AI अनुवाद सेव्हचा वापर करून अनुवादित केले गेले आहे — Co-op Translator (https://github.com/Azure/co-op-translator). आम्ही अचूकतेसाठी प्रयत्नशील असलो तरी, कृपया लक्षात घ्या की स्वयंचलित अनुवादांमध्ये चुका किंवा अचूकतेच्या तर्कांमध्ये त्रुटी असू शकतात. मूळ दस्तऐवज त्याच्या मूळ भाषेत अधिकृत स्रोत मानला पाहिजे. महत्त्वाच्या माहितीकरता व्यावसायिक मानवी अनुवाद करणे शिफारसीय आहे. या अनुवादाच्या वापरामुळे उद्भवणाऱ्या कोणत्याही गैरसमजुतींसाठी किंवा चुकीच्या अर्थबोधासाठी आम्ही जबाबदार नाही.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
