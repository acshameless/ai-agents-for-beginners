# %% [markdown]
# ## **नमुने: हॉटेल बुकिंगसाठी मल्टी-AI एजंट्स**
#
# आजच्या वेगवान जगात, व्यावसायिक प्रवासाची योजना बनवणे केवळ फ्लाइट आणि हॉटेल रूम बुक करण्यापुरते मर्यादित नाही. यासाठी समन्वय आणि कार्यक्षमतेची पातळी आवश्यक असते जी साध्य करणे आव्हानात्मक असू शकते. याच ठिकाणी मल्टी-AI एजंट्स काम करत आहेत, जे आपल्या प्रवासाच्या गरजा व्यवस्थापित करण्याच्या पद्धतीत क्रांती घडवत आहेत.
#
# कल्पना करा की तुमच्याकडे बुद्धिमान एजंट्सची एक टीम आहे, जी तुमच्या प्रवासाचा प्रत्येक पैलू अचूकता आणि सोयीने हाताळण्यासाठी एकत्र काम करत आहे. आमच्या प्रगत AI तंत्रज्ञानाच्या माध्यमातून, आम्ही सेवा बुकिंग आणि प्रवासाचे कार्यक्रम आखणी यासाठी विशेष एजंट्स तयार केले आहेत, जे एक निर्विघ्न आणि तणावमुक्त प्रवासाचा अनुभव देतात.
#
# हे एक मूलभूत उदाहरण आहे. व्यवसाय प्रवासाची योजना तयार करताना, आपल्याला विमान तिकीट माहिती, हॉटेल माहिती इत्यादी मिळवण्यासाठी व्यवसाय प्रवास एजंटशी सल्लामसलत करावी लागते. AI एजंट्सच्या माध्यमातून, आम्ही सेवा बुक करण्यासाठी एजंट्स आणि प्रवास कार्यक्रम रचण्याचे एजंट्स तयार करू शकतो जे सहकार्य करतात आणि बुद्धिमत्तेची पातळी सुधारतात.

# %% [markdown]
# # Azure AI Agent Service प्रारंभ करा आणि **.env** मधून कॉन्फिगरेशन माहिती घ्या
#
# ### **.env**
#
# एक .env फाइल तयार करा
#
# **.env** मध्ये Azure AI Agent Service ची कनेक्शन स्ट्रिंग, AOAI द्वारे वापरला जाणारा मॉडेल आणि संबंधित Google API Search सेवा API, ENDPOINT इत्यादी असतात.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "तुमच्या Azure AI Agent Service मॉडेल डिप्लॉयमेंटचे नाव"
#
# [**NOTE**] तुम्हाला 100,000 रेट लिमिट (मिनिटातील टोकन्स) आणि 600 रेट लिमिट (मिनिटातील विनंत्या) असलेला मॉडेल आवश्यक आहे.
#
#   तुम्ही Microsoft Foundry - Model and Endpoint मध्ये मॉडेल मिळवू शकता.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "तुमच्या Azure AI Agent Service प्रोजेक्टची कनेक्शन स्ट्रिंग"
#
#   तुम्ही AI Foundry पोर्टल स्क्रीनवरील प्रोजेक्ट ओव्हरव्ह्यूमध्ये प्रोजेक्ट कनेक्शन स्ट्रिंग मिळवू शकता.
#
# - **SERPAPI_SEARCH_API_KEY** = "तुमचा SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "तुमचा SERPAPI Search Endpoint"
#
# Azure AI Agent Service चा मॉडेल डिप्लॉयमेंट नाव आणि प्रोजेक्ट कनेक्शन स्ट्रिंग मिळविण्यासाठी, तुम्हाला Azure AI Agent Service तयार करावी लागेल.
# हे थेट तयार करण्यासाठी [हा टेम्पलेट](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) वापरण्याची शिफारस आहे (***टीप:*** Azure AI Agent Service सध्या मर्यादित प्रदेशात सेट केले आहे. प्रदेश सेट करण्यासाठी [हा दुवा](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) पाहण्याची शिफारस केली जाते)
#
# Agent ला SERPAPI ला ऍक्सेस करणे आवश्यक आहे. नोंदणीसाठी [हा दुवा](https://serpapi.com/searches) वापरण्याची शिफारस केली जाते. नोंदणी केल्यानंतर, तुम्हाला एक अद्वितीय API KEY आणि ENDPOINT मिळेल.

# %% [markdown]
# # Azure मध्ये लॉगिन करा
#
# आपण आता Azure मध्ये लॉगिन करणे आवश्यक आहे. VScode मध्ये एक टर्मिनल उघडा आणि `az login` कमांड चालवा.

# %% [markdown]
# # Setup
#
# To run this notebook, you will need to install the following libraries. Here is a list of the required libraries and the corresponding pip install commands:
#
# azure-identity: Azure प्रमाणीकरणासाठी.
# requests: HTTP विनंत्या करण्यासाठी.
# semantic-kernel: सेमॅंटिक कर्नल फ्रेमवर्कसाठी (समजून चला की ही एखादी सानुकूल किंवा विशिष्ट लायब्ररी आहे, ती एखाद्या विशिष्ट स्त्रोत किंवा रिपॉझिटरीमधून इंस्टॉल करावी लागेल).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # स्पष्टीकरण:
# import asyncio: हे asyncio मॉड्यूल आयात करते, जे पायथनमध्ये असिंक्रोनस प्रोग्रामिंगसाठी समर्थन प्रदान करते. हे तुम्हाला async आणि await सिंटॅक्स वापरून एकाच वेळी चालणारे कोड लिहिण्याची परवानगी देते.
# from typing import Annotated: हे typing मॉड्यूलमधून Annotated प्रकार आयात करते. Annotated प्रकाराच्या संकेतांसाठी मेटाडेटा जोडण्यासाठी वापरले जाते, जे विविध कारणांसाठी उपयुक्त असू शकते जसे की प्रमाणीकरण, दस्तऐवजीकरण, किंवा साधने.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # स्पष्टीकरण:
# from dotenv import load_dotenv आणि load_dotenv() वापरून, तुम्ही .env फाइलमधील कॉन्फिगरेशन सेटिंग्ज आणि संवेदनशील माहिती (जसे की API की आणि डेटाबेस URL) सहजपणे व्यवस्थापित करू शकता, ज्यामुळे ती तुमच्या स्रोत कोडपासून वेगळी राहतात आणि तुमचे अनुप्रयोग अधिक सुरक्षित व सुलभपणे कॉन्फिगर करता येतात.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # स्पष्टीकरण:
#
# इम्पोर्ट स्टेटमेंट: from azure.identity.aio import DefaultAzureCredential: हे azure.identity.aio मॉड्यूलमधून DefaultAzureCredential वर्ग आयात करते. aio हा मॉड्यूल नावाचा भाग असिंक्रोनस ऑपरेशन्ससाठी डिझाइन करण्यात आला आहे हे सूचित करतो.
#
# DefaultAzureCredential चे उद्दिष्ट: DefaultAzureCredential वर्ग Azure SDK for Python चा भाग आहे. हे Azure सेवा वापरण्यासाठी प्रमाणीकरण करण्याचा एक डीफॉल्ट मार्ग प्रदान करते. हे विशिष्ट क्रमाने अनेक पद्धती वापरून प्रमाणीकरण करण्याचा प्रयास करते, जसे की पर्यावरणीय व्हेरिएबल्स, व्यवस्थापित ओळख, आणि Azure CLI क्रेडेन्शियल्स.
#
# असिंक्रोनस ऑपरेशन्स: aio मॉड्यूल सूचित करते की DefaultAzureCredential वर्ग असिंक्रोनस ऑपरेशन्सना समर्थन करतो. याचा अर्थ तुम्ही याचा asyncio सह वापर करू शकता जेणेकरून नॉन-ब्लॉकिंग प्रमाणीकरण विनंत्या करता येतील.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # स्पष्टीकरण:
# semantic_kernel पॅकेजमधून विविध मॉड्यूल्स आणि क्लासेस आयात करतो. प्रत्येक आयात यांचे विघटन पुढीलप्रमाणे आहे:
#
# AgentGroupChat from semantic_kernel.agents: हा क्लास AI एजंटसाठी समूह चॅट संबंधित फंक्शनॅलिटीस हाताळतो.
# AzureAIAgent आणि AzureAIAgentSettings from semantic_kernel.agents.azure_ai:
#
# AzureAIAgent: हा क्लास Azure AI सेवांचा वापर करणारे AI एजंट तयार करण्यासाठी आणि व्यवस्थापित करण्यासाठी वापरला जातो.
#
# AzureAIAgentSettings: हा क्लास AzureAIAgent चे सेटिंग्ज कॉन्फिगर करण्यासाठी वापरला जातो.
# TerminationStrategy from semantic_kernel.agents.strategies.termination.termination_strategy:
#
# हा क्लास काही अटींअंतर्गत AI एजंट्सच्या अंमलबजावणीची समाप्ती कशी करावी हे ठरवणाऱ्या स्ट्रॅटेजीज परिभाषित करतो.
# ChatMessageContent from semantic_kernel.contents.chat_message_content:
#
# हा क्लास चॅट मेसेजेसच्या कंटेंटचे हाताळणी करण्यासाठी वापरला जातो.
# AuthorRole from semantic_kernel.contents.utils.author_role:
#
# हा क्लास चॅट मेसेजेसच्या संदर्भातील वेगवेगळ्या लेखकांच्या भूमिका परिभाषित करतो.
#
# kernel_function from semantic_kernel.functions.kernel_function_decorator: हा डेकोरेटर kernel functions, म्हणजे semantic kernel फ्रेमवर्कमध्ये चालवू शकणारे फंक्शन्स, परिभाषित करण्यासाठी वापरला जातो.
# ही आयाती ग्रुप चॅट वातावरणात संवाद साधू शकणारे AI एजंट तयार करण्यासाठी आणि व्यवस्थापित करण्यासाठी आवश्यक घटक सेट करतात, जसे की हॉटेल बुकिंग किंवा तत्सम कामांसाठी.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # स्पष्टीकरण:
# नंतर आपण azure.ai.projects.models मॉड्यूलमधून CodeInterpreterTool वर्ग आयात करतो.
#
# CodeInterpreterTool: हा वर्ग Azure AI SDK चा भाग आहे आणि AI प्रकल्पांच्या संदर्भात कोडचे अर्थ लावणे आणि अंमलबजावणी करण्यासाठी वापरला जातो. हे कोड स्निपेट चालविणे, कोडचे विश्लेषण करणे, किंवा AI वर्कफ्लोमध्ये कोड एक्सिक्युशन एकत्रित करण्याची कार्यक्षमता प्रदान करते.
# ही आयात आपल्या प्रकल्पात CodeInterpreterTool वापरण्यासाठी आवश्यक घटक सेट करते, जे गतिशीलपणे कोडचे अर्थ लावणे आणि अंमलबजावणी करणे यामध्ये उपयुक्त ठरू शकते.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # स्पष्टीकरण:
# ApprovalTerminationStrategy वर्ग AI एजंटच्या ऑपरेशनला समाप्त करण्यासाठी विशिष्ट धोरण पुरवतो. एजंट त्याच्या संवाद इतिहासातील शेवटच्या संदेशात "saved" शब्द आढळल्यास समाप्त होईल. जेव्हा एजंटच्या कार्याला "saved" झाल्याची पुष्टी मिळते तेव्हा कार्य पूर्ण समजले जाते अशा परिस्थितीत हे उपयुक्त ठरू शकते. संवाद पद्धत निश्चित करा. आरक्षण योजना जतन झाल्यानंतर saved सिग्नल प्राप्त होताच थांबवू शकतो.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # स्पष्टीकरण:
#
# कोडची ओळ एक AzureAIAgentSettings ऑब्जेक्ट डीफॉल्ट किंवा पूर्वनिर्धारित सेटिंग्जसह तयार करण्यासाठी create() पद्धत कॉल करते. नंतर हा सेटिंग्ज ऑब्जेक्ट (ai_agent_settings) AzureAIAgent उदाहरण कॉन्फिगर करण्यासाठी आणि व्यवस्थापित करण्यासाठी वापरला जाऊ शकतो.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # स्पष्टीकरण:
# requests लायब्ररी आयात करून, आपण सहजपणे HTTP विनंत्या करू शकता आणि आपल्या Python कोडमध्ये वेब सेवा वापरू शकता.

# %%
import requests

# %% [markdown]
# # स्पष्टीकरण:
# हा एक व्हेरिएबल आहे जो SERP (सर्च इंजिन रिजल्ट्स पेज) API सेवेसाठी API की संग्रहीत करतो. API की ही एक अद्वितीय ओळख आहे जी आपल्या खात्यासंबंधित विनंत्यांचे प्रमाणीकरण करण्यासाठी वापरली जाते.
#
# 'GOOGLE_SEARCH_API_KEY': हा एक प्लेसहोल्डर स्ट्रिंग आहे. आपण ''GOOGLE_SEARCH_API_KEY' आपल्या वास्तविक SERP API कीने बदलणे आवश्यक आहे.
#
# उद्दिष्ट: या ओळीचा उद्देश म्हणजे API कीला व्हेरिएबलमध्ये साठवणे, जेणेकरून ती SERP API सेवेला विनंत्या प्रमाणीकरण करण्यासाठी वापरली जाऊ शकते. या सेवेचा प्रवेश करण्यासाठी आणि शोध करण्यासाठी API की आवश्यक आहे.
#
# SERP API की कशी मिळवायची: SERP API की मिळवण्यासाठी, https://serpapi.com येथे खालील सामान्य पायऱ्या अनुसरा (तुम्ही वापरत असलेल्या विशिष्ट SERP API सेवेनुसार पायऱ्या भिन्न असू शकतात):
#
# SERP API सेवा निवडा: SerpAPI, Google Custom Search JSON API, आणि इतर अशी अनेक SERP API सेवा उपलब्ध आहेत. तुमच्या गरजेनुसार योग्य सेवा निवडा.
#
# खाते तयार करा:
#
# निवडलेल्या SERP API सेवांच्या वेबसाइटवर जा https://www.serpapi.com आणि खाते तयार करा. तुम्हाला काही मूलभूत माहिती द्यावी लागेल आणि तुमचा ईमेल पत्ता सत्यापित करावा लागू शकतो.
#
# API की तयार करा:
#
# साइन अप केल्यानंतर, तुमच्या खात्यात लॉगिन करा आणि API विभाग किंवा डॅशबोर्डमध्ये जावे. नवीन API की तयार करण्याचा पर्याय शोधा.
#
# API की कॉपी करा:
#
# जेव्हा API की तयार होईल, तेव्हा ती कॉपी करा. या कीचा वापर तुमच्या विनंत्यांचे SERP API सेवेला प्रमाणीकरण करण्यासाठी केला जाईल.
#
# प्लेसहोल्डर बदला:
#
# . env फाइलमधील प्लेसहोल्डर बदला

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # स्पष्टीकरण:
# BookingPlugin वर्ग Serpapi.com Google Search API वापरून हॉटेल आणि फ्लाइट बुक करण्यासाठी पद्धती प्रदान करतो. तो आवश्यक पॅरामीटर्स तयार करतो, API विनंत्या पाठवतो, आणि संबंधित बुकिंग माहिती परत करण्यासाठी प्रतिसाद प्रक्रिया करतो. API की (SERPAPI_SEARCH_API_KEY) आणि एंडपॉइंट (SERPAPI_SEARCH_ENDPOINT) वापरून Google Search API ला प्रमाणीकरण केले जाते आणि विनंत्या पाठवल्या जातात.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # स्पष्टीकरण:
# SavePlugin वर्ग Azure AI सेवा वापरून प्रवास योजना जतन करण्यासाठी saving_plan पद्धत प्रदान करतो. हे Azure क्रेडेन्शियल्स सेट करते, AI एजंट तयार करते, वापरकर्त्याच्या इनपुट्सवर प्रक्रिया करते जेणेकरून प्रवास योजना सामग्री तयार करणे आणि जतन करणे, तसेच फाइल जतन आणि साफसफाईचे ऑपरेशन्स हाताळते. पद्धत यशस्वी पूर्ण झाल्यानंतर "Saved" परत करते.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # स्पष्टीकरण:
# हा कोड वापरकर्त्याच्या इनपुटवर आधारित फ्लाइट आणि हॉटेल बुकिंग करण्यासाठी आणि ट्रिप योजना जतन करण्यासाठी Azure AI एजंट्स सेटअप करतो. तो एजंट तयार आणि संरचीत करण्यासाठी Azure प्रमाणपत्रांचा वापर करतो, वापरकर्त्याच्या इनपुट्सचे ग्रुप चॅटलाद्वारे परीक्षण करतो, आणि कार्ये पूर्ण झाल्यानंतर योग्य स्वच्छता सुनिश्चित करतो. एजंट्स त्यांच्या विशिष्ट कार्यांसाठी BookingPlugin आणि SavePlugin प्लगइन्स वापरतात.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **उल्लेखनीय सूचना**:
# हा दस्तऐवज AI भाषांतर सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) वापरून भाषांतरित केला आहे. आम्ही अचूकतेसाठी प्रयत्नशील आहोत, तरी कृपया लक्षात घ्या की स्वयंचलित भाषांतरांत चुका किंवा अचूकतेत त्रुटी असू शकतात. मूळ दस्तऐवज त्याच्या मूळ भाषेत अधिकृत स्त्रोत मानला पाहिजे. महत्त्वाची माहिती असल्यास, व्यावसायिक मानवी भाषांतर करण्याचा सल्ला दिला जातो. या भाषांतरामुळे उद्भवलेल्या गैरसमजुतींसाठी किंवा चुकीच्या अर्थसरणीसाठी आम्ही जबाबदार नाही.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
