# %% [markdown]
# # 🔍 Enterprise RAG with Microsoft Foundry (.NET)
#
# ## 📋 Learning Objectives
#
# This notebook တွင် Microsoft Agent Framework ကို .NET မှ အသုံးပြု၍ Microsoft Foundry ဖြင့် enterprise-grade Retrieval-Augmented Generation (RAG) စနစ်များကို ဘယ်လိုတည်ဆောက်ရမယ်ဆိုတာကို ပြသသည်။ သင်သည် စာရွက်စာတမ်းများကို ရှာဖွေနိုင်ပြီး အမှန်တကယ် မှန်ကန်သော၊ context ကို သတိထားထားသော ဖြေရှင်းချက်များ ပေးနိုင်သည့် production-ready agents များကို ဖန်တီးနည်းကို လေ့လာမည်။
#
# **Enterprise RAG Capabilities You'll Build:**
# - 📚 **Document Intelligence**: Azure AI ဝန်ဆောင်မှုများဖြင့် မြင့်မားသော စာရွက်စာတမ်း ချိတ်ဆက်နှင့် ပြုပြင်ခြင်း
# - 🔍 **Semantic Search**: enterprise လက္ခဏာများပါရှိသည့် အမြန် vector search
# - 🛡️ **Security Integration**: role-based access နှင့် ဒေတာကာကွယ်မှု ပုံစံများ
# - 🏢 **Scalable Architecture**: မောင့်တာန့်နှင့် အကောင်အထည်ဖော်ရန် အသင့် RAG စနစ်များ
#
# ## 🎯 Enterprise RAG Architecture
#
# ### Core Enterprise Components
# - **Microsoft Foundry**: လုံခြုံမှုနှင့် လိုက်နာမှုများပါရှိသည့် managed enterprise AI ပလက်ဖောင်း
# - **Persistent Agents**: စကားလျှို့ဝှက်ခြင်းသမိုင်းနှင့် context ကို စီမံခန့်ခွဲနိုင်သည့် stateful agents
# - **Vector Store Management**: enterprise-အဆင့် စာရွက်စာတမ်း ညိမ်းညမ်းခြင်းနှင့် ပြန်ရွာခြင်း
# - **Identity Integration**: Azure AD authentication နှင့် role-based access control
#
# ### .NET Enterprise Benefits
# - **Type Safety**: RAG အလုပ်ဆောင်မှုများနှင့် ဒေတာဖွဲ့စည်းမှုများအတွက် compile-time validation
# - **Async Performance**: non-blocking စာရွက်စာတမ်း ပြုပြင်ခြင်းနှင့် ရှာဖွေမှု လုပ်ဆောင်ချက်များ
# - **Memory Management**: ကြီးမားသော စာရွက်စာတမ်းစုစည်းမှုများအတွက် ထိရောက်သော အရင်းအမြစ် အသုံးပြုမှု
# - **Integration Patterns**: dependency injection ဖြင့် native Azure ဝန်ဆောင်မှုများ ထည့်သွင်းမှု ပုံစံများ
#
# ## 🏗️ Technical Architecture
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Core .NET Components
# - **Azure.AI.Agents.Persistent**: state persistence ပါရှိသော enterprise agent စီမံခန့်ခွဲမှု
# - **Azure.Identity**: Azure ဝန်ဆောင်မှုများသို့ လုံခြုံစွာ ဝင်ရောက်ရန် integrated authentication
# - **Microsoft.Agents.AI.AzureAI**: Azure အတွက် အထူးပြင်ဆင်ထားေသာ agent framework implementation
# - **System.Linq.Async**: မြင့်မားသော အသားပေး asynchronous LINQ လုပ်ဆောင်ချက်များ
#
# ## 🔧 Enterprise Features & Benefits
#
# ### Security & Compliance
# - **Azure AD Integration**: Enterprise identity management နှင့် authentication
# - **Role-Based Access**: စာရွက်စာတမ်း ဝင်ရောက်ခွင့်နှင့် လုပ်ဆောင်ချက်များအတွက် ကြော့ကောင်းသည့် ခွင့်ပြုချက်များ
# - **Data Protection**: သာမန်စာရွက်စာတမ်းများအတွက် rest နှင့် transit တွင် ထိုးထည့်ထားသော encryption
# - **Audit Logging**: လိုက်နာမှု လိုအပ်ချက်များအတွက် လုပ်ဆောင်ချက် အပြည့်အစုံ မှတ်တမ်းတင်ခြင်း
#
# ### Performance & Scalability
# - **Connection Pooling**: Azure ဝန်ဆောင်မှု ချိတ်ဆက်မှုများကို ထိရောက်စွာ စီမံခြင်း
# - **Async Processing**: high-throughput အခြေအနေများအတွက် non-blocking လုပ်ဆောင်ချက်များ
# - **Caching Strategies**: မကြာခဏ အသုံးပြုသော စာရွက်စာတမ်းများအတွက် အတွင်းခံ caching အကြံဥာဏ်များ
# - **Load Balancing**: ကြီးမားသော မျိုးဆက်ဖြန့်ချိမှုများအတွက် ဖော်ပြထားသော အလုပ်ခွဲခြင်း
#
# ### Management & Monitoring
# - **Health Checks**: RAG စနစ် အစိတ်အပိုင်းများအတွက် built-in မော်နီတာစနစ်များ
# - **Performance Metrics**: ရှာဖွေရေးအရည်အသွေးနှင့် တုံ့ပြန်ချိန်များအပေါ် အသေးစိတ် သုံးသပ်ချက်များ
# - **Error Handling**: retry policies ပါရှိသည့် အပြည့်အစုံ exception စီမံခန့်ခွဲမှု
# - **Configuration Management**: သတ်မှတ်ထားသည့် ပတ်ဝန်းကျင်အလိုက် ဆက်တင်များနှင့် validation
#
# ## ⚙️ Prerequisites & Setup
#
# **Development Environment:**
# - .NET 9.0 SDK သို့မဟုတ် အထက်
# - Visual Studio 2022 သို့မဟုတ် C# extension ပါရှိသော VS Code
# - AI Foundry အကောင့်ပါသော Azure subscription
#
# **Required NuGet Packages:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure Authentication Setup:**
# ```bash
# # Azure CLI ကို တပ်ဆင်ပြီး အတည်ပြုပါ။
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Environment Configuration (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Enterprise RAG Patterns
#
# ### Document Management Patterns
# - **Bulk Upload**: ကြီးမားသော စာရွက်စာတမ်းစုစည်းမှုများကို ထိရောက်စွာ 처리ခြင်း
# - **Incremental Updates**: စာရွက်စာတမ်းများကို real-time ဖြင့် ထပ်ထည့်ခြင်းနှင့် ပြင်ဆင်ခြင်း
# - **Version Control**: စာရွက်စာတမ်း ဗားရှင်းများနှင့် ပြောင်းလဲမှု မှတ်တမ်းတင်ခြင်း
# - **Metadata Management**: စာရွက်စာတမ်းများအတွက် သွင်းထားသော attribute များနှင့် taxonomy
#
# ### Search & Retrieval Patterns
# - **Hybrid Search**: semantic နှင့် keyword search ကို ပေါင်းစပ်၍ အကောင်းဆုံး ရလဒ်ရရှိစေခြင်း
# - **Faceted Search**: မျိုးစုံ စစ်ထုတ်ခြင်းနှင့် အမျိုးအစားအလိုက် သတ်မှတ်ခြင်း
# - **Relevance Tuning**: domain အလိုက် အထူး scoring အယ်လဂေါရිතမ်များ
# - **Result Ranking**: လုပ်ငန်းလိုက် business logic ထည့်သွင်း၍ အဆင့်ချခြင်း
#
# ### Security Patterns
# - **Document-Level Security**: စာရွက်စာတမ်း တစ်ခုချင်းစီအတွက် ကြော့ကောင်းသည့် access control
# - **Data Classification**: အလိုအလျောက် သတင်းအချက်အလက် အရေးပါတ်မှု အဆင့်သတ်မှတ်ခြင်းနှင့် ကာကွယ်မှု
# - **Audit Trails**: 모든 RAG လုပ်ဆောင်ချက်များအတွက် အပြည့်အစုံ မှတ်တမ်းတင်ခြင်း
# - **Privacy Protection**: PII တွေကို တွေ့ရှိ၍ ဖျောက်သိမ်းခြင်း စွမ်းရည်များ
#
# ## 🔒 Enterprise Security Features
#
# ### Authentication & Authorization
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Data Protection
# - **Encryption**: စာရွက်စာတမ်းများနှင့် search indices များအတွက် end-to-end encryption
# - **Access Controls**: user နှင့် group ခွင့်ပြုချက်များအတွက် Azure AD နှင့် ပေါင်းစည်းခြင်း
# - **Data Residency**: လိုက်နာမှုအတွက် ဒေတာတည်နေရာ ဧရိယာ ထိန်းချုပ်မှုများ
# - **Backup & Recovery**: automated backup နှင့် disaster recovery စွမ်းရည်များ
#
# ## 📈 Performance Optimization
#
# ### Async Processing Patterns
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Memory Management
# - **Streaming Processing**: မေမရီပြဿနာ မဖြစ်စေဘဲ ကြီးမားသော စာရွက်စာတမ်းများကို 처리နိုင်မှု
# - **Resource Pooling**: သင့်တော်သော အကြမ်းဖျင်း အရင်းအမြစ်များကို ထပ်မံ အသုံးပြုခြင်း
# - **Garbage Collection**: memory လက်ဝဲဝဲ ရယူမှု ညှိနှိုင်းထားသော ပုံစံများ
# - **Connection Management**: Azure ဝန်ဆောင်မှု ချိတ်ဆက်မှုများ၏ သက်တမ်းစီမံခန့်ခွဲမှု
#
# ### Caching Strategies
# - **Query Caching**: မကြာခဏ လုပ်ဆောင်သော ရှာဖွေမှုများကို cache ထားခြင်း
# - **Document Caching**: hot စာရွက်စာတမ်းများအတွက် in-memory caching
# - **Index Caching**: optimized vector index caching
# - **Result Caching**: ဖန်တီးထားသည့် ဖြေရှင်းချက်များကို သိပ္ပံကျဖွယ် caching
#
# ## 📊 Enterprise Use Cases
#
# ### Knowledge Management
# - **Corporate Wiki**: ကုမ္ပဏီ အသိပညာဗေဒာများ အလျှာပေါ်ရှိ အချက်အလက်များကို အင်တယ်လစ်ဂျင့်န့်ရှာဖွေရေး
# - **Policy & Procedures**: အလိုအလျောက် လိုက်နာမှုနှင့် လုပ်ထုံးလုပ်နည်း ညွှန်ကြားမှု
# - **Training Materials**: လေ့လာရေးနှင့် ဖွံ့ဖြိုးရေး အကူအညီ အချက်အလက်များ
# - **Research Databases**: ပညာရှင်နှင့် သုတေသနစာတမ်း များကို ခေတ်မီ စိတ်ကူးဖြင့် စိစစ်ခြင်း စနစ်များ
#
# ### Customer Support
# - **Support Knowledge Base**: အလိုအလျော customer service ဖြေကြားချက်များ
# - **Product Documentation**: ထုတ်ကုန် အချက်အလက် ရှာဖွေရေး အင်တယ်လစ်ဂျင့်
# - **Troubleshooting Guides**: context အလိုက် ပြဿနာဖြေရှင်းနည်း များ
# - **FAQ Systems**: စာရွက်စာတမ်းစုစည်းမှုများမှ dynamic FAQ ဖန်တီးခြင်း
#
# ### Regulatory Compliance
# - **Legal Document Analysis**: စာချုပ်နှင့် ဥပဒေရေးစာရွက်စာတမ်း အချက်အလက် ဗဟုသုတ
# - **Compliance Monitoring**: automated regulatory compliance စစ်ဆေးခြင်း
# - **Risk Assessment**: စာရွက်စာတမ်း အပေါ် မူတည်၍ ဧကရာဇ် အကဲဖြတ်ခြင်းနှင့် အစီရင်ခံ
# - **Audit Support**: audit များအတွက် အချက်အလက် ရှာဖွေရေး အကူအညီ
#
# ## 🚀 Production Deployment
#
# ### Monitoring & Observability
# - **Application Insights**: အသေးစိတ် telemetry နှင့် performance မော်နီတာခြင်း
# - **Custom Metrics**: စီးပွားရေး အထူး KPI လိုက်နာခြင်းနှင့် အရေးပေါ် အချက်အလက် သတိပေးချက်များ
# - **Distributed Tracing**: ဝန်ဆောင်မှုများအနှံ့ အဆုံးမှ အဆုံး request tracking
# - **Health Dashboards**: စနစ် ကျန်းမာမှုနှင့် performance ကို အချိန်နှင့်တပြေးညီ ကြည့်ရှုနိုင်သော dashboard များ
#
# ### Scalability & Reliability
# - **Auto-Scaling**: load နှင့် performance metrics အပေါ်မူတည်၍ အလိုအလျောက် အရွယ်ချိန်ညှိခြင်း
# - **High Availability**: failover အင်အားပါရှိသည့် multi-region ထုတ်ပိုးခြင်း
# - **Load Testing**: enterprise-level load အောက်တွင် performance ကို သတ်မှတ်၍ စစ်ဆေးခြင်း
# - **Disaster Recovery**: automated backup နှင့် recovery လုပ်ထုံးလုပ်နည်းများ
#
# Ready to build enterprise-grade RAG systems that can handle sensitive documents at scale? Let's architect intelligent knowledge systems for the enterprise! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **တာဝန်ပယ်ချခြင်း**:
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှုဖြစ်သည့် [Co-op Translator](https://github.com/Azure/co-op-translator) ဖြင့် ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှုကို ကြိုးစားပါသဖြင့်၊ သို့သော် အလိုအလျောက် ဘာသာပြန်ချက်များတွင် အမှားများ သို့မဟုတ် မမှန်ကန်ချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါ။ မူလစာတမ်းကို မူလဘာသာဖြင့်သာ တရားဝင် အရင်းအမြစ်အဖြစ် ယူဆသင့်ပါသည်။ အရေးကြီးသော အချက်အလက်များအတွက် များသောအားဖြင့် ပရော်ဖက်ရှင်နယ် လူ့ဘာသာပြန် အစီအစဉ်ကို အသုံးပြုရန် အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်အသုံးပြုမှုမှ ဖြစ်ပေါ်လာသည့် နားလည်မှုမမှန်ခြင်းများ သို့မဟုတ် မှားယွင်းဖော်ပြချက်များအတွက် ကျွန်ုပ်တို့သည် တာဝန်မယူပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
