# %% [markdown]
# ## **နမူနာများ - ဟိုတယ်ဘွတ်ကင်လုပ်ရန် မျိုးစုံ AI ကိုယ်စားလှယ်များ**
#
# ယနေ့ခေတ်မြန်ဆန္ဒရွိသည့်ကမ္ဘာတွင်၊ စီးပွားရေးခရီးစဉ်အစီအစဉ်ရေးဆွဲခြင်းသည် လေယာဉ်တစ်စီးနှင့် ဟိုတယ်အခန်းတစ်ခန်းဘွတ်ကင်မှာခြင်းထက်ပိုပြီး ဖြစ်ပါသည်။ ၎င်းသည် စနစ်တကျညှိနှိုင်းမှုနှင့် ထိရောက်မှုတစ်ခုလိုအပ်ပြီး၊ ၎င်းကိုရရှိရန်အခက်အခဲကြုံတွေ့နိုင်သည်။ ဒီမှာ မျိုးစုံ AI ကိုယ်စားလှယ်များ ပါဝင်လာပြီး၊ ကျွန်ုပ်တို့၏ခရီးစဉ်လိုအပ်ချက်များကိုစီမံခန့်ခွဲသည့်နည်းကိုတိုးတက်ပြောင်းလဲစေသည်။
#
# သင်၏အသုံးပြုရန်အတွက် မြန်မာျမန္မာ AI ကိုယ်စားလှယ်အဖွဲ့တစ်ခုရှိပြီး၊ ခရီးစဉ်၏အပိုင်းတိုင်းကို ကြည့်ရှုပြီး တိကျပြည့်စုံမှုနှင့်လွယ်ကူမှုဖြင့် အလုပ်လုပ်ဆောင်ကြောင်း စဥ်းစားကြည့်ပါ။ ကျွန်ုပ်တို့၏အဆင့်မြင့် AI နည်းပညာဖြင့်၊ ဝန်ဆောင်မှုဘွတ်ကင်လုပ်ရန်နှင့် ခရီးစဉ်စီစဉ်ရေးဆွဲရန် အထူးပြုကိုယ်စားလှယ်များကို ဖန်တီးခဲ့ပြီး၊ ခရီးသွားမှုကို အဆင်ပြေပြီး စိတ်ပင်ပန်းမှုကင်းစေသည့် အတွေ့အကြုံတစ်ခု ရရှိစေခဲ့ပါသည်။
#
# ဤသည်မှာ အခြေခံနမူနာတစ်ခု ဖြစ်သည်။ စီးပွားရေးခရီးတစ်ခုအစီအစဉ်ရေးဆွဲစဉ်၊ လေယာဉ်လက်မှတ်အချက်အလက်၊ ဟိုတယ်အချက်အလက် စသဖြင့် အချက်အလက်ရယူရန် စီးပွားရေးခရီးသွားကိုယ်စားလှယ်နှင့်အတူ ဆွေးနွေးရန်လိုအပ်သည်။ AI ကိုယ်စားလှယ်များမှတဆင့် ဝန်ဆောင်မှုဘွတ်ကင်လုပ်ရန်ကိုယ်စားလှယ်များနှင့် ခရီးစဉ်စီစဉ်ရေးဆွဲရန်ကိုယ်စားလှယ်များကို တည်ဆောက်ပြီး ပူးပေါင်းဆောင်ရွက်ခြင်းဖြင့် ဉာဏ်ရည်အဆင့်ကို မြှင့်တင်နိုင်ပါသည်။

# %% [markdown]
# # Azure AI Agent Service ကို စတင်အသုံးပြုခြင်းနှင့် **.env** မှ ဖန်တီးထားသော configuration သတင်းအချက်များရယူခြင်း
#
# ### **.env**
#
# .env ဖိုင်တစ်ခု ဖန်တီးပါ
#
# **.env** တွင် Azure AI Agent Service ၏ ချိတ်ဆက်မှု string၊ AOAI မှ အသုံးပြုမည့် မော်ဒယ်နှင့် ဆက်စပ် Google API Search service API, ENDPOINT စသည့် အသေးစိတ်များ ပါဝင်သည်။
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "သင့် Azure AI Agent Service Model Deployment အမည်"
#
# [**NOTE**] မိနစ်ကို တိုကင် 100,000 ရှိသည့် မော်ဒယ်လမ်းကြောင်းနှင့် မိနစ်ကို တောင်းဆိုမှု 600 ရှိသည့် Rate Limit လိုအပ်ပါသည်။
#
#   Microsoft Foundry - Model and Endpoint ၌ မော်ဒယ် ရယူနိုင်သည်။
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "သင့် Azure AI Agent Service Project Connection String"
#
#   AI ​​Foundry Portal မျက်နှာပြင်၏ project overview တွင် Project Connection String ရယူနိုင်သည်။
#
# - **SERPAPI_SEARCH_API_KEY** = "သင့် SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "သင့် SERPAPI Search Endpoint"
#
# Azure AI Agent Service ၏ Model Deployment Name နှင့် Project Connection String ရယူရန်၊ Azure AI Agent Service ကိုဖန်တီးရမည်။ [ဒီ template](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ကို အသုံးပြုပြီး တိုက်ရိုက်ဖန်တီးရန် အကြံပြုထားသည် (***မှတ်ချက်:*** Azure AI Agent Service သည် လက်ရှိတွင် အကန့်အသတ်ရှိသည့် ဒေသများတွင်သာ သတ်မှတ်ထားသည်။ [ဒီလင့်ခ်](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ကို လေ့လာပြီး ဒေသကို သတ်မှတ်ရန် အကြံပြုသည်)
#
# Agent သည် SERPAPI အသုံးပြုရန် လိုအပ်သည်။ [ဒီလင့်ခ်](https://serpapi.com/searches) မှာ မှတ်ပုံတင်ပြီး သီးသန့် API KEY နှင့် ENDPOINT ရယူနိုင်သည်။

# %% [markdown]
# # Azure သို့ လော့ဂ်အင် ဝင်ရန်
#
# တကယ်တော့ သင် Azure ထဲဝင်ရန် လော့ဂ်အင် ပြုလုပ်ရန် လိုအပ်ပါသည်။ VScode မှ terminal တစ်ခုဖွင့်ပြီး `az login` command ကို ရိုက်ထည့်ပါ။

# %% [markdown]
# # Setup
#
# To run this notebook, you will need to install the following libraries. Here is a list of the required libraries and the corresponding pip install commands:
#
# azure-identity: Azure သို့ အတည်ပြုခွင့်ရယူရန်။
# requests: HTTP အတောင်းများ ဆောင်ရွက်ရန်။
# semantic-kernel: semantic kernel framework အတွက် (ဤသည်မှာ custom သို့မဟုတ် သီးသန့် library ဖြစ်နိုင်ပြီး၊ သင့်အား သီးသန့်ရင်းမြစ် သို့မဟုတ် repository မှ ထည့်သွင်းရန်လိုအပ်နိုင်သည်)।

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Explanation:
# import asyncio: ၎င်းသည် Python တွင် asynchronous programming အား ပံ့ပိုးပေးသည့် asyncio module ကို імпорт လုပ်သည်။ ၎င်းသည် async နှင့် await သရုပ်မှန်များကို အသုံးပြု၍ တပြိုင်နက် ကုဒ်ရေးသားနိုင်စေသည်။
# from typing import Annotated: ၎င်းသည် typing module မှ Annotated type ကို імпорт လုပ်သည်။ Annotated ကို တိုင်းထွာရေးအတွက် metadata ထည့်ရန် အသုံးပြုသည်၊ ၎င်းသည် အတည်ပြုချက်၊ စာရွက်စာတမ်း၊ သို့မဟုတ် ကိရိယာများအတွက် အသုံးဝင်နိုင်သည်။

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Explanation:
# dotnev မှ load_dotenv ကို import လုပ်ပြီး load_dotenv() ကိုသုံးခြင်းအားဖြင့် သင်သည် configuration settings နှင့် sensitive အချက်အလက်များ (API keys နှင့် database URLs ကဲ့သို့သော) ကို .env ဖိုင်တစ်ခုထဲတွင် လွယ်ကူစွာ စီမံခန့်ခွဲနိုင်ပြီး၊ source code မှ သီးခြားထား၍ သင့် application ကို လုံခြုံပြီး configure လုပ်ရလွယ်ကူစေပါသည်။

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Explanation:
#
# Import Statement: from azure.identity.aio import DefaultAzureCredential: ၎င်းသည် azure.identity.aio module မှ DefaultAzureCredential class ကို import လုပ်သည်။ aio ဆိုသည်မှာ asynchronous operations အတွက် အထူးသဖြင့် ဒီ module ကို ဒီဇိုင်းပြုလုပ်ထားကြောင်းကို ပြသသည်။
#
# Purpose of DefaultAzureCredential: DefaultAzureCredential class သည် Azure SDK for Python ၏ အစိတ်အပိုင်းတစ်ခုဖြစ်သည်။ ၎င်းသည် Azure ဝန်ဆောင်မှုများနှင့် စနစ်တကျ authentication ပြုလုပ်ရန် ပုံမှန်နည်းလမ်းတစ်ခုဖြစ်သည်။ ၎င်းသည် environment variables၊ managed identity နှင့် Azure CLI credentials ကဲ့သို့သော အတည်ပြုမှု နည်းလမ်းမျိုးစုံကို တိကျစွာ စဉ်ဆက်မပြတ် ကြိုးစားခွင့်ပြုသည်။
#
# Asynchronous Operations: aio module သည် DefaultAzureCredential class သည် asynchronous operations များကို ပံ့ပိုးကြောင်း ပြသသည်။ ၎င်းက asyncio နှင့်အတူ အသုံးပြု၍ non-blocking authentication requests များကို ဖော်ဆောင်နိုင်သည်။

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Explanation:
# semantic_kernel package မှ နောက်ထပ် modules နှင့် classes များကို import လုပ်သည်။ အောက်ပါအတိုင်း import လုပ်ထားသော အချက်အလက်များ ကို ဖော်ပြထားသည်-
#
# semantic_kernel.agents မှ AgentGroupChat - ဤ class သည် AI agents များအတွက် group chat နှင့် ဆက်စပ်သော အလုပ်လုပ်နိုင်မှုများကို ကိုင်တွယ်ပေးသည်။
# semantic_kernel.agents.azure_ai မှ AzureAIAgent နှင့် AzureAIAgentSettings
#
# AzureAIAgent - Azure AI ဝန်ဆောင်မှုများကို အသုံးပြုသော AI agent များကို ဖန်တီး၊ စီမံထိန်းချုပ်ရန် အတွက် သတ်မှတ်ထားသော class ဖြစ်သည်။
#
# AzureAIAgentSettings - AzureAIAgent အတွက် ဆက်တင်များကို သတ်မှတ်ရန် အသုံးပြုသည်။
# semantic_kernel.agents.strategies.termination.termination_strategy မှ TerminationStrategy-
#
# ဤ class သည် AI agent များ၏ လည်ပတ်မှုကို အချို့သော အခြေအနေများတွင် ပြတ်တောက်ရန် ရည်ရွယ်သော စနစ်များကို သတ်မှတ်ပေးသည်။
# semantic_kernel.contents.chat_message_content မှ ChatMessageContent-
#
# ဤ class သည် chat messages များ၏ ဝတ္ထုအကြောင်းအရာများကို ကိုင်တွယ်ရန် အသုံးပြုသည်။
# semantic_kernel.contents.utils.author_role မှ AuthorRole-
#
# ဤ class သည် chat message များအတွက် အကြောင်းပြု ကုန်သူအဖြစ် 역할များကို သတ်မှတ်ပေးသည်။
#
# semantic_kernel.functions.kernel_function_decorator မှ kernel_function-
# ဤ decorator သည် semantic kernel ပုံစံအတွင်း အလုပ်ကိုင်နိုင်သော kernel functions များ သတ်မှတ်ရန် အသုံးပြုသည်။
# ဤ Imports များသည် group chat ပတ်ဝန်းကျင်တွင် ဆက်သွယ်နိုင်သော AI agents များကို ဖန်တီး၊ စီမံရန် လိုအပ်သော အစိတ်အပိုင်းများကို ပြင်ဆင်ပေးပြီး၊ hotel booking သို့မဟုတ် ဆင်တူလုပ်ဆောင်ချက်များအတွက် အသုံးပြုနိုင်သည်။

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Explanation:
# Next we import the CodeInterpreterTool class from the azure.ai.projects.models module.
#
# CodeInterpreterTool: ဒီ class က Azure AI SDK ရဲ့ အစိတ်အပိုင်းဖြစ်ပြီး AI ပရောဂျက်တွေရဲ့ context အတွင်းမှာ code ကို interpret လုပ်ပြီး 실행ရန် အသုံးပြုတယ်။ ဒါက code snippets တွေ run လုပ်၊ code ကို 분석၊ ဒါမှမဟုတ် AI workflow တွေထဲမှာ code 실행 ပေါင်းစပ်မှုလုပ်ဆောင်ဖို့ 기능တွေ ပေးတယ်။
# ဒီ import က သင့်ပရောဂျက်မှာ CodeInterpreterTool ကို အသုံးပြုဖို့ လိုအပ်တဲ့ component ကို စတင်တပ်ဆင်ပေးပြီဖြစ်ပြီး၊ ဒါက dynamic အတိုင်းအတာနဲ့ code ကို interpret လုပ်ပြီး 실행ရတဲ့ အလုပ်တွေအတွက် အသုံးဝင်နိုင်တယ်။

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # ရှင်းလင်းချက်:
# ApprovalTerminationStrategy class သည် AI ကိုယ်စားလှယ်၏ လုပ်ဆောင်မှုကို သတ်မှတ်ထားသော ဘက်စုံစွမ်းရည်တစ်ခုဖြစ်သည်။ အခုကိုယ်စားလှယ်သည် ၎င်း၏ ဆက်သွယ်မှုသမိုင်းတွင် နောက်ဆုံးစာတိုက်စာတစ်ခုတွင် "saved" ဆိုသော စကားလုံးပါဝင်လျှင် ပိတ်သိမ်းမည် ဖြစ်သည်။ ၎င်းသည် အလုပ်တာဝန်ပြီးဆုံးသည့်အခါ "saved" ဖြစ်ကြောင်း အတည်ပြုချက်ကို ရရှိသည့်အခါ အသုံးဝင်နိုင်သည်။ ဆက်သွယ်မှုနည်းလမ်းကို သတ်မှတ်ပါ။ ရှယ်ယာအစီအစဉ်ကို သိမ်းဆည်းပြီးနောက် "saved" အချက်ပြ SIG ကို လက်ခံရရှိရာတွင် ပိတ်နိုင်ပါသည်။

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Explanation:
#
# ကုဒ်လိုင်းသည် create() 메소드를 호출하여 기본값 또는 미리 정의된 설정으로 AzureAIAgentSettings 객체를 초기화합니다. 이 설정 객체(ai_agent_settings)는 이후 AzureAIAgent 인스턴스를 구성하고 관리하는 데 사용할 수 있습니다.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Explanation:
# requests 라이브러리를 임포트하면 Python 코드에서 쉽게 HTTP 요청을 만들고 웹 서비스와 상호 작용할 수 있습니다.

# %%
import requests

# %% [markdown]
# # Explanation:
# ဒီဟာက SERP (Search Engine Results Page) API ဝန်ဆောင်မှုကိုဝင်ရောက်အသုံးပြုဖို့အတွက် API key ကိုသိမ်းဆည်းထားတဲ့ variable ဖြစ်ပါတယ်။ API key ဆိုတာက သင့်အကောင့်နဲ့ဆက်စပ်တဲ့ တောင်းဆိုမှုတွေကို အတည်ပြုဖို့အသုံးပြုတဲ့ ထူးခြားသတ်မှတ်မှတ်တမ်းတစ်ခုပါ။
#
# 'GOOGLE_SEARCH_API_KEY': ဒီဟာက placeholder string တစ်ခုဖြစ်ပါတယ်။ သင့်ရဲ့ အမှန်တကယ် SERP API keyနဲ့ 'GOOGLE_SEARCH_API_KEY' ကို အစားထိုးဖို့လိုပါတယ်။
#
# ရည်ရွယ်ချက်: ဒီလိုင်းရဲ့ရည်ရွယ်ချက်က API key ကို variable တစ်ခုထဲမှာသိမ်းဆည်းထားပြီး SERP API ဝန်ဆောင်မှုကိုတောင်းဆိုမှုတွေကို အတည်ပြုဖို့အသုံးပြုနိုင်စေရန်ဖြစ်ပါတယ်။ API key က ဝန်ဆောင်မှုကို ဝင်ရောက်အသုံးပြုဖို့နဲ့ ရှာဖွေမှုတွေပြုလုပ်ဖို့လိုအပ်ပါတယ်။
#
# SERP API Key ရယူနည်း: SERP API key ရယူဖို့အတွက် https://serpapi.com မှာ အထွေထွေ အဆင့်တွေကိုလိုက်နာပါ (သင်အသုံးပြုနေတဲ့ SERP API ဝန်ဆောင်မှုအပေါ်မူတည်ပြီး အတိအကျအဆင့်တွေကွာခြားနိုင်ပါတယ်)။
#
# SERP API ဝန်ဆောင်မှုတစ်ခုရွေးချယ်ပါ: SerpAPI, Google Custom Search JSON API နဲ့ အခြား SERP API ဝန်ဆောင်မှုတွေရှိပါတယ်။ သင့်လိုအပ်ချက်အတွက် အကောင်းဆုံးသော ဝန်ဆောင်မှုကို ရွေးချယ်ပါ။
#
# အကောင့်တစ်ခုဖွင့်ပါ:
#
# ရွေးချယ်ထားတဲ့ SERP API ဝန်ဆောင်မှု https://www.serpapi.com ကိုသွားပြီး အကောင့်တစ်ခုဖွင့်ပါ။ အခြေခံအချက်အလက်တစ်ချို့ပေးပို့ရနိုင်ပြီး အီးမေးလ်လိပ်စာကိုအတည်ပြုဖို့လိုနိုင်ပါတယ်။
#
# API Key တစ်ခုဖန်တီးပါ:
#
# အကောင့်ဖွင့်ပြီးပါက သင့်အကောင့်ထဲ ဝင်ပြီး API အပိုင်း သို့မဟုတ် ဒပ်ရှ်ဘုတ်ကိုသွားပါ။ API key အသစ်ဖန်တီးရန် သို့မဟုတ်ထုတ်လုပ်ရန် ရွေးချယ်မှုကိုရှာပါ။
# API Key ကိုကူးယူပါ:
#
# API key ထုတ်လုပ်ပြီးသွားပါက ထို key ကို ကူးယူပါ။ ထို key ကို SERP API ဝန်ဆောင်မှုသို့ တောင်းဆိုမှုတွေကို အတည်ပြုဖို့ အသုံးပြုပါလိမ့်မယ်။
# Placeholder ကိုအစားထိုးပါ:
#
# သင့်ရဲ့ .env ဖိုင်ထဲမှာရှိတဲ့ placeholder ကို အစားထိုးပါ။

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Explanation:
# BookingPlugin class သည် Serpapi.com Google Search API ကိုအသုံးပြုပြီး ဟိုတယ်နှင့် ထပ်မံခရီးစဉ်များစာရင်းပေးခြင်းအတွက် နည်းလမ်းများကို ပေးသည်။ ၎င်းသည် လိုအပ်သော ပါရာမီတာများကို ဖန်တီး၊ API တောင်းဆိုမှုများကို ပြုလုပ်၊ ပြန်လည်တိုက်ဆိုင်မှုကို လုပ်ဆောင်ကာ သက်ဆိုင်ရာ booking အချက်အလက်များကို ပြန်ပေးသည်။ API key (SERPAPI_SEARCH_API_KEY) နှင့် endpoint (SERPAPI_SEARCH_ENDPOINT) ကို Google Search API တွင် အသုံးပြုခြင်းနှင့် တောင်းဆိုမှုများပို့ရန် သက်ဆိုင်သည်။

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Explanation:
# The SavePlugin class သည် Azure AI ဝန်ဆောင်မှုများကိုအသုံးပြု၍ ခရီးစဉ်အစီအစဉ်များကိုသိမ်းဆည်းရန် saving_plan ဟုခေါ်သောမက်သော့တစ်ခုကိုပေးသည်။ ၎င်းသည် Azure မှတ်ပုံတင်အချက်အလက်များကိုသတ်မှတ်၊ AI ကိုယ်စားလှယ်တစ်ဦးကိုဖန်တီး၊ အသုံးပြုသူရဲ့အချက်အလက်များကိုစီမံကိန်းပါဝင်ပစ္စည်းတင်ဆက်ထုတ်လုပ်၍ သိမ်းဆည်းခြင်းဆိုင်ရာလုပ်ငန်းဆောင်တာများကိုကဏ္ဍဖြတ်ဆောင်ရွက်ပြီး ဖိုင်သိမ်းခြင်းနှင့် သန့်ရှင်းရေးလုပ်ငန်းဆောင်တာများကိုစောင့်ကြပ်ပေးသည်။ မက်သော့သည် အောင်မြင်စွာပြီးဆုံးပါက "Saved" ကိုပြန်အပ်သည်။

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # ရှင်းလင်းချက်:
# ဤကုဒ်သည် အသုံးပြုသူ၏အချက်အလက်များအရ လေယာဉ်လက်မှတ်နှင့် ဟိုတယ့်များစာရင်းသွင်းခြင်း၊ ခရီးစဉ်အစီအစဉ်များသိမ်းဆည်းခြင်းတို့ကို ကိုင်တွယ်ရန် Azure AI အေးဂျင့်များကိုစီစဉ်ထားသည်။ ၎င်းသည် Azure အမှတ်ပြုလက်မှတ်များကို အသုံးပြု၍ အေးဂျင့်များကို ဖန်တီးကာ စနစ်တကျ ပြင်ဆင်ပြီး အသုံးပြုသူ၏ အချက်အလက်များကို အုပ်စုစကားပြောမှတဆင့် ကိုင်တွယ်ကာ လုပ်ငန်းများပြီးစီးသည့်အခါ သေချာစွာ လုပ်ငန်းနောက်ပြန်သန့်ရှင်းချက် ပြုလုပ်သည်။ အဲ့ဒီအေးဂျင့်များသည် ၎င်းတို့တာဝန်ယူဆောင်ရွက်ရမည့် လုပ်ငန်းများအတွက် BookingPlugin နှင့် SavePlugin ဆိုသည့် ထူးခြားသော ပလက်ဂင်များကို အသုံးပြုသည်။

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **အကြောင်းကြားချက်**
# ဤစာရွက်စာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှုဖြစ်သော [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ တိကျမှန်ကန်မှုအတွက် ကြိုးစားပေမယ့် အလိုအလျောက်ဘာသာပြန်မှုတွင် အမှားများ သို့မဟုတ် မှားယွင်းမှုများ ဖြစ်ပေါ်နိုင်ကြောင်း သတိပြုရန်လိုအပ်ပါသည်။ မူရင်းစာရွက်စာတမ်းကို သင်၏ဒေသခံဘာသာစကားဖြင့်သာ အတိအကျ အာဏာရှိသော အရင်းအမြစ်အဖြစ် ယူဆသင့်ပါသည်။ အရေးကြီးသောသတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူ့ဘာသာပြန်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်မှု အသုံးပြုရာမှ ဖြစ်ပေါ်လာနိုင်သည့် အနားလွဲမှုများ သို့မဟုတ် မှားကြီးမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မယူပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
