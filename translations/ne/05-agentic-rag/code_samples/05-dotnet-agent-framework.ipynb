# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) सहित उद्यम RAG
#
# ## 📋 सिकाइ उद्देश्यहरू
#
# यो नोटबुकले Microsoft Foundry सँग .NET मा Microsoft Agent Framework प्रयोग गरेर उद्यम-स्तरको Retrieval-Augmented Generation (RAG) प्रणालीहरू कसरी बनाउन सकिन्छ भनेर देखाउँछ। तपाईंले उत्पादन-तयार एजेन्टहरू सिर्जना गर्न सिक्नुहुनेछ जुन कागजातहरू खोज्न सक्छन् र उद्यम सुरक्षा र स्केलेबिलिटीका साथ सही, प्रसंग-सचेत उत्तरहरू प्रदान गर्न सक्छन्।
#
# **तपाईंले निर्माण गर्ने उद्यम RAG क्षमताहरू:**
# - 📚 **कागजात बुद्धिमत्ता**: Azure AI सेवाहरू संग उन्नत कागजात प्रसोधन
# - 🔍 **सेमान्टिक सर्च**: उद्यम सुविधाहरू भएको उच्च-प्रदर्शन भेक्टर खोज
# - 🛡️ **सुरक्षा एकीकरण**: भूमिका-आधारित पहुँच र डाटा सुरक्षा ढाँचा
# - 🏢 **स्केलेबल वास्तुकला**: अनुगमन सहित उत्पादन-तयार RAG प्रणालीहरू
#
# ## 🎯 उद्यम RAG वास्तुकला
#
# ### मुख्य उद्यम अवयवहरू
# - **Microsoft Foundry**: सुरक्षा र अनुपालन सहित व्यवस्थापित उद्यम AI प्लेटफर्म
# - **Persistent Agents**: कुराकानी इतिहास र सन्दर्भ व्यवस्थापन भएको स्टेटफुल एजेन्टहरू
# - **भेक्टर स्टोर व्यवस्थापन**: उद्यम-स्तरको कागजात इंडेक्सिङ र प्राप्ति
# - **पहिचान एकीकरण**: Azure AD प्रमाणीकरण र भूमिका-आधारित पहुँच नियन्त्रण
#
# ### .NET उद्यम लाभहरू
# - **Type Safety**: RAG अपरेसन र डाटा संरचनाहरूका लागि कम्पाइल-समय मान्यकरण
# - **Async Performance**: नन-ब्लकिङ कागजात प्रसोधन र खोज अपरेसनहरू
# - **Memory Management**: ठूलो कागजात संग्रहहरूको लागि कुशल स्रोत उपयोग
# - **Integration Patterns**: निर्भरता इन्जेक्सनसहित नेटिभ Azure सेवा एकीकरण
#
# ## 🏗️ प्राविधिक वास्तुकला
#
# ### उद्यम RAG पाइपलाइन
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### मुख्य .NET अवयवहरू
# - **Azure.AI.Agents.Persistent**: स्टेट स्थायित्वसहित उद्यम एजेन्ट व्यवस्थापन
# - **Azure.Identity**: सुरक्षित Azure सेवा पहुँचका लागि एकीकृत प्रमाणीकरण
# - **Microsoft.Agents.AI.AzureAI**: Azure-अनुकूलित एजेन्ट फ्रेमवर्क कार्यान्वयन
# - **System.Linq.Async**: उच्च-प्रदर्शन असिन्क्रोनस LINQ अपरेसनहरू
#
# ## 🔧 उद्यम सुविधाहरू र लाभहरू
#
# ### सुरक्षा र अनुपालन
# - **Azure AD एकीकरण**: उद्यम पहिचान व्यवस्थापन र प्रमाणीकरण
# - **भूमिका-आधारित पहुँच**: कागजात पहुँच र अपरेसनहरूको लागि सूक्ष्म-स्तरीय अनुमति
# - **डाटा सुरक्षा**: संवेदनशील कागजातहरूको लागि रेस्टमा र ट्रान्जिटमा इन्क्रिप्सन
# - **अडिट लगिङ**: अनुपालन आवश्यकताहरूका लागि व्यापक गतिविधि ट्र्याकिङ
#
# ### प्रदर्शन र स्केलेबिलिटी
# - **कनेक्सन पूलिङ**: Azure सेवा कनेक्सन व्यवस्थापनमा कुशलता
# - **Async प्रसोधन**: उच्च-थ्रुपुट परिदृश्यहरूको लागि नन-ब्लकिङ अपरेसनहरू
# - **क्याचिङ रणनीतिहरू**: बारम्बार पहुँच गरिने कागजातहरूको लागि बुद्धिमानी क्याचिङ
# - **लोड ब्यालेन्सिङ**: ठूलो-स्केल डिप्लोइमेन्टहरूको लागि वितरण गरिएको प्रसोधन
#
# ### व्यवस्थापन र अनुगमन
# - **हेल्थ चेकहरू**: RAG सिस्टम अवयवहरूको लागि बिल्ट-इन अनुगमन
# - **प्रदर्शन मेट्रिक्स**: खोज गुणस्तर र प्रतिक्रिया समयमा विस्तृत विश्लेषण
# - **त्रुटि ह्यान्डलिङ**: रिट्राइ नीतिहरू सहित व्यापक अपवाद व्यवस्थापन
# - **कन्फिगरेसन व्यवस्थापन**: वातावरण-विशिष्ट सेटिङहरू साथमा मान्यकरण
#
# ## ⚙️ पूर्वआवश्यकताहरू र सेटअप
#
# **विकास वातावरण:**
# - .NET 9.0 SDK or higher
# - Visual Studio 2022 वा VS Code सँग C# एक्सटेन्सन
# - AI Foundry पहुँच सहित Azure सदस्यता
#
# **आवश्यक NuGet प्याकेजहरू:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure प्रमाणीकरण सेटअप:**
# ```bash
# # Azure CLI स्थापना गर्नुहोस् र प्रमाणिकरण गर्नुहोस्
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **पर्यावरण कन्फिगरेसन (.env फाइल):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 उद्यम RAG ढाँचाहरू
#
# ### कागजात व्यवस्थापन ढाँचाहरू
# - **Bulk Upload**: ठूलो कागजात संग्रहहरूको कुशल प्रसोधन
# - **Incremental Updates**: वास्तविक-समय कागजात थप र संशोधन
# - **Version Control**: कागजात भर्सनिङ र परिवर्तन ट्र्याकिङ
# - **Metadata Management**: समृद्ध कागजात गुणहरू र वर्गीकरण
#
# ### खोज र प्राप्ति ढाँचाहरू
# - **Hybrid Search**: उत्तम परिणामका लागि सेम्यान्टिक र कुञ्जीशब्द खोजको संयोजन
# - **Faceted Search**: बहु-आयामी फिल्टरिङ र वर्गीकरण
# - **Relevance Tuning**: डोमेन-विशिष्ट आवश्यकताहरूका लागि कस्टम स्कोरिङ एल्गोरिदमहरू
# - **Result Ranking**: व्यापारिक लॉजिक एकीकरणसहित उन्नत र्याङ्किङ
#
# ### सुरक्षा ढाँचाहरू
# - **Document-Level Security**: प्रत्येक कागजातका लागि सूक्ष्म-स्तरीय पहुँच नियन्त्रण
# - **Data Classification**: स्वत: संवेदनशीलता लेबलिङ र सुरक्षा
# - **Audit Trails**: सबै RAG अपरेसनहरूको व्यापक लगिङ
# - **Privacy Protection**: PII पत्ता लगाउने र रेड्याक्सन क्षमता
#
# ## 🔒 उद्यम सुरक्षा सुविधाहरू
#
# ### प्रमाणीकरण र अधिकार
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### डाटा सुरक्षा
# - **इन्क्रिप्सन**: कागजात र खोज सूचकांकहरूको लागि सुरुदेखि अन्त्यसम्मको इन्क्रिप्सन
# - **Access Controls**: प्रयोगकर्ता र समूह अनुमतिका लागि Azure AD सँग एकीकरण
# - **Data Residency**: अनुपालनको लागि भौगोलिक डाटा स्थान नियंत्रणहरू
# - **Backup & Recovery**: स्वचालित ब्याकअप र डिजास्टर रिकभरी क्षमता
#
# ## 📈 प्रदर्शन अनुकूलन
#
# ### Async प्रसोधन ढाँचाहरू
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### मेमोरी व्यवस्थापन
# - **Streaming Processing**: ठूलो कागजातहरू मेमोरी समस्या बिना व्यवस्थापन गर्ने
# - **Resource Pooling**: महँगो स्रोतहरूको प्रभावकारी पुन:प्रयोग
# - **Garbage Collection**: अनुकूलित मेमोरी आवंटन ढाँचाहरू
# - **Connection Management**: उचित Azure सेवा कनेक्सन लाइफसाइकल
#
# ### क्याचिङ रणनीतिहरू
# - **Query Caching**: बारम्बार सञ्चालन हुने खोजहरू क्याच गर्ने
# - **Document Caching**: हट कागजातहरूको लागि इन-मेमोरी क्याचिङ
# - **Index Caching**: अनुकूलित भेक्टर इन्डेक्स क्याचिङ
# - **Result Caching**: उत्पन्न प्रतिक्रियाहरूको बुद्धिमानी क्याचिङ
#
# ## 📊 उद्यम प्रयोग केसहरू
#
# ### ज्ञान व्यवस्थापन
# - **Corporate Wiki**: कम्पनी ज्ञान बेसहरूमा बुद्धिमानी खोज
# - **Policy & Procedures**: स्वचालित अनुपालन र प्रक्रिया मार्गदर्शन
# - **Training Materials**: बुद्धिमानी सिकाइ र विकास सहायता
# - **Research Databases**: शैक्षिक र अनुसन्धान पेपर विश्लेषण प्रणालीहरू
#
# ### ग्राहक समर्थन
# - **Support Knowledge Base**: स्वचालित ग्राहक सेवा प्रतिक्रियाहरू
# - **Product Documentation**: बुद्धिमानी उत्पादन जानकारी प्राप्ति
# - **Troubleshooting Guides**: प्रसंग-आधारित समस्या समाधान सहायता
# - **FAQ Systems**: कागजात संग्रहबाट गतिशील FAQ निर्माण
#
# ### नियामक अनुपालन
# - **Legal Document Analysis**: सम्झौता र कानुनी कागजात बुद्धिमत्ता
# - **Compliance Monitoring**: स्वचालित नियामक अनुपालन जाँच
# - **Risk Assessment**: कागजात-आधारित जोखिम विश्लेषण र रिपोर्टिङ
# - **Audit Support**: अडिटको लागि बुद्धिमानी कागजात खोज
#
# ## 🚀 उत्पादन डिप्लोइमेन्ट
#
# ### अनुगमन र अवलोकनीयता
# - **Application Insights**: विस्तृत टेलिमेट्री र प्रदर्शन अनुगमन
# - **Custom Metrics**: व्यवसाय-विशिष्ट KPI ट्र्याकिङ र सूचनाहरू
# - **Distributed Tracing**: सेवाहरूभरि अन्तदेखि अन्तसम्म अनुरोध ट्र्याकिङ
# - **Health Dashboards**: वास्तविक-समय सिस्टम स्वास्थ्य र प्रदर्शन दृश्यावलोकन
#
# ### स्केलेबिलिटी र विश्वसनीयता
# - **Auto-Scaling**: लोड र प्रदर्शन मेट्रिक्सको आधारमा स्वचालित स्केलिङ
# - **High Availability**: फेलओभर क्षमतासहित बहु-क्षेत्र डिप्लोइमेन्ट
# - **Load Testing**: उद्यम लोड अवस्थाहरूमा प्रदर्शन मान्यकरण
# - **Disaster Recovery**: स्वचालित ब्याकअप र रिकभरी प्रक्रियाहरू
#
# संवेदनशील कागजातहरूलाई ठूलो परिमाणमा व्यवस्थापन गर्न सक्षम उद्यम-स्तरका RAG प्रणालीहरू निर्माण गर्न तयार हुनुहुन्छ? आउनुस् उद्यमका लागि बुद्धिमानी ज्ञान प्रणालीहरू आर्किटेक्ट गरौं! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# अस्वीकरण:
# यस कागजातलाई AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरी अनुवाद गरिएको हो। हामी शुद्धताको लागि प्रयास गर्छौं, तर कृपया ध्यान दिनुहोस् कि स्वचालित अनुवादमा त्रुटि वा अशुद्धता हुन सक्छ। मूल कागजातलाई यसको मूल भाषामा नै आधिकारिक स्रोत मानिनु पर्छ। महत्त्वपूर्ण जानकारीका लागि पेशेवर मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न हुने कुनै पनि गलत बुझाइ वा गलत व्याख्याको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
