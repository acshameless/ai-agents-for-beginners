# %% [markdown]
# # Handleiding: TITEL
#
# Doelgroep:
# - Beschrijf voor wie dit bedoeld is.
#
# Vereisten:
# - Noem vereiste concepten of instellingen.
#
# Leerdoelen:
# - Aan het einde kan de lezer...

# %% [markdown]
# ## Overzicht
#
# 1. Installatie
# 2. Een minimaal werkend voorbeeld
# 3. Variaties en valkuilen
# 4. Oefeningen

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Stap 1 - Begin met een klein voorbeeld
#
# Leg in eenvoudige bewoordingen uit wat de volgende cel doet.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Oefeningen
#
# - Probeer een andere invoer.
# - Voorspel de uitvoer voordat je de code uitvoert.
# - Noem een veelvoorkomende fout en hoe je die kunt oplossen.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vrijwaring**:
# Dit document is vertaald met behulp van de AI-vertalingsdienst [Co-op Translator](https://github.com/Azure/co-op-translator). Hoewel we naar nauwkeurigheid streven, dient u er rekening mee te houden dat geautomatiseerde vertalingen fouten of onjuistheden kunnen bevatten. Het oorspronkelijke document in de oorspronkelijke taal moet worden beschouwd als de gezaghebbende bron. Voor kritieke informatie wordt een professionele menselijke vertaling aanbevolen. Wij zijn niet aansprakelijk voor eventuele misverstanden of verkeerde interpretaties die voortvloeien uit het gebruik van deze vertaling.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
