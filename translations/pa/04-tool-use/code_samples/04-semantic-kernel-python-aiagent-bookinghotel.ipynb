# %% [markdown]
# # Example Sample Hotel and Flight Booker Agent
#
# ਇਹ ਹੱਲ ਤੁਹਾਡੀ ਮਦਦ ਕਰੇਗਾ ਫਲਾਈਟ ਟਿਕਟਾਂ ਅਤੇ ਹੋਟਲ ਬੁੱਕ ਕਰਨ ਵਿੱਚ। ਸੰਦਰਭ ਇੱਕ ਯਾਤਰਾ ਹੈ ਲੰਡਨ ਹੀਥਰੋ LHR 20 ਫਰਵਰੀ 2024 ਤੋਂ ਨਿਊਯਾਰਕ JFK ਤੱਕ ਜਾ ਰਹੀ ਹੈ ਜਿਸਦਾ ਵਾਪਸੀ 27 ਫਰਵਰੀ 2025 ਨੂੰ ਹੈ, ਜੋ ਕਿ ਬ੍ਰਿਟਿਸ਼ ਏਅਰਵੇਜ਼ ਦੇ ਨਾਲ ਕੇਵਲ ਇਕਨਾਮੀ ਕਲਾਸ ਵਿੱਚ ਹੈ। ਮੈਂ ਨਿਊਯਾਰਕ ਵਿੱਚ ਇੱਕ ਹਿਲਟਨ ਹੋਟਲ ਵਿੱਚ ਰੁਕਣਾ ਚਾਹੁੰਦਾ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਫਲਾਈਟ ਅਤੇ ਹੋਟਲ ਦੇ ਖਰਚੇ ਦੱਸੋ।

# %% [markdown]
# # Azure AI Agent Service ਨੂੰ ਪ੍ਰਾਰੰਭ ਕਰੋ ਅਤੇ **.env** ਤੋਂ ਸੰਰਚਨਾ ਜਾਣਕਾਰੀ ਪ੍ਰਾਪਤ ਕਰੋ
#
# ### **.env**
#
# ਇੱਕ .env ਫਾਈਲ ਬਣਾਓ
#
# **.env** ਵਿੱਚ Azure AI Agent Service ਦਾ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ, AOAI ਦੁਆਰਾ ਵਰਤਿਆ ਮਾਡਲ, ਅਤੇ ਸੰਬੰਧਿਤ Google API ਖੋਜ ਸੇਵਾ API, ENDPOINT ਆਦਿ ਹੁੰਦੇ ਹਨ।
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "ਤੁਹਾਡੇ Azure AI Agent Service ਮਾਡਲ ਡੀਪਲੋਇਮੈਂਟ ਦਾ ਨਾਮ"
#
# [**NOTE**] ਤੁਹਾਨੂੰ 100,000 ਰੇਟ ਲਿਮਿਟ (ਟੋਕਨ ਪ੍ਰਤੀ ਮਿੰਟ) ਅਤੇ 600 ਰੇਟ ਲਿਮਿਟ (ਰਿਕਵੈਸਟ ਪ੍ਰਤੀ ਮਿੰਟ) ਵਾਲਾ ਮਾਡਲ ਚਾਹੀਦਾ ਹੈ।
#
#   ਤੁਸੀਂ Microsoft Foundry - Model and Endpoint ਵਿੱਚ ਮਾਡਲ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "ਤੁਹਾਡੇ Azure AI Agent Service ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ"
#
#   ਤੁਸੀਂ AI Foundry ਪੋਰਟਲ ਸਕਰੀਨ ਵਿੱਚ ਆਪਣੇ ਪ੍ਰੋਜੈਕਟ ਦੇ ਓਵਰਵਿਊ ਵਿੱਚ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
# - **SERPAPI_SEARCH_API_KEY** = "ਤੁਹਾਡੇ SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "ਤੁਹਾਡੇ SERPAPI Search Endpoint"
#
# Azure AI Agent Service ਦਾ ਮਾਡਲ ਡੀਪਲੋਇਮੈਂਟ ਨਾਮ ਅਤੇ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, ਤੁਹਾਨੂੰ Azure AI Agent Service ਬਣਾਉਣੀ ਪਵੇਗੀ। ਇਸ ਨੂੰ ਸਿੱਧਾ ਬਣਾਉਣ ਲਈ [ਇਸ ਟੈਮਪਲੇਟ](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ਨੂੰ ਵਰਤਣਾ ਸੁਝਾਇਆ ਜਾਂਦਾ ਹੈ (***ਨੋਟ:*** Azure AI Agent Service ਨੂੰ ਇਸ ਸਮੇਂ ਸੀਮਤ ਖੇਤਰ ਵਿੱਚ ਸੈੱਟ ਕੀਤਾ ਗਿਆ ਹੈ। ਖੇਤਰ ਸੈੱਟ ਕਰਨ ਲਈ [ਇਸ ਲਿੰਕ](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ਨੂੰ ਦੇਖਣਾ ਸੁਝਾਇਆ ਜਾਂਦਾ ਹੈ)
#
# Agent ਨੂੰ SERPAPI ਤੱਕ ਪਹੁੰਚ ਦੀ ਲੋੜ ਹੈ। ਰਜਿਸਟਰ ਕਰਨ ਲਈ [ਇਸ ਲਿੰਕ](https://serpapi.com/searches) ਨੂੰ ਵਰਤਣਾ ਸੁਝਾਇਆ ਜਾਂਦਾ ਹੈ। ਰਜਿਸਟਰੇਸ਼ਨ ਤੋਂ ਬਾਅਦ, ਤੁਸੀਂ ਇਕ ਵਿਲੱਖਣ API KEY ਅਤੇ ENDPOINT ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।

# %% [markdown]
# # ਸੈਟਅਪ
#
# ਇਸ ਨੋਟਬੁੱਕ ਨੂੰ ਚਲਾਉਣ ਲਈ, ਤੁਹਾਨੂੰ ਯਕੀਨੀ ਬਣਾਉਣਾ ਪਵੇਗਾ ਕਿ ਤੁਸੀਂ ਲੋੜੀਂਦੇ ਲਾਇਬ੍ਰੇਰੀਸ ਨੂੰ `pip install -r requirements.txt` ਚਲਾਕੇ ਇੰਸਟਾਲ ਕੀਤਾ ਹੈ।

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# ਤੁਹਾਡੇ ਸੈਮੈਂਟਿਕ ਕਰਨਲ ਦਾ ਵਰਜਨ ਘੱਟੋ-ਘੱਟ 1.27.2 ਹੋਣਾ ਚਾਹੀਦਾ ਹੈ।

# %% [markdown]
# ਆਪਣਾ .env ਫਾਇਲ ਸੈਟਿੰਗ ਅਤੇ ਸਾਧਨ ਲੋਡ ਕਰੋ, ਕ੍ਰਿਪਾ ਕਰਕੇ ਯਕੀਨੀ ਬਣਾਓ ਕਿ ਤੁਸੀਂ ਆਪਣੇ ਕੀਜ਼ ਅਤੇ ਸੈਟਿੰਗ ਜੋੜੀ ਹੈ ਅਤੇ ਇੱਕ ਸਥਾਨਕ .env ਫਾਇਲ ਬਣਾਈ ਹੈ।

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # ਅਜ਼ਯੂਰ 'ਚ ਲੌਗਇਨ ਕਰੋ
#
# ਹੁਣ ਤੁਹਾਨੂੰ ਅਜ਼ਯੂਰ ਵਿੱਚ ਲੌਗਇਨ ਕਰਨ ਦੀ ਜ਼ਰੂਰਤ ਹੈ। ਇੱਕ ਟਰਮੀਨਲ ਖੋਲ੍ਹੋ ਅਤੇ ਹੇਠਾਂ ਦਿੱਤਾ ਆਗਿਆਚਿੰਨ ਚਲਾਓ:
#
# ```bash
# az login
# ```
#
# ਇਹ ਆਗਿਆਚਿੰਨ ਤੁਹਾਨੂੰ ਆਪਣੀਆਂ ਅਜ਼ਯੂਰ ਪ੍ਰਮਾਣਿਕਤਾ ਦਰਜ ਕਰਨ ਲਈ ਕਹੇਗਾ, ਜਿਸ ਨਾਲ ਅਜ਼ਯੂਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਸਹੀ ਤਰੀਕੇ ਨਾਲ ਕੰਮ ਕਰ ਸਕੇਗੀ।

# %% [markdown]
# # Explanation:
# ਇਹ ਇੱਕ ਵੈਰੀਏਬਲ ਹੈ ਜੋ SERP (ਸਰਚ ਇੰਜਣ ਨਤੀਜੇ ਪੰਨਾ) API ਸੇਵਾ ਦੇ ਐਕਸੈਸ ਲਈ API ਕੁੰਜੀ ਸੰਭਾਲਦਾ ਹੈ। ਇੱਕ API ਕੁੰਜੀ ਇੱਕ ਵਿਲੱਖਣ ਪਹਚਾਣ ਹੈ ਜੋ ਤੁਹਾਡੇ ਖਾਤੇ ਨਾਲ ਜੁੜੀਆਂ ਬੇਨਤੀਆਂ ਨੂੰ ਪ੍ਰਮਾਣਿਤ ਕਰਨ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ।
#
# Purpose: ਇਸ ਲਾਈਨ ਦਾ ਉਦੱਦੇਸ਼ API ਕੁੰਜੀ ਨੂੰ ਇੱਕ ਵੈਰੀਏਬਲ ਵਿੱਚ ਸਟੋਰ ਕਰਨਾ ਹੈ ਤਾਂ ਜੋ ਇਸ ਨੂੰ SERP API ਸੇਵਾ ਨੂੰ ਪ੍ਰਮਾਣਿਤ ਕਰਨ ਵਾਲੀਆਂ ਬੇਨਤੀਆਂ ਲਈ ਵਰਤਿਆ ਜਾ ਸਕੇ। ਸੇਵਾ ਤੱਕ ਪਹੁੰਚ ਅਤੇ ਖੋਜਾਂ ਕਰਨ ਲਈ API ਕੁੰਜੀ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ।
# How to Get a SERP API Key: SERP API ਕੁੰਜੀ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, https://serpapi.com ਤੇ ਇਹਨਾਂ ਆਮ ਕਦਮਾਂ ਦਾ ਪਾਲਣ ਕਰੋ (ਿਜਿਹੜੇ ਕਦਮ ਵੱਖ-ਵੱਖ SERP API ਸੇਵਾਵਾਂ ਅਨੁਸਾਰ ਭਿੰਨ ਹੋ ਸਕਦੇ ਹਨ):
#
# Choose a SERP API Service: ਕਈ SERP API ਸੇਵਾਵਾਂ ਮੁਹੱਈਆ ਹਨ, ਜਿਵੇਂ SerpAPI, Google Custom Search JSON API, ਅਤੇ ਹੋਰ। ਆਪਣੀਆਂ ਲੋੜਾਂ ਮੁਤਾਬਕ ਸਭ ਤੋਂ ਵਧੀਆ ਚੁਣੋ।
#
# Sign Up for an Account: ਚੁਣੀ ਗਈ SERP API ਸੇਵਾ ਦੀ ਵੈੱਬਸਾਈਟ 'ਤੇ ਜਾਓ ਅਤੇ ਖਾਤਾ ਬਣਾਓ। ਤੁਹਾਨੂੰ ਕੁਝ ਬੁਨਿਆਦੀ ਜਾਣਕਾਰੀ ਦੇਣੀ ਪੈ ਸਕਦੀ ਹੈ ਅਤੇ ਆਪਣਾ ਈਮੇਲ ਪਤਾ ਸੱਚਾ ਕਰਨਾ ਪੈ ਸਕਦਾ ਹੈ।
#
# Create an API Key: ਸਾਈਨ ਅੱਪ ਕਰਨ ਤੋਂ ਬਾਅਦ, ਆਪਣੇ ਖਾਤੇ ਵਿੱਚ ਲੌਗ ਇਨ ਕਰੋ ਅਤੇ API ਖੇਤਰ ਜਾਂ ਡੈਸ਼ਬੋਰਡ 'ਤੇ ਜਾਓ। ਕਿਸੇ ਨਵੀਂ API ਕੁੰਜੀ ਬਣਾਉਣ ਜਾਂ ਉਤਪੰਨ ਕਰਨ ਦਾ ਵਿਕਲਪ ਲੱਭੋ।
# Copy the API Key to your .env file.

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # Explanation:
# BASE_URL: ਇਹ ਇੱਕ ਵੈਰੀਏਬਲ ਹੈ ਜੋ SERP API ਐਂਡਪੋਇੰਟ ਲਈ ਬੇਸ URL ਨੂੰ ਸਟੋਰ ਕਰਦਾ ਹੈ। ਵੈਰੀਏਬਲ ਨਾਮ BASE_URL ਇੱਕ ਰਿਵਾਜ਼ ਹੈ ਜੋ ਦਰਸਾਉਂਦਾ ਹੈ ਕਿ ਇਹ URL API ਬੇਨਤੀਆਂ ਕਰਨ ਦਾ ਸ਼ੁਰੂਆਤੀ ਬਿੰਦੂ ਹੈ।
# 'https://serpapi.com/search':
#
# ਇਹ ਉਹ ਅਸਲ URL ਸਟਰਿੰਗ ਹੈ ਜੋ BASE_URL ਵੈਰੀਏਬਲ ਨੂੰ ਸੌਂਪੀ ਗਈ ਹੈ। ਇਹ SERP API ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਖੋਜ ਪ੍ਰਸ਼ਨਾਂ ਨੂੰ ਕਰਨ ਲਈ ਐਂਡਪੋਇੰਟ ਨੂੰ ਦਰਸਾਉਂਦਾ ਹੈ।
#
# # Purpose:
# ਇਸ ਲਾਈਨ ਦਾ ਮਕਸਦ ਇੱਕ ਅਸਥਿਰ ਵੈਰੀਏਬਲ ਪਰਿਭਾਸ਼ਿਤ ਕਰਨਾ ਹੈ ਜੋ SERP API ਲਈ ਬੇਸ URL ਨੂੰ ਰੱਖਦਾ ਹੈ। ਇਹ URL ਖੋਜ ਕਾਰਵਾਈਆਂ ਕਰਨ ਲਈ API ਬੇਨਤੀਆਂ ਬਣਾਉਣ ਦਾ ਸ਼ੁਰੂਆਤੀ ਬਿੰਦੂ ਵਜੋਂ ਵਰਤਿਆ ਜਾਵੇਗਾ।
#
# # Usage:
# ਬੇਸ URL ਨੂੰ ਇੱਕ ਵੈਰੀਏਬਲ ਵਿੱਚ ਪਰਿਭਾਸ਼ਿਤ ਕਰਕੇ, ਤੁਸੀਂ ਆਪਣੇ ਕੋਡ ਵਿੱਚ ਵੱਖ-ਵੱਖ ਥਾਵਾਂ 'ਤੇ ਜਦੋਂ ਵੀ SERP API ਲਈ ਬੇਨਤੀ ਕਰਨ ਦੀ ਲੋੜ ਹੋਵੇ, ਇਸ ਨੂੰ ਆਸਾਨੀ ਨਾਲ ਦੁਬਾਰਾ ਵਰਤ ਸਕਦੇ ਹੋ। ਇਹ ਤੁਹਾਡੇ ਕੋਡ ਨੂੰਹੋਰ ਸਹਿਜ ਅਤੇ ਰੱਖ-ਰਖਾਵ ਯੋਗ ਬਣਾਉਂਦਾ ਹੈ ਅਤੇ ਇੱਕੋ URL ਨੂੰ ਵੱਖ-ਵੱਖ ਥਾਵਾਂ 'ਤੇ ਹਾਰਡਕੋਡ ਕਰਨ ਨਾਲ ਹੋ ਸਕਣ ਵਾਲੀਆਂ ਗਲਤੀਆਂ ਦੀ ਸੰਭਾਵਨਾ ਨੂੰ ਘਟਾਉਂਦਾ ਹੈ। ਮੌਜੂਦਾ ਉਦਾਹਰਨ https://serpapi.com/search?engine=bing ਹੈ ਜੋ Bing ਖੋਜ API ਦੀ ਵਰਤੋਂ ਕਰ ਰਿਹਾ ਹੈ। ਵੱਖ-ਵੱਖ API ਨੂੰ https://Serpapi.com 'ਤੇ ਚੁਣਿਆ ਜਾ ਸਕਦਾ ਹੈ।

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # ਵਿਆਖਿਆ:
#
# ਇਹ ਥਾਂ ਤੁਹਾਡੇ ਪਲੱਗਇਨ ਕੋਡ ਦੀ ਥਾਂ ਹੈ।
#
# ਕਲਾਸ ਪਰਿਭਾਸ਼ਾ: `class BookingPlugin`: BookingPlugin ਨਾਮ ਦੀ ਇੱਕ ਕਲਾਸ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦੀ ਹੈ ਜਿਸ ਵਿੱਚ ਹੋਟਲ ਅਤੇ ਫਲਾਈਟ ਬੁਕਿੰਗ ਲਈ ਮੈਥਡ ਹਨ।
#
# ਹੋਟਲ ਬੁਕਿੰਗ ਮੈਥਡ:
#
# - `@kernel_function(description="booking hotel")`: ਇੱਕ ਡੈਕਾਰੇਟਰ ਜੋ ਫੰਕਸ਼ਨ ਨੂੰ ਹੋਟਲਾਂ ਦੀ ਬੁਕਿੰਗ ਲਈ kernel ਫੰਕਸ਼ਨ ਵਜੋਂ ਵਰਣਨ ਕਰਦਾ ਹੈ।
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: Annotated ਪੈਰਾਮੀਟਰਾਂ ਅਤੇ ਰਿਟਰਨ ਟਾਈਪ ਨਾਲ ਹੋਟਲ ਬੁਕਿੰਗ ਲਈ ਇੱਕ ਮੈਥਡ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
#
# ਇਹ ਮੈਥਡ ਹੋਟਲ ਬੁਕਿੰਗ ਅਰਜ਼ੀਆਂ ਲਈ ਪੈਰਾਮੀਟਰਾਂ ਦਾ ਡਿਕਸ਼ਨਰੀ ਬਣਾਉਂਦਾ ਹੈ ਅਤੇ SERP API ਨੂੰ GET ਅਰਜ਼ੀ ਭੇਜਦਾ ਹੈ। ਇਹ ਜਵਾਬ ਸਥਿਤੀ ਦੀ ਜਾਂਚ ਕਰਦਾ ਹੈ ਅਤੇ ਜੇ ਸਫਲ ਹੋਵੇ ਤਾਂ ਹੋਟਲ ਦੀਆਂ ਤੁਹਫ਼ਿਆਂ ਨੂੰ ਵਾਪਸ ਕਰਦਾ ਹੈ, ਨਹੀਂ ਤਾਂ None ਵਾਪਸ ਕਰਦਾ ਹੈ।
#
# ਫਲਾਈਟ ਬੁਕਿੰਗ ਮੈਥਡ:
#
# - `@kernel_function(description="booking flight")`: ਇੱਕ ਡੈਕਾਰੇਟਰ ਜੋ ਫੰਕਸ਼ਨ ਨੂੰ ਫਲਾਈਟਾਂ ਦੀ ਬੁਕਿੰਗ ਲਈ kernel ਫੰਕਸ਼ਨ ਵਜੋਂ ਵਰਣਨ ਕਰਦਾ ਹੈ।
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: Annotated ਪੈਰਾਮੀਟਰਾਂ ਅਤੇ ਰਿਟਰਨ ਟਾਈਪ ਨਾਲ ਫਲਾਈਟ ਬੁਕਿੰਗ ਲਈ ਇੱਕ ਮੈਥਡ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
#
# ਇਹ ਮੈਥਡ ਆਉਟਬਾਊਂਡ ਅਤੇ ਵਾਪਸੀ ਫਲਾਈਟ ਅਰਜ਼ੀਆਂ ਲਈ ਪੈਰਾਮੀਟਰ ਡਿਕਸ਼ਨਰੀਆਂ ਬਣਾਉਂਦਾ ਹੈ ਅਤੇ SERP API ਨੂੰ GET ਅਰਜ਼ੀਆਂ ਭੇਜਦਾ ਹੈ। ਇਹ ਜਵਾਬ ਸਥਿਤੀ ਦੀ ਜਾਂਚ ਕਰਦਾ ਹੈ ਅਤੇ ਜੇ ਸਫਲ ਹੋਵੇ ਤਾਂ ਨਤੀਜੇ ਦੀ ਸਤਰ ਵਿੱਚ ਫਲਾਈਟ ਜਾਣਕਾਰੀ ਸ਼ਾਮਲ ਕਰਦਾ ਹੈ, ਨਹੀਂ ਤਾਂ ਏਰਰ ਸੁਨੇਹਾ ਪ੍ਰਿੰਟ ਕਰਦਾ ਹੈ। ਮੈਥਡ ਨਤੀਜੇ ਦੀ ਸਤਰ ਵਾਪਸ ਕਰਦਾ ਹੈ ਜਿਸ ਵਿੱਚ ਫਲਾਈਟ ਜਾਣਕਾਰੀ ਹੁੰਦੀ ਹੈ।

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # ਵਿਵਰਣ:
# ਆਯਾਤ ਬਿਆਨ: Azure ਪ੍ਰਮਾਣ ਪੱਤਰ, AI ਏਜੰਟ, ਚੈਟ ਸੁਨੇਹਾ ਸਮੱਗਰੀ, ਲੇਖਕ ਭੂਮਿਕਾ, ਅਤੇ ਕਿਰਨਲ ਫੰਕਸ਼ਨ ਡੈਕੋਰੇਟਰ ਲਈ ਜ਼ਰੂਰੀ ਮਾਡਿਊਲ ਆਯਾਤ ਕਰੋ।
#
# ਅਸਿੰਕ੍ਰੋਨਸ ਸੰਦਰਭ ਪ੍ਰਬੰਧਕ: async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,): ਇਹ ਇੱਕ ਅਸਿੰਕ੍ਰੋਨਸ ਸੰਦਰਭ ਪ੍ਰਬੰਧਕ ਸੈੱਟ ਕਰਦਾ ਹੈ ਜੋ Azure ਪ੍ਰਮਾਣ ਪੱਤਰ ਨੂੰ ਸੰਭਾਲਦਾ ਹੈ ਅਤੇ AI ਏਜੰਟ ਕਲਾਇਂਟ ਬਣਾਉਂਦਾ ਹੈ।
#
# ਏਜੰਟ ਦਾ ਨਾਮ ਅਤੇ ਹਦਾਇਤਾਂ:
# - `AGENT_NAME = "BookingAgent"`: ਏਜੰਟ ਦਾ ਨਾਮ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
# - `AGENT_INSTRUCTIONS = """..."""`: ਬੁਕਿੰਗ ਦੀਆਂ ਮੰਗਾਂ ਨੂੰ ਸੰਭਾਲਣ ਲਈ ਏਜੰਟ ਲਈ ਵਿਸਥਾਰਵੱਧ ਹਦਾਇਤਾਂ ਦਿੰਦਾ ਹੈ।
#
# ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ ਬਣਾਉਣਾ: `agent_definition = await client.agents.create_agent(...)`: ਦਿੱਤੇ ਮਾਡਲ, ਨਾਮ, ਅਤੇ ਹਦਾਇਤਾਂ ਨਾਲ ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ ਬਣਾਉਂਦਾ ਹੈ।
#
# AzureAI ਏਜੰਟ ਬਣਾਉਣਾ: `agent = AzureAIAgent(...)`: ਕਲਾਇਂਟ, ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ, ਅਤੇ ਪਰਿਭਾਸ਼ਿਤ ਪਲੱਗਇਨ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਇੱਕ AzureAI ਏਜੰਟ ਬਣਾਉਂਦਾ ਹੈ।
#
# ਥ੍ਰੈੱਡ ਬਣਾਉਣਾ: `thread: AzureAIAgentThread | None = None`: ਏਜੰਟ ਲਈ ਇੱਕ ਥ੍ਰੈੱਡ ਬਣਾਉਣ ਲਈ। ਪਹਿਲਾਂ ਥ੍ਰੈੱਡ ਬਣਾਉਣਾ ਜਰੂਰੀ ਨਹੀਂ - ਜੇ `None` ਦਿੱਤਾ ਗਿਆ, ਤਾਂ ਪਹਿਲੀ ਬਾਰ ਕਾਲ ਤੇ ਇੱਕ ਨਵੀਂ ਥ੍ਰੈੱਡ ਬਣਾਈ ਜਾਵੇਗੀ ਅਤੇ ਜਵਾਬ ਵਿੱਚ ਵਾਪਸ ਦਿੱਤੀ ਜਾਵੇਗੀ।
#
# ਯੂਜ਼ਰ ਇਨਪੁਟ: `user_inputs = ["..."]`: ਏਜੰਟ ਵਲੋਂ ਪ੍ਰੋਸੈਸ ਕਰਨ ਲਈ ਯੂਜ਼ਰ ਇਨਪੁੱਟ ਦੀ ਸੂਚੀ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
#
# ਅਖੀਰਲੇ ਬਲਾਕ ਵਿੱਚ, ਸੰਸਾਧਨਾਂ ਨੂੰ ਸਾਫ਼ ਕਰਨ ਲਈ ਥ੍ਰੈੱਡ ਅਤੇ ਏਜੰਟ ਨੂੰ ਮਿਟਾ ਦਿਓ।

# %% [markdown]
# # ਪ੍ਰਮਾਣੀਕਰਨ
#
# `DefaultAzureCredential` ਕਲਾਸ ਅਜ਼ੂਰ SDK ਫਾਰ ਪਾਈਥਨ ਦਾ ਹਿੱਸਾ ਹੈ। ਇਹ ਅਜ਼ੂਰ ਸੇਵਾਵਾਂ ਨਾਲ ਪ੍ਰਮਾਣੀਕਰਨ ਕਰਨ ਦਾ ਡਿਫਾਲਟ ਤਰੀਕਾ ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ। ਇਹ ਬੀਨਿਆਂ ਦੇ ਵਾਤਾਵਰਣ, ਪ੍ਰਬੰਧਿਤ ਪਛਾਣ, ਅਤੇ ਅਜ਼ੂਰ CLI ਪ੍ਰਮਾਣ-ਪੱਤਰਾਂ ਵਰਗੀਆਂ ਕਈ ਵਿਧੀਆਂ ਨੂੰ ਕਿਸੇ ਵਿਸ਼ੇਸ਼ ਕ੍ਰਮ ਵਿੱਚ ਪ੍ਰਮਾਣੀਕਰਨ ਕਰਨ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦੀ ਹੈ।
#
# ਅਸੰਕ੍ਰਾਮਿਕ ਓਪਰੇਸ਼ਨ: aio ਮੋਡੀਊਲ ਦਰਸਾਉਂਦਾ ਹੈ ਕਿ DefaultAzureCredential ਕਲਾਸ ਅਸੰਕ੍ਰਾਮਿਕ ਓਪਰੇਸ਼ਨਾਂ ਨੂੰ ਸਮਰਥਨ ਕਰਦੀ ਹੈ। ਇਸਦਾ ਮਤਲਬ ਹੈ ਕਿ ਤੁਸੀਂ ਇਸਨੂੰ asyncio ਨਾਲ ਵਰਤ ਸਕਦੇ ਹੋ ਤਾਂ ਜੋ ਗੈਰ-ਅਵਰੋਧਕ ਪ੍ਰਮਾਣੀਕਰਨ ਬੇਨਤੀਆਂ ਕਰ ਸਕੋ।

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਰਣ**:
# ਇਹ ਦਸਤਾਵੇਜ਼ ਏ.ਆਈ. ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦਿਤ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਅਤਾ ਲਈ ਯਤਨ ਕਰਦੇ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸੁਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਥਿਰਤਾਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਇਸ ਮੂਲ ਦਸਤਾਵੇਜ਼ ਨੂੰ ਇਸ ਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਣਾ ਚਾਹੀਦਾ ਹੈ। ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ਾਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਇਸਤੇਮਾਲ ਕਰਕੇ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
