# %% [markdown]
# # 🔍 ਐਂਟਰਪ੍ਰਾਈਜ਼ RAG Microsoft Foundry (.NET) ਨਾਲ
#
# ## 📋 ਸਿੱਖਣ ਦੇ ਉਦੇਸ਼
#
# ਇਹ ਨੋਟਬੁੱਕ ਦਿਖਾਉਂਦੀ ਹੈ ਕਿ Microsoft Foundry ਨਾਲ .NET ਵਿੱਚ Microsoft Agent Framework ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਐਂਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ Retrieval-Augmented Generation (RAG) ਸਿਸਟਮ ਕਿਵੇਂ ਬਣਾਏ ਜਾਂਦੇ ਹਨ। ਤੁਸੀਂ ਸਿੱਖੋਗੇ ਕਿ ਉਤਪਾਦਨ-ਤਯਾਰ ਏਜੰਟ ਕਿਵੇਂ ਬਣਾਏ ਜਾਂਦੇ ਹਨ ਜੋ ਦਸਤਾਵੇਜ਼ਾਂ ਵਿੱਚ ਖੋਜ ਕਰ ਸਕਦੇ ਹਨ ਅਤੇ ਐਂਟਰਪ੍ਰਾਈਜ਼ ਸੁਰੱਖਿਆ ਅਤੇ ਸਕੇਲਬਿਲਿਟੀ ਦੇ ਨਾਲ ਸਹੀ, ਸੰਦਰਭ-ਅਗਾਹ ਜਵਾਬ ਪ੍ਰਦਾਨ ਕਰਦੇ ਹਨ।
#
# **ਤੁਸੀਂ ਬਣਾਉਗੇ ਐਂਟਰਪ੍ਰਾਈਜ਼ RAG ਸਮਰੱਥਾਵਾਂ:**
# - 📚 **ਦਸਤਾਵੇਜ਼ ਬੁੱਧਿਮਤਾ**: Azure AI ਸੇਵਾਵਾਂ ਨਾਲ ਉੱਨਤ ਦਸਤਾਵੇਜ਼ ਪ੍ਰੋਸੈਸਿੰਗ
# - 🔍 **ਸੈਮੈਂਟਿਕ ਖੋਜ**: ਐਂਟਰਪ੍ਰਾਈਜ਼ ਖਾਸੀਅਤਾਂ ਨਾਲ ਉੱਚ-ਕਾਰਗੁਜ਼ਾਰੀ ਵੇਕਟਰ ਖੋਜ
# - 🛡️ **ਸੁਰੱਖਿਆ ਇੰਟਿਗ੍ਰੇਸ਼ਨ**: ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ ਅਤੇ ਡੇਟਾ ਸੁਰੱਖਿਆ ਪੈਟਰਨ
# - 🏢 **ਸਕੇਲਬਲ ਆਰਕੀਟੈਕਚਰ**: ਮਾਨੀਟਰਿੰਗ ਸਮੇਤ ਉਤਪਾਦਨ-ਤਯਾਰ RAG ਸਿਸਟਮ
#
# ## 🎯 ਐਂਟਰਪ੍ਰਾਈਜ਼ RAG ਆਰਕੀਟੈਕਚਰ
#
# ### ਮੁੱਖ ਐਂਟਰਪ੍ਰਾਈਜ਼ ਘਟਕ
# - **Microsoft Foundry**: ਸੁਰੱਖਿਆ ਅਤੇ ਅਨੁਕੂਲਤਾ ਨਾਲ ਪ੍ਰਬੰਧਿਤ ਐਂਟਰਪ੍ਰਾਈਜ਼ AI ਪਲੇਟਫਾਰਮ
# - **ਸਥਾਈ ਏਜੰਟ**: ਗੱਲਬਾਤ ਇਤਿਹਾਸ ਅਤੇ ਸੰਦਰਭ ਪ੍ਰਬੰਧਨ ਵਾਲੇ ਸਟੇਟਫੁਲ ਏਜੰਟ
# - **ਵੇਕਟਰ ਸਟੋਰ ਪ੍ਰਬੰਧਨ**: ਐਂਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ ਦਸਤਾਵੇਜ਼ ਇੰਡੈਕਸਿੰਗ ਅਤੇ ਪ੍ਰਾਪਤੀ
# - **ਪਹਿਚਾਣ ਇੰਟਿਗ੍ਰੇਸ਼ਨ**: Azure AD ਪ੍ਰਮਾਣਿਕਤਾ ਅਤੇ ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ ਨਿਯੰਤਰਣ
#
# ### .NET ਐਂਟਰਪ੍ਰਾਈਜ਼ ਫਾਇਦੇ
# - **ਟਾਈਪ ਸੁਰੱਖਿਆ**: RAG ਓਪਰੇਸ਼ਨ ਅਤੇ ਡੇਟਾ ਸਟ੍ਰਕਚਰਾਂ ਲਈ ਕੰਪਾਈਲ-ਟਾਈਮ ਵੈਧਤਾ
# - **ਐਸਿੰਕ ਪ੍ਰਦਰਸ਼ਨ**: ਗੈਰ-ਬਲੌਕਿੰਗ ਦਸਤਾਵੇਜ਼ ਪ੍ਰੋਸੈਸਿੰਗ ਅਤੇ ਖੋਜ ਓਪਰੇਸ਼ਨ
# - **ਮੇਮੋਰੀ ਪ੍ਰਬੰਧਨ**: ਵੱਡੀਆਂ ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹੀਆਂ ਲਈ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਰਿਸੋਰਸ ਉਪਯੋਗ
# - **ਇੰਟਿਗ੍ਰੇਸ਼ਨ ਪੈਟਰਨ**: ਡਿਪੈਂਡਿੰਸੀ ਇੰਜੈਕਸ਼ਨ ਨਾਲ ਮੂਲ Azure ਸੇਵਾ ਇੰਟਿਗ੍ਰੇਸ਼ਨ
#
# ## 🏗️ Technical Architecture
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Core .NET Components
# - **Azure.AI.Agents.Persistent**: ਸਟੇਟ ਪ੍ਰੈਜ਼ਿਸਟੈਂਸ ਵਾਲੇ ਐਂਟਰਪ੍ਰਾਈਜ਼ ਏਜੰਟ ਪ੍ਰਬੰਧਨ
# - **Azure.Identity**: ਸੁਰੱਖਿਅਤ Azure ਸੇਵਾ ਪਹੁੰਚ ਲਈ ਇਕੀਕ੍ਰਿਤ ਪ੍ਰਮਾਣਿਕਤਾ
# - **Microsoft.Agents.AI.AzureAI**: Azure-ਅਪਟਿਮਾਈਜ਼ਡ ਏਜੰਟ ਫ੍ਰੇਮਵਰਕ ਕਾਰਜਾਨਵਿਆਈ
# - **System.Linq.Async**: ਉੱਚ-ਕਾਰਗੁਜ਼ਾਰੀ ਅਸਿੰਕ੍ਰੋਨਸ LINQ ਓਪਰੇਸ਼ਨ
#
# ## 🔧 Enterprise Features & Benefits
#
# ### Security & Compliance
# - **Azure AD ਇੰਟਿਗ੍ਰੇਸ਼ਨ**: ਐਂਟਰਪ੍ਰਾਈਜ਼ ਪਹਿਚਾਣ ਪ੍ਰਬੰਧਨ ਅਤੇ ਪ੍ਰਮਾਣਿਕਤਾ
# - **ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ**: ਦਸਤਾਵੇਜ਼ ਪਹੁੰਚ ਅਤੇ ਓਪਰੇਸ਼ਨਾਂ ਲਈ ਬਰੀਕੀ ਵਾਲੀਆਂ ਅਨੁਮਤੀਆਂ
# - **ਡੇਟਾ ਸੁਰੱਖਿਆ**: ਸੰਵੇਦਨਸ਼ੀਲ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਸਥਿਤੀ ਵਿੱਚ (at rest) ਅਤੇ ਪਰਿਵਹਨ ਦੌਰਾਨ (in transit) ਐਨਕ੍ਰਿਪਸ਼ਨ
# - **ਆਡਿਟ ਲੌਗਿੰਗ**: ਅਨੁਕੂਲਤਾ ਦੀਆਂ ਲੋੜਾਂ ਲਈ ਵਿਸਤ੍ਰਿਤ ਗਤੀਵਿਧੀ ਟਰੈਕਿੰਗ
#
# ### Performance & Scalability
# - **ਕਨੈਕਸ਼ਨ ਪੂਲਿੰਗ**: ਪ੍ਰਭਾਵਸ਼ਾਲੀ Azure ਸੇਵਾ ਕਨੈਕਸ਼ਨ ਪ੍ਰਬੰਧਨ
# - **ਐਸਿੰਕ ਪ੍ਰੋਸੈਸਿੰਗ**: ਉੱਚ-ਥਰਪੁੱਟ ਸਿਤੂਏਸ਼ਨਾਂ ਲਈ ਗੈਰ-ਬਲੌਕਿੰਗ ਓਪਰੇਸ਼ਨ
# - **ਕੈਸ਼ਿੰਗ ਰਣਨੀਤੀਆਂ**: ਅਕਸਰ ਪਹੁੰਚ ਕੀਤੇ ਜਾਣ ਵਾਲੇ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਸਮਾਰਟ ਕੈਸ਼ਿੰਗ
# - **ਲੋਡ ਬੈਲੈਂਸਿੰਗ**: ਵੱਡੇ ਪੱਧਰ ਦੀ ਡਿਪਲੋਇਮੈਂਟ ਲਈ ਵੰਡਿਆ ਪ੍ਰੋਸੈਸਿੰਗ
#
# ### Management & Monitoring
# - **ਹੈਲਥ ਚੈਕਸ**: RAG ਸਿਸਟਮ ਘਟਕਾਂ ਲਈ ਨਿਰਮਿਤ ਨਿਗਰਾਨੀ
# - **ਪਰਫਾਰਮੈਂਸ ਮੈਟ੍ਰਿਕਸ**: ਖੋਜ ਗੁਣਵੱਤਾ ਅਤੇ ਜਵਾਬ ਸਮਿਆਂ ਦੇ ਵਿਸਤ੍ਰਿਤ ਵਿਸ਼ਲੇਸ਼ਣ
# - **ਏਰਰ ਹੈਂਡਲਿੰਗ**: ਰੀਟ੍ਰਾਈ ਨੀਤੀਆਂ ਨਾਲ ਵਿਸਤ੍ਰਿਤ ਐਕਸਪਸ਼ਨ ਪ੍ਰਬੰਧਨ
# - **ਕੰਫਿਗਰੇਸ਼ਨ ਮੈਨੇਜਮੈਂਟ**: ਵਾਤਾਵਰਣ-ਵਿਸ਼ੇਸ਼ ਸੈਟਿੰਗਜ਼ ਨਾਲ ਵੈਧਤਾ
#
# ## ⚙️ ਜ਼ਰੂਰੀ ਸ਼ਰਤਾਂ ਅਤੇ ਸੈਟਅੱਪ
#
# **ਡਿਵੈਲਪਮੈਂਟ ਵਾਤਾਵਰਣ:**
# - .NET 9.0 SDK ਜਾਂ ਉੱਪਰ
# - Visual Studio 2022 ਜਾਂ VS Code ਨਾਲ C# ਐਕਸਟੈਨਸ਼ਨ
# - AI Foundry ਪਹੁੰਚ ਵਾਲੀ Azure subscription
#
# **ਲੋੜੀਂਦੇ NuGet ਪੈਕੇਜ:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure Authentication Setup:**
# ```bash
# # ਅਜ਼ੂਰ CLI ਇੰਸਟਾਲ ਕਰੋ ਅਤੇ ਪ੍ਰਮਾਣੀਕਰਣ ਕਰੋ
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **ਮਾਹੌਲ ਸੰਰਚਨਾ (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 ਐਂਟਰਪ੍ਰਾਈਜ਼ RAG ਪੈਟਰਨ
#
# ### ਦਸਤਾਵੇਜ਼ ਪ੍ਰਬੰਧਨ ਪੈਟਰਨ
# - **ਬਲਕ ਅਪਲੋਡ**: ਵੱਡੀਆਂ ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹੀਆਂ ਦੀ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਪ੍ਰੋਸੈਸਿੰਗ
# - **ਕ੍ਰਮਿਕ ਅਪਡੇਟ**: ਰੀਅਲ-ਟਾਈਮ ਦਸਤਾਵੇਜ਼ ਜੋੜ ਅਤੇ ਤਬਦੀਲੀ
# - **ਵਰਜਨ ਕੰਟ੍ਰੋਲ**: ਦਸਤਾਵੇਜ਼ ਵਰਜਨਿੰਗ ਅਤੇ ਤਬਦੀਲੀ ਟ੍ਰੈਕਿੰਗ
# - **ਮੇਟਾਡੇਟਾ ਪ੍ਰਬੰਧਨ**: ਸਮ੍ਰਿਧ ਦਸਤਾਵੇਜ਼ ਗੁਣ ਅਤੇ ਟੈਕਸੋਨੋਮੀ
#
# ### ਖੋਜ & ਪ੍ਰਾਪਤੀ ਪੈਟਰਨ
# - **ਹਾਈਬ੍ਰਿਡ ਖੋਜ**: ਸ਼੍ਰੇਸ਼্ঠ ਨਤੀਜਿਆਂ ਲਈ ਸੈਮੈਂਟਿਕ ਅਤੇ ਕੀਵਰਡ ਖੋਜ ਨੂੰ ਜੋੜਨਾ
# - **ਫੇਸਟੀਡ ਖੋਜ**: ਬਹੁ-ਆਯਾਮੀ ਫਿਲਟਰਿੰਗ ਅਤੇ ਵਰਗੀਕਰਨ
# - **ਸਬੰਧਤਾ ਟਿਊਨਿੰਗ**: ਡੋਮੇਨ-ਵਿਸ਼ੇਸ਼ ਜ਼ਰੂਰਤਾਂ ਲਈ ਕਸਟਮ ਸਕੋਰਿੰਗ ਅਲਗੋਰਿਦਮ
# - **ਨਤੀਜਾ ਰੈਂਕਿੰਗ**: ਕਾਰੋਬਾਰੀ ਲਜਿਕ ਇੰਟਿਗ੍ਰੇਸ਼ਨ ਨਾਲ ਉੱਨਤ ਰੈਂਕਿੰਗ
#
# ### ਸੁਰੱਖਿਆ ਪੈਟਰਨ
# - **ਦਸਤਾਵੇਜ਼-ਸਤਰ ਸੁਰੱਖਿਆ**: ਹਰ ਦਸਤਾਵੇਜ਼ ਲਈ ਬਰੀਕੀ ਵਾਲਾ ਪਹੁੰਚ ਨਿਯੰਤਰਣ
# - **ਡੇਟਾ ਵਰਗੀਕਰਨ**: ਆਟੋਮੈਟਿਕ ਸੰਵੇਦਨਸ਼ੀਲਤਾ ਲੇਬਲਿੰਗ ਅਤੇ ਸੁਰੱਖਿਆ
# - **ਆਡਿਟ ਟ੍ਰੇਲਸ**: ਸਭ RAG ਓਪਰੇਸ਼ਨਾਂ ਦੀ ਵਿਸਤ੍ਰਿਤ ਲੌਗਿੰਗ
# - **ਪ੍ਰਾਇਵੇਸੀ ਸੁਰੱਖਿਆ**: PII ਪਛਾਣ ਅਤੇ ਰੈਡੈਕਸ਼ਨ ਸਮਰੱਥਾਵਾਂ
#
# ## 🔒 ਐਂਟਰਪ੍ਰਾਈਜ਼ ਸੁਰੱਖਿਆ ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ
#
# ### ਪ੍ਰਮਾਣਿਕਤਾ ਅਤੇ ਅਧਿਕਾਰਨ
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### ਡੇਟਾ ਸੁਰੱਖਿਆ
# - **ਐਨਕ੍ਰਿਪਸ਼ਨ**: ਦਸਤਾਵੇਜ਼ਾਂ ਅਤੇ ਖੋਜ ਇੰਡੈਕਸਾਂ ਲਈ ਆਖਿਰ ਤੱਕ ਐਨਕ੍ਰਿਪਸ਼ਨ
# - **ਪਹੁੰਚ ਨਿਯੰਤਰਣ**: ਯੂਜ਼ਰ ਅਤੇ ਗਰੁੱਪ ਅਨੁਮਤੀਆਂ ਲਈ Azure AD ਨਾਲ ਇੰਟਿਗ੍ਰੇਸ਼ਨ
# - **ਡੇਟਾ ਰਿਹਾਇਸ਼**: ਅਨੁਕੂਲਤਾ ਲਈ ਭੂਗੋਲਿਕ ਡੇਟਾ ਸਥਾਨ ਨਿਯੰਤਰਣ
# - **ਬੈਕਅੱਪ ਅਤੇ ਰਿਕਵਰੀ**: ਆਟੋਮੇਟਿਕ ਬੈਕਅੱਪ ਅਤੇ ਡਿਜਾਸਟਰ ਰਿਕਵਰੀ ਸਮਰੱਥਾਵਾਂ
#
# ## 📈 ਪ੍ਰਦਰਸ਼ਨ ਅਪਟੀਮਾਈਜ਼ੇਸ਼ਨ
#
# ### ਐਸਿੰਕ ਪ੍ਰੋਸੈਸਿੰਗ ਪੈਟਰਨ
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### ਮੇਮੋਰੀ ਪ੍ਰਬੰਧਨ
# - **ਸਟ्रीमਿੰਗ ਪ੍ਰੋਸੈਸਿੰਗ**: ਮੇਮੋਰੀ ਸਮੱਸਿਆਵਾਂ ਦੇ ਬਿਨਾਂ ਵੱਡੇ ਦਸਤਾਵੇਜ਼ ਸੰਭਾਲੋ
# - **ਰਿਸੋਰਸ ਪੂਲਿੰਗ**: ਮਹਿੰਗੇ ਸਰੋਤਾਂ ਦੀ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਮੁੜ ਵਰਤੋਂ
# - **ਗਾਰਬੇਜ ਕਲੇਕਸ਼ਨ**: ਅਪਟੀਮਾਈਜ਼ਡ ਮੈਮੋਰੀ ਅਲੋਕੇਸ਼ਨ ਪੈਟਰਨ
# - **ਕਨੈਕਸ਼ਨ ਪ੍ਰਬੰਧਨ**: ਸਹੀ Azure ਸੇਵਾ ਕਨੈਕਸ਼ਨ ਲਾਈਫਸਾਈਕਲ
#
# ### ਕੈਸ਼ਿੰਗ ਰਣਨੀਤੀਆਂ
# - **ਕਵੈਰੀ ਕੈਸ਼ਿੰਗ**: ਅਕਸਰ ਚਲਣ ਵਾਲੀਆਂ ਖੋਜਾਂ ਨੂੰ ਕੈਸ਼ ਕਰੋ
# - **ਦਸਤਾਵੇਜ਼ ਕੈਸ਼ਿੰਗ**: ਹਾਟ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਇਨ-ਮੇਮੋਰੀ ਕੈਸ਼ਿੰਗ
# - **ਇੰਡੈਕਸ ਕੈਸ਼ਿੰਗ**: ਅਪਟੀਮਾਈਜ਼ਡ ਵੇਕਟਰ ਇੰਡੈਕਸ ਕੈਸ਼ਿੰਗ
# - **ਨਤੀਜਾ ਕੈਸ਼ਿੰਗ**: ਤਿਆਰ ਕੀਤੀਆਂ ਜਵਾਬਾਂ ਦੀ ਸਮਾਰਟ ਕੈਸ਼ਿੰਗ
#
# ## 📊 ਐਂਟਰਪ੍ਰਾਈਜ਼ ਉਪਯੋਗ ਕੇਸ
#
# ### ਗਿਆਨ ਪ੍ਰਬੰਧਨ
# - **ਕੋਰਪੋਰੇਟ ਵਿਕੀ**: ਕੰਪਨੀ ਗਿਆਨ ਬੇਸਾਂ ਵਿੱਚ ਸਮਾਰਟ ਖੋਜ
# - **ਪਾਲਿਸੀ ਅਤੇ ਪ੍ਰਕਿਰਿਆਵਾਂ**: ਆਟੋਮੇਟਿਕ ਅਨੁਕੂਲਤਾ ਅਤੇ ਪ੍ਰਕਿਰਿਆ ਮਾਰਗਦਰਸ਼ਨ
# - **ਤਾਲੀਮੀ ਸਮੱਗਰੀ**: ਸਮਾਰਟ ਲਰਨਿੰਗ ਅਤੇ ਵਿਕਾਸ ਮਦਦ
# - **ਰਿਸਰਚ ਡੇਟਾਬੇਸ**: ਅਕਾਦਮੀਕ ਅਤੇ ਰਿਸਰਚ ਪੇਪਰ ਵਿਸ਼ਲੇਸ਼ਣ ਸਿਸਟਮ
#
# ### ਗ੍ਰਾਹਕ ਸਹਾਇਤਾ
# - **ਸਪੋਰਟ ਗਿਆਨ ਬੇਸ**: ਆਟੋਮੇਟਿਕ ਗ੍ਰਾਹਕ ਸੇਵਾ ਜਵਾਬ
# - **ਉਤਪਾਦ ਦਸਤਾਵੇਜ਼ੀकरण**: ਸਮਾਰਟ ਉਤਪਾਦ ਜਾਣਕਾਰੀ ਪ੍ਰਾਪਤੀ
# - **ਟ੍ਰਬਲਸ਼ੂਟਿੰਗ ਗਾਈਡਜ਼**: ਸੰਦਰਭਕ ਸਮੱਸਿਆ-ਸੋਲਵਿੰਗ ਮਦਦ
# - **FAQ ਸਿਸਟਮ**: ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹੀਆਂ ਤੋਂ ਡਾਇਨੈਮਿਕ FAQ ਤਿਆਰ ਕਰਨਾ
#
# ### ਨਿਯਮਕ ਅਨੁਕੂਲਤਾ
# - **ਕਾਨੂੰਨੀ ਦਸਤਾਵੇਜ਼ ਵਿਸ਼ਲੇਸ਼ਣ**: ਸੰਝੌਤੇ ਅਤੇ ਕਾਨੂੰਨੀ ਦਸਤਾਵੇਜ਼ ਬੁੱਧਿਮਤਾ
# - **ਅਨੁਕੂਲਤਾ ਨਿਗਰਾਨੀ**: ਆਟੋਮੇਟਿਕ ਨਿਯਮਕ ਅਨੁਕੂਲਤਾ ਜਾਂਚ
# - **ਖਤਰਾ ਮੁਲਾਂਕਣ**: ਦਸਤਾਵੇਜ਼-ਆਧਾਰਤ ਖਤਰਾ ਵਿਸ਼ਲੇਸ਼ਣ ਅਤੇ ਰਿਪੋਰਟਿੰਗ
# - **ਆਡਿਟ ਸਹਾਇਤਾ**: ਆਡਿਟਾਂ ਲਈ ਸਮਾਰਟ ਦਸਤਾਵੇਜ਼ ਖੋਜ
#
# ## 🚀 ਪ੍ਰੋਡਕਸ਼ਨ ਡਿਪਲੌਇਮੈਂਟ
#
# ### ਨਿਗਰਾਨੀ ਅਤੇ ਨਿਰੀਖਣਯੋਗਤਾ
# - **Application Insights**: ਵਿਸਥਾਰਪੂਰਕ ਟੈਲੀਮੇਟਰੀ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਨਿਗਰਾਨੀ
# - **ਕਸਟਮ ਮੈਟ੍ਰਿਕਸ**: ਕਾਰੋਬਾਰੀ-ਵਿਸ਼ੇਸ਼ KPI ਟ੍ਰੈਕਿੰਗ ਅਤੇ ਅਲਾਰਟਿੰਗ
# - **ਵੰਡਿਆ ਟ੍ਰੇਸਿੰਗ**: ਸੇਵਾਵਾਂ ਵਿੱਚ ਪੂਰਾ-ਰਾਹੀ ਅਨੁਰੋਧ ਟ੍ਰੈਕਿੰਗ
# - **ਹੈਲਥ ਡੈਸ਼ਬੋਰਡ**: ਰੀਅਲ-ਟਾਈਮ ਸਿਸਟਮ ਸਿਹਤ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਵਿਜ਼ੁਅਲਾਈਜ਼ੇਸ਼ਨ
#
# ### ਸਕੇਲਬਿਲਿਟੀ ਅਤੇ ਭਰੋਸੇਯੋਗਤਾ
# - **ਆਟੋ-ਸਕੇਲਿੰਗ**: ਲੋਡ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਮੈਟ੍ਰਿਕਸ ਦੇ ਆਧਾਰ ਤੇ ਆਟੋਮੈਟਿਕ ਸਕੇਲਿੰਗ
# - **ਹਾਈ ਅਵੇਲੇਬਿਲਿਟੀ**: ਫੇਲਓਵਰ ਸਮਰੱਥਾਵਾਂ ਨਾਲ ਬਹੁ-ਰੀਜਨ ਡਿਪਲੋਇਮੈਂਟ
# - **ਲੋਡ ਟੈਸਟਿੰਗ**: ਐਂਟਰਪ੍ਰਾਈਜ਼ ਲੋਡ ਹਾਲਤਾਂ ਹੇਠ ਪ੍ਰਦਰਸ਼ਨ ਚੈਕ
# - **ਡਿਜਾਸਟਰ ਰਿਕਵਰੀ**: ਆਟੋਮੇਟਿਕ ਬੈਕਅੱਪ ਅਤੇ ਰਿਕਵਰੀ ਪ੍ਰਕਿਰਿਆਵਾਂ
#
# ਕੀ ਤੁਸੀਂ ਤਿਆਰ ਹੋ ਐਂਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ RAG ਸਿਸਟਮ ਬਣਾਉਣ ਲਈ ਜੋ ਸਕੇਲ 'ਤੇ ਸੰਵੇਦਨਸ਼ੀਲ ਦਸਤਾਵੇਜ਼ਾਂ ਨੂੰ ਸੰਭਾਲ ਸਕਣ? ਆਓ ਐਂਟਰਪ੍ਰਾਈਜ਼ ਲਈ ਬੁੱਧਿਮਾਨ ਗਿਆਨ ਸਿਸਟਮਾਂ ਦੀ ਆਰਕੀਟੈਕਚਰ ਕਰੀਏ! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# ਅਸਪਸ਼ਟੀਕਰਨ:
# ਇਹ ਦਸਤਾਵੇਜ਼ AI ਅਨੁਵਾਦ ਸੇਵਾ Co-op Translator (https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦ ਕੀਤਾ ਗਿਆ ਹੈ। ਅਸੀਂ ਸ਼ੁੱਧਤਾ ਲਈ ਕੋਸ਼ਿਸ਼ ਕਰਦੇ ਹਾਂ, ਪਰ ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸ਼ੁੱਧੀਆਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਨੂੰ ਇਸ ਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਿਕ ਸ੍ਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਲਈ ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਿਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੀ ਵਰਤੋਂ ਕਾਰਨ ਉੱਥਪੰਨ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
