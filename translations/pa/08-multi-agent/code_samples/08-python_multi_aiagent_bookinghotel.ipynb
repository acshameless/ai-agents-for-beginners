# %% [markdown]
# ## **ਨਮੂਨੇ: ਹੋਟਲ ਬੁਕਿੰਗ ਲਈ ਬਹੁ-ਏਆਈ ਏਜੰਟ**
#
# ਅਜੋਕੇ ਤੇਜ਼ੀ ਨਾਲ ਬਦਲਦੇ ਜਹਾਨ ਵਿੱਚ, ਇੱਕ ਕਾਰੋਬਾਰੀ ਯਾਤਰਾ ਦੀ ਯੋਜਨਾ ਸਿਰਫ਼ ਉਡਾਣ ਅਤੇ ਹੋਟਲ ਦਾ ਕਮਰਾ ਬੁਕ ਕਰਨ ਤੋਂ ਵੱਧ ਕੁਝ ਹੈ। ਇਸ ਲਈ ਇਕੋ ਸਥਿਤੀ ਅਤੇ ਕੁਸ਼ਲਤਾ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ ਜੋ ਪ੍ਰਾਪਤ ਕਰਨੀ ਮੁਸ਼ਕਲ ਹੋ ਸਕਦੀ ਹੈ। ਇੱਥੇ ਬਹੁ-ਏਆਈ ਏਜੰਟ ਕਦਮ ਰਖਦੇ ਹਨ, ਜੋ ਸਾਡੀਆਂ ਯਾਤਰਾ ਦੀਆਂ ਜ਼ਰੂਰਤਾਂ ਨੂੰ ਸੰਭਾਲਣ ਦੇ ਤਰੀਕੇ ਨੂੰ ਬਦਲਣਗੇ।
#
# ਇਹ ਸੋਚੋ ਕਿ ਤੁਹਾਡੇ ਕੋਲ ਅਕਲਮੰਦ ਏਜੰਟਾਂ ਦੀ ਇੱਕ ਟੀਮ ਹੈ ਜੋ ਇਕੱਠੇ ਮਿਲ ਕੇ ਤੁਹਾਡੀ ਯਾਤਰਾ ਦੇ ਹਰ ਪਹਲੂ ਨੂੰ ਨਿਪਟਾਉਂਦੀ ਹੈ ਸਹੀ ਅਤੇ ਆਸਾਨੀ ਨਾਲ। ਸਾਡੇ ਅਧੁਨਿਕ ਏਆਈ ਤਕਨਾਲੋਜੀ ਦੇ ਨਾਲ, ਅਸੀਂ ਬੁਕਿੰਗ ਸੇਵਾਵਾਂ ਅਤੇ ਯਾਤਰਾ ਯੋਜਨਾ ਬਣਾਉਣ ਲਈ ਵਿਸ਼ੇਸ਼ ਏਜੰਟ ਬਣਾਏ ਹਨ, ਜੋ ਇੱਕ ਸਹਜ ਅਤੇ ਬੇਫਿਕਰ ਯਾਤਰਾ ਦਾ ਤਜਰਬਾ ਯਕੀਨੀ ਬਣਾਉਂਦੇ ਹਨ।
#
# ਇਹ ਇੱਕ ਮੂਲ ਦ੍ਰਿਸ਼ ਹੈ। ਜਦੋਂ ਕਾਰੋਬਾਰੀ ਯਾਤਰਾ ਦੀ ਯੋਜਨਾ ਬਣਾਈ ਜਾ ਰਹੀ ਹੋਵੇ, ਤਾਂ ਸਾਨੂੰ ਏਅਰ ਟਿਕਟ ਜਾਣਕਾਰੀ, ਹੋਟਲ ਜਾਣਕਾਰੀ ਆਦਿ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ ਕਾਰੋਬਾਰੀ ਯਾਤਰਾ ਏਜੰਟ ਨਾਲ ਸਲਾਹ ਮਸ਼ਵਰਾ ਕਰਨ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ। ਏਆਈ ਏਜੰਟਾਂ ਰਾਹੀਂ, ਅਸੀਂ ਬੁਕਿੰਗ ਸੇਵਾਵਾਂ ਲਈ ਏਜੰਟ ਅਤੇ ਯਾਤਰਾ ਯੋਜਨਾ ਲਈ ਏਜੰਟ ਬਣਾਕੇ ਸਹਿਯੋਗ ਕਰ ਸਕਦੇ ਹਾਂ ਅਤੇ ਬੁੱਧੀਮੱਤਾ ਦਾ ਪੱਧਰ ਵਧਾ ਸਕਦੇ ਹਾਂ।

# %% [markdown]
# # Azure AI Agent Service ਨੂੰ ਸ਼ੁਰੂ ਕਰੋ ਅਤੇ **.env** ਤੋਂ ਕੰਫ਼ਿਗਰੇਸ਼ਨ ਜਾਣਕਾਰੀ ਪ੍ਰਾਪਤ ਕਰੋ
#
# ### **.env**
#
# ਇੱਕ .env ਫਾਇਲ ਬਣਾਓ
#
# **.env** ਵਿੱਚ Azure AI Agent Service ਦਾ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ, AOAI ਦੁਆਰਾ ਵਰਤੀ ਜਾਣ ਵਾਲੀ ਮਾਡਲ, ਅਤੇ ਸੰਬੰਧਤ Google API Search ਸਰਵਿਸ API, ENDPOINT, ਆਦਿ ਸ਼ਾਮਲ ਹਨ।
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "ਤੁਹਾਡੇ Azure AI Agent Service ਮਾਡਲ ਡਿਪਲੋਇਮੈਂਟ ਦਾ ਨਾਮ"
#
# [**NOTE**] ਤੁਹਾਨੂੰ 100,000 ਰੇਟ ਲਿਮਿਟ (ਮਿੰਟ ਪ੍ਰਤੀ ਟੋਕਨ) ਅਤੇ 600 ਰੇਟ ਲਿਮਿਟ (ਮਿੰਟ ਪ੍ਰਤੀ ਬੇਨਤੀ) ਵਾਲਾ ਮਾਡਲ ਚਾਹੀਦਾ ਹੈ
#
#   ਤੁਸੀਂ Microsoft Foundry - ਮਾਡਲ ਅਤੇ Endpoint ਵਿੱਚ ਮਾਡਲ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "ਤੁਹਾਡੇ Azure AI Agent Service ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ"
#
#   ਤੁਸੀਂ AI Foundry ਪੋਰਟਲ ਸਕ੍ਰੀਨ ਵਿੱਚ ਆਪਣੇ ਪ੍ਰੋਜੈਕਟ ਓਵਰਵਿਊ ਵਿੱਚ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
# - **SERPAPI_SEARCH_API_KEY** = "ਤੁਹਾਡਾ SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "ਤੁਹਾਡਾ SERPAPI Search Endpoint"
#
# Azure AI Agent Service ਦਾ ਮਾਡਲ ਡਿਪਲੋਇਮੈਂਟ ਨਾਮ ਅਤੇ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, ਤੁਹਾਨੂੰ Azure AI Agent Service ਬਣਾਉਣੀ ਪਵੇਗੀ। ਇਸਨੂੰ ਸਿੱਧਾ ਬਣਾਉਣ ਲਈ [ਇਸ ਟੈਮਪਲੇਟ](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ਵਰਤਣ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ （***ਨੋਟ:*** Azure AI Agent Service ਇਸ ਸਮੇਂ ਸੀਮਤ ਖੇਤਰ ਵਿੱਚ ਸੈੱਟ ਹੈ। ਖੇਤਰ ਸੈੱਟ ਕਰਨ ਲਈ [ਇਸ ਲਿੰਕ](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ਨੂੰ ਦੇਖਣ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ)
#
# Agent ਨੂੰ SERPAPI ਤੱਕ ਪਹੁੰਚ ਚਾਹੀਦੀ ਹੈ। ਰਜਿਸਟਰ ਕਰਨ ਲਈ [ਇਸ ਲਿੰਕ](https://serpapi.com/searches) ਨੂੰ ਵਰਤਣਾ ਸਿਫ਼ਾਰਸ਼ ਹੈ। ਰਜਿਸਟ੍ਰੇਸ਼ਨ ਤੋਂ ਬਾਅਦ, ਤੁਸੀਂ ਇਕ ਵਿਲੱਖਣ API KEY ਅਤੇ ENDPOINT ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।

# %% [markdown]
# # Login to Azure
#
# ਤੁਹਾਨੂੰ ਹੁਣ Azure ਵਿੱਚ ਲਾਗਇਨ ਕਰਨ ਦੀ ਲੋੜ ਹੈ VScode ਵਿਚ ਇੱਕ ਟਰਮੀਨਲ ਖੋਲ੍ਹੋ ਅਤੇ `az login` ਕਮਾਂਡ ਚਲਾਓ

# %% [markdown]
# # ਸੈਟਅੱਪ
#
# ਇਸ ਨੋਟਬੁੱਕ ਨੂੰ ਚਲਾਉਣ ਲਈ, ਤੁਹਾਨੂੰ ਹੇਠਾਂ ਦਿੱਤੀਆਂ ਲਾਇਬ੍ਰੇਰੀਆਂ ਨੂੰ ਇੰਸਟਾਲ ਕਰਨਾ ਪਵੇਗਾ। ਇੱਥੇ ਲੋੜੀਂਦੀਆਂ ਲਾਇਬ੍ਰੇਰੀਆਂ ਅਤੇ ਉਹਨਾਂ ਨਾਲ ਜੁੜੇ pip ਇੰਸਟਾਲ ਕਮਾਂਡ ਦੀ ਸੂਚੀ ਦਿੱਤੀ ਗਈ ਹੈ:
#
# azure-identity: ਏਜ਼ੂਰ ਪ੍ਰਮਾਣੀਕਰਨ ਲਈ।
# requests: HTTP ਬੇਨਤੀ ਕਰਨ ਲਈ।
# semantic-kernel: ਸੈਮਾਂਟਿਕ ਕਰਨਲ ਫਰੇਮਵਰਕ ਲਈ (ਮੰਨਿਆ ਜਾ ਰਿਹਾ ਹੈ ਕਿ ਇਹ ਕੋਈ ਕਸਟਮ ਜਾਂ ਖਾਸ ਲਾਇਬ੍ਰੇਰੀ ਹੈ, ਤੁਹਾਨੂੰ ਇਹ ਕਿਸੇ ਖਾਸ ਸਰੋਤ ਜਾਂ ਰਿਪੋਜ਼ਿਟਰੀ ਤੋਂ ਇੰਸਟਾਲ ਕਰਨੀ ਪੈ ਸਕਦੀ ਹੈ)।

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Explanation:
# import asyncio: ਇਹ asyncio ਮੋਡੀਊਲ ਨੂੰ ਇੰਪੋਰਟ ਕਰਦਾ ਹੈ, ਜੋ Python ਵਿੱਚ ਐਸਿੰਕ੍ਰੋਨਸ ਪ੍ਰੋਗਰਾਮਿੰਗ ਲਈ ਸਮਰਥਨ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ। ਇਹ ਤੁਹਾਨੂੰ async ਅਤੇ await ਸਿੰਟੈਕਸ ਦੀ ਵਰਤੋਂ ਕਰਦੇ ਹੋਏ ਸਮਕਾਲੀ ਕੋਡ لکھਣ ਦੀ ਆਗਿਆ ਦਿੰਦਾ ਹੈ।
# from typing import Annotated: ਇਹ typing ਮੋਡੀਊਲ ਤੋਂ Annotated ਟਾਈਪ ਨੂੰ ਇੰਪੋਰਟ ਕਰਦਾ ਹੈ। Annotated ਨੂੰ ਟਾਈਪ ਹਿੰਟਸ ਵਿੱਚ ਮੈਟਾਡੇਟਾ ਸ਼ਾਮਲ ਕਰਨ ਲਈ ਵਰਤਿਆ ਜਾਂਦਾ ਹੈ, ਜੋ ਵੈਧਤਾ, ਦਸਤਾਵੇਜ਼ੀਕਰਨ ਜਾਂ ਟੂਲਿੰਗ ਵਰਗੇ ਵੱਖ-ਵੱਖ ਮਕਸਦਾਂ ਲਈ ਲਾਭਦਾਇਕ ਹੋ ਸਕਦਾ ਹੈ।

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Explanation:
# from dotenv import load_dotenv ਅਤੇ load_dotenv() ਨੂੰ ਵਰਤ ਕੇ, ਤੁਸੀਂ ਅਸਾਨੀ ਨਾਲ ਸੰਰਚਨਾ ਸੈਟਿੰਗਾਂ ਅਤੇ ਸੰਵੇਦਨਸ਼ੀਲ ਜਾਣਕਾਰੀ (ਜਿਵੇਂ ਕਿ API ਕੁੰਜੀਆਂ ਅਤੇ ਡੇਟਾਬੇਸ URL) ਨੂੰ .env ਫਾਇਲ ਵਿੱਚ ਸੰਭਾਲ ਸਕਦੇ ਹੋ, ਉਨ੍ਹਾਂ ਨੂੰ ਤੁਹਾਡੇ ਸੋਰਸ ਕੋਡ ਤੋਂ ਵੱਖਰਾ ਰੱਖਦੇ ਹੋ ਅਤੇ ਤੁਹਾਡੇ ਐਪਲੀਕੇਸ਼ਨ ਨੂੰ ਜ਼ਿਆਦਾ ਸੁਰੱਖਿਅਤ ਅਤੇ ਸੰਰਚਿਤ ਕਰਨ ਲਈ ਆਸਾਨ ਬਣਾਉਂਦੇ ਹੋ।

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # ਵਿਆਖਿਆ:
#
# Import Statement: from azure.identity.aio import DefaultAzureCredential: ਇਹ azure.identity.aio ਮੋਡੀਊਲ ਤੋਂ DefaultAzureCredential ਕਲਾਸ ਨੂੰ ਇੰਪੋਰਟ ਕਰਦਾ ਹੈ। ਮੋਡੀਊਲ ਨਾਮ ਦਾ aio ਹਿੱਸਾ ਦਰਸਾਉਂਦਾ ਹੈ ਕਿ ਇਹ ਅਸਿੰਕ੍ਰੋਨਸ ਓਪਰੇਸ਼ਨਾਂ ਲਈ ਡਿਜ਼ਾਇਨ ਕੀਤਾ ਗਿਆ ਹੈ।
#
# DefaultAzureCredential ਦਾ ਉਦੇਸ਼: DefaultAzureCredential ਕਲਾਸ Azure SDK for Python ਦਾ ਹਿੱਸਾ ਹੈ। ਇਹ Azure ਸੇਵਾਵਾਂ ਨਾਲ ਪ੍ਰਮਾਣੀਕਰਨ ਕਰਨ ਦਾ ਡਿਫ਼ੌਲਟ ਤਰੀਕਾ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ। ਇਹ ਵੱਖ-ਵੱਖ ਤਰੀਕਿਆਂ ਨਾਲ ਪ੍ਰਮਾਣੀਕਰਨ ਕਰਨ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦਾ ਹੈ, ਜਿਵੇਂ ਕਿ ਵਾਤਾਵਰਣ ਵੇਰੀਏਬਲ, ਮੈਨੇਜਡ ਆਈਡੈਂਟਿਟੀ, ਅਤੇ Azure CLI ਕ੍ਰੇਡੇਂਸ਼ਲਜ਼ ਨੂੰ ਖਾਸ ਕ੍ਰਮ ਵਿੱਚ ਵਰਤਦਿਆਂ।
#
# ਅਸਿੰਕ੍ਰੋਨਸ ਓਪਰੇਸ਼ਨਜ਼: aio ਮੋਡੀਊਲ ਦਰਸਾਉਂਦਾ ਹੈ ਕਿ DefaultAzureCredential ਕਲਾਸ ਅਸਿੰਕ੍ਰੋਨਸ ਓਪਰੇਸ਼ਨਜ਼ ਨੂੰ ਸਪੋਰਟ ਕਰਦੀ ਹੈ। ਇਸਦਾ مطلب ਹੈ ਕਿ ਤੁਸੀਂ ਇਸਨੂੰ asyncio ਨਾਲ ਵਰਤ ਸਕਦੇ ਹੋ ਤਾਂ ਜੋ ਨਾਨ-ਬਲਾਕਿੰਗ ਪ੍ਰਮਾਣੀਕਰਨ ਬੇਨਤੀ ਕੀਤੀ ਜਾ ਸਕੇਂ।

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Explanation:
# semantic_kernel ਪੈਕੇਜ ਤੋਂ ਵੱਖ-ਵੱਖ ਮੋਡੀਊਲ ਅਤੇ ਕਲਾਸਾਂ ਨੂੰ ਇੰਪੋਰਟ ਕਰਦਾ ਹੈ। ਇੱਥੇ ਹਰ ਇੰਪੋਰਟ ਦਾ ਵਿਸਥਾਰ ਦਿੱਤਾ ਗਿਆ ਹੈ:
#
# semantic_kernel.agents ਤੋਂ AgentGroupChat: ਇਹ ਕਲਾਸ AI ਏਜੰਟਾਂ ਲਈ ਗਰੁੱਪ ਚੈੱਟ ਨਾਲ ਸਬੰਧਿਤ ਫੰਕਸ਼ਨਾਲਿਟੀਜ਼ ਨੂੰ ਸੰਭਾਲਦੀ ਹੈ। semantic_kernel.agents.azure_ai ਤੋਂ AzureAIAgent ਅਤੇ AzureAIAgentSettings
#
# AzureAIAgent: ਇਹ ਕਲਾਸ ਉਹ AI ਏਜੰਟ ਬਣਾਉਣ ਅਤੇ ਪ੍ਰਬੰਧਿਤ ਕਰਨ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ ਜੋ Azure AI ਸੇਵਾਵਾਂ ਦੀ ਵਰਤੋਂ ਕਰਦੇ ਹਨ।
#
# AzureAIAgentSettings: ਇਹ ਕਲਾਸ AzureAIAgent ਲਈ ਸੈਟਿੰਗਜ਼ ਨੂੰ ਕਨਫਿਗਰ ਕਰਨ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ। semantic_kernel.agents.strategies.termination.termination_strategy ਤੋਂ TerminationStrategy:
#
# ਇਹ ਕਲਾਸ ਕੁਝ ਸ਼ਰਤਾਂ ਤਹਿਤ AI ਏਜੰਟਾਂ ਦੀ ਕਾਰਵਾਈ ਨੂੰ ਖਤਮ ਕਰਨ ਲਈ ਰਣਨੀਤੀਆਂ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦੀ ਹੈ। semantic_kernel.contents.chat_message_content ਤੋਂ ChatMessageContent:
#
# ਇਹ ਕਲਾਸ ਚੈਟ ਸੰਦਰਭਾਂ ਦੀ ਸਮੱਗਰੀ ਨੂੰ ਸੰਭਾਲਣ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ।
# semantic_kernel.contents.utils.author_role ਤੋਂ AuthorRole:
#
# ਇਹ ਕਲਾਸ ਚੈੱਟ ਸੰਦਰਭਾਂ ਵਿੱਚ ਲੇਖਕਾਂ ਲਈ ਵੱਖ-ਵੱਖ ਭੂਮਿਕਾਵਾਂ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦੀ ਹੈ।
#
# semantic_kernel.functions.kernel_function_decorator ਤੋਂ kernel_function: ਇਹ ਡੈੱਕੋਰੇਟਰ kernel ਫੰਕਸ਼ਨਾਂ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਨ ਲਈ ਵਰਤਿਆ ਜਾਂਦਾ ਹੈ, ਜੋ ਕਿ ਐਸੇ ਫੰਕਸ਼ਨ ਹੁੰਦੇ ਹਨ ਜੋ semantic kernel ਫਰੇਮਵਰਕ ਵਿੱਚ ਚਲਾਏ ਜਾ ਸਕਦੇ ਹਨ।
# ਇਹ ਇੰਪੋਰਟਜ਼ AI ਏਜੰਟਾਂ ਨੂੰ ਬਣਾਉਣ ਅਤੇ ਪ੍ਰਬੰਧਿਤ ਕਰਨ ਲਈ ਜ਼ਰੂਰੀ ਹਿੱਸਿਆਂ ਨੂੰ ਸੈੱਟ ਕਰਦੇ ਹਨ ਜੋ ਗਰੁੱਪ ਚੈਟ ਵਾਤਾਵਰਨ ਵਿੱਚ ਇੰਟਰਐਕਟ ਕਰ ਸਕਦੇ ਹਨ, ਸੰਭਵਤ: ਹੋਟਲ ਬੁਕਿੰਗ ਜਾਂ ਇਸੇ ਤਰ੍ਹਾਂ ਦੀਆਂ ਸਰਗਰਮੀਆਂ ਲਈ।

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Explanation:
# Next we import the CodeInterpreterTool class from the azure.ai.projects.models module.
#
# CodeInterpreterTool: ਇਹ ਕਲਾਸ Azure AI SDK ਦਾ ਹਿੱਸਾ ਹੈ ਅਤੇ AI ਪ੍ਰੋਜੈਕਟਾਂ ਦੇ ਸੰਦਰਭ ਵਿੱਚ ਕੋਡ ਦੀ ਵਿਆਖਿਆ ਕਰਨ ਅਤੇ ਚਲਾਉਣ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ। ਇਹ ਕੋਡ ਸਨਿਪੇਟ ਚਲਾਉਣ, ਕੋਡ ਦਾ ਵਿਸ਼ਲੇਸ਼ਣ ਕਰਨ ਜਾਂ AI ਵਰਕਫ਼ਲੋਜ਼ ਦੇ ਅੰਦਰ ਕੋਡ ਚਲਾਉਣ ਨੂੰ ਇਕੱਠਾ ਕਰਨ ਲਈ ਕਾਰਜਕੁਸ਼ਲਤਾਵਾਂ ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ।
# ਇਹ ਇੰਪੋਰਟ ਤੁਹਾਡੇ ਪ੍ਰੋਜੈਕਟ ਵਿੱਚ CodeInterpreterTool ਦੀ ਵਰਤੋਂ ਲਈ ਜ਼ਰੂਰੀ ਘੜੀ ਜਾਂ ਮੌਜੂਦਗੀ ਸੈਟ ਕਰਦਾ ਹੈ, ਜੋ ਅਜਿਹੀਆਂ ਟਾਸਕਾਂ ਲਈ ਲਾਭਦਾਇਕ ਹੋ ਸਕਦਾ ਹੈ ਜਿਹੜੀਆਂ ਗਤਿਸ਼ੀਲ ਤਰੀਕੇ ਨਾਲ ਕੋਡ ਦੀ ਵਿਆਖਿਆ ਅਤੇ ਚਲਾਉਣ ਨਾਲ ਸੰਬੰਧਿਤ ਹਨ।

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Explanation:
# The ApprovalTerminationStrategy class provides a specific strategy for terminating an AI agent's operation. The agent will terminate if the last message in its interaction history contains the word "saved". This could be useful in scenarios where the agent's task is considered complete once it receives confirmation that something has been "saved".Define the interaction method. After the reservation plan is saved, it can be stopped when receiving the saved signal

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Explanation:
#
# ਕੋਡ ਦੀ ਲਾਈਨ ਇੱਕ AzureAIAgentSettings ਆਬਜੈਕਟ ਨੂੰ ਡਿਫਾਲਟ ਜਾਂ ਪੂਰਵ-ਨਿਰਧਾਰਿਤ ਸੈਟਿੰਗਾਂ ਨਾਲ ਸ਼ੁਰੂ ਕਰਦੀ ਹੈ ਜਦੋਂ create() ਮੈਥਡ ਨੂੰ ਕਾਲ ਕਰਕੇ। ਇਹ ਸੈਟਿੰਗਾਂ ਵਾਲਾ ਆਬਜੈਕਟ (ai_agent_settings) ਫਿਰ ਇੱਕ AzureAIAgent ਇੰਸਟੈਂਸ ਨੂੰ ਸੰਰਚਿਤ ਅਤੇ ਪ੍ਰਬੰਧਿਤ ਕਰਨ ਲਈ ਵਰਤਿਆ ਜਾ ਸਕਦਾ ਹੈ।

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Explanation:
# requests ਲਾਇਬ੍ਰੇਰੀ ਨੂੰ ਇੰਪੋਰਟ ਕਰਕੇ, ਤੁਸੀਂ ਆਸਾਨੀ ਨਾਲ HTTP ਬੇਨਤੀਆਂ ਕਰ ਸਕਦੇ ਹੋ ਅਤੇ ਆਪਣੇ Python ਕੋਡ ਵਿੱਚ ਵੈੱਬ ਸੇਵਾਵਾਂ ਨਾਲ ਇੰਟਰੈਕਟ ਕਰ ਸਕਦੇ ਹੋ।

# %%
import requests

# %% [markdown]
# # ਵਿਆਖਿਆ:
# ਇਹ ਇੱਕ ਵੈਰੀਏਬਲ ਹੈ ਜੋ SERP (Search Engine Results Page) API ਸੇਵਾ ਤੱਕ ਪਹੁੰਚਣ ਲਈ API ਕੁੰਜੀ ਨੂੰ ਸਟੋਰ ਕਰਦਾ ਹੈ। ਇੱਕ API ਕੁੰਜੀ ਇੱਕ ਵਿਲੱਖਣ ਪਛਾਣ ਹੈ ਜੋ ਤੁਹਾਡੇ ਖਾਤੇ ਨਾਲ ਸੰਬੰਧਿਤ ਬੇਨਤੀਆਂ ਨੂੰ ਪ੍ਰਮਾਣਿਤ ਕਰਨ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ।
#
# 'GOOGLE_SEARCH_API_KEY': ਇਹ ਇੱਕ ਪਲੇਸਹੋਲਡਰ ਸਤਰ ਹੈ। ਤੁਹਾਨੂੰ ''GOOGLE_SEARCH_API_KEY' ਨੂੰ ਆਪਣੇ ਅਸਲੀ SERP API ਕੁੰਜੀ ਨਾਲ ਬਦਲਣਾ ਚਾਹੀਦਾ ਹੈ।
#
# ਮਕਸਦ: ਇਸ ਲਾਈਨ ਦਾ ਮਕਸਦ API ਕੁੰਜੀ ਨੂੰ ਇੱਕ ਵੈਰੀਏਬਲ ਵਿੱਚ ਸਟੋਰ ਕਰਨਾ ਹੈ ਤਾਂ ਜੋ ਇਸਨੂੰ SERP API ਸੇਵਾ ਵੱਲ ਬੇਨਤੀਆਂ ਪ੍ਰਮਾਣਿਤ ਕਰਨ ਲਈ ਵਰਤਿਆ ਜਾ ਸਕੇ। ਸੇਵਾ ਤੱਕ ਪਹੁੰਚ ਅਤੇ ਖੋਜਾਂ ਕਰਨ ਲਈ API ਕੁੰਜੀ ਲਾਜ਼ਮੀ ਹੈ।
#
# SERP API ਕੁੰਜੀ ਕਿਵੇਂ ਪ੍ਰਾਪਤ ਕਰੀਏ: SERP API ਕੁੰਜੀ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, https://serpapi.com 'ਤੇ ਹੇਠਾਂ ਦਿੱਤੇ ਆਮ ਕਦਮਾਂ ਦੀ ਪਾਲਣਾ ਕਰੋ (ਵਿਸ਼ੇਸ਼ SERP API ਸੇਵਾ ਦੇ ਅਨੁਸਾਰ ਕਦਮ ਵੱਖ-ਵੱਖ ਹੋ ਸਕਦੇ ਹਨ):
#
# SERP API ਸੇਵਾ ਚੁਣੋ: ਕਈ SERP API ਸੇਵਾਵਾਂ ਉਪਲਬਧ ਹਨ, ਜਿਵੇਂ SerpAPI, Google Custom Search JSON API, ਅਤੇ ਹੋਰ। ਉਹ ਸੇਵਾ ਚੁਣੋ ਜੋ ਤੁਹਾਡੇ ਜਰੂਰਤਾਂ ਨੂੰ ਸਭ ਤੋਂ ਵਧੀਆ ਪੂਰਾ ਕਰਦੀ ਹੈ।
#
# ਖਾਤਾ ਬਣਾਓ:
#
# ਚੁਣੀ ਹੋਈ SERP API ਸੇਵਾ ਦੀ ਵੈੱਬਸਾਈਟ https://www.serpapi.com 'ਤੇ ਜਾਓ ਅਤੇ ਖਾਤਾ ਬਣਾਓ। ਤੁਹਾਨੂੰ ਕੁਝ ਬੁਨਿਆਦੀ ਜਾਣਕਾਰੀ ਦੇਣੀ ਪੜ ਸਕਦੀ ਹੈ ਅਤੇ ਆਪਣਾ ਈਮੇਲ ਪਤਾ ਸੱਚਾ ਕਰਨਾ ਪੈ ਸਕਦਾ ਹੈ।
#
# API ਕੁੰਜੀ ਬਣਾਓ:
#
# ਖਾਤਾ ਬਣਾਉਣ ਤੋਂ ਬਾਅਦ, ਆਪਣੇ ਖਾਤੇ ਵਿੱਚ ਲੌਗਿਨ ਕਰੋ ਅਤੇ API ਖੰਡ ਜਾਂ ਡੈਸ਼ਬੋਰਡ ਵੱਲ ਜਾਓ। ਨਵੀਂ API ਕੁੰਜੀ ਬਣਾਉਣ ਜਾਂ ਜਨਰੇਟ ਕਰਨ ਲਈ ਵਿਕਲਪ ਲੱਭੋ।
#
# API ਕੁੰਜੀ ਕਾਪੀ ਕਰੋ:
#
# ਜਦੋਂ API ਕੁੰਜੀ ਜਨਰੇਟ ਹੋ ਜਾਵੇ, ਤਾਂ ਇਸ ਨੂੰ ਕਾਪੀ ਕਰੋ। ਇਸ ਕੁੰਜੀ ਨਾਲ ਤੁਹਾਡੀਆਂ SERP API ਸੇਵਾ ਵੱਲ ਬੇਨਤੀਆਂ ਪ੍ਰਮਾਣਿਤ ਕੀਤੀਆਂ ਜਾਣਗੀਆਂ।
# ਪਲੇਸਹੋਲਡਰ ਬਦਲੋ:
#
# ਆਪਣੇ .env ਫਾਈਲ ਵਿੱਚ ਪਲੇਸਹੋਲਡਰ ਨੂੰ ਬਦਲੋ

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # ਵਿਆਖਿਆ:
# BookingPlugin ਕਲਾਸ Serpapi.com ਗੂਗਲ ਸਰਚ API ਦੀ ਵਰਤੋਂ ਕਰਦਿਆਂ ਹੋਟਲਾਂ ਅਤੇ ਉਡਾਣਾਂ ਦੀ ਬੁਕਿੰਗ ਲਈ ਤਰੀਕੇ ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ। ਇਹ ਜ਼ਰੂਰੀ ਪੈਰਾਮੀਟਰ ਬਣਾਉਂਦੀ ਹੈ, API ਬਿਨੈ ਭੇਜਦੀ ਹੈ, ਅਤੇ ਜਵਾਬਾਂ ਨੂੰ ਪ੍ਰਕਿਰਿਆ ਕਰਕੇ ਸਬੰਧਿਤ ਬੁਕਿੰਗ ਜਾਣਕਾਰੀ ਵਾਪਸ ਕਰਦੀ ਹੈ। API ਕੁੰਜੀ (SERPAPI_SEARCH_API_KEY) ਅਤੇ ਐਂਡਪੋਇੰਟ (SERPAPI_SEARCH_ENDPOINT) ਦੀ ਵਰਤੋਂ ਗੂਗਲ ਸਰਚ API ਲਈ ਪ੍ਰਮਾਣਕਰਨ ਅਤੇ ਬਿਨੈ ਭੇਜਣ ਲਈ ਕੀਤੀ ਜਾਂਦੀ ਹੈ।

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Explanation:
# SavePlugin ਕਲਾਸ ਇੱਕ ਮੈਥਡ saving_plan ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ ਜੋ Azure AI ਸੇਵਾਵਾਂ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਯਾਤਰਾ ਦੀਆਂ ਯੋਜਨਾਵਾਂ ਨੂੰ ਸੇਵ ਕਰਦੀ ਹੈ। ਇਹ Azure ਕ੍ਰੈਡੈਂਸ਼ਲ ਸੈੱਟ ਕਰਦਾ ਹੈ, ਇੱਕ AI ਏਜੰਟ ਬਣਾਉਂਦਾ ਹੈ, ਯੂਜ਼ਰ ਇਨਪੁਟਸ ਨੂੰ ਪ੍ਰੋਸੈਸ ਕਰਦਾ ਹੈ ਤਾਂ ਜੋ ਯਾਤਰਾ ਦੀ ਯੋਜਨਾ ਦੀ ਸਮਗ੍ਰੀ ਤਿਆਰ ਅਤੇ ਸੇਵ ਕੀਤੀ ਜਾ ਸਕੇ, ਅਤੇ ਫਾਈਲ ਸੰਭਾਲਣ ਅਤੇ ਸਾਫ਼-ਸੁਥਰਾ ਕਰਨ ਵਾਲੇ ਕਾਰਜ ਨਿਭਾਉਂਦਾ ਹੈ। ਇਹ ਮੈਥਡ ਸਫਲਤਾਪੂਰਵਕ ਸਮਾਪਤੀ ’ਤੇ "Saved" ਵਾਪਸ ਕਰਦਾ ਹੈ।

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # ਵਿਆਖਿਆ:
# ਇਹ ਕੋਡ ਯੂਜ਼ਰ ਇਨਪੁੱਟ ਦੇ ਆਧਾਰ 'ਤੇ ਫਲਾਈਟਾਂ ਅਤੇ ਹੋਟਲਾਂ ਦੀ ਬੁਕਿੰਗ ਕਰਨ ਅਤੇ ਯਾਤਰਾ ਯੋਜਨਾਵਾਂ ਸੁਰੱਖਿਅਤ ਕਰਨ ਲਈ ਅਜ਼ੂਰ ਏਆਈ ਏਜੰਟਾਂ ਨੂੰ ਸੈੱਟ ਕਰਦਾ ਹੈ। ਇਹ ਏਜੰਟਾਂ ਨੂੰ ਬਣਾਉਣ ਅਤੇ ਸੰਰਚਿਤ ਕਰਨ ਲਈ ਅਜ਼ੂਰ ਸਹੀਕਰਨ ਦਾ ਉਪਯੋਗ ਕਰਦਾ ਹੈ, ਯੂਜ਼ਰ ਇਨਪੁੱਟ ਨੂੰ ਇੱਕ ਗਰੁੱਪ ਚੈਟ ਰਾਹੀਂ ਪ੍ਰਕਿਰਿਆ ਕਰਦਾ ਹੈ, ਅਤੇ ਕੰਮ ਪੂਰਾ ਹੋਣ ਤੋਂ ਬਾਅਦ ਢੰਗ ਨਾਲ ਸਫਾਈ ਨੂੰ ਯਕੀਨੀ ਬਨਾਉਂਦਾ ਹੈ। ਏਜੰਟਾਂ ਆਪਣੇ-ਆਪਣੇ ਕੰਮ ਕਰਨ ਲਈ ਖਾਸ ਪਲੱਗਇਨਾਂ (BookingPlugin ਅਤੇ SavePlugin) ਦੀ ਵਰਤੋਂ ਕਰਦੇ ਹਨ।

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਤਿਆਗਪੱਤਰ**:
# ਇਹ ਦਸਤਾਵੇਜ਼ AI ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦਿਤ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਅਤੀ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਵਿੱਚ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਹੀਤੀਆਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਨੂੰ ਇਸ ਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਤ ਸਰੋਤ ਵਜੋਂ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜ਼ਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤ ਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਵਸਥਾ ਲਈ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
