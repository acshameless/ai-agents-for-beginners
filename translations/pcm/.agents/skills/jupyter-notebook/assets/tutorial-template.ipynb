# %% [markdown]
# # Tutorial: TITLE
#
# Audience:
# - Tok becos who dis one de for.
#
# Prerequisites:
# - List beta tins or setup weh you go need.
#
# Learning goals:
# - By di end, di person wey read fit...

# %% [markdown]
# ## Outline
#
# 1. Setup
# 2. A minimal working example
# 3. Variations and pitfalls
# 4. Exercises

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Step 1 - Start with a tiny example
#
# Explain wetin di next cell dey do for simple tori.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Exercises
#
# - Try different input.
# - Predict wetin go show before you run the code.
# - Talk one common mistake and how to correct am.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# Dis document na translate weh dem do wit AI translation service [Co-op Translator](https://github.com/Azure/co-op-translator). Even tho we try make e correct, abeg make you sabi say automated translations fit get some mistakes or no too correct. Di original document wey dem write for im own language na di correct source. For important info, e better make human professional translate am. We no dey responsible for any misunderstanding or wrong interpretation we fit happen from dis translation.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
