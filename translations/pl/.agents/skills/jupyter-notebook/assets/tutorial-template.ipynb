# %% [markdown]
# # Samouczek: TITLE
#
# Odbiorcy:
# - Opisz, dla kogo to jest.
#
# Wymagania wstępne:
# - Wymień wymagane pojęcia lub konfigurację.
#
# Cele nauki:
# - Po zakończeniu czytelnik będzie potrafił...

# %% [markdown]
# ## Zarys
#
# 1. Konfiguracja
# 2. Minimalny działający przykład
# 3. Wariacje i pułapki
# 4. Ćwiczenia

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Krok 1 - Zacznij od małego przykładu
#
# Wyjaśnij, co robi następna komórka w prostych słowach.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Ćwiczenia
#
# - Wypróbuj inne dane wejściowe.
# - Przewidź wynik przed uruchomieniem kodu.
# - Zanotuj jeden powszechny błąd i jak go naprawić.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Zastrzeżenie:
# Niniejszy dokument został przetłumaczony z użyciem usługi tłumaczenia AI Co-op Translator (https://github.com/Azure/co-op-translator). Dokładamy starań, aby tłumaczenie było jak najbardziej trafne, jednak proszę mieć na uwadze, że tłumaczenia automatyczne mogą zawierać błędy lub nieścisłości. Oryginalny dokument w języku źródłowym należy traktować jako dokument wiążący. W przypadku informacji istotnych zalecane jest skorzystanie z profesjonalnego tłumaczenia wykonanego przez człowieka. Nie ponosimy odpowiedzialności za jakiekolwiek nieporozumienia lub błędne interpretacje wynikające z korzystania z tego tłumaczenia.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
