# %% [markdown]
# # 🔍 Enterprise RAG with Microsoft Foundry (.NET)
#
# ## 📋 Cele szkoleniowe
#
# Ten notatnik pokazuje, jak zbudować systemy Retrieval-Augmented Generation (RAG) klasy korporacyjnej przy użyciu Microsoft Agent Framework w .NET z Microsoft Foundry. Nauczysz się tworzyć gotowe do produkcji agenty, które potrafią przeszukiwać dokumenty i dostarczać dokładne, kontekstowe odpowiedzi z zachowaniem bezpieczeństwa i skalowalności przedsiębiorstwa.
#
# **Możliwości Enterprise RAG, które zbudujesz:**
# - 📚 **Document Intelligence**: Zaawansowane przetwarzanie dokumentów z użyciem usług Azure AI
# - 🔍 **Semantic Search**: Wysokowydajne wyszukiwanie wektorowe z funkcjami korporacyjnymi
# - 🛡️ **Security Integration**: Wzorce ochrony danych i dostępów oparte na rolach
# - 🏢 **Scalable Architecture**: Systemy RAG gotowe do produkcji z monitoringiem
#
# ## 🎯 Architektura Enterprise RAG
#
# ### Podstawowe komponenty korporacyjne
# - **Microsoft Foundry**: Zarządzana platforma AI dla przedsiębiorstw z funkcjami bezpieczeństwa i zgodności
# - **Persistent Agents**: Trwałe agenty z historią konwersacji i zarządzaniem kontekstem
# - **Vector Store Management**: Indeksowanie i pobieranie dokumentów na poziomie korporacyjnym
# - **Identity Integration**: Uwierzytelnianie Azure AD i kontrola dostępu oparta na rolach
#
# ### Korzyści .NET dla przedsiębiorstw
# - **Type Safety**: Walidacja w czasie kompilacji dla operacji RAG i struktur danych
# - **Async Performance**: Nieblokujące przetwarzanie dokumentów i operacje wyszukiwania
# - **Memory Management**: Efektywne wykorzystanie zasobów dla dużych kolekcji dokumentów
# - **Integration Patterns**: Natywna integracja usług Azure z wstrzykiwaniem zależności
#
# ## 🏗️ Architektura techniczna
#
# ### Rura przetwarzania Enterprise RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Podstawowe komponenty .NET
# - **Azure.AI.Agents.Persistent**: Zarządzanie agentami korporacyjnymi z trwałością stanu
# - **Azure.Identity**: Zintegrowane uwierzytelnianie dla bezpiecznego dostępu do usług Azure
# - **Microsoft.Agents.AI.AzureAI**: Implementacja frameworka agentów zoptymalizowana pod Azure
# - **System.Linq.Async**: Wysokowydajne asynchroniczne operacje LINQ
#
# ## 🔧 Funkcje i korzyści dla przedsiębiorstw
#
# ### Bezpieczeństwo i zgodność
# - **Azure AD Integration**: Zarządzanie tożsamością i uwierzytelnianie dla przedsiębiorstw
# - **Role-Based Access**: Szczegółowe uprawnienia do dostępu i operacji na dokumentach
# - **Data Protection**: Szyfrowanie w spoczynku i w tranzycie dla wrażliwych dokumentów
# - **Audit Logging**: Kompleksowe śledzenie aktywności dla wymogów zgodności
#
# ### Wydajność i skalowalność
# - **Connection Pooling**: Efektywne zarządzanie połączeniami z usługami Azure
# - **Async Processing**: Nieblokujące operacje dla scenariuszy o dużej przepustowości
# - **Caching Strategies**: Inteligentne cachowanie dla często wykorzystywanych dokumentów
# - **Load Balancing**: Rozproszone przetwarzanie dla wdrożeń na dużą skalę
#
# ### Zarządzanie i monitorowanie
# - **Health Checks**: Wbudowany monitoring komponentów systemu RAG
# - **Performance Metrics**: Szczegółowe analizy jakości wyszukiwania i czasów odpowiedzi
# - **Error Handling**: Kompleksowe zarządzanie wyjątkami z politykami ponawiania
# - **Configuration Management**: Ustawienia specyficzne dla środowiska z walidacją
#
# ## ⚙️ Wymagania wstępne i konfiguracja
#
# **Środowisko programistyczne:**
# - .NET 9.0 SDK lub nowszy
# - Visual Studio 2022 lub VS Code z rozszerzeniem C#
# - Subskrypcja Azure z dostępem do AI Foundry
#
# **Wymagane pakiety NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Konfiguracja uwierzytelniania w Azure:**
# ```bash
# # Zainstaluj Azure CLI i uwierzytelnij się
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Konfiguracja środowiska (plik .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Wzorce Enterprise RAG
#
# ### Wzorce zarządzania dokumentami
# - **Bulk Upload**: Efektywne przetwarzanie dużych kolekcji dokumentów
# - **Incremental Updates**: Przyrostowe dodawanie i modyfikacja dokumentów w czasie rzeczywistym
# - **Version Control**: Wersjonowanie dokumentów i śledzenie zmian
# - **Metadata Management**: Bogate atrybuty dokumentów i taksonomia
#
# ### Wzorce wyszukiwania i pobierania
# - **Hybrid Search**: Łączenie wyszukiwania semantycznego i słów kluczowych dla optymalnych wyników
# - **Faceted Search**: Wielowymiarowe filtrowanie i kategoryzacja
# - **Relevance Tuning**: Dostosowywanie trafności za pomocą niestandardowych algorytmów
# - **Result Ranking**: Zaawansowany ranking z integracją logiki biznesowej
#
# ### Wzorce bezpieczeństwa
# - **Document-Level Security**: Szczegółowa kontrola dostępu na poziomie dokumentu
# - **Data Classification**: Automatyczne etykietowanie wrażliwości i ochrona danych
# - **Audit Trails**: Kompleksowe logowanie wszystkich operacji RAG
# - **Privacy Protection**: Wykrywanie i zaciemnianie danych osobowych (PII)
#
# ## 🔒 Funkcje bezpieczeństwa dla przedsiębiorstw
#
# ### Uwierzytelnianie i autoryzacja
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Ochrona danych
# - **Encryption**: Szyfrowanie end-to-end dla dokumentów i indeksów wyszukiwania
# - **Access Controls**: Integracja z Azure AD dla uprawnień użytkowników i grup
# - **Data Residency**: Kontrole lokalizacji danych dla zgodności regulacyjnej
# - **Backup & Recovery**: Zautomatyzowane kopie zapasowe i możliwości odzyskiwania po awarii
#
# ## 📈 Optymalizacja wydajności
#
# ### Wzorce przetwarzania asynchronicznego
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Zarządzanie pamięcią
# - **Streaming Processing**: Obsługa dużych dokumentów bez problemów z pamięcią
# - **Resource Pooling**: Efektywne ponowne wykorzystywanie kosztownych zasobów
# - **Garbage Collection**: Optymalizowane wzorce alokacji pamięci
# - **Connection Management**: Prawidłowy cykl życia połączeń z usługami Azure
#
# ### Strategie buforowania
# - **Query Caching**: Buforowanie często wykonywanych zapytań
# - **Document Caching**: Buforowanie w pamięci dla gorących dokumentów
# - **Index Caching**: Optymalizowane buforowanie indeksów wektorowych
# - **Result Caching**: Inteligentne przechowywanie wygenerowanych odpowiedzi
#
# ## 📊 Zastosowania korporacyjne
#
# ### Zarządzanie wiedzą
# - **Corporate Wiki**: Inteligentne wyszukiwanie w firmowych bazach wiedzy
# - **Policy & Procedures**: Automatyczne wsparcie w zgodności i procedurach
# - **Training Materials**: Inteligentne wsparcie dla nauki i rozwoju
# - **Research Databases**: Systemy analizy artykułów naukowych i baz badawczych
#
# ### Obsługa klienta
# - **Support Knowledge Base**: Automatyczne odpowiedzi w obsłudze klienta
# - **Product Documentation**: Inteligentne pobieranie informacji o produktach
# - **Troubleshooting Guides**: Kontekstowe wsparcie rozwiązywania problemów
# - **FAQ Systems**: Dynamiczne generowanie FAQ z kolekcji dokumentów
#
# ### Zgodność regulacyjna
# - **Legal Document Analysis**: Analiza kontraktów i dokumentów prawnych
# - **Compliance Monitoring**: Zautomatyzowane sprawdzanie zgodności regulacyjnej
# - **Risk Assessment**: Analiza ryzyka oparta na dokumentach i raportowanie
# - **Audit Support**: Inteligentne odnajdywanie dokumentów na potrzeby audytów
#
# ## 🚀 Wdrożenie do produkcji
#
# ### Monitorowanie i obserwowalność
# - **Application Insights**: Szczegółowa telemetria i monitoring wydajności
# - **Custom Metrics**: Śledzenie KPI specyficznych dla biznesu i alertowanie
# - **Distributed Tracing**: End-to-end śledzenie żądań między usługami
# - **Health Dashboards**: Wizualizacja stanu systemu i wydajności w czasie rzeczywistym
#
# ### Skalowalność i niezawodność
# - **Auto-Scaling**: Automatyczne skalowanie w oparciu o obciążenie i metryki wydajności
# - **High Availability**: Wieloregionowe wdrożenie z mechanizmami failover
# - **Load Testing**: Walidacja wydajności pod obciążeniem korporacyjnym
# - **Disaster Recovery**: Zautomatyzowane procedury tworzenia kopii zapasowych i odzyskiwania
#
# Gotowy, aby zbudować systemy RAG klasy korporacyjnej, które radzą sobie z poufnymi dokumentami na dużą skalę? Zaprojektujmy inteligentne systemy wiedzy dla przedsiębiorstw! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Zastrzeżenie:
# Niniejszy dokument został przetłumaczony przy użyciu usługi tłumaczeń AI [Co-op Translator](https://github.com/Azure/co-op-translator). Chociaż dokładamy starań o dokładność, prosimy pamiętać, że tłumaczenia automatyczne mogą zawierać błędy lub nieścisłości. Oryginalny dokument w jego języku źródłowym powinien być traktowany jako źródło nadrzędne. W przypadku informacji krytycznych zalecane jest skorzystanie z profesjonalnego tłumaczenia wykonanego przez człowieka. Nie ponosimy odpowiedzialności za jakiekolwiek nieporozumienia lub błędne interpretacje wynikające z korzystania z tego tłumaczenia.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
