# %% [markdown]
# # Tutorial: TITLE
#
# Público-alvo:
# - Descreva para quem isto é.
#
# Pré-requisitos:
# - Liste os conceitos ou configurações necessários.
#
# Objetivos de aprendizagem:
# - Ao final, o leitor será capaz de...

# %% [markdown]
# ## Roteiro
#
# 1. Configuração
# 2. Um exemplo mínimo funcional
# 3. Variações e armadilhas
# 4. Exercícios

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Etapa 1 - Comece com um exemplo bem pequeno
#
# Explique em linguagem simples o que a próxima célula faz.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Exercícios
#
# - Experimente uma entrada diferente.
# - Preveja a saída antes de executar o código.
# - Observe um erro comum e como corrigi-lo.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Isenção de responsabilidade:
# Este documento foi traduzido usando o serviço de tradução por IA [Co-op Translator](https://github.com/Azure/co-op-translator). Embora nos esforcemos pela precisão, esteja ciente de que traduções automatizadas podem conter erros ou imprecisões. O documento original, em seu idioma nativo, deve ser considerado a fonte autoritativa. Para informações críticas, recomenda-se tradução humana profissional. Não nos responsabilizamos por quaisquer mal-entendidos ou interpretações equivocadas decorrentes do uso desta tradução.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
