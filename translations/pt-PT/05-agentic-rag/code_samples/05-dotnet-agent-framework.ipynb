# %% [markdown]
# # 🔍 RAG Empresarial com Microsoft Foundry (.NET)
#
# ## 📋 Objetivos de Aprendizagem
#
# Este notebook demonstra como construir sistemas de Retrieval-Augmented Generation (RAG) de nível empresarial utilizando o Microsoft Agent Framework em .NET com o Microsoft Foundry. Irá aprender a criar agentes prontos para produção que conseguem pesquisar em documentos e fornecer respostas precisas e contextualizadas com segurança e escalabilidade empresariais.
#
# **Funcionalidades de RAG Empresarial que irá Construir:**
# - 📚 **Document Intelligence**: Processamento avançado de documentos com serviços Azure AI
# - 🔍 **Semantic Search**: Pesquisa vetorial de alto desempenho com funcionalidades empresariais
# - 🛡️ **Security Integration**: Padrões de controlo de acesso baseado em funções e proteção de dados
# - 🏢 **Scalable Architecture**: Sistemas RAG prontos para produção com monitorização
#
# ## 🎯 Arquitetura de RAG Empresarial
#
# ### Componentes Empresariais Principais
# - **Microsoft Foundry**: Plataforma de IA empresarial gerida com segurança e conformidade
# - **Persistent Agents**: Agentes com estado, histórico de conversação e gestão de contexto
# - **Vector Store Management**: Indexação e recuperação de documentos de nível empresarial
# - **Identity Integration**: Autenticação Azure AD e controlo de acesso baseado em funções
#
# ### Benefícios .NET para Empresas
# - **Type Safety**: Validação em tempo de compilação para operações RAG e estruturas de dados
# - **Async Performance**: Processamento de documentos e operações de pesquisa não bloqueantes
# - **Memory Management**: Utilização eficiente de recursos para coleções de documentos grandes
# - **Integration Patterns**: Integração nativa com serviços Azure através de dependency injection
#
# ## 🏗️ Arquitetura Técnica
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Componentes .NET Principais
# - **Azure.AI.Agents.Persistent**: Gestão empresarial de agentes com persistência de estado
# - **Azure.Identity**: Autenticação integrada para acesso seguro a serviços Azure
# - **Microsoft.Agents.AI.AzureAI**: Implementação do framework de agentes otimizada para Azure
# - **System.Linq.Async**: Operações LINQ assíncronas de alto desempenho
#
# ## 🔧 Funcionalidades & Benefícios Empresariais
#
# ### Segurança & Conformidade
# - **Azure AD Integration**: Gestão de identidade empresarial e autenticação
# - **Role-Based Access**: Permissões granulares para acesso e operações em documentos
# - **Data Protection**: Criptografia em repouso e em trânsito para documentos sensíveis
# - **Audit Logging**: Rastreio de atividade abrangente para requisitos de conformidade
#
# ### Desempenho & Escalabilidade
# - **Connection Pooling**: Gestão eficiente de ligações a serviços Azure
# - **Async Processing**: Operações não bloqueantes para cenários de alto débito
# - **Caching Strategies**: Caching inteligente para documentos acedidos com frequência
# - **Load Balancing**: Processamento distribuído para implementações em grande escala
#
# ### Gestão & Monitorização
# - **Health Checks**: Monitorização incorporada para os componentes do sistema RAG
# - **Performance Metrics**: Análise detalhada da qualidade de pesquisa e tempos de resposta
# - **Error Handling**: Gestão abrangente de exceções com políticas de retry
# - **Configuration Management**: Definições específicas por ambiente com validação
#
# ## ⚙️ Pré-requisitos & Configuração
#
# **Ambiente de Desenvolvimento:**
# - .NET 9.0 SDK ou superior
# - Visual Studio 2022 ou VS Code com a extensão C#
# - Assinatura Azure com acesso ao AI Foundry
#
# **Pacotes NuGet Necessários:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Configuração de Autenticação Azure:**
# ```bash
# # Instale a Azure CLI e autentique-se
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Configuração do Ambiente (ficheiro .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Padrões de RAG Empresarial
#
# ### Padrões de Gestão de Documentos
# - **Bulk Upload**: Processamento eficiente de coleções de documentos volumosas
# - **Incremental Updates**: Adição e modificação de documentos em tempo real
# - **Version Control**: Versão de documentos e rastreio de alterações
# - **Metadata Management**: Atributos ricos de documentos e taxonomia
#
# ### Padrões de Pesquisa & Recuperação
# - **Hybrid Search**: Combinação de pesquisa semântica e por palavras-chave para resultados ótimos
# - **Faceted Search**: Filtragem e categorização multidimensional
# - **Relevance Tuning**: Algoritmos de pontuação personalizados para necessidades específicas do domínio
# - **Result Ranking**: Ranking avançado com integração de lógica empresarial
#
# ### Padrões de Segurança
# - **Document-Level Security**: Controlo de acesso granulado por documento
# - **Data Classification**: Etiquetagem automática de sensibilidade e proteção
# - **Audit Trails**: Registo abrangente de todas as operações RAG
# - **Privacy Protection**: Detecção e mascaramento de PII
#
# ## 🔒 Funcionalidades de Segurança Empresariais
#
# ### Autenticação & Autorização
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Proteção de Dados
# - **Encryption**: Criptografia ponta-a-ponta para documentos e índices de pesquisa
# - **Access Controls**: Integração com Azure AD para permissões de utilizadores e grupos
# - **Data Residency**: Controlo geográfico da localização dos dados para conformidade
# - **Backup & Recovery**: Capabilidades automatizadas de backup e recuperação de desastres
#
# ## 📈 Otimização de Desempenho
#
# ### Padrões de Processamento Assíncrono
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Gestão de Memória
# - **Streaming Processing**: Lidar com documentos grandes sem problemas de memória
# - **Resource Pooling**: Reutilização eficiente de recursos caros
# - **Garbage Collection**: Padrões de alocação de memória otimizados
# - **Connection Management**: Ciclo de vida adequado das ligações a serviços Azure
#
# ### Estratégias de Caching
# - **Query Caching**: Cache de pesquisas executadas frequentemente
# - **Document Caching**: Cache em memória para documentos quentes
# - **Index Caching**: Caching otimizado do índice vetorial
# - **Result Caching**: Caching inteligente das respostas geradas
#
# ## 📊 Casos de Uso Empresariais
#
# ### Gestão do Conhecimento
# - **Corporate Wiki**: Pesquisa inteligente em bases de conhecimento da empresa
# - **Policy & Procedures**: Orientação automatizada de conformidade e procedimentos
# - **Training Materials**: Assistência inteligente para aprendizagem e desenvolvimento
# - **Research Databases**: Sistemas de análise de papers académicos e de investigação
#
# ### Apoio ao Cliente
# - **Support Knowledge Base**: Respostas automatizadas de suporte ao cliente
# - **Product Documentation**: Recuperação inteligente de informação de produto
# - **Troubleshooting Guides**: Assistência contextual para resolução de problemas
# - **FAQ Systems**: Geração dinâmica de FAQs a partir de coleções de documentos
#
# ### Conformidade Regulamentar
# - **Legal Document Analysis**: Inteligência para contratos e documentos legais
# - **Compliance Monitoring**: Verificação automatizada de conformidade regulamentar
# - **Risk Assessment**: Análise e reporte de risco baseada em documentos
# - **Audit Support**: Descoberta inteligente de documentos para auditorias
#
# ## 🚀 Implementação em Produção
#
# ### Monitorização & Observability
# - **Application Insights**: Telemetria detalhada e monitorização de desempenho
# - **Custom Metrics**: Monitorização e alertas de KPI específicos do negócio
# - **Distributed Tracing**: Rastreio end-to-end de pedidos entre serviços
# - **Health Dashboards**: Visualização em tempo real da saúde e desempenho do sistema
#
# ### Escalabilidade & Fiabilidade
# - **Auto-Scaling**: Dimensionamento automático com base na carga e métricas de desempenho
# - **High Availability**: Implementação multi-região com capacidades de failover
# - **Load Testing**: Validação de desempenho sob condições de carga empresarial
# - **Disaster Recovery**: Procedimentos automatizados de backup e recuperação
#
# Pronto para construir sistemas RAG de nível empresarial que consigam lidar com documentos sensíveis em escala? Vamos arquitetar sistemas de conhecimento inteligentes para a empresa! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Isenção de responsabilidade:
# Este documento foi traduzido utilizando o serviço de tradução por IA Co-op Translator (https://github.com/Azure/co-op-translator). Apesar de nos esforçarmos por garantir a precisão, esteja ciente de que traduções automáticas podem conter erros ou imprecisões. O documento original, na sua língua original, deve ser considerado a fonte autoritativa. Para informações críticas, recomenda-se a tradução por um tradutor profissional. Não nos responsabilizamos por quaisquer mal-entendidos ou interpretações incorretas decorrentes da utilização desta tradução.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
