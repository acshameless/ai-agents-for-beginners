# %% [markdown]
# # Tutorial: TITLE
#
# Public țintă:
# - Descrie pentru cine este destinat.
#
# Cerințe prealabile:
# - Enumeră conceptele sau configurația necesare.
#
# Obiective de învățare:
# - La final, cititorul va putea...

# %% [markdown]
# ## Cuprins
#
# 1. Configurare
# 2. Un exemplu minim funcțional
# 3. Variații și capcane
# 4. Exerciții

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Pasul 1 - Începe cu un exemplu mic
#
# Explică ce face celula următoare în termeni simpli.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Exerciții
#
# - Încercați o intrare diferită.
# - Preziceți rezultatul înainte de a rula codul.
# - Notați o greșeală comună și cum să o remediați.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Declinare de responsabilitate**:
# Acest document a fost tradus folosind serviciul de traducere AI [Co-op Translator](https://github.com/Azure/co-op-translator). Deși ne străduim pentru acuratețe, vă rugăm să rețineți că traducerile automate pot conține erori sau inexactități. Documentul original în limba sa nativă trebuie considerat sursa autoritativă. Pentru informații critice, se recomandă traducerea profesională realizată de un traducător uman. Nu ne asumăm răspunderea pentru eventualele neînțelegeri sau interpretări eronate rezultate din utilizarea acestei traduceri.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
