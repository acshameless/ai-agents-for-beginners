# %% [markdown]
# # 🔍 Enterprise RAG with Microsoft Foundry (.NET)
#
# ## 📋 Obiective de învățare
#
# Acest notebook demonstrează cum să construiești sisteme Retrieval-Augmented Generation (RAG) la nivel enterprise folosind Microsoft Agent Framework în .NET cu Microsoft Foundry. Vei învăța să creezi agenți pregătiți pentru producție care pot căuta în documente și oferi răspunsuri precise, conștiente de context, cu securitate și scalabilitate enterprise.
#
# **Capabilități RAG pentru întreprinderi pe care le vei construi:**
# - 📚 **Document Intelligence**: Procesare avansată a documentelor cu servicii Azure AI
# - 🔍 **Semantic Search**: Căutare vectorială de înaltă performanță cu caracteristici enterprise
# - 🛡️ **Security Integration**: Modele de protecție a datelor și control bazat pe roluri
# - 🏢 **Scalable Architecture**: Sisteme RAG pregătite pentru producție cu monitorizare
#
# ## 🎯 Arhitectura RAG pentru întreprinderi
#
# ### Componente enterprise de bază
# - **Microsoft Foundry**: Platformă AI enterprise gestionată cu securitate și conformitate
# - **Persistent Agents**: Agenți stateful cu istoric de conversații și management al contextului
# - **Vector Store Management**: Indexare și recuperare a documentelor la nivel enterprise
# - **Identity Integration**: Autentificare Azure AD și control al accesului bazat pe roluri
#
# ### Beneficii .NET pentru întreprinderi
# - **Type Safety**: Validare la compilare pentru operațiuni RAG și structuri de date
# - **Async Performance**: Procesare asincronă non-blocantă a documentelor și operațiuni de căutare
# - **Memory Management**: Utilizare eficientă a resurselor pentru colecții mari de documente
# - **Integration Patterns**: Integrare nativă cu serviciile Azure folosind dependency injection
#
# ## 🏗️ Arhitectură tehnică
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Componente .NET de bază
# - **Azure.AI.Agents.Persistent**: Gestionare agenți enterprise cu persistență a stării
# - **Azure.Identity**: Autentificare integrată pentru acces securizat la serviciile Azure
# - **Microsoft.Agents.AI.AzureAI**: Implementare a framework-ului de agenți optimizată pentru Azure
# - **System.Linq.Async**: Operațiuni LINQ asincrone de înaltă performanță
#
# ## 🔧 Caracteristici & beneficii enterprise
#
# ### Securitate & Conformitate
# - **Azure AD Integration**: Management identitate enterprise și autentificare
# - **Role-Based Access**: Permisiuni fine-grained pentru accesul și operațiunile asupra documentelor
# - **Data Protection**: Criptare la repaus și în tranzit pentru documentele sensibile
# - **Audit Logging**: Urmărire completă a activităților pentru cerințe de conformitate
#
# ### Performanță & Scalabilitate
# - **Connection Pooling**: Management eficient al conexiunilor la serviciile Azure
# - **Async Processing**: Operațiuni non-blocante pentru scenarii cu debit ridicat
# - **Caching Strategies**: Caching inteligent pentru documentele accesate frecvent
# - **Load Balancing**: Procesare distribuită pentru implementări la scară largă
#
# ### Management & Monitorizare
# - **Health Checks**: Monitorizare încorporată pentru componentele sistemului RAG
# - **Performance Metrics**: Analitică detaliată privind calitatea căutărilor și timpii de răspuns
# - **Error Handling**: Management cuprinzător al excepțiilor cu politici de retry
# - **Configuration Management**: Setări specifice mediului cu validare
#
# ## ⚙️ Precondiții & Configurare
#
# **Mediu de dezvoltare:**
# - .NET 9.0 SDK sau mai recent
# - Visual Studio 2022 sau VS Code cu extensia C#
# - Abonament Azure cu acces la AI Foundry
#
# **Pachete NuGet necesare:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Configurare autentificare Azure:**
# ```bash
# # Instalați Azure CLI și autentificați-vă
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Configurare mediu (fișier .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Modele RAG pentru întreprinderi
#
# ### Modele de management al documentelor
# - **Bulk Upload**: Procesare eficientă a colecțiilor mari de documente
# - **Incremental Updates**: Adăugare și modificare în timp real a documentelor
# - **Version Control**: Versionare a documentelor și urmărirea modificărilor
# - **Metadata Management**: Atribute bogate ale documentelor și taxonomie
#
# ### Modele de căutare & recuperare
# - **Hybrid Search**: Combinarea căutării semantice și pe cuvinte cheie pentru rezultate optime
# - **Faceted Search**: Filtrare și categorisire multidimensională
# - **Relevance Tuning**: Algoritmi de scor personalizați pentru nevoi specifice domeniului
# - **Result Ranking**: Clasare avansată cu integrare de logică de business
#
# ### Modele de securitate
# - **Document-Level Security**: Control de acces granular per document
# - **Data Classification**: Etichetare automată a sensibilității și protecție
# - **Audit Trails**: Înregistrare completă a tuturor operațiunilor RAG
# - **Privacy Protection**: Detectare și redactare PII
#
# ## 🔒 Caracteristici de securitate pentru întreprinderi
#
# ### Autentificare & Autorizare
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Protecția datelor
# - **Encryption**: Criptare end-to-end pentru documente și indici de căutare
# - **Access Controls**: Integrare cu Azure AD pentru permisiuni pe utilizatori și grupuri
# - **Data Residency**: Controale privind locația geografică a datelor pentru conformitate
# - **Backup & Recovery**: Capacități automate de backup și recuperare în caz de dezastru
#
# ## 📈 Optimizarea performanței
#
# ### Modele de procesare asincronă
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Gestionarea memoriei
# - **Streaming Processing**: Tratarea documentelor mari fără probleme de memorie
# - **Resource Pooling**: Refolosire eficientă a resurselor costisitoare
# - **Garbage Collection**: Modele optimizate de alocare a memoriei
# - **Connection Management**: Ciclu de viață corect al conexiunilor la serviciile Azure
#
# ### Strategii de caching
# - **Query Caching**: Cache pentru interogările executate frecvent
# - **Document Caching**: Caching în memorie pentru documentele hot
# - **Index Caching**: Caching optimizat pentru indicii vectoriali
# - **Result Caching**: Caching inteligent al răspunsurilor generate
#
# ## 📊 Cazuri de utilizare pentru întreprinderi
#
# ### Gestionarea cunoștințelor
# - **Corporate Wiki**: Căutare inteligentă în bazele de cunoștințe ale companiei
# - **Policy & Procedures**: Ghidare automată pentru conformitate și proceduri
# - **Training Materials**: Asistență inteligentă pentru învățare și dezvoltare
# - **Research Databases**: Sisteme de analiză pentru lucrări academice și de cercetare
#
# ### Asistență pentru clienți
# - **Support Knowledge Base**: Răspunsuri automate pentru servicii clienți
# - **Product Documentation**: Recuperare inteligentă a informațiilor despre produs
# - **Troubleshooting Guides**: Asistență contextuală pentru rezolvarea problemelor
# - **FAQ Systems**: Generare dinamică de FAQ din colecții de documente
#
# ### Conformitate reglementară
# - **Legal Document Analysis**: Inteligență pentru contracte și documente legale
# - **Compliance Monitoring**: Verificare automată a conformității reglementare
# - **Risk Assessment**: Analiză și raportare a riscurilor bazate pe documente
# - **Audit Support**: Descoperire inteligentă a documentelor pentru audituri
#
# ## 🚀 Implementare în producție
#
# ### Monitorizare & Observabilitate
# - **Application Insights**: Telemetrie detaliată și monitorizare a performanței
# - **Custom Metrics**: Urmărire KPI specifice afacerii și alertare
# - **Distributed Tracing**: Trasare end-to-end a cererilor între servicii
# - **Health Dashboards**: Vizualizare în timp real a stării și performanței sistemului
#
# ### Scalabilitate & Fiabilitate
# - **Auto-Scaling**: Scalare automată bazată pe încărcare și metrici de performanță
# - **High Availability**: Implementare multi-regiune cu capabilități de failover
# - **Load Testing**: Validare a performanței sub condiții de încărcare enterprise
# - **Disaster Recovery**: Proceduri automate de backup și recuperare
#
# Gata să construiești sisteme RAG la nivel enterprise care pot gestiona documente sensibile la scară? Să proiectăm sisteme inteligente de gestionare a cunoștințelor pentru întreprindere! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Declinare de responsabilitate**:
# Acest document a fost tradus folosind serviciul de traducere AI [Co-op Translator](https://github.com/Azure/co-op-translator). Deși ne străduim pentru acuratețe, vă rugăm să rețineți că traducerile automate pot conține erori sau inexactități. Documentul original, în limba sa nativă, trebuie considerat sursa autorizată. Pentru informații critice, se recomandă o traducere profesională realizată de un traducător uman. Nu ne asumăm răspunderea pentru eventuale neînțelegeri sau interpretări greșite rezultate din utilizarea acestei traduceri.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
