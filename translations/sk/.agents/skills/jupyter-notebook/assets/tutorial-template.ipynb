# %% [markdown]
# # Návod: NÁZOV
#
# Cieľová skupina:
# - Opíšte, pre koho je toto určené.
#
# Predpoklady:
# - Uveďte požadované koncepty alebo nastavenie.
#
# Ciele učenia:
# - Na konci bude čitateľ schopný...

# %% [markdown]
# ## Osnova
#
# 1. Nastavenie
# 2. Minimálny funkčný príklad
# 3. Varianty a úskalia
# 4. Cvičenia

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Krok 1 - Začnite s malým príkladom
#
# Vysvetlite, čo nasledujúca bunka robí zrozumiteľným jazykom.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Cvičenia
#
# - Vyskúšajte iný vstup.
# - Predpovedajte výstup pred spustením kódu.
# - Uveďte jednu bežnú chybu a ako ju opraviť.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Zrieknutie sa zodpovednosti:
# Tento dokument bol preložený pomocou AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Aj keď sa snažíme o presnosť, majte prosím na pamäti, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Originálny dokument v jeho pôvodnom jazyku treba považovať za rozhodujúci zdroj. Pre kritické informácie odporúčame profesionálny (ľudský) preklad. Za akékoľvek nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu nenesieme zodpovednosť.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
