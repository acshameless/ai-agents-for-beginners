# %% [markdown]
# # 🔍 Podnikové RAG s Microsoft Foundry (.NET)
#
# ## 📋 Ciele učenia
#
# Táto poznámka ukazuje, ako vytvoriť podnikové systémy Retrieval-Augmented Generation (RAG) pomocou Microsoft Agent Framework v .NET s Microsoft Foundry. Naučíte sa vytvárať produkčne pripravených agentov, ktorí dokážu prehľadávať dokumenty a poskytovať presné, kontextovo zamerané odpovede s podnikových zabezpečením a škálovateľnosťou.
#
# **Možnosti Enterprise RAG, ktoré si vybudujete:**
# - 📚 **Inteligencia dokumentov**: Pokročilé spracovanie dokumentov s Azure AI službami
# - 🔍 **Sémantické vyhľadávanie**: Vyhľadávanie pomocou vektorov s vysokým výkonom a podnikovými funkciami
# - 🛡️ **Integrácia zabezpečenia**: Vzory ochrany dát a prístupu založeného na rolách
# - 🏢 **Škálovateľná architektúra**: Produkčne pripravené RAG systémy s monitorovaním
#
# ## 🎯 Architektúra Enterprise RAG
#
# ### Hlavné podnikové komponenty
# - **Microsoft Foundry**: Spravovaná podniková AI platforma so zabezpečením a súladom
# - **Persistent Agents**: Stavoví agenti s históriou konverzácií a správou kontextu
# - **Vector Store Management**: Podnikové indexovanie a vyhľadávanie dokumentov
# - **Identity Integration**: Overovanie Azure AD a riadenie prístupu založené na rolách
#
# ### Výhody .NET pre podniky
# - **Type Safety**: Overenie počas kompilácie pre RAG operácie a dátové štruktúry
# - **Async Performance**: Neblokujúce spracovanie dokumentov a vyhľadávacích operácií
# - **Memory Management**: Efektívne využitie zdrojov pre veľké kolekcie dokumentov
# - **Integration Patterns**: Nativná integrácia Azure služieb s dependency injection
#
# ## 🏗️ Technická architektúra
#
# ### Pipeline Enterprise RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Hlavné .NET komponenty
# - **Azure.AI.Agents.Persistent**: Správa podnikových agentov s perzistenciou stavu
# - **Azure.Identity**: Integrované overovanie pre bezpečný prístup k Azure službám
# - **Microsoft.Agents.AI.AzureAI**: Implementácia agentného rámca optimalizovaná pre Azure
# - **System.Linq.Async**: Vysokovýkonné asynchrónne LINQ operácie
#
# ## 🔧 Podnikové funkcie a výhody
#
# ### Zabezpečenie a súlad
# - **Integrácia Azure AD**: Podnikové riadenie identity a overovanie
# - **Prístup založený na rolách**: Jemnozrnné povolenia pre prístup k dokumentom a operáciám
# - **Ochrana dát**: Šifrovanie v pokoji aj počas prenosu pre citlivé dokumenty
# - **Auditné záznamy**: Komplexné sledovanie aktivít pre potreby súladu
#
# ### Výkon a škálovateľnosť
# - **Pooling pripojení**: Efektívna správa spojení k Azure službám
# - **Asynchrónne spracovanie**: Neblokujúce operácie pre scenáre s vysokou priepustnosťou
# - **Cachingové stratégie**: Inteligentné cachovanie často pristupovaných dokumentov
# - **Load Balancing**: Distribuované spracovanie pre veľkoplošné nasadenia
#
# ### Správa a monitorovanie
# - **Kontroly zdravia**: Zabudované monitorovanie komponentov RAG systému
# - **Metriky výkonu**: Podrobná analytika kvality vyhľadávania a časov odozvy
# - **Spracovanie chýb**: Komplexné riadenie výnimiek s retry politikami
# - **Správa konfigurácie**: Prostredne špecifické nastavenia s validáciou
#
# ## ⚙️ Predpoklady a nastavenie
#
# **Vývojové prostredie:**
# - .NET 9.0 SDK alebo novší
# - Visual Studio 2022 alebo VS Code s rozšírením C#
# - Predplatné Azure s prístupom k AI Foundry
#
# **Požadované balíčky NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Nastavenie overovania Azure:**
# ```bash
# # Nainštalujte Azure CLI a prihláste sa
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Konfigurácia prostredia (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Vzory Enterprise RAG
#
# ### Vzory správy dokumentov
# - **Hromadné nahrávanie**: Efektívne spracovanie veľkých kolekcií dokumentov
# - **Priebežné aktualizácie**: Pridávanie a modifikácia dokumentov v reálnom čase
# - **Verzovanie**: Verzovanie dokumentov a sledovanie zmien
# - **Správa metadát**: Bohaté atribúty dokumentov a taxonómia
#
# ### Vzory vyhľadávania a získavania
# - **Hybridné vyhľadávanie**: Kombinácia sémantického a kľúčového vyhľadávania pre optimálne výsledky
# - **Faceted Search**: Viacdimenziálne filtrovanie a kategorizácia
# - **Ladenie relevantnosti**: Vlastné skórovacie algoritmy pre doménové potreby
# - **Zoraďovanie výsledkov**: Pokročilé zoraďovanie s integráciou biznis logiky
#
# ### Vzory zabezpečenia
# - **Zabezpečenie na úrovni dokumentu**: Jemnozrnné riadenie prístupu pre každý dokument
# - **Klasifikácia dát**: Automatické označovanie citlivosti a ochrana
# - **Auditné stopy**: Komplexné logovanie všetkých RAG operácií
# - **Ochrana súkromia**: Detekcia PII a možnosti redakcie
#
# ## 🔒 Podnikové bezpečnostné funkcie
#
# ### Autentifikácia a autorizácia
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Ochrana dát
# - **Šifrovanie**: End-to-end šifrovanie pre dokumenty a indexy vyhľadávania
# - **Riadenie prístupu**: Integrácia s Azure AD pre povolenia používateľov a skupín
# - **Umiestnenie dát**: Geografická kontrola umiestnenia dát pre súlad s predpismi
# - **Zálohovanie a obnova**: Automatizované zálohovanie a schopnosti obnovy po havárii
#
# ## 📈 Optimalizácia výkonu
#
# ### Vzory asynchrónneho spracovania
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Správa pamäte
# - **Streamingové spracovanie**: Riešenie veľkých dokumentov bez problémov s pamäťou
# - **Pooling zdrojov**: Efektívne znovupoužitie nákladných zdrojov
# - **Garbage Collection**: Optimalizované vzory prideľovania pamäte
# - **Správa spojení**: Správny životný cyklus pripojení k Azure službám
#
# ### Cachingové stratégie
# - **Cache dotazov**: Caching často vykonávaných vyhľadávaní
# - **Cache dokumentov**: Pamäťové cachovanie pre často používané dokumenty
# - **Cache indexu**: Optimalizované cachovanie vektorového indexu
# - **Cache výsledkov**: Inteligentné cachovanie generovaných odpovedí
#
# ## 📊 Podnikové prípady použitia
#
# ### Správa znalostí
# - **Firemné wiki**: Inteligentné vyhľadávanie naprieč internými zdrojmi znalostí
# - **Politiky a postupy**: Automatizované pokyny pre súlad a postupy
# - **Vzdelávacie materiály**: Inteligentná asistencie pri učení a rozvoji
# - **Výskumné databázy**: Systémy na analýzu akademických a výskumných článkov
#
# ### Zákaznícka podpora
# - **Znalostná báza podpory**: Automatizované odpovede zákazníckej podpory
# - **Dokumentácia produktov**: Inteligentné vyhľadávanie informácií o produktoch
# - **Sprievodcovia riešením problémov**: Kontextová pomoc pri riešení problémov
# - **FAQ systémy**: Dynamické generovanie FAQ z kolekcií dokumentov
#
# ### Regulačný súlad
# - **Analýza právnych dokumentov**: Inteligencia zmlúv a právnych dokumentov
# - **Monitorovanie súladu**: Automatizované kontroly regulačného súladu
# - **Hodnotenie rizík**: Analýza rizík a reportovanie založené na dokumentoch
# - **Podpora auditov**: Inteligentné objavovanie dokumentov pri auditoch
#
# ## 🚀 Produkčné nasadenie
#
# ### Monitorovanie a pozorovateľnosť
# - **Application Insights**: Podrobná telemetria a monitorovanie výkonu
# - **Vlastné metriky**: Sledovanie a alertovanie špecifických KPI
# - **Distribuované trasovanie**: End-to-end sledovanie požiadaviek naprieč službami
# - **Dashboardy zdravia**: Vizualizácia stavu systému a výkonu v reálnom čase
#
# ### Škálovateľnosť a spoľahlivosť
# - **Auto-scaling**: Automatické škálovanie podľa zaťaženia a metrík výkonu
# - **Vysoká dostupnosť**: Viacregionálne nasadenie s failover schopnosťami
# - **Load testing**: Overenie výkonu pri podnikových zaťaženiach
# - **Obnova po havárii**: Automatizované postupy zálohovania a obnovy
#
# Pripravení vybudovať podnikové RAG systémy, ktoré dokážu bezpečne spracovať citlivé dokumenty vo veľkom? Poďme navrhnúť inteligentné znalostné systémy pre podnik! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Upozornenie:
# Tento dokument bol preložený s využitím AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Hoci sa snažíme o presnosť, majte prosím na pamäti, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho pôvodnom jazyku treba považovať za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nie sme zodpovední za žiadne nedorozumenia ani nesprávne výklady vyplývajúce z použitia tohto prekladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
