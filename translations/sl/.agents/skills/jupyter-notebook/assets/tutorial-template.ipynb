# %% [markdown]
# # Vodič: TITLE
#
# Ciljna publika:
# - Opišite, za koga je to namenjeno.
#
# Predpogoji:
# - Navedite potrebne koncepte ali nastavitev.
#
# Cilji učenja:
# - Na koncu bo bralec lahko...

# %% [markdown]
# ## Oris
#
# 1. Nastavitev
# 2. Minimalen delujoč primer
# 3. Variacije in pasti
# 4. Vaje

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Korak 1 - Začnite z majhnim primerom
#
# Pojasnite, kaj naredi naslednja celica v preprostem jeziku.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Vaje
#
# - Poskusi drugačen vhod.
# - Predvidi izhod, preden zaženeš kodo.
# - Navedi eno pogosto napako in kako jo odpraviti.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Izjava o omejitvi odgovornosti**:
# Ta dokument je bil preveden z uporabo storitve za prevajanje z umetno inteligenco [Co-op Translator](https://github.com/Azure/co-op-translator). Čeprav si prizadevamo za natančnost, upoštevajte, da avtomatizirani prevodi lahko vsebujejo napake ali netočnosti. Izvirni dokument v njegovem izvirnem jeziku velja za avtoritativni vir. Za kritične informacije priporočamo strokovni prevod, opravljen s strani človeškega prevajalca. Ne odgovarjamo za morebitne nesporazume ali napačne razlage, ki bi nastale zaradi uporabe tega prevoda.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
