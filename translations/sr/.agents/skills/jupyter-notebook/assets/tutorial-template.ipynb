# %% [markdown]
# # Туторијал: TITLE
#
# Циљна публика:
# - Описати за кога је намењено.
#
# Преуслови:
# - Навести потребне појмове или подешавања.
#
# Циљеви учења:
# - На крају, читаоци ће моћи...

# %% [markdown]
# ## Садржај
#
# 1. Подешавање
# 2. Минималан радни пример
# 3. Варијације и замке
# 4. Вежбе

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Корак 1 - Почните са малим примером
#
# Објасните на једноставан начин шта следећа ћелија ради.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Вежбе
#
# - Пробајте други унос.
# - Предвидите излаз пре покретања кода.
# - Наведите једну уобичајену грешку и како је исправити.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Изјава о одрицању одговорности**:
# Овај документ је преведен помоћу услуге за превод на бази вештачке интелигенције [Co-op Translator](https://github.com/Azure/co-op-translator). Иако се трудимо да обезбедимо тачност, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитетним извором. За критичне информације препоручује се професионални превод од стране људског преводиоца. Нисмо одговорни за било какве неспоразуме или погрешна тумачења која произилазе из употребе овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
