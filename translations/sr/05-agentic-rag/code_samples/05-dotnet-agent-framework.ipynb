# %% [markdown]
# # 🔍 RAG за предузећа са Microsoft Foundry (.NET)
#
# ## 📋 Циљеви учења
#
# Овај нотебук демонстрира како да изградите RAG (генерацију обогаћену претрагом) системе класе за предузећа користећи Microsoft Agent Framework у .NET-у са Microsoft Foundry. Научићете како да креирате агенте спремне за продукцију који могу претраживати документе и давати тачне одговоре осетљиве на контекст са безбедношћу и скалабилношћу за предузећа.
#
# **Капабилности Enterprise RAG које ћете изградити:**
# - 📚 **Интелигенција докумената**: Напредна обрада докумената са Azure AI сервисима
# - 🔍 **Семантичка претрага**: Високоперформансна векторска претрага са ентерпрајз карактеристикама
# - 🛡️ **Интеграција безбедности**: Патерни за приступ на основу улога и заштиту података
# - 🏢 **Скалабилна архитектура**: RAG системи спремни за продукцију са мониторингом
#
# ## 🎯 Архитектура Enterprise RAG
#
# ### Кључне компоненте за предузећа
# - **Microsoft Foundry**: Менаџовани ентерпрајз AI платформа са безбедношћу и усаглашеношћу
# - **Persistent Agents**: Стајтфул агенти са историјом конверзације и управљањем контекстом
# - **Vector Store Management**: Индексирање и претрага докумената ентерпрајз класе
# - **Identity Integration**: Аутентикација преко Azure AD и контролa приступа на основу улога
#
# ### .NET предности за предузећа
# - **Type Safety**: Валидација у време компајлирања за RAG операције и структуре података
# - **Async Performance**: Не-блокирајућа обрада докумената и операције претраге
# - **Memory Management**: Ефикасна употреба ресурса за велике колекције докумената
# - **Integration Patterns**: Нативна интеграција Azure сервиса са dependency injection
#
# ## 🏗️ Техничка архитектура
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Кључне .NET компоненте
# - **Azure.AI.Agents.Persistent**: Управљање ентерпрајз агентима са перзистенцијом стања
# - **Azure.Identity**: Интегрисана аутентикација за сигуран приступ Azure сервисима
# - **Microsoft.Agents.AI.AzureAI**: Azure-оптимизована имплементација оквира за агенте
# - **System.Linq.Async**: Високоперформансне асинхроне LINQ операције
#
# ## 🔧 Функције и бенефити за предузећа
#
# ### Безбедност и усаглашеност
# - **Интеграција са Azure AD**: Управљање идентитетом и аутентикација за предузећа
# - **Приступ на основу улога**: Фино подесива дозвола за приступ документима и операцијама
# - **Заштита података**: Шифровање у мировању и током преноса за осетљиве документе
# - **Евиденција активности**: Свеобухватно праћење активности за захтеве усаглашености
#
# ### Перформансе и скалабилност
# - **Пул снабдевања веза (Connection Pooling)**: Ефикасно управљање везама ка Azure сервисима
# - **Асинхрона обрада**: Не-блокирајуће операције за високе пропусне могућности
# - **Стратегије кеширања**: Интелигентно кеширање за често приступане документе
# - **Балансирање оптерећења**: Дистрибуирана обрада за велико оптерећење
#
# ### Управљање и мониторинг
# - **Health Checks**: Уграђен мониторинг за компоненте RAG система
# - **Метрике перформанси**: Детаљна аналитика квалитета претраге и времена одговора
# - **Руковање грешкама**: Свеобухватно управљање изузецима са политиком поновних покушаја
# - **Управљање конфигурацијом**: Подешавања специфична за окружење са валидацијом
#
# ## ⚙️ Захтеви и подешавање
#
# **Развојно окружење:**
# - .NET 9.0 SDK или новији
# - Visual Studio 2022 или VS Code са C# проширењем
# - Azure претплата са приступом AI Foundry
#
# **Потребни NuGet пакети:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Подешавање Azure аутентикације:**
# ```bash
# # Инсталирајте Azure CLI и аутентификујте се
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфигурација окружења (фајл .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Патерни за Enterprise RAG
#
# ### Патерни управљања документима
# - **Bulk Upload**: Ефикасна обрада великих колекција докумената
# - **Incremental Updates**: Додавање и измена докумената у реалном времену
# - **Version Control**: Верзионисање докумената и праћење промена
# - **Metadata Management**: Богати атрибути докумената и таксономија
#
# ### Патерни претраге и преузимања
# - **Hybrid Search**: Комбинација семантичке и кључно-речне претраге за оптималне резултате
# - **Faceted Search**: Вишедимензионално филтрирање и категоризација
# - **Relevance Tuning**: Прилагођавање бодовања за специфичне домене
# - **Result Ranking**: Напредно рангирање са интеграцијом пословне логике
#
# ### Патерни безбедности
# - **Document-Level Security**: Фино контролисан приступ по документу
# - **Data Classification**: Аутоматско означавање осетљивости и заштита
# - **Audit Trails**: Свеобухватно логовање свих RAG операција
# - **Privacy Protection**: Детекција и редакција PII података
#
# ## 🔒 Безбедносне функције за предузећа
#
# ### Аутентикација и ауторизација
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Заштита података
# - **Шифровање**: Крај-до-крај шифровање за документе и индекс претраге
# - **Контроле приступа**: Интеграција са Azure AD за дозволе корисника и група
# - **Резиденција података**: Контрола географске локације података за усаглашеност
# - **Бекап и опоравак**: Аутоматизоване резервне копије и могућности опоравка од катастрофа
#
# ## 📈 Оптимизација перформанси
#
# ### Асинхрони патерни обраде
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управљање меморијом
# - **Стриминг обрада**: Рад са великим документима без проблема са меморијом
# - **Пул ресурса**: Ефикасно поновно коришћење скупих ресурса
# - **Garbage Collection**: Оптимизовани шаблони алокације меморије
# - **Управљање везама**: Правилни животни циклус веза ка Azure сервисима
#
# ### Стратегије кеширања
# - **Кеширање упита**: Кеширање често извршаваних претрага
# - **Кеширање докумената**: Меморијско кеширање за „хот“ документе
# - **Кеширање индекса**: Оптимизовано кеширање векторских индекса
# - **Кеширање резултата**: Интелигентно кеширање генерисаних одговора
#
# ## 📊 Коришћења у предузећу
#
# ### Управљање знањем
# - **Корпоративни Wiki**: Интелигентна претрага кроз базе знања компаније
# - **Политике и процедуре**: Аутоматизовано вођење по питању усаглашености и процедура
# - **Материјали за обуку**: Интелигентна помоћ у учењу и развоју
# - **Базе истраживања**: Системи за анализу академских и научних радова
#
# ### Корисничка подршка
# - **База знања за подршку**: Аутоматизовани одговори корисничкој подршци
# - **Документација производа**: Интелигентно проналажење информација о производу
# - **Водичи за решавање проблема**: Контекстуална помоћ за решавање проблема
# - **FAQ системи**: Динамичко генерисање FAQ-а из скупова докумената
#
# ### Регулаторна усаглашеност
# - **Анализа правних докумената**: Интелигенција за уговоре и правне документе
# - **Мониторинг усаглашености**: Аутоматизована провера регулаторне usaglašenosti
# - **Процена ризика**: Анализа ризика заснована на документима и извештавање
# - **Подршка ревизији**: Интелигентно проналажење докумената за ревизије
#
# ## 🚀 Продукционо развршавање
#
# ### Мониторинг и опсервабилност
# - **Application Insights**: Детаљна телеметрија и мониторинг перформанси
# - **Прилагођене метрике**: Праћење KPI-ева специфичних за посао и алармирање
# - **Дистрибуирано праћење (Distributed Tracing)**: Праћење захтева кроз услуге
# - **Health Dashboards**: Визуелизација здравља система и перформанси у реалном времену
#
# ### Скалабилност и поузданост
# - **Аутоматско скалирање**: Аутоматско скалирање на основу оптерећења и метрика перформанси
# - **Висока доступност**: Деплој над више региона са failover могућностима
# - **Тестирање оптерећења**: Валидација перформанси под ентерпрајз оптерећењем
# - **Опоравак од катастрофа**: Аутоматизоване процедуре резервних копија и опоравка
#
# Спремни да изградите RAG системе класе за предузећа који могу да обрађују осетљиве документе у великој скали? Хајде да архитектурамо интелигентне системе знања за предузећа! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Искључење одговорности:
# Овај документ је преведен помоћу AI сервиса за превођење Co-op Translator (https://github.com/Azure/co-op-translator). Иако настојимо да обезбедимо тачност, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на свом изворном језику треба сматрати меродавним извором. За критичне информације препоручује се професионалан људски превод. Не сносимо одговорност за било какве неспоразуме или погрешна тумачења која произилазе из коришћења овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
