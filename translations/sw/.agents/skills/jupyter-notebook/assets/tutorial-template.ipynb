# %% [markdown]
# # Mafunzo: TITLE
#
# Audience:
# - Eleza ni nani hii ni kwa ajili yake.
#
# Prerequisites:
# - Orodhesha dhana au usanidi unaohitajika.
#
# Learning goals:
# - Mwishowe, msomaji ataweza...

# %% [markdown]
# ## Muhtasari
#
# 1. Usanidi
# 2. Mfano wa kazi mdogo
# 3. Tofauti na mitego
# 4. Mazoezi

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Hatua 1 - Anza na mfano mdogo
#
# Elezea kwa lugha rahisi kile seli inayofuata inafanya.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Mazoezi
#
# - Jaribu ingizo tofauti.
# - Tabiri matokeo kabla ya kuendesha msimbo.
# - Tambua kosa moja la kawaida na jinsi ya kulirekebisha.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Taarifa ya kutokuwajibika:
# Nyaraka hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kuhakikisha usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Nyaraka ya asili katika lugha yake ya asili inapaswa kuchukuliwa kama chanzo rasmi. Kwa taarifa muhimu, inashauriwa kupata tafsiri ya kitaalamu iliyoendeshwa na mtaalamu wa binadamu. Hatuwajibiki kwa kutoelewana au tafsiri potofu zinazotokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
