# %% [markdown]
# # Mwakilishi wa Mfano wa Booking ya Hoteli na Ndege
#
# Suluhisho hili litakusaidia kuhifadhi tiketi za ndege na hoteli. Hali ni safari kutoka London Heathrow LHR tarehe 20 Februari 2024 kwenda New York JFK kurudi tarehe 27 Februari 2025 ukiruka katika daraja la uchumi kwa kutumia ndege za British Airways pekee. Nataka kukaa katika hoteli ya Hilton huko New York tafadhali toa gharama za ndege na hoteli.

# %% [markdown]
# # Anzisha Huduma ya Wakala wa Azure AI na upate habari za usanidi kutoka **.env**
#
# ### **.env**
#
# Tengeneza faili la .env
#
# **.env** lina mfuatano wa muunganisho wa Huduma ya Wakala wa Azure AI, mfano unaotumiwa na AOAI, na huduma ya API ya Utafutaji ya Google API inayolingana, ENDPOINT, n.k.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Jina la Usambazaji wa Mfano wa Huduma ya Wakala wa Azure AI lako"
#
# [**NOTE**] Utahitaji mfano wenye Kikomo cha Kiwango cha 100,000 (Tokens kwa dakika) Kikomo cha Kiwango cha 600 (Ombi kwa dakika)
#
#   Unaweza kupata mfano katika Microsoft Foundry - Mfano na Endpoint.
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Mfano wa Muunganisho wa Mradi wa Huduma ya Wakala wa Azure AI wako"
#
#   Unaweza kupata mfuatano wa muunganisho wa mradi kwenye muhtasari wa mradi wako katika Skrini ya Kimtandao ya AI Foundry.
#
# - **SERPAPI_SEARCH_API_KEY** = "API KEY yako ya SERPAPI Search"
# - **SERPAPI_SEARCH_ENDPOINT** = "ENDPOINT yako ya SERPAPI Search"
#
# Ili kupata Jina la Usambazaji wa Mfano na Mfuatano wa Muunganisho wa Mradi wa Huduma ya Wakala wa Azure AI, unahitaji kuunda Huduma ya Wakala wa Azure AI. Inapendekezwa kutumia [kiolezo hiki](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) kuunda moja kwa moja (***Kumbuka:*** Huduma ya Wakala wa Azure AI kwa sasa iko katika eneo lililopunguzwa. Inapendekezwa kutiwa moyo kwa kusoma [kiungo hiki](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) kuweka eneo)
#
# Wakala anahitaji kupata SERPAPI. Inapendekezwa kujiandikisha kwa kutumia [kiungo hiki](https://serpapi.com/searches). Baada ya usajili, unaweza kupata API KEY na ENDPOINT ya kipekee

# %% [markdown]
# # Setup
#
# Ili kuendesha daftari hili, utahitaji kuhakikisha umeweka maktaba zinazohitajika kwa kukimbiza `pip install -r requirements.txt`.

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# Toleo lako la Semantic Kernel linapaswa kuwa angalau 1.27.2.

# %% [markdown]
# Pakia faili lako la .env la mipangilio na rasilimali tafadhali hakikisha umeongeza funguo zako na mipangilio na umeunda faili la ndani la .env.

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Ingia kwenye Azure
#
# Sasa unahitaji kuingia kwenye Azure. Fungua terminal na endesha amri ifuatayo:
#
# ```bash
# az login
# ```
#
# Amri hii itakuomba uingize nyaraka zako za Azure, kuruhusu huduma ya Azure AI Agent kufanya kazi ipasavyo.

# %% [markdown]
# # Maelezo:
# Hii ni variable inayohifadhi ufunguo wa API kwa ajili ya kufikia huduma ya SERP (Search Engine Results Page) API. Ufunguo wa API ni kitambulisho cha kipekee kinachotumika kuthibitisha maombi yanayohusiana na akaunti yako.
#
# Madhumuni: Madhumuni ya mstari huu ni kuhifadhi ufunguo wa API katika variable ili uwekeze kuthibitisha maombi kwa huduma ya SERP API. Ufunguo wa API unahitajika kufikia huduma hiyo na kufanya utafutaji.
# Jinsi ya Kupata Ufunguo wa SERP API: Ili kupata ufunguo wa SERP API, fuata hatua hizi za jumla kwenye https://serpapi.com (hatua halisi zinaweza kutofautiana kulingana na huduma maalum ya SERP API unayotumia):
#
# Chagua Huduma ya SERP API: Kuna huduma kadhaa za SERP API zinazopatikana, kama SerpAPI, Google Custom Search JSON API, na nyinginezo. Chagua ile inayokidhi mahitaji yako vyema.
#
# Jisajili kwa Akaunti: Nenda kwenye tovuti ya huduma ya SERP API uliyoyachagua na jisajili kwa akaunti. Huenda ukahitaji kutoa baadhi ya taarifa za msingi na kuthibitisha anwani yako ya barua pepe.
#
# Tengeneza Ufunguo wa API: Baada ya kusajili, ingia kwenye akaunti yako na nenda sehemu ya API au dashibodi. Tafuta chaguo la kuunda au kutoa ufunguo mpya wa API.
# Nakili Ufunguo wa API kwenye faili lako la .env.

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # Maelezo:
# BASE_URL: Hii ni variable inayohifadhi URL msingi kwa ajili ya sehemu ya SERP API. Jina la variable BASE_URL ni desturi inayotumika kuonyesha kwamba URL hii ni sehemu ya kuanzia kwa kutuma maombi ya API.
# 'https://serpapi.com/search':
#
# Hii ni kamba ya URL halisi iliyowekwa kwa variable ya BASE_URL. Inawakilisha sehemu ya mwisho ya kufanya maswali ya utafutaji kwa kutumia SERP API.
#
# # Kusudi:
# Kusudi la mstari huu ni kuweka thamani ya kudumu inayoshikilia URL msingi wa SERP API. URL hii itatumika kama sehemu ya kuanzia kutengeneza maombi ya API kufanya shughuli za utafutaji.
#
# # Matumizi:
# Kwa kuweka URL msingi katika variable, unaweza kuitumia tena kwa urahisi katika sehemu zote za msimbo wako wakati wowote utakapohitaji kutuma maombi kwa SERP API. Hii inafanya msimbo wako kudumishwa kwa urahisi na kupunguza hatari ya makosa kutoka kuandika URL moja kwa moja sehemu nyingi tofauti. Mfano wa sasa ni https://serpapi.com/search?engine=bing ambayo inatumia Bing search API. API tofauti zinaweza kuchaguliwa kwenye https://Serpapi.com

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # Maelezo:
#
# Hapa ndiko ambapo msimbo wako wa kiendelezi umewekwa.
#
# Ufafanuzi wa Darasa: `class BookingPlugin`: Inafafanua darasa linaloitwa BookingPlugin ambalo lina njia za kuhifadhi hoteli na ndege.
#
# Njia ya Kuhifadhi Hotel:
#
# - `@kernel_function(description="booking hotel")`: Muwekaji wa kazi unaoelezea kazi kama kazi ya kernel kwa kuhifadhi hoteli.
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: Inafafanua njia ya kuhifadhi hoteli yenye vigezo vilivyoandikwa na aina ya kurudi.
#
# Njia hii huunda dikishinari ya vigezo kwa ombi la kuhifadhi hoteli na kutuma ombi la GET kwa SERP API. Hukagua hali ya jibu na kurudisha mali za hoteli ikiwa imefanikiwa, au None ikiwa ombi limeshindwa.
#
# Njia ya Kuhifadhi Ndege:
#
# - `@kernel_function(description="booking flight")`: Muwekaji wa kazi unaoelezea kazi kama kazi ya kernel kwa kuhifadhi ndege.
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: Inafafanua njia ya kuhifadhi ndege yenye vigezo vilivyoandikwa na aina ya kurudi.
#
# Njia hii huunda dikishinari za vigezo kwa maombi ya ndege ya kutoka na ya kurudi na kutuma maombi ya GET kwa SERP API. Hukagua hali ya jibu na kuongeza taarifa za ndege kwenye kamba ya matokeo ikiwa imefanikiwa, au kuchapisha ujumbe wa kosa ikiwa ombi limeshindwa. Njia inarudisha kamba ya matokeo yenye taarifa za ndege.

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # Maelezo:
# Kauli za Kuingiza: Ingiza moduli zinazohitajika kwa vyeti vya Azure, wakala wa AI, maudhui ya ujumbe wa mazungumzo, nafasi ya mwandishi, na mtofautishaji wa kazi ya kernel.
#
# Msimamizi wa Muktadha wa Asynchronous: async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,): Hii inaweka msimamizi wa muktadha wa asynchronous kushughulikia vyeti vya Azure na kuunda mteja wa wakala wa AI.
#
# Jina la Wakala na Maelekezo:
# - `AGENT_NAME = "BookingAgent"`: Inaeleza jina la wakala.
# - `AGENT_INSTRUCTIONS = """..."""`: Imeweka maelekezo ya kina kwa wakala kuhusu jinsi ya kushughulikia maombi ya uhifadhi.
#
# Unda Maelezo ya Wakala: `agent_definition = await client.agents.create_agent(...)`: Unda maelezo ya wakala kwa kutumia mfano ulioainishwa, jina, na maelekezo.
#
# Unda Wakala wa AzureAI: `agent = AzureAIAgent(...)`: Unda wakala wa AzureAI kwa kutumia mteja, maelezo ya wakala, na kiendelezi kilichoainishwa.
#
# Unda Thread: `thread: AzureAIAgentThread | None = None`: Unda thread kwa ajili ya wakala. Haihitajiki kuunda thread kwanza - ikiwa thamani ya `None` itatolewa, thread mpya itaundwa wakati wa mwito wa kwanza na itarudishwa kama sehemu ya jibu.
#
# Ingizo za Mtumiaji: `user_inputs = ["..."]`: Inaeleza orodha ya ingizo za mtumiaji kwa wakala kushughulikia.
#
# Katika sehemu ya finally, futa thread na wakala ili kusafisha rasilimali.

# %% [markdown]
# # Uthibitishaji
#
# Darasa la `DefaultAzureCredential` ni sehemu ya Azure SDK kwa Python. Linatoa njia ya kiasili ya kuingia kwenye huduma za Azure. Linajaribu kuthibitisha kwa kutumia mbinu kadhaa kwa mpangilio maalum, kama vile mabadiliko ya mazingira, utambulisho ulioendeshwa, na vyeti vya Azure CLI.
#
# Mifumo Isiyotegemea Mfululizo: Moduli ya aio inaonyesha kwamba darasa la DefaultAzureCredential linaunga mkono mifumo isiyoegemea mfululizo. Hii ina maana unaweza kulitumia na asyncio kufanya maombi ya uthibitishaji yasiyozuia.

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Taarifa ya Kukataa**:
# Nyaraka hii imetafsiriwa kwa kutumia huduma ya kutafsiri kwa AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kutoa tafsiri sahihi, tafadhali fahamu kuwa tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Nyaraka asilia kwa lugha yake ya asili inapaswa kuzingatiwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tunapendekeza kutafsiriwa na mtaalamu wa binafsi. Hatubiriki kwa kutokuelewana au tafsiri mbaya zinazotokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
