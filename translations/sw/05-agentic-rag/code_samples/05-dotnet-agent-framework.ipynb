# %% [markdown]
# # 🔍 RAG ya Shirika na Microsoft Foundry (.NET)
#
# ## 📋 Malengo ya Kujifunza
#
# Kitabu hiki cha kumbukumbu kinaonyesha jinsi ya kujenga mifumo ya Retrieval-Augmented Generation (RAG) ya kiwango cha shirika kwa kutumia Microsoft Agent Framework katika .NET na Microsoft Foundry. Utajifunza kuunda maajenti tayari kwa uzalishaji yanayoweza kutafuta ndani ya nyaraka na kutoa majibu sahihi, yanayotambua muktadha, kwa usalama na uwezo wa kupanuka wa shirika.
#
# **Uwezo wa RAG wa Shirika Utakaoujenga:**
# - 📚 **Uchambuzi wa Nyaraka**: Usindikaji wa nyaraka wa hali ya juu kwa kutumia huduma za Azure AI
# - 🔍 **Utafutaji wa Semantiki**: Utafutaji wa vektor wenye utendaji wa juu na vipengele vya shirika
# - 🛡️ **Uunganishaji wa Usalama**: Ufikiaji kwa misingi ya jukumu na mifumo ya ulinzi wa data
# - 🏢 **Miundombinu Inayoweza Kupanuka**: Mifumo ya RAG tayari kwa uzalishaji yenye ufuatiliaji
#
# ## 🎯 Miundo ya RAG ya Shirika
#
# ### Vipengele vya Msingi vya Shirika
# - **Microsoft Foundry**: Jukwaa la AI la shirika linalosimamiwa lenye usalama na uzingatiaji
# - **Maajenti Wenye Kudumu**: Maajenti wenye hali, wenye historia ya mazungumzo na usimamizi wa muktadha
# - **Usimamizi wa Hifadhi ya Vektor**: Uorodheshaji na urejeshaji wa nyaraka wa kiwango cha shirika
# - **Uunganishaji wa Utambulisho**: Uthibitishaji wa Azure AD na udhibiti wa ufikiaji kwa misingi ya jukumu
#
# ### Manufaa ya .NET kwa Shirika
# - **Usalama wa Aina**: Uthibitishaji wakati wa kuunda programu kwa ajili ya shughuli za RAG na miundo ya data
# - **Utendaji wa Asynchronous**: Usindikaji wa nyaraka na shughuli za utafutaji zisizozuia
# - **Usimamizi wa Kumbukumbu**: Matumizi bora ya rasilimali kwa makusanyo makubwa ya nyaraka
# - **Mifumo ya Uunganishaji**: Uunganisho wa huduma za asili za Azure kwa kutumia dependency injection
#
# ## 🏗️ Miundo ya Kiufundi
#
# ### Mstari wa Kazi wa RAG wa Shirika
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Vipengele vya Msingi vya .NET
# - **Azure.AI.Agents.Persistent**: Usimamizi wa maajenti wa shirika yenye uhifadhi wa hali
# - **Azure.Identity**: Uthibitishaji uliounganishwa kwa ufikiaji salama wa huduma za Azure
# - **Microsoft.Agents.AI.AzureAI**: Utekelezaji wa fremu ya maajenti iliyoboreshwa kwa Azure
# - **System.Linq.Async**: Shughuli za LINQ za asynchronous za utendaji wa juu
#
# ## 🔧 Vipengele na Manufaa ya Shirika
#
# ### Usalama na Uzingatiaji
# - **Uunganisho wa Azure AD**: Usimamizi wa utambulisho wa shirika na uthibitishaji
# - **Ufikiaji kwa Misingi ya Jukumu**: Vibali vya kina kwa ufikiaji wa nyaraka na shughuli
# - **Ulinzi wa Data**: Usimbaji wakati wa hifadhi na wakati wa kusafirishwa kwa nyaraka nyeti
# - **Kuingia Kumbukumbu za Ukaguzi**: Ufuatiliaji kamili wa shughuli kwa mahitaji ya uzingatiaji
#
# ### Utendaji na Uwezo wa Kupanuka
# - **Kusanyiko la Miunganisho**: Usimamizi wa ufanisi wa miunganisho ya huduma za Azure
# - **Usindikaji Asynchronous**: Shughuli zisizozuia kwa mazingira ya throughput ya juu
# - **Mikakati ya Caching**: Kuhifadhi kwa werevu kwa nyaraka zinazoapitwa mara kwa mara
# - **Kusasawazisha Mzigo**: Usindikaji uliogawanywa kwa utoaji wa kiwango kikubwa
#
# ### Usimamizi na Ufuatiliaji
# - **Upimaji wa Afya**: Ufuatiliaji uliojengwa kwa vipengele vya mfumo wa RAG
# - **Vipimo vya Utendaji**: Uchambuzi wa kina juu ya ubora wa utafutaji na nyakati za majibu
# - **Ushughulikiaji wa Makosa**: Usimamizi kamili wa makosa pamoja na sera za jaribio tena
# - **Usimamizi wa Mipangilio**: Mipangilio maalum kwa mazingira pamoja na uthibitishaji
#
# ## ⚙️ Matakwa na Usanidi
#
# **Mazingira ya Maendeleo:**
# - .NET 9.0 SDK au zaidi
# - Visual Studio 2022 au VS Code yenye upanuzi wa C#
# - Azure subscription yenye ufikiaji wa AI Foundry
#
# **Pakiti za NuGet Zinazohitajika:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Usanidi wa Uthibitishaji wa Azure:**
# ```bash
# # Sakinisha Azure CLI na ingia ili uthibitishe utambulisho wako
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Mifumo ya RAG ya Shirika
#
# ### Mifano ya Usimamizi wa Nyaraka
# - **Kupakia kwa Misa**: Usindikaji wenye ufanisi wa makusanyo makubwa ya nyaraka
# - **Sasisho za Hatua kwa Hatua**: Uongezaji na mabadiliko ya nyaraka kwa wakati halisi
# - **Udhibiti wa Toleo**: Utolewaji wa matoleo ya nyaraka na ufuatiliaji wa mabadiliko
# - **Usimamizi wa Metadata**: Sifa tajiri za nyaraka na taksonomia
#
# ### Mifano ya Utafutaji na Urejeshaji
# - **Utafutaji Mchanganyiko**: Kuchanganya utafutaji wa semantiki na maneno ya msingi kwa matokeo bora
# - **Utafutaji wa Vipengele**: Kuchuja na kutambua kwa vipimo vingi
# - **Kurekebisha Uhalisia**: Algoritimu za kupima maalum kwa mahitaji ya kikoa maalum
# - **Kupangilia Matokeo**: Kuweka vipaumbele vya matokeo kwa uunganisho wa mantiki ya biashara
#
# ### Mifano ya Usalama
# - **Usalama kwa Ngazi ya Nyaraka**: Udhibiti wa ufikiaji wa kina kwa kila nyaraka
# - **Uainishaji wa Data**: Uwekaji lebo wa unyeti wa data kwa njia ya kiotomatiki na ulinzi
# - **Vifuatiliaji vya Ukaguzi**: Kuingia kumbukumbu kwa kina kwa shughuli zote za RAG
# - **Ulinzi wa Faragha**: Ugunduzi na kufifisha (redaction) wa PII
#
# ## 🔒 Vipengele vya Usalama vya Shirika
#
# ### Uthibitishaji na Uidhinishaji
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Ulinzi wa Data
# - **Usimbaji**: Usimbaji kutoka mwanzo hadi mwisho kwa nyaraka na faharasa za utafutaji
# - **Udhibiti wa Ufikiaji**: Uunganisho na Azure AD kwa vibali vya watumiaji na makundi
# - **Makazi ya Data**: Udhibiti wa eneo la kijiografia la data kwa uzingatiaji wa sheria
# - **Hifadhi Nakala & Urejeshaji**: Uwezo wa kuhifadhi nakala kiotomatiki na urejeshaji wa maafa
#
# ## 📈 Uboreshaji wa Utendaji
#
# ### Mifano ya Usindikaji Asynchronous
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Usimamizi wa Kumbukumbu
# - **Streaming Processing**: Kushughulikia nyaraka kubwa bila matatizo ya kumbukumbu
# - **Resource Pooling**: Matumizi ya ufanisi ya rasilimali ghali kwa kutumia tena
# - **Garbage Collection**: Mifumo iliyoboreshwa ya ugawaji wa kumbukumbu
# - **Connection Management**: Mzunguko sahihi wa maisha wa miunganisho ya huduma za Azure
#
# ### Mikakati ya Caching
# - **Query Caching**: Kuhifadhi kwenye cache utaftaji unaotekelezwa mara kwa mara
# - **Document Caching**: Kuhifadhi kwenye kumbukumbu (in-memory) kwa nyaraka zinazotumika mara kwa mara
# - **Index Caching**: Kuhifadhi kwa ufanisi faharasa za vektor
# - **Result Caching**: Kuhifadhi kwa werevu majibu yaliyotengenezwa
#
# ## 📊 Matumizi ya Shirika
#
# ### Usimamizi wa Maarifa
# - **Corporate Wiki**: Utafutaji wa werevu katika hifadhidata za maarifa za kampuni
# - **Policy & Procedures**: Mwongozo wa uzingatiaji na taratibu kiotomatiki
# - **Training Materials**: Msaada wa kujifunza na maendeleo wa werevu
# - **Research Databases**: Mifumo ya uchambuzi wa karatasi za kitaaluma na utafiti
#
# ### Usaidizi kwa Wateja
# - **Support Knowledge Base**: Majibu ya huduma kwa wateja yaliyotengenezwa kiotomatiki
# - **Product Documentation**: Urejeshaji wa taarifa za bidhaa kwa werevu
# - **Troubleshooting Guides**: Msaada wa utatuzi wa matatizo unaozingatia muktadha
# - **FAQ Systems**: Utengenezaji wa FAQ zinazoendeshwa kutoka kwa makusanyo ya nyaraka
#
# ### Uzingatiaji wa Kanuni
# - **Legal Document Analysis**: Ufahamu wa mikataba na nyaraka za kisheria
# - **Compliance Monitoring**: Ukaguzi wa uzingatiaji wa kanuni kwa njia ya kiotomatiki
# - **Risk Assessment**: Uchambuzi wa hatari na utoaji ripoti unaotokana na nyaraka
# - **Audit Support**: Ugunduzi wa werevu wa nyaraka kwa ajili ya ukaguzi
#
# ## 🚀 Utekelezaji wa Uzalishaji
#
# ### Ufuatiliaji na Uwezo wa Kuonekana
# - **Application Insights**: Telemetry ya kina na ufuatiliaji wa utendaji
# - **Custom Metrics**: Ufuatiliaji na tahadhari kwa KPI maalum za biashara
# - **Ufuatiliaji Uliogawanywa**: Ufuatiliaji wa maombi kutoka mwanzo hadi mwisho kuvuka huduma
# - **Dashibodi za Afya**: Mionyesho ya afya ya mfumo na utendaji kwa wakati halisi
#
# ### Uwezo wa Kupanuka na Uaminifu
# - **Kuongezeka Kiotomatiki**: Ukuaji wa moja kwa moja kulingana na mzigo na vipimo vya utendaji
# - **Upatikanaji wa Juu**: Utekelezaji katika maeneo mengi kwa uwezo wa failover
# - **Upimaji wa Mzigo**: Uthibitishaji wa utendaji chini ya masharti ya mzigo ya shirika
# - **Urejeshaji baada ya Maafa**: Taratibu za kuhifadhi nakala na urejeshaji za kiotomatiki
#
# Je, uko tayari kujenga mifumo ya RAG ya kiwango cha shirika inayoweza kushughulikia nyaraka nyeti kwa wingi? Hebu tuunde miundo ya mifumo ya maarifa yenye werevu kwa shirika! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Taarifa ya kutokuwa na dhamana:
# Waraka huu umetafsiriwa kwa kutumia huduma ya utafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kuwa sahihi, tafadhali fahamu kuwa tafsiri za kiotomatiki zinaweza kuwa na makosa au ukosefu wa usahihi. Waraka wa asili katika lugha yake ya asili unapaswa kutazamwa kama chanzo chenye mamlaka. Kwa taarifa muhimu, inapendekezwa kutumia utafsiri wa kitaalamu unaofanywa na mtu. Hatutawajibika kwa kutokuelewana au tafsiri mbaya zitokanazo na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
