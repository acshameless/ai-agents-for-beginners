# %% [markdown]
# ## **Mifano: Wakala wa AI Wengi kwa ajili ya Kufanya Uhifadhi wa Hoteli**
#
# Katika dunia ya leo yenye kasi, kupanga safari ya biashara inahusisha zaidi ya kuweka tiketi ya ndege na chumba cha hoteli. Inahitaji kiwango cha uratibu na ufanisi ambacho kinaweza kuwa changamoto kuyafanikisha. Hapa ndipo Wakala wa AI Wengi wanapojitokeza, wakibadilisha jinsi tunavyosimamia mahitaji yetu ya kusafiri.
#
# Fikiria kuwa na timu ya mawakala werevu waliokuwepo, wakishirikiana kushughulikia kila sehemu ya safari yako kwa usahihi na urahisi. Kwa kutumia teknolojia yetu ya AI ya kisasa, tumeunda mawakala maalum kwa ajili ya huduma za uhifadhi na upangaji wa ratiba, kuhakikisha uzoefu wa kusafiri usio na matatizo na usio na msongo.
#
# Huu ni mfano wa msingi. Wakati wa kupanga safari ya biashara, tunahitaji kushauriana na wakala wa usafiri wa biashara kupata habari za tiketi za ndege, habari za hoteli, n.k. Kupitia Wakala wa AI, tunaweza kujenga mawakala kwa ajili ya huduma za uhifadhi na mawakala kwa ajili ya upangaji wa ratiba ili kushirikiana na kuboresha kiwango cha akili.

# %% [markdown]
# # Anzisha Huduma ya Wakala wa Azure AI na upate taarifa za usanidi kutoka **.env**
#
# ### **.env**
#
# Tengeneza faili la .env
#
# **.env** lina mfuatano wa kuunganisha wa Huduma ya Wakala wa Azure AI, mfano unaotumika na AOAI, na huduma husika ya API ya Google API Search, ENDPOINT, n.k.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Jina la Usambazaji la Mfano wa Huduma ya Wakala wa Azure AI"
#
# [**KUMBUKUMBU**] Utahitaji mfano wenye Kiwango cha Kiwango cha 100,000 (Tokens kwa dakika) Kiwango cha Kiwango cha 600 (Maombi kwa dakika)
#
#   Unaweza kupata mfano katika Microsoft Foundry - Mfano na Endpoint.
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Mfuatano wako wa Muunganisho wa Mradi wa Huduma ya Wakala wa Azure AI"
#
#   Unaweza kupata mfuatano wa muunganisho wa mradi katika muhtasari wa mradi wako katika AI ​​Foundry Portal Screen.
#
# - **SERPAPI_SEARCH_API_KEY** = "Ufunguo wako wa API wa SERPAPI Search"
# - **SERPAPI_SEARCH_ENDPOINT** = "Endpoint yako ya SERPAPI Search"
#
# Ili kupata Jina la Usambazaji wa Mfano na Mfuatano wa Muunganisho wa Mradi wa Huduma ya Wakala wa Azure AI, unahitaji kuunda Huduma ya Wakala wa Azure AI. Inashauriwa kutumia [kiolezo hiki](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) kuunda moja kwa moja （***Kumbuka:*** Huduma ya Wakala wa Azure AI kwa sasa imewekwa katika eneo lililopunguzwa. Inashauriwa utumie [kiungo hiki](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) kuweka eneo)
#
# Wakala anahitaji kufikia SERPAPI. Inashauriwa kujiandikisha kwa kutumia [kiungo hiki](https://serpapi.com/searches). Baada ya usajili, unaweza kupata Ufunguo wa API wa kipekee na ENDPOINT

# %% [markdown]
# # Ingia kwenye Azure
#
# Sasa unahitaji kuingia kwenye Azure Fungua terminal ndani ya VScode na endesha amri ya `az login`

# %% [markdown]
# # Setup
#
# Ili kuendesha daftari hili, utahitaji kufunga maktaba zifuatazo. Hapa kuna orodha ya maktaba zinazohitajika na amri za pip install zinazohusiana nazo:
#
# azure-identity: Kwa uthibitishaji wa Azure.
# requests: Kwa kutuma maombi ya HTTP.
# semantic-kernel: Kwa mfumo wa semantic kernel (kikadiri hii ni maktaba ya kawaida au maalum, huenda ukahitaji kuifunga kutoka kwenye chanzo maalum au hifadhidata).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Maelezo:
# import asyncio: Hii inaingiza moduli ya asyncio, ambayo inatoa msaada kwa programu zisizofuata mkondo moja kwa moja (asynchronous) katika Python. Inakuwezesha kuandika msimbo unaofanya kazi sambamba kwa kutumia sintaksia ya async na await.
# from typing import Annotated: Hii inaingiza aina ya Annotated kutoka moduli ya typing. Annotated hutumika kuongeza metadata kwenye vidokezo vya aina, ambavyo vinaweza kuwa muhimu kwa madhumuni mbalimbali kama vile uthibitishaji, nyaraka, au zana za programu

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Maelezo:
# Kwa kutumia from dotenv import load_dotenv na load_dotenv(), unaweza kwa urahisi kusimamia mipangilio ya usanidi na taarifa nyeti (kama vile funguo za API na anwani za hifadhidata) katika faili la .env, ukiwaweka mbali na msimbo wako wa chanzo na kufanya programu yako kuwa salama zaidi na rahisi kusanidi.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Maelezo:
#
# Import Statement: from azure.identity.aio import DefaultAzureCredential: Hii inaingiza darasa la DefaultAzureCredential kutoka kwenye moduli ya azure.identity.aio. Sehemu ya aio ya jina la moduli inaonyesha kuwa imetengenezwa kwa ajili ya shughuli zisizo za mfululizo.
#
# Madhumuni ya DefaultAzureCredential: Darasa la DefaultAzureCredential ni sehemu ya Azure SDK kwa Python. Linatoa njia ya msingi ya kuthibitisha utambulisho na huduma za Azure. Linajaribu kuthibitisha kutumia mbinu nyingi kwa mpangilio maalum, kama vile vigezo vya mazingira, utambulisho unaosimamiwa, na vyeti vya Azure CLI.
#
# Shughuli zisizo za mfululizo: Moduli ya aio inaonyesha kuwa darasa la DefaultAzureCredential linaunga mkono shughuli zisizo za mfululizo. Hii inamaanisha unaweza kulitumia pamoja na asyncio kutekeleza maombi ya uthibitishaji yasiyozuia.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Maelezo:
# Inaagiza moduli na madarasa mbalimbali kutoka kwa kifurushi cha semantic_kernel. Hapa kuna ufafanuzi wa kila kuagiza:
#
# AgentGroupChat kutoka semantic_kernel.agents: Darasa hili linaendesha kazi zinazohusiana na mazungumzo ya kikundi kwa maajenti wa AI. AzureAIAgent na AzureAIAgentSettings kutoka semantic_kernel.agents.azure_ai
#
# AzureAIAgent: Darasa hili hutumiwa kuunda na kusimamia maajenti wa AI wanaotumia huduma za Azure AI.
#
# AzureAIAgentSettings: Darasa hili hutumiwa kusanidi mipangilio ya AzureAIAgent. TerminationStrategy kutoka semantic_kernel.agents.strategies.termination.termination_strategy:
#
# Darasa hili linaelezea mikakati ya kumalizia utekelezaji wa maajenti wa AI chini ya hali fulani. ChatMessageContent kutoka semantic_kernel.contents.chat_message_content:
#
# Darasa hili hutumiwa kushughulikia maudhui ya ujumbe wa mazungumzo.
# AuthorRole kutoka semantic_kernel.contents.utils.author_role:
#
# Darasa hili linaelezea majukumu tofauti ya waandishi katika muktadha wa ujumbe wa mazungumzo.
#
# kernel_function kutoka semantic_kernel.functions.kernel_function_decorator: Mhifadhi huyu hutumiwa kufafanua kazi za kernel, ambazo ni kazi zinazoweza kutekelezwa ndani ya mfumo wa semantic kernel.
# Kuagiza haya kunaandaa vipengele vinavyohitajika kwa ajili ya kuunda na kusimamia maajenti wa AI wanaoweza kuingiliana katika mazingira ya mazungumzo ya kikundi, pengine kwa kazi kama vile kuhifadhi hoteli au shughuli zinazofanana.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Maelezo:
# Ifuatayo tunaleta darasa la CodeInterpreterTool kutoka kwenye moduli ya azure.ai.projects.models.
#
# CodeInterpreterTool: Darasa hili ni sehemu ya Azure AI SDK na linatumika kutafsiri na kutekeleza msimbo ndani ya muktadha wa miradi ya AI. Linatoa uwezo wa kuendesha vipande vya msimbo, kuchambua msimbo, au kuunganisha utekelezaji wa msimbo ndani ya mitiririko ya kazi ya AI.
# Uingizaji huu unaandaa sehemu inayohitajika kwa kutumia CodeInterpreterTool katika mradi wako, ambayo inaweza kuwa muhimu kwa kazi zinazohusiana na kutafsiri na kutekeleza msimbo kwa njia inayobadilika.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Maelezo:
# Darasa la ApprovalTerminationStrategy linatoa mkakati maalum wa kusitisha utendakazi wa wakala wa AI. Wakala ataacha kazi ikiwa ujumbe wa mwisho katika historia ya mwingiliano wake una neno "saved". Hii inaweza kuwa muhimu katika hali ambapo kazi ya wakala inachukuliwa kuwa imekamilika mara tu inapopokea uthibitisho kwamba kitu kimehifadhiwa. Eleza njia ya mwingiliano. Baada ya mpango wa uhifadhi kuhifadhiwa, unaweza kusitishwa wakati unapopokea ishara ya kuhifadhiwa

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Maelezo:
#
# Mstari wa msimbo unaanzisha kitu cha AzureAIAgentSettings kwa mipangilio ya chaguo-msingi au iliyowekwa awali kwa kuita njia ya create(). Kitu hiki cha mipangilio (ai_agent_settings) kisha kinaweza kutumika kusanidi na kusimamia mfano wa AzureAIAgent.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Maelezo:
# Kwa kuingiza maktaba ya requests, unaweza kwa urahisi kufanya maombi ya HTTP na kuingiliana na huduma za wavuti katika msimbo wako wa Python.

# %%
import requests

# %% [markdown]
# # Maelezo:
# Hii ni variable ambayo huhifadhi kitufe cha API kwa ajili ya kufikia huduma ya SERP (Search Engine Results Page) API. Kitufe cha API ni kitambulisho cha kipekee kinachotumika kuthibitisha maombi yanayohusiana na akaunti yako.
#
# 'GOOGLE_SEARCH_API_KEY': Hii ni mfululizo wa sehemu tu. Unahitaji kubadilisha ''GOOGLE_SEARCH_API_KEY' na kitufe chako halisi cha SERP API.
#
# Madhumuni: Madhumuni ya mstari huu ni kuhifadhi kitufe cha API katika variable ili kiweze kutumika kuthibitisha maombi kwa huduma ya SERP API. Kitufe cha API kinahitajika kufikia huduma na kufanya utafutaji.
#
# Jinsi ya Kupata Kitufe cha SERP API: Ili kupata kitufe cha SERP API, fuata hatua hizi za jumla kwenye https://serpapi.com (hatua halisi zinaweza kutofautiana kulingana na huduma maalum ya SERP API unayotumia):
#
# Chagua Huduma ya SERP API: Kuna huduma kadhaa za SERP API zinazopatikana, kama SerpAPI, Google Custom Search JSON API, na nyingine. Chagua ile inayokidhi mahitaji yako vizuri zaidi.
#
# Jisajili kwa Akaunti:
#
# Nenda kwenye tovuti ya huduma ya SERP API uliyoiainisha https://www.serpapi.com na jisajili kwa akaunti. Huenda ukahitaji kutoa taarifa za msingi na kuthibitisha anwani yako ya barua pepe.
#
# Unda Kitufe cha API:
#
# Baada ya kujisajili, ingia kwenye akaunti yako na nenda katika sehemu ya API au dashibodi. Tafuta chaguo la kuunda au kuzalisha kitufe kipya cha API.
# Nakili Kitufe cha API:
#
# Mara kitufe cha API kinapotengenezwa, nakili. Kitufe hiki kitatumika kuthibitisha maombi yako kwa huduma ya SERP API.
# Badilisha Sehemu ya Sehemu:
#
# Badilisha sehemu hiyo katika faili lako la .env

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Maelezo:
# Daraja la BookingPlugin linatoa mbinu za kuhifadhi hoteli na ndege kwa kutumia API ya Google Search ya Serpapi.com. Linajenga vigezo vinavyohitajika, linatuma maombi ya API, na kuchakata majibu ili kurudisha taarifa muhimu za uhifadhi. Ufunguo wa API (SERPAPI_SEARCH_API_KEY) na endpoint (SERPAPI_SEARCH_ENDPOINT) vinatumiwa kuthibitisha na kutuma maombi kwa Google Search API.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Maelezo:
# Darasa la SavePlugin linatoa njia ya saving_plan kuhifadhi mipango ya safari kwa kutumia huduma za Azure AI. Linaweka vibali vya Azure, huunda wakala wa AI, huchakata maingizo ya mtumiaji ili kuzalisha na kuhifadhi maudhui ya mpango wa safari, na hushughulikia uhifadhi wa faili na shughuli za usafishaji. Njia hii hurudisha "Imehifadhiwa" baada ya kukamilika kwa mafanikio.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # Maelezo:
# Msimbo huu unaanzisha maajenti wa Azure AI kushughulikia uhifadhi wa ndege na hoteli, na kuhifadhi mipango ya safari kulingana na maingizo ya mtumiaji. Unatumia vyeti vya Azure kuunda na kusanidi maajenti, kusindika maingizo ya mtumiaji kupitia mazungumzo ya kikundi, na kuhakikisha usafi sahihi baada ya kazi kufanyika. Maajenti hutumia virutubisho maalum (BookingPlugin na SavePlugin) kutekeleza majukumu yao.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Tangazo la Kuachilia**:
# Nyaraka hii imetafsiriwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Wakati tunajitahidi kupata usahihi, tafadhali fahamu kuwa tafsiri za kiotomatiki zinaweza kuwa na makosa au kasoro za usahihi. Nyaraka ya asili katika lugha yake ya asili inapaswa kuzingatiwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya mtaalamu wa binadamu inapendekezwa. Hatuwajibiki kwa kutoelewana au tafsiri potofu zinazotokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
