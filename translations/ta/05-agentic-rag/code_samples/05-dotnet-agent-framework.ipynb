# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) மூலம் நிறுவன RAG
#
# ## 📋 கற்றல் நோக்கங்கள்
#
# இந்த நோட்புக் Microsoft Foundry உடன் .NET இல் Microsoft Agent Framework ஐப் பயன்படுத்தி நிறுவன தரமான Retrieval-Augmented Generation (RAG) அமைப்புகளை எவ்வாறு உருவாக்குவது என்பதைக் கற்பிக்கிறது. நீங்கள் ஆவணங்களைத் தேடி, சரியான, சூழல் அறிந்த பதில்களை நிறுவன பாதுகாப்பு மற்றும் பரிமாணத்துடன் வழங்கக்கூடிய தயாரிப்பு தயாரான முகவர்களை உருவாக்க கற்றுக்கொள்வீர்கள்.
#
# **நீங்கள் உருவாக்கப்போகும் நிறுவன RAG திறன்கள்:**
# - 📚 **ஆவண நுண்ணறிவு**: Azure AI சேவைகளைப் பயன்படுத்தி முன்னேற்றப்பட்ட ஆவணம் செயலாக்கம்
# - 🔍 **அர்த்தவியல் தேடல்**: நிறுவன அம்சங்களுடன் உயர் செயல்திறன் வெக்டர் தேடல்
# - 🛡️ **பாதுகாப்பு ஒருங்கிணைப்பு**: பங்கு அடிப்படையிலான அணுகல் மற்றும் தரவு பாதுகாப்பு முறைகள்
# - 🏢 **பரிமாணக்கூடிய கட்டமைப்பு**: கண்காணிப்புடன் தயாரிப்பு தயாரான RAG அமைப்புகள்
#
# ## 🎯 நிறுவன RAG கட்டமைப்பு
#
# ### மைய நிறுவன கூறுகள்
# - **Microsoft Foundry**: பாதுகாப்பு மற்றும் ஒழுங்குமுறை சால்பட்டியுடன் நிருவகிக்கப்பட்ட நிறுவன AI பிளாட்ஃபாரம்
# - **நிலைத்த முகவர்கள்**: உரையாடல் வரலாறு மற்றும் சூழல் மேலாண்மையுடன் மாநில முகவர்கள்
# - **வெக்டர் அங்கீகாரம் மேலாண்மை**: நிறுவன தரமான ஆவண குறியீடு மற்றும் மீட்பாற்றல்
# - **அடையாள ஒருங்கிணைப்பு**: Azure AD அங்கீகாரம் மற்றும் பங்கு அடிப்படையிலான அணுகல் கட்டுப்பாடு
#
# ### .NET நிறுவன நன்மைகள்
# - **தரவு வகை பாதுகாப்பு**: RAG செயல்பாடுகள் மற்றும் தரவு கட்டமைப்புகளுக்கான குறியீட்டு நேர சரிபார்ப்பு
# - **அசிங்க் செயல்திறன்**: தடையற்ற ஆவண செயலாக்கம் மற்றும் தேடல் செயல்பாடுகள்
# - **மெமரி மேலாண்மை**: பெரிய ஆவண சேகரிப்புகளுக்கான சிறந்த வள பயன்பாடு
# - **ஒருங்கிணைப்பு முறைகள்**: சார்புகள் ஊட்டத்துடன் இயல்புநிலை Azure சேவை ஒருங்கிணைப்பு
#
# ## 🏗️ தொழில்நுட்ப கட்டமைப்பு
#
# ### நிறுவன RAG குழாய்
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### மைய .NET கூறுகள்
# - **Azure.AI.Agents.Persistent**: மாநில நிலைத்தன்மையுடன் நிறுவன முகவர் மேலாண்மை
# - **Azure.Identity**: பாதுகாப்பான Azure சேவை அணுகலுக்கான ஒருங்கிணைந்த அங்கீகாரம்
# - **Microsoft.Agents.AI.AzureAI**: Azureக்கு பொருத்தமான முகவர் கட்டமைப்பு செயலாக்கம்
# - **System.Linq.Async**: உயர் செயல்திறன் அசிங்க் LINQ செயல்பாடுகள்
#
# ## 🔧 நிறுவன அம்சங்கள் மற்றும் நன்மைகள்
#
# ### பாதுகாப்பு மற்றும் ஒழுங்குமுறை
# - **Azure AD ஒருங்கிணைப்பு**: நிறுவன அடையாள மேலாண்மை மற்றும் அங்கீகாரம்
# - **பங்கு அடிப்படையிலான அணுகல்**: ஆவண அணுகல் மற்றும் செயல்பாடுகளுக்கான λεπு அனுமதிகள்
# - **தரவு பாதுகாப்பு**: பாதுகாப்பான ஆவணங்களுக்கு இருப்பிலும் பரிமாற்றத்திலும் குறியாக்கம்
# - **தணிக்கை பதிவுகள்**: ஒழுங்குமுறை தேவைகளுக்கான விரிவான செயல்பாடு கண்காணிப்பு
#
# ### செயல்திறன் மற்றும் பரிமாணம்
# - **இணைப்பு குளிமையாக்கம்**: Azure சேவை இணைப்புக் மேலாண்மையில் திறமை
# - **அசிங்க் செயலாக்கம்**: உயர் படிமுறை காட்சிகளுக்கான தடையற்ற செயல்பாடுகள்
# - **கேசிங் திட்டங்கள்**: அடிக்கடி அணுகப்படும் ஆவணங்களுக்கான நுண்ணறிவு கேசிங்
# - **புகைப்பட சமநிலை**: பெரிய அளவிலான செருகல்களுக்கு விநியோகிக்கப்பட்ட செயலாக்கம்
#
# ### மேலாண்மை மற்றும் கண்காணிப்பு
# - **ஆரோக்கியச் சோதனைகள்**: RAG அமைப்பு கூறுகளுக்கான உள்ளமைக்கப்பட்ட கண்காணிப்பு
# - **செயல்திறன் அளவுகோல்கள்**: தேடு தரம் மற்றும் பதிலை நேரம் தொடர்பான விரிவான அறிவியல்
# - **பிழை கையாளல்**: மறுபடி கொள்கைகளுடன் விரிவான தவறு மேலாண்மை
# - **கட்டமைப்பு மேலாண்மை**: சூழல்-சார்ந்த அமைப்புகள் சரிபார்ப்புடன்
#
# ## ⚙️ முன்பதிவு தேவைகள் மற்றும் அமைப்பு
#
# **முன்னேற்ற சூழல்:**
# - .NET 9.0 SDK அல்லது மேற்பட்டது
# - Visual Studio 2022 அல்லது C# விரிவாக்கத்துடன் VS Code
# - AI Foundry அணுகலுடன் Azure சந்தா
#
# **தேவையான NuGet தொகுப்புகள்:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure அங்கீகாரம் அமைப்பு:**
# ```bash
# # Azure CLIஐ நிறுவி அங்கீகரிக்கவும்
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **சூழல் நாட்டு பதிவு (.env கோப்பு):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 நிறுவன RAG முறைகள்
#
# ### ஆவண மேலாண்மை முறைகள்
# - **தூய்மையான அப்லோடு**: பெரிய ஆவண சேகரிப்புகளுக்கான திறமையான செயலாக்கம்
# - **கட்டடவிளைவான புதுப்பிப்புகள்**: நேரடி ஆவண சேர்க்கை மற்றும் மாற்றம்
# - **பதிப்பு கட்டுப்பாடு**: ஆவணி பதிப்பாக்கம் மற்றும் மாற்ற கண்காணிப்பு
# - **மெட்டாடேட்டா மேலாண்மை**: செழிப்பான ஆவண பண்புகள் மற்றும் வர்க்கமொழி
#
# ### தேடல் மற்றும் மீட்பு முறைகள்
# - **இணைப்புமுறை தேடல்**: சிறந்த முடிவுகளுக்காக அர்த்தவியல் மற்றும் முக்கிய வார்த்தை தேடல்களின் சேர்க்கை
# - **உருப்படைக் கூறு தேடல்**: பல-பரிமாண வடிகட்டி மற்றும் வகைப்பாடு
# - **தகுதி திருத்தம்**: டொமைன்-சந்தர்ப தேவைகளுக்கான தனிப்பயன் மதிப்பீட்டு الگோரிதம்கள்
# - **முடிவு தரவரிசை**: வணிக நியமங்களுடன் முன்னேற்றிய தரவரிசை
#
# ### பாதுகாப்பு முறைகள்
# - **ஆவண அளவிலான பாதுகாப்பு**: ஆவணங்களுக்கு λεπு அணுகல் கட்டுப்பாடு
# - **தரவு வகைப்படுத்தல்**: தானியங்கி உணர்வு லேபிளிங் மற்றும் பாதுகாப்பு
# - **தணிக்கை தடங்கள்**: அனைத்து RAG செயல்பாடுகளுக்கும் விரிவான பதிவு
# - **தனியுரிமை பாதுகாப்பு**: PII கண்டறிதல் மற்றும் திருத்த வசதிகள்
#
# ## 🔒 நிறுவன பாதுகாப்பு அம்சங்கள்
#
# ### அங்கீகாரம் மற்றும் உரிமை வழங்கல்
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### தரவு பாதுகாப்பு
# - **குறியாக்கம்**: ஆவணங்களுக்கும் தேடல் குறியீடுகளுக்கும் இறுதி முதல் இறுதி குறியாக்கம்
# - **அணுகல் கட்டுப்பாடுகள்**: பயனர் மற்றும் குழு அனுமதிகளுக்கான Azure AD உடன் ஒருங்கிணைப்பு
# - **தரவு இருப்பிடம்**: ஒழுங்குமுறை தேவைகளுக்கான புவியியல் தரவு இட கட்டுப்பாடுகள்
# - **மீள்பார்வை மற்றும் மீட்பு**: தானாக செயல் நடைமுறை மற்றும் பேரழிவு மீட்பு வசதிகள்
#
# ## 📈 செயல்திறன் மேம்படுத்தல்
#
# ### அசிங்க் செயலாக்க முறைகள்
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### மெமரி மேலாண்மை
# - **ஒழுங்குமுறை செயலாக்கம்**: மெமரி சிக்கலുകളின்றி பெரிய ஆவணங்களை கையாளுதல்
# - **வள குளிமையாக்கம்**: செலவான வளங்களின் திறமையான மறுபயன்பாடு
# - **குப்பை சேகரிப்பு**: மெமரி ஒதுக்கீடு முறைகளை ஒழுங்குபடுத்தல்
# - **இணைப்பு மேலாண்மை**: சரியான Azure சேவை இணைப்பு வாழ்நாள்
#
# ### கேசிங் திட்டங்கள்
# - **வினவல் கேசிங்**: அடிக்கடி மேற்கொள்ளப்படும் தேடல்களுக்கு கேசிங்
# - **ஆவண கேசிங்**: வெப்பமான ஆவணங்களுக்கு மெமரியில் கேசிங்
# - **அங்கீகாரம் கேசிங்**: மேம்படுத்தப்பட்ட வெக்டர் அங்கீகாரம் கேசிங்
# - **முடிவு கேசிங்**: உருவாக்கப்பட்ட பதில்களின் நுண்ணறிவு கேசிங்
#
# ## 📊 நிறுவன பயன்பாடுகள்
#
# ### அறிவு மேலாண்மை
# - **நிறுவன விக்கி**: நிறுவன அறிவு அடிப்படைகளில் நுண்ணறிவு தேடல்
# - **நெறிமுறை மற்றும் செயல்முறைகள்**: தானாக ஒழுங்குமுறை மற்றும் நடைமுறை வழிகாட்டி
# - **பயிற்சி பொருட்கள்**: நுண்ணறிவு கற்றல் மற்றும் மேம்பாட்டு உதவி
# - **ஆராய்ச்சி தரவுத்தளம்**: கல்வி மற்றும் ஆராய்ச்சி கட்டுரைகள் பகுப்பாய்வு அமைப்புகள்
#
# ### வாடிக்கையாளர் ஆதரவு
# - **ஆதரவு அறிவு அடிப்படை**: தானாக வாடிக்கையாளர் சேவை பதில்கள்
# - **தயாரிப்பு ஆவணங்கள்**: நுண்ணறிவு தயாரிப்பு தகவல் மீட்பு
# - **துணை இயக்க வழிகாட்டிகள்**: சூழல் சார்ந்த பிரச்சினை தீர்வு உதவி
# - **கேள்வி பதில் அமைப்புகள்**: ஆவண் சேகரிப்பிலிருந்து தானியங்கி கேள்வி பதில்கள் உருவாக்கம்
#
# ### ஒழுங்குமுறை ஒத்திருப்பு
# - **சட்ட ஆவண பகுப்பாய்வு**: ஒப்பந்தம் மற்றும் சட்ட ஆவண நுண்ணறிவு
# - **ஒற்றுமை கண்காணிப்பு**: தானாக ஒழுங்குமுறை ஒத்திருப்பு சரிபார்ப்பு
# - **பாத்திரத்தன்மை மதிப்பீடு**: ஆவண அடிப்படையிலான பாத்திர நுண்ணறிவு மற்றும் அறிக்கை
# - **தணிக்கை ஆதரவு**: தணிக்கைகளுக்கான நுண்ணறிவு ஆவண கண்டுபிடிப்பு
#
# ## 🚀 தயாரிப்பு வெளியீடு
#
# ### கண்காணிப்பு மற்றும் பார்வை
# - **விண்ணப்ப洞察ங்கள்**: விரிவான தொலைநோக்கு மற்றும் செயல்திறன் கண்காணிப்பு
# - **தனிப்பயன் அளவுகோல்கள்**: வணிக-சார்ந்த முக்கிய செயல்திறன் குறியீடுகள் கண்காணிப்பு மற்றும் எச்சரிக்கை
# - **விநியோகிக்கப்பட்ட தடதடிப்பு**: சேவைகளுக்கு இடையில் கோரிக்கை முழுமையான கண்காணிப்பு
# - **ஆரோக்கிய டாஷ்போர்ட்கள்**: நேரடி அமைப்பு ஆரோக்கியம் மற்றும் செயல்திறன் காட்சிப்படுத்தல்
#
# ### பரிமாணக்கூடல் மற்றும் நம்பகத்தன்மை
# - **தானியங்கி பரிமாணம்**: ஏற்றத்தை மற்றும் செயல்திறனைக் கொண்டு தானியங்கி பரிமாணம்
# - **உயர் கிடைக்கும்**: பல மண்டல பரப்புகளில் தோல்வி மாற்றும் வசதியுடன்
# - **ஏற்றம் சோதனை**: நிறுவன ஏற்ற நிலைகளில் செயல்திறன் நம்பகத்தன்மை
# - **பேரழிவு மீட்பு**: தானாக மீள்பார்வை மற்றும் மீட்பு நடைமுறைகள்
#
# பரிமாணத்தில் நுண்ணறிவு ஆவணங்களை கையாளக்கூடிய நிறுவன தர RAG அமைப்புகளை உருவாக்க தயாரா? நிறுவனத்திற்கான நுண்ணறிவு அறிவு அமைப்புகளை வடிவமைப்போம்! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **குறிப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) மூலம் மொழிபெயர்க்கப்பட்டது. நாங்கள் துல்லியமாக்கக் கடமைப்பட்டிருந்தாலும், தானாக செய்யப்பட்ட மொழிபெயர்ப்பில் பிழைகள் அல்லது தவறுகள் இருக்க வாய்ப்பு உள்ளது என்பதை தயவு செய்து அறியவும். இயல்பான மொழியில் உள்ள அசல் ஆவணம் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்காக, தொழில்முனைவர் மனித மொழிபெயர்ப்பை பரிந்துரைக்கிறோம். இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் யாரேனும் தவறான புரிதல்கள் அல்லது தவறான பொருளாக்கங்களுக்கு நாம் பொறுப்பாளிகள் அல்ல.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
