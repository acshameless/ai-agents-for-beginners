# %% [markdown]
# ## **மாதிரிகள்: ஹோட்டல் முன்பதிவு செய்வதற்கான.Multi-AI முகவர்கள்**
#
# இன்றைய வேகமான உலகத்தில், ஒரு வணிக பயணத்தை திட்டமிடுவது கூட ஒரு விமானமும் ஹோட்டல் அறையும் முன்பதிவு செய்வதற்கு மட்டும் அல்ல. இது ஒருங்கிணைப்பு மற்றும் திறமைகளை தேவைபடுத்துகிறது, அதை அடைதல் சவாலை உருவாக்கும். இங்கே Multi-AI முகவர்கள் முக்கிய பங்கு வகிக்கின்றனர், நமது பயண தேவைகளை நிர்வகிப்பதில் புரட்சியை கொண்டு வருகின்றனர்.
#
# உங்களது பயணத்தின் ஒவ்வொரு அம்சத்தையும் துல்லியமாகவும் எளிமையாகவும் கையாளும் புத்திசாலித் தரகர் குழுவைக் கற்பனை செய்யுங்கள். நமது முன்னேற்ற AI தொழில்நுட்பத்துடன், முன்பதிவு சேவைகள் மற்றும் பயண திட்டமிடலை உறுதி செய்யும் சிறப்பு முகவர்களை உருவாக்கி, இடையூறு இல்லாவிடில் பயண அனுபவத்தை வழங்குகிறோம்.
#
# இது ஒரு அடிப்படை சூழ்நிலை. வணிக பயணத்தை திட்டமிடும் போது, விமானமீது தகவல், ஹோட்டல் தகவல் போன்றவற்றை பெற வணிக பயண முகவருடன் ஆலோசனை செய்ய வேண்டும். AI முகவர்கள் மூலம், முன்பதிவு சேவைகளுக்கான முகவர்கள் மற்றும் பயண திட்டமிடலுக்கான முகவர்களை உருவாக்கி கூட்டு வேலை செய்து புத்திசாலித்தனத்தை மேம்படுத்தலாம்.

# %% [markdown]
# # Azure AI முகவர் சேவையை ஆரம்பித்து **.env** இலிருந்து கட்டமைப்பு தகவல்களை பெறுதல்
#
# ### **.env**
#
# ஒரு .env கோப்பை உருவாக்கவும்
#
# **.env**-இல் Azure AI முகவர் சேவையின் இணைப்பு சரம், AOAI பயன்படுத்தும் மாதிரி மற்றும் அதற்கான Google API தேடல் சேவை API, ENDPOINT, முதலியன அடங்கும்.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "உங்கள் Azure AI முகவர் சேவை மாதிரிப் பதிப்பு பெயர்"
#
# [**NOTE**] 100,000 கணக்கெடுப்பு வரம்பு (நொடிக்கு குறியீடுகள்) மற்றும் 600 வரம்பு (நொடிக்கு கோரிக்கைகள்) கொண்ட மாதிரியைப் பெற வேண்டும்
#
#   Microsoft Foundry - மாதிரி மற்றும் ENDPOINT-இல் மாதிரியைப் பெறலாம்.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "உங்கள் Azure AI முகவர் சேவை திட்ட இணைப்பு சரம்"
#
#   AI Foundry போர்டல் திரையில் உங்கள் திட்டத்தின் மேலோட்டத்தில் திட்ட இணைப்பு சரத்தை பெறலாம்.
#
# - **SERPAPI_SEARCH_API_KEY** = "உங்கள் SERPAPI தேடல் API விசை"
# - **SERPAPI_SEARCH_ENDPOINT** = "உங்கள் SERPAPI தேடல் ENDPOINT"
#
# Azure AI முகவர் சேவையின் மாதிரி பதிப்பு பெயர் மற்றும் திட்ட இணைப்பு சரத்தை பெற, Azure AI முகவர் சேவையை உருவாக்க வேண்டும். நேரடியாக உருவாக்க [இந்த டெம்ப்ளேட்டை](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) பயன்படுத்த பரிந்துரைக்கப்படுகிறது （***கவனம்:*** Azure AI முகவர் சேவை தற்போது வரம்பிடப்பட்ட பிராந்தியத்தில் அமைக்கப்படுகிறது. பிராந்தியத்தை அமைக்கும் போது [இந்த இணைப்பை](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) பார்த்து பரிந்துரைக்கப்படுகிறது)
#
# முகவர் SERPAPI-ஐ அணுக வேண்டும். [இந்த இணைப்பில்](https://serpapi.com/searches) பதிவு செய்து, பதிவு செய்யப்பட்ட பிறகு தனித்துவ API விசை மற்றும் ENDPOINT பெற்றுக்கொள்ள பரிந்துரைக்கப்படுகிறது.

# %% [markdown]
# # Azure-இல் உள்நுழையவும்
#
# நீங்கள் இப்போது Azure-இல் உள்நுழைய வேண்டும் VScode-ல் ஒரு டெர்மினலை திறந்து `az login` கட்டளையை இயக்கவும்

# %% [markdown]
# # அமைப்பு
#
# இந்த நோட்புகை இயக்க, கீழ்காணும் நூலகங்களை நிறுவவேண்டும். தேவையான நூலகங்களும் அதற்கான pip நிறுவல் கட்டளைகள் பின்வருமாறு:
#
# azure-identity: Azure அங்கீகாரத்திற்காக.
# requests: HTTP கோரிக்கைகள் செய்ய.
# semantic-kernel: செமாண்டிக் கெர்னல் அமைப்பிற்காக (இது தனிப்பயன் அல்லது குறிப்பிட்ட நூலகமாயிருக்கலாம், அதனால் குறிப்பிட்ட மூலத்திலிருந்து அல்லது தொகுப்பகம்(ரெப்போ)யில் இருந்து நிறுவ வேண்டி இருக்கலாம்).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # விளக்கம்:
# import asyncio: இது asyncio மூடியை இறக்குமதி செய்கிறது, இது Python இல் அசிங்க்ரோனஸ் நிரலாக்கத்திற்கு ஆதரவு வழங்குகிறது. async மற்றும் await குறியீடுகளைப் பயன்படுத்தி ஒரே நேரத்தில் செயல்படும் குறியீட்டைக் எழுத அனுமதிக்கிறது.
# from typing import Annotated: இது typing மூடியிலிருந்து Annotated வகுப்பைப் இறக்குமதி செய்கிறது. Annotated என்பது வகை குறிப்புகளுக்குக் குறிப்பிட்ட மெட்டாதரவைச் சேர்க்க பயன்படுத்தப்படுகிறது, இது சரிபார்ப்பு, ஆவணம் அல்லது கருவி போன்ற பல்வேறு நோக்கங்களுக்கு பயன்படும்.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # விளக்கம்:
# from dotenv import load_dotenv மற்றும் load_dotenv() ஐ பயன்படுத்துவதன் மூலம், நீங்கள் .env கோப்பில் உள்ள கட்டமைப்பு அமைப்புகள் மற்றும் حساسமான தகவல்களை (உதாரணமாக API சாவிகள் மற்றும் தரவுத்தளம் URL கள்) எளிதாக நிர்வகிக்கலாம், அவற்றை உங்கள் மூலக் குறியீட்டிலிருந்து தனித்துவமாக வைத்துக் கொண்டு உங்கள் பயன்பாட்டை பாதுகாப்பானதும், கட்டமைக்க எளிதானதும் ஆக்கலாம்.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # விளக்கம்:
#
# இறக்குமதி அறிக்கை: from azure.identity.aio import DefaultAzureCredential: இது azure.identity.aio மாடியூலிலிருந்து DefaultAzureCredential வகுப்பை இறக்குமதி செய்கிறது. aio என்பது மாடியூல்名称இல் உள்ள பகுதி, இது அசிங்க்ரோனஸ் செயல்பாடுகளுக்கு வடிவமைக்கப்பட்டுள்ளது என்பதை குறிக்கிறது.
#
# DefaultAzureCredential இன் நோக்கம்: DefaultAzureCredential வகுப்பு Azure SDK பைதான் தொகுப்பில் ஒரு பகுதியாக உள்ளது. இது Azure சேவைகளுடன் உறுதிப்படுத்த எந்தவொரு வழியையும் வழங்குகிறது. இது ஒரு குறிப்பிட்ட வரிசையில் பல முறைகளைக் கொண்டு உறுதிப்படுத்த முயல்கிறது, உதாரணத்திற்கு சூழல் மாறிலிகள், நிர்வகிக்கப்பட்ட அடையாளம் மற்றும் Azure CLI உறுதிப்பத்திரங்கள்.
#
# அசிங்க்ரோனஸ் செயல்பாடுகள்: aio மாடியூல் DefaultAzureCredential வகுப்பு அசிங்க்ரோனஸ் செயல்பாடுகளை ஆதரிக்கின்றது என்பதை குறிக்கிறது. இதன் மூலம் நீங்கள் asyncio உடன் பயன்படுத்தி தடையின்றி உறுதிப்படுத்தல் கோரிக்கைகளை செய்ய முடியும்.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # விளக்கம்:
# semantic_kernel தொகுப்பில் இருந்து பல மாடியூல்கள் மற்றும் வகுப்புகளை இறக்குமதி செய்கிறது. ஒவ்வொரு இறக்குமதிக்கும் கீழே விளக்கம்:
#
# semantic_kernel.agents இல் இருந்து AgentGroupChat: இந்த வகுப்பு AI முகவர்கள் குழு அரட்டை தொடர்பான பணிகளுக்கு பொறுப்பானது. semantic_kernel.agents.azure_ai இல் இருந்து AzureAIAgent மற்றும் AzureAIAgentSettings
#
# AzureAIAgent: Azure AI சேவைகளை பயன்படுத்தும் AI முகவர்களை உருவாக்கவும் நிர்வகிக்கவும் இந்த வகுப்பு பயன்படும்.
#
# AzureAIAgentSettings: AzureAIAgent க்கான அமைப்புகளை உருவாக்க இந்த வகுப்பு பயன்படுத்தப்படுகிறது. semantic_kernel.agents.strategies.termination.termination_strategy இல் இருந்து TerminationStrategy:
#
# குறிப்பிட்ட சூழ்நிலைகளில் AI முகவர்களின் செயல்பாட்டை நிறுத்த விதிகள் இந்த வகுப்பு வரையறுக்கிறது. semantic_kernel.contents.chat_message_content இல் இருந்து ChatMessageContent:
#
# இந்த வகுப்பு அரட்டை செய்திகளின் உள்ளடக்கத்தை கையாள பயன்படுகிறது.
# semantic_kernel.contents.utils.author_role இல் இருந்து AuthorRole:
#
# அரட்டை செய்திகளின் சூழலில் எழுத்தாளர்களுக்கான வேறுபட்ட பங்குகளை இந்த வகுப்பு வரையறுக்கிறது.
#
# semantic_kernel.functions.kernel_function_decorator இல் இருந்து kernel_function: இந்த அலங்காரம் semantic kernel கட்டமைப்பில் இயங்கக்கூடிய கர்னல் செயல்பாடுகளை வரையறுக்க பயன்படும்.
# இந்த இறக்குமதிகள், குழு அரட்டை சூழல் போன்ற சுற்றுப்புறத்தில் தொடர்பு கொள்ளக்கூடிய AI முகவர்கள் உருவாக்கவும் நிர்வகிக்கவும் தேவையான கூறுகளை அமைக்கின்றன, உதாரணமாக ஹோட்டல் முன்பதிவு அல்லது இதர சமான பணிகளுக்கு.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # விளக்கம்:
# அடுத்ததாக azure.ai.projects.models மொடியூல் இருந்து CodeInterpreterTool வகுப்பை இறக்குமதி செய்கிறோம்.
#
# CodeInterpreterTool: இந்த வகுப்பு Azure AI SDK இன் ஒரு பகுதி மற்றும் AI திட்டங்களின் உட்பிரிவில் குறியீட்டை புரிந்து கொண்டு செயல்படுத்த பயன்படுத்தப்படுகிறது. இது குறியீட்டுத் துண்டுகளை இயக்க, குறியீட்டை பகுப்பாய்வு செய்ய, அல்லது AI பணிச்சூழல்களில் குறியீட்டு செயல்பாட்டை ஒருங்கிணைக்க உதவுகிறது.
# இந்த இறக்குமதி உங்கள் திட்டத்தில் CodeInterpreterTool ஐ பயன்படுத்த தேவையான கூறுகளை அமைக்கிறது, இது கலந்துரையாடல் மூலம் குறியீட்டை புரிந்து கொண்டு இயக்குதல் போன்ற பணிகளுக்குப் பயன்படலாம்.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # விளக்கம்:
# ApprovalTerminationStrategy வகுப்பு ஒரு AI முகவரியின் செயல்பாட்டை நிறுத்த ஒரு குறிப்பிட்ட தந்திரத்தை வழங்குகிறது. முகவர் தனது தொடர்பு வரலாற்றில் உள்ள கடைசி செய்தியில் "saved" எனும் சொல் இருந்தால் செயல்பாட்டை நிறுத்தும். இது, முகவரியின் பணி முடிந்துவிட்டது என்று ஒரே நேரத்தில் "saved" என்ற உறுதிப்படுத்தல் வந்தவுடன் நிறுத்தப்பட வேண்டிய சூழ்நிலைகளில் பயன்பட வாய்ப்பு உள்ளது. தொடர்பு முறைத்தைนิர்ணயிக்கவும். பதுக்கல் திட்டம் சேமிக்கப்பட்ட பிறகு, "saved" என்ற சிக்னல் கிடைக்கும் போது அது நிறுத்தப்படலாம்.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # விளக்கம்:
#
# இந்த கோட்டு ஒரு AzureAIAgentSettings பொருளை இயல்பான அல்லது முன்கூறிய அமைப்புகளுடன் create() முறையை அழைத்து ஆரம்பிக்கிறது. இந்த அமைப்புப் பொருள் (ai_agent_settings) பிறகு ஒரு AzureAIAgent எடுத்துக்காட்டை வடிவமைக்க மற்றும் நிர்வகிக்க பயன்படுத்தப்படலாம்.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # விளக்கம்:
# requests நூலகத்தை இறக்குமதி செய்வதன் மூலம், நீங்கள் எளிதாக HTTP கோரிக்கைகளை செய்யவும் உங்கள் Python குறியீட்டில் வலை சேவைகளை தொடர்புகொள்ளவும் முடியும்.

# %%
import requests

# %% [markdown]
# # விளக்கம்:
# இது SERP (Search Engine Results Page) API சேவைக்கு அணுகுவதற்கான API முக்கியத்தை சேமிக்கும் மாறி ஆகும். API முக்கியம் என்பது உங்கள் கணக்குச் சார்ந்த கோரிக்கைகளை அங்கீகரிக்க பயன்படுத்தப்படும் தனித்துவமான அடையாள எண்ணாகும்.
#
# 'GOOGLE_SEARCH_API_KEY': இது ஒரு இடமாற்று உரை. உங்கள் உண்மையான SERP API முக்கியத்துடன் 'GOOGLE_SEARCH_API_KEY' ஐ மாற்ற வேண்டும்.
#
# ந مقصدம்: இந்த வரியின் நோக்கம் API முக்கியத்தை ஒரு மாறியில் சேமிப்பதற்கும்தான், இதனால் அது SERP API சேவைக்கு கோரிக்கைகளை அங்கீகரிக்க பயன்படுத்தலாம். சேவையை அணுகுவதற்கும் தேடல்களைச் செய்பவருக்கும் API முக்கியம் அவசியம் ஆகும்.
#
# SERP API முக்கியம் பெறும் வழி: SERP API முக்கியம் பெற, https://serpapi.com இல் பின்வரும் பொதுவான படிகளை பின்பற்றவும் (குறிப்பிட்ட SERP API சேவையைப் பொருத்து படிகள் மாறக்கூடும்):
#
# SERP API சேவையை தேர்வு செய்யவும்: SerpAPI, Google Custom Search JSON API போன்ற பல SERP API சேவைகள் உள்ளன. உங்கள் தேவைக்கேகு ஒன்றை தேர்வு செய்யவும்.
#
# கணக்கு பதிவு செய்யவும்:
#
# தேர்ந்தெடுத்த SERP API சேவையின் தளத்திற்கு https://www.serpapi.com சென்றுகொண்டு ஒரு கணக்கு பதிவு செய்யவும். சில அடிப்படைக் தகவல்களைத் தர வேண்டும் மற்றும் உங்கள் மின்னஞ்சல் முகவரியை உறுதிப்படுத்த கூடலாம்.
#
# API முக்கியம் உருவாக்கவும்:
#
# பதிவு செய்த பின்பு, உங்கள் கணக்கில் இணைந்து API பகுதிக்கு அல்லது டாஷ்போர்டுக்கு செல்லவும். புதிய API முக்கியத்தை உருவாக்க அல்லது உருவாக்கும் விருப்பத்தைக் காணவும்.
# API முக்கியத்தை நகலெடுக்கவும்:
#
# API முக்கியம் தயாரானவுடன், அதை நகலெடுக்கவும். இந்த முக்கியம் உங்கள் கோரிக்கைகளை SERP API சேவைக்கு அங்கீகரிக்க பயன்படுத்தப்படும்.
# இடமாற்றை மாற்றவும்:
#
# உங்கள் .env கோப்பில் உள்ள இடமாற்று உரையை மாற்றவும்

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # விளக்கம்:
# BookingPlugin வகுப்பு Serpapi.com கூகுள் தேடல் API-யை பயன்படுத்தி ஓட்டல்கள் மற்றும் விமானங்களை முன்பதிவு செய்யும் முறைமைகளை வழங்குகிறது. இது தேவையான பராமரிப்புகளை உருவாக்கி, API கோரிக்கைகளை அனுப்பி, தொடர்புடைய முன்பதிவு தகவல்களை திருப்பி அளிக்க பதில்களை செயலாக்குகிறது. API விசை (SERPAPI_SEARCH_API_KEY) மற்றும் கடைசி புள்ளி (SERPAPI_SEARCH_ENDPOINT) கூகுள் தேடல் API-க்கு அங்கீகாரம் அளித்து கோரிக்கைகளை அனுப்ப பயன்படுத்தப்படுகிறது.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # விளக்கம்:
# SavePlugin வகுப்பு Azure AI சேவைகளைக் கொண்டு பயணம் திட்டங்களை சேமிக்க saving_plan என்ற முறையை வழங்குகிறது. இது Azure அங்கீகாரங்களை அமைத்து, ஒரு AI முகவரை உருவாக்கி, பயனர் உள்ளீடுகளை செயலாக்கி பயணம் திட்ட உள்ளடக்கத்தை உருவாக்கி சேமிக்கிறது மற்றும் கோப்பு சேமிப்பு மற்றும் சுத்தப்படுத்தும் நடவடிக்கைகளை கையாள்கிறது. வெற்றிகரமாக முடிந்ததும் இது "Saved" என்பதை திருப்பி விடுகிறது.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # விளக்கம்:
# இந்த குறியீடு பயனர் உள்ளீடுகளின் அடிப்படையில் விமானப் பயணங்கள் மற்றும் ஹோட்டல்கள் முன்பதிவு செய்வதற்கும் பயணத் திட்டங்களை சேமிப்பதற்கும் Azure AI முகவர்களை அமைக்கிறது. இது Azure அடையாளப்பத்திரங்களைப் பயன்படுத்தி முகவர்களை உருவாக்கி அமைக்கிறது, குழு உரையாடல் மூலம் பயனர் உள்ளீடுகளை செயலாக்குகிறது மற்றும் பணிகள் முடிந்தபின் சரியான ஸ்திதிபார்க்கலை உறுதிசெய்கிறது. முகவர்கள் தங்கள் பேச்சு பணிகளை செய்ய BookingPlugin மற்றும் SavePlugin என்ற குறிப்பிட்ட பிளகின்களைப் பயன்படுத்துகின்றனர்.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **உறுதிப்பத்திரம்**:
# இந்த ஆவணம் AI மொழிபெயர்க்கும் சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சித்தாலும், தானியங்கி மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருப்பதற்கான வாய்ப்பு உள்ளது என்பதை தயவுசெய்து கவனிக்கவும். அவர்களின் தாய்மொழியில் உள்ள அசல் ஆவணம் அதிகாரப்பூர்வ மூலமாக கருத வேண்டும். முக்கியமான தகவல்களுக்கு, முறைப்பூர்வமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்பட்ட எந்த புரிதறிப்புகளுக்கும் அல்லது தவறான விளக்கங்களுக்கும் நாங்கள் பொறுப்பேற்க மாட்டோம்.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
