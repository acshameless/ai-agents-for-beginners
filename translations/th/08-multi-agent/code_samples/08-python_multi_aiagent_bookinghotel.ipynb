# %% [markdown]
# ## **ตัวอย่าง: ตัวแทน AI หลายตัวสำหรับการจองโรงแรม**
#
# ในโลกที่เร่งรีบในปัจจุบัน การวางแผนทริปธุรกิจไม่ได้หมายถึงแค่การจองตั๋วเครื่องบินและห้องพักโรงแรมเท่านั้น แต่ยังต้องการระดับของการประสานงานและประสิทธิภาพที่อาจเป็นเรื่องท้าทายที่จะทำให้สำเร็จ นี่คือจุดที่ตัวแทน AI หลายตัวเข้ามามีบทบาท ปฏิวัติวิธีที่เราจัดการความต้องการการเดินทางของเรา
#
# ลองจินตนาการว่าคุณมีทีมตัวแทนอัจฉริยะที่พร้อมให้บริการ ทำงานร่วมกันเพื่อจัดการทุกแง่มุมของการเดินทางของคุณด้วยความแม่นยำและง่ายดาย ด้วยเทคโนโลยี AI ขั้นสูงของเรา เราได้สร้างตัวแทนเฉพาะสำหรับบริการจองและการจัดตารางเส้นทาง เพื่อให้มั่นใจว่าประสบการณ์การเดินทางของคุณเป็นไปอย่างราบรื่นและไร้ความเครียด
#
# นี่คือสถานการณ์พื้นฐาน เมื่อวางแผนทริปธุรกิจ เราจำเป็นต้องปรึกษากับตัวแทนการเดินทางธุรกิจเพื่อขอข้อมูลตั๋วเครื่องบิน ข้อมูลโรงแรม ฯลฯ ผ่านตัวแทน AI เราสามารถสร้างตัวแทนสำหรับบริการจองและตัวแทนสำหรับการจัดตารางเส้นทางเพื่อทำงานร่วมกันและเพิ่มระดับความฉลาดขึ้นได้

# %% [markdown]
# # เริ่มต้นใช้ Azure AI Agent Service และดึงข้อมูลกำหนดค่าจาก **.env**
#
# ### **.env**
#
# สร้างไฟล์ .env
#
# **.env** ประกอบด้วยสายการเชื่อมต่อของ Azure AI Agent Service, แบบจำลองที่ใช้โดย AOAI, และบริการค้นหา Google API ที่เกี่ยวข้อง, ENDPOINT, ฯลฯ
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "ชื่อการปรับใช้แบบจำลอง Azure AI Agent Service ของคุณ"
#
# [**หมายเหตุ**] คุณจะต้องใช้แบบจำลองที่มีขีดจำกัดอัตรา 100,000 (โทเค็นต่อนาที) ขีดจำกัดอัตรา 600 (คำขอต่อนาที)
#
#   คุณสามารถรับแบบจำลองได้ใน Microsoft Foundry - แบบจำลองและจุดสิ้นสุด
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "สายการเชื่อมต่อโครงการ Azure AI Agent Service ของคุณ"
#
#   คุณสามารถรับสายการเชื่อมต่อโครงการได้ในภาพรวมโครงการของคุณที่หน้าจอ AI Foundry Portal
#
# - **SERPAPI_SEARCH_API_KEY** = "กุญแจ API สำหรับ SERPAPI Search ของคุณ"
# - **SERPAPI_SEARCH_ENDPOINT** = "ENDPOINT ของ SERPAPI Search ของคุณ"
#
# เพื่อรับชื่อการปรับใช้แบบจำลองและสายการเชื่อมต่อโครงการของ Azure AI Agent Service คุณจะต้องสร้าง Azure AI Agent Service แนะนำให้ใช้ [แม่แบบนี้](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) เพื่อสร้างโดยตรง （***หมายเหตุ:*** ขณะนี้ Azure AI Agent Service กำหนดไว้ในภูมิภาคจำกัด แนะนำให้อ้างอิง [ลิงก์นี้](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) เพื่อกำหนดภูมิภาค)
#
# เอเย่นต์จำเป็นต้องเข้าถึง SERPAPI แนะนำให้ลงทะเบียนโดยใช้ [ลิงก์นี้](https://serpapi.com/searches) หลังจากลงทะเบียนแล้ว คุณจะได้รับกุญแจ API ที่ไม่ซ้ำและ ENDPOINT

# %% [markdown]
# # Login to Azure
#
# คุณต้องเข้าสู่ระบบ Azure ตอนนี้ เปิดเทอร์มินัลใน VScode และรันคำสั่ง `az login`

# %% [markdown]
# # Setup
#
# ในการรันโน้ตบุ๊กนี้ คุณจะต้องติดตั้งไลบรารีต่อไปนี้ นี่คือรายชื่อไลบรารีที่จำเป็นพร้อมคำสั่ง pip install ที่สอดคล้องกัน:
#
# azure-identity: สำหรับการตรวจสอบสิทธิ์ Azure
# requests: สำหรับการทำคำขอ HTTP
# semantic-kernel: สำหรับกรอบงาน semantic kernel (สมมติว่านี่คือไลบรารีที่กำหนดเองหรือเฉพาะ คุณอาจต้องติดตั้งจากแหล่งหรือที่เก็บเฉพาะ)

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Explanation:
# import asyncio: นี่คือการนำเข้าโมดูล asyncio ซึ่งให้การสนับสนุนสำหรับการเขียนโปรแกรมแบบอะซิงโครนัสในภาษา Python ช่วยให้คุณเขียนโค้ดที่ทำงานพร้อมกันโดยใช้ไวยากรณ์ async และ await
# from typing import Annotated: นี่คือการนำเข้าประเภท Annotated จากโมดูล typing ซึ่ง Annotated ใช้เพื่อเพิ่มเมตาดาต้าให้กับการบอกชนิดข้อมูล ซึ่งมีประโยชน์ในหลายกรณี เช่น การตรวจสอบความถูกต้อง, การทำเอกสาร หรือเครื่องมือช่วยพัฒนา

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # คำอธิบาย:
# โดยการใช้ from dotenv import load_dotenv และ load_dotenv() คุณสามารถจัดการการตั้งค่าคอนฟิกและข้อมูลสำคัญ (เช่น คีย์ API และ URL ฐานข้อมูล) ในไฟล์ .env ได้อย่างง่ายดาย โดยแยกพวกมันออกจากซอร์สโค้ดของคุณ ทำให้แอปพลิเคชันของคุณปลอดภัยมากขึ้นและง่ายต่อการตั้งค่า.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Explanation:
#
# Import Statement: from azure.identity.aio import DefaultAzureCredential: นำเข้าคลาส DefaultAzureCredential จากโมดูล azure.identity.aio ส่วน aio ของชื่อโมดูลบ่งชี้ว่าออกแบบมาสำหรับการทำงานแบบอะซิงโครนัส
#
# Purpose of DefaultAzureCredential: คลาส DefaultAzureCredential เป็นส่วนหนึ่งของ Azure SDK สำหรับ Python ซึ่งให้วิธีการเริ่มต้นเพื่อยืนยันตัวตนกับบริการ Azure โดยพยายามยืนยันตัวตนด้วยหลายวิธีตามลำดับ เช่น ตัวแปรแวดล้อม managed identity และข้อมูลประจำตัว Azure CLI
#
# Asynchronous Operations: โมดูล aio บ่งชี้ว่าคลาส DefaultAzureCredential รองรับการทำงานแบบอะซิงโครนัส ซึ่งหมายความว่าคุณสามารถใช้ร่วมกับ asyncio เพื่อทำคำขอยืนยันตัวตนแบบไม่บล็อกได้

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # คำอธิบาย:
# นำเข้ามอดูลและคลาสต่าง ๆ จากแพ็กเกจ semantic_kernel รายละเอียดการนำเข้าแต่ละรายการมีดังนี้:
#
# AgentGroupChat จาก semantic_kernel.agents: คลาสนี้จัดการฟังก์ชันที่เกี่ยวข้องกับการแชทกลุ่มสำหรับเอเจนต์ AI AzureAIAgent และ AzureAIAgentSettings จาก semantic_kernel.agents.azure_ai
#
# AzureAIAgent: คลาสนี้ใช้สำหรับสร้างและจัดการเอเจนต์ AI ที่ใช้บริการ AI ของ Azure
#
# AzureAIAgentSettings: คลาสนี้ใช้สำหรับกำหนดค่าการตั้งค่าสำหรับ AzureAIAgent TerminationStrategy จาก semantic_kernel.agents.strategies.termination.termination_strategy:
#
# คลาสนี้กำหนดกลยุทธ์ในการสิ้นสุดการทำงานของเอเจนต์ AI ภายใต้เงื่อนไขบางประการ ChatMessageContent จาก semantic_kernel.contents.chat_message_content:
#
# คลาสนี้ใช้จัดการเนื้อหาของข้อความแชท
# AuthorRole จาก semantic_kernel.contents.utils.author_role:
#
# คลาสนี้กำหนดบทบาทต่าง ๆ สำหรับผู้แต่งในบริบทของข้อความแชท
#
# kernel_function จาก semantic_kernel.functions.kernel_function_decorator: ตัวตกแต่งนี้ใช้สำหรับกำหนดฟังก์ชัน kernel ซึ่งเป็นฟังก์ชันที่สามารถดำเนินการภายในกรอบงาน semantic kernel
# การนำเข้าดังกล่าวตั้งค่าคอมโพเนนต์ที่จำเป็นสำหรับการสร้างและจัดการเอเจนต์ AI ที่สามารถโต้ตอบในสภาพแวดล้อมแชทกลุ่ม อาจใช้สำหรับงาน เช่น การจองโรงแรมหรือกิจกรรมที่คล้ายกัน

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Explanation:
# Next we import the CodeInterpreterTool class from the azure.ai.projects.models module.
#
# CodeInterpreterTool: คลาสนี้เป็นส่วนหนึ่งของ Azure AI SDK และใช้สำหรับแปลและรันโค้ดภายในบริบทของโครงการ AI มันให้ฟังก์ชันสำหรับการรันโค้ดส่วนเล็กๆ การวิเคราะห์โค้ด หรือการรวมการรันโค้ดเข้าไว้ในเวิร์กโฟลว์ AI
# การนำเข้าแบบนี้จะเป็นการตั้งค่าส่วนประกอบที่จำเป็นสำหรับการใช้งาน CodeInterpreterTool ในโครงการของคุณ ซึ่งอาจมีประโยชน์สำหรับงานที่เกี่ยวข้องกับการแปลและรันโค้ดแบบไดนามิก

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Explanation:
# คลาส ApprovalTerminationStrategy ให้กลยุทธ์เฉพาะสำหรับการยุติการทำงานของเอเจนต์ AI เอเจนต์จะยุติการทำงานหากข้อความล่าสุดในประวัติการโต้ตอบของมันมีคำว่า "saved" สิ่งนี้อาจมีประโยชน์ในสถานการณ์ที่งานของเอเจนต์ถือว่าสมบูรณ์เมื่อได้รับการยืนยันว่าบางสิ่งถูก "saved" กำหนดวิธีการโต้ตอบ หลังจากแผนการจองถูกบันทึกแล้ว สามารถหยุดได้เมื่อได้รับสัญญาณ saved

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # คำอธิบาย:
#
# บรรทัดของโค้ดนี้เป็นการสร้างวัตถุ AzureAIAgentSettings ด้วยการตั้งค่าปริยายหรือค่าที่กำหนดไว้ล่วงหน้าด้วยการเรียกใช้เมธอด create() วัตถุการตั้งค่านี้ (ai_agent_settings) สามารถนำไปใช้ตั้งค่าและจัดการอินสแตนซ์ของ AzureAIAgent ได้ต่อไป

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # คำอธิบาย:
# โดยการนำเข้าไลบรารี requests คุณสามารถส่งคำขอ HTTP และโต้ตอบกับบริการเว็บได้อย่างง่ายดายในโค้ด Python ของคุณได้ง่ายขึ้น.

# %%
import requests

# %% [markdown]
# # Explanation:
# นี่คือ ตัวแปรที่เก็บ API key สำหรับการเข้าถึงบริการ SERP (Search Engine Results Page) API API key คือรหัสประจำตัวเฉพาะที่ใช้ในการตรวจสอบสิทธิ์คำขอที่เกี่ยวข้องกับบัญชีของคุณ
#
# 'GOOGLE_SEARCH_API_KEY': นี่คือสตริงตัวแทน คุณต้องแทนที่ 'GOOGLE_SEARCH_API_KEY' ด้วย SERP API key ที่แท้จริงของคุณ
#
# วัตถุประสงค์: วัตถุประสงค์ของบรรทัดนี้คือเพื่อเก็บ API key ไว้ในตัวแปรเพื่อใช้ในการตรวจสอบสิทธิ์คำขอไปยังบริการ SERP API ที่ต้องใช้ API key เพื่อเข้าสู่บริการและทำการค้นหา
#
# วิธีรับ SERP API Key: ในการรับ SERP API key ให้ทำตามขั้นตอนทั่วไปที่ https://serpapi.com (ขั้นตอนที่แน่นอนอาจแตกต่างกันไปตามบริการ SERP API ที่คุณใช้):
#
# เลือกบริการ SERP API: มีบริการ SERP API หลายตัว เช่น SerpAPI, Google Custom Search JSON API และอื่นๆ เลือกตัวที่เหมาะสมกับความต้องการของคุณที่สุด
#
# สมัครบัญชี:
#
# ไปที่เว็บไซต์ของบริการ SERP API ที่เลือก https://www.serpapi.com และสมัครบัญชี คุณอาจต้องให้ข้อมูลพื้นฐานบางอย่างและยืนยันที่อยู่อีเมลของคุณ
#
# สร้าง API Key:
#
# หลังจากสมัครแล้ว ให้เข้าสู่ระบบบัญชีและไปที่ส่วน API หรือแดชบอร์ด ค้นหาตัวเลือกในการสร้างหรือสร้าง API key ใหม่
# คัดลอก API Key:
#
# เมื่อสร้าง API key แล้ว ให้คัดลอกคีย์นี้ คีย์นี้จะใช้ในการตรวจสอบสิทธิ์คำขอของคุณไปยังบริการ SERP API
# แทนที่ตัวแทน:
#
# แทนที่ตัวแทนในไฟล์ .env ของคุณ

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Explanation:
# The BookingPlugin class provides methods for booking hotels and flights using the Serpapi.com Google Search API. It constructs the necessary parameters, sends API requests, and processes the responses to return relevant booking information. The API key (SERPAPI_SEARCH_API_KEY) and endpoint (SERPAPI_SEARCH_ENDPOINT) are used to authenticate and send requests to the Google Search API.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # คำอธิบาย:
# คลาส SavePlugin มีเมธอด saving_plan เพื่อบันทึกแผนการเดินทางโดยใช้บริการ Azure AI โดยจะตั้งค่าข้อมูลรับรองของ Azure สร้างเอเจนต์ AI ประมวลผลอินพุตของผู้ใช้เพื่อสร้างและบันทึกเนื้อหาแผนการเดินทาง และจัดการการบันทึกไฟล์รวมถึงการล้างข้อมูล เมธอดจะส่งค่ากลับเป็น "Saved" เมื่อดำเนินการเสร็จสิ้นอย่างสำเร็จ

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # Explanation:
# โค้ดนี้ตั้งค่าเอเจนต์ Azure AI เพื่อจัดการการจองเที่ยวบินและโรงแรม รวมถึงการบันทึกแผนการเดินทางตามข้อมูลที่ผู้ใช้ป้อนเข้าไป โดยใช้ข้อมูลประจำตัวของ Azure เพื่อสร้างและกำหนดค่าเอเจนต์ ประมวลผลข้อมูลจากผู้ใช้ผ่านกลุ่มแชท และทำความสะอาดอย่างเหมาะสมหลังจากงานเสร็จสิ้น เอเจนต์เหล่านี้ใช้ปลั๊กอินเฉพาะ (BookingPlugin และ SavePlugin) เพื่อดำเนินการตามหน้าที่ของตนเอง

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ข้อจำกัดความรับผิดชอบ**:
# เอกสารนี้ถูกแปลโดยใช้บริการแปลภาษาอัตโนมัติ [Co-op Translator](https://github.com/Azure/co-op-translator) แม้เราจะพยายามให้มีความถูกต้องมากที่สุด แต่โปรดทราบว่าการแปลอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่แม่นยำ เอกสารฉบับภาษาแม่ของต้นฉบับถือเป็นแหล่งข้อมูลที่น่าเชื่อถือที่สุด สำหรับข้อมูลสำคัญควรใช้บริการแปลโดยมืออาชีพที่เป็นมนุษย์ เราจะไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความผิดพลาดใด ๆ ที่เกิดจากการใช้การแปลนี้
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
