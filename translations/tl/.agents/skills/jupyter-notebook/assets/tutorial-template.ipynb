# %% [markdown]
# # Tutorial: TITLE
#
# Mga mambabasa:
# - Ilahad kung para kanino ito.
#
# Mga Paunang Kaalaman:
# - Ilahad ang mga kinakailangang konsepto o pagsasaayos.
#
# Mga Layunin sa Pagkatuto:
# - Sa pagtatapos, magagawa ng mambabasa...

# %% [markdown]
# ## Balangkas
#
# 1. Pagsasaayos
# 2. Isang minimal na gumaganang halimbawa
# 3. Mga baryasyon at mga bitag
# 4. Mga ehersisyo

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Hakbang 1 - Magsimula sa isang maliit na halimbawa
#
# Ipaliwanag sa payak na pananalita kung ano ang ginagawa ng susunod na cell.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Mga Ehersisyo
#
# - Subukan ang ibang input.
# - Hulaan ang output bago patakbuhin ang code.
# - Tandaan ang isang karaniwang pagkakamali at kung paano ito ayusin.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Paunawa:
# Ang dokumentong ito ay isinalin gamit ang AI na serbisyo sa pagsasalin [Co-op Translator] (https://github.com/Azure/co-op-translator). Bagaman nagsusumikap kami para sa katumpakan, pakitandaan na ang mga awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi tumpak na paglalahad. Ang orihinal na dokumento sa katutubong wika nito ang dapat ituring na pinakapinagkakatiwalaang sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang paggamit ng propesyonal na tagasalin. Hindi kami mananagot sa anumang hindi pagkakaintindihan o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
