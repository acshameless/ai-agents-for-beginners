# %% [markdown]
# # Deney: TITLE
#
# Amaç:
# - Yanıtlamak istediğiniz soruyu belirtin.
# - Başarı kriterlerini tanımlayın.

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## Plan
#
# - Hipotez:
# - Taranacak değişkenler:
# - Kaydedilecek metrikler:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## Sonuçlar
#
# - Ana gözlemler:
# - Sürprizler veya başarısızlık modları:
# - Karar: devam et, yön değiştir veya dur:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## Sonraki adımlar
#
# - Ne denemeli:
# - Başka yerde belgelenmesi gerekenler (PRD, notlar, issue):

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Sorumluluk Reddi**:
# Bu belge, AI çeviri hizmeti [Co-op Translator](https://github.com/Azure/co-op-translator) kullanılarak çevrilmiştir. Doğruluk için çaba göstermemize rağmen, otomatik çevirilerin hatalar veya yanlışlıklar içerebileceğini lütfen unutmayın. Belgenin ana dilindeki orijinal versiyonu yetkili kaynak olarak kabul edilmelidir. Kritik bilgiler için profesyonel bir insan çevirisi önerilir. Bu çevirinin kullanımı sonucunda ortaya çıkabilecek herhangi bir yanlış anlaşılma veya yanlış yorumlamadan sorumlu değiliz.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
