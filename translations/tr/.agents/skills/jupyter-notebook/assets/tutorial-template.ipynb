# %% [markdown]
# # Öğretici: TITLE
#
# Hedef kitle:
# - Bunun kimler için olduğunu açıklayın.
#
# Önkoşullar:
# - Gerekli kavramları veya kurulumu listeleyin.
#
# Öğrenme hedefleri:
# - Sonunda, okuyucu şunu yapabilir...

# %% [markdown]
# ## Genel Bakış
#
# 1. Kurulum
# 2. Çalışan en temel örnek
# 3. Varyasyonlar ve tuzaklar
# 4. Alıştırmalar

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Adım 1 - Küçük bir örnekle başlayın
#
# Bir sonraki hücrenin ne yaptığını yalın bir dille açıklayın.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Alıştırmalar
#
# - Farklı bir girdi deneyin.
# - Kodu çalıştırmadan önce çıktıyı tahmin edin.
# - Yaygın bir hatayı ve nasıl düzelteceğinizi not edin.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Feragatname:
# Bu belge, AI çeviri hizmeti Co-op Translator (https://github.com/Azure/co-op-translator) kullanılarak çevrilmiştir. Doğruluk için çaba göstermemize rağmen, otomatik çevirilerin hatalar veya yanlışlıklar içerebileceğini lütfen unutmayın. Orijinal belge, kaynak dilindeki haliyle yetkili/otoritatif kaynak olarak kabul edilmelidir. Kritik/önemli bilgiler için profesyonel bir insan çevirisi önerilir. Bu çevirinin kullanımından kaynaklanan herhangi bir yanlış anlama veya yanlış yorumlamadan sorumlu değiliz.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
