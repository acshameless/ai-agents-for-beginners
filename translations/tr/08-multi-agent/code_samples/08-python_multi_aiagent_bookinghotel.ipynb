# %% [markdown]
# ## **Örnekler: Otel Rezervasyonu için Çoklu Yapay Zeka Ajanları**
#
# Günümüzün hızlı tempolu dünyasında, bir iş seyahati planlamak sadece uçak bileti ve otel odası rezervasyonu yapmaktan daha fazlasını gerektirir. Başarması zor olabilen bir koordinasyon ve verimlilik seviyesi gerektirir. İşte burada Çoklu Yapay Zeka Ajanları devreye girer ve seyahat ihtiyaçlarımızı yönetme biçimimizi devrim niteliğinde değiştirir.
#
# Yanınızda, seyahatinizin her yönünü hassasiyetle ve kolaylıkla yönetmek için birlikte çalışan zeki ajanlardan oluşan bir ekip olduğunu hayal edin. Gelişmiş yapay zeka teknolojimizle, rezervasyon hizmetleri ve seyahat planı düzenleme için özel ajanlar yarattık; böylece sorunsuz ve stresiz bir seyahat deneyimi sağlıyoruz.
#
# Bu temel bir senaryodur. Bir iş seyahati planlarken, uçak bileti bilgisi, otel bilgisi vb. almak için bir iş seyahati acentesine danışmamız gerekir. Yapay Zeka Ajanları aracılığıyla, rezervasyon hizmetleri için ajanlar ve seyahat planı düzenleme için ajanlar oluşturarak işbirliği yapabilir ve zeka seviyesini artırabiliriz.

# %% [markdown]
# # Azure AI Agent Servisini Başlatma ve **.env** Dosyasından Yapılandırma Bilgilerini Alma
#
# ### **.env**
#
# Bir .env dosyası oluşturun
#
# **.env** Azure AI Agent Servisinin bağlantı dizesini, AOAI tarafından kullanılan modeli ve ilgili Google API Arama servisi API’sini, ENDPOINT gibi bilgileri içerir.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Azure AI Agent Servis Model Dağıtım Adınız"
#
# [**NOT**] 100.000 Rate Limit (Dakikadaki Token Sayısı) ve 600 Rate Limit (Dakikadaki İstek Sayısı) olan bir modele ihtiyacınız olacak
#
#   Microsoft Foundry - Model ve Endpoint bölümünden model alabilirsiniz.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Azure AI Agent Servis Proje Bağlantı Diziniz"
#
#   Proje bağlantı dizesini AI Foundry Portal Ekranındaki proje genel görünümünden alabilirsiniz.
#
# - **SERPAPI_SEARCH_API_KEY** = "SERPAPI Arama API ANAHTARINIZ"
# - **SERPAPI_SEARCH_ENDPOINT** = "SERPAPI Arama Endpointiniz"
#
# Azure AI Agent Servisi Model Dağıtım Adını ve Proje Bağlantı Dizesini almak için Azure AI Agent Servisi oluşturmanız gerekir. Doğrudan oluşturmak için [bu şablonu](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) kullanmanız tavsiye edilir (***Not:*** Azure AI Agent Servisi şu anda sınırlı bölgede ayarlanmıştır. Bölge ayarlaması için [bu bağlantıya](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) bakmanız önerilir)
#
# Agent’ın SERPAPI’ya erişmesi gerekir. Kayıt için [bu linki](https://serpapi.com/searches) kullanmanız tavsiye edilir. Kayıt sonrası benzersiz bir API ANAHTARI ve ENDPOINT alabilirsiniz.

# %% [markdown]
# # Azure'a Giriş Yap
#
# Artık Azure'a giriş yapmanız gerekiyor. VScode'da bir terminal açın ve `az login` komutunu çalıştırın.

# %% [markdown]
# # Kurulum
#
# Bu defteri çalıştırmak için aşağıdaki kütüphaneleri kurmanız gerekecek. İşte gerekli kütüphanelerin listesi ve karşılık gelen pip kurulum komutları:
#
# azure-identity: Azure kimlik doğrulama için.
# requests: HTTP istekleri yapmak için.
# semantic-kernel: Anlamsal çekirdek çerçevesi için (bu özel veya belirli bir kütüphane varsayılıyorsa, muhtemelen belirli bir kaynaktan veya depodan kurmanız gerekir).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # Açıklama:
# import asyncio: Bu, Python'da asenkron programlamayı destekleyen asyncio modülünü içe aktarır. async ve await sözdizimini kullanarak eşzamanlı kod yazmanıza olanak tanır.
# from typing import Annotated: Bu, typing modülünden Annotated türünü içe aktarır. Annotated, doğrulama, dokümantasyon veya araç desteği gibi çeşitli amaçlar için kullanılabilecek tür ipuçlarına meta veriler eklemek için kullanılır.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # Açıklama:
# from dotenv import load_dotenv ve load_dotenv() kullanarak, ayarları ve hassas bilgileri (API anahtarları ve veritabanı URL’leri gibi) .env dosyasında kolayca yönetebilir, bunları kaynak kodunuzdan ayrı tutabilir ve uygulamanızı daha güvenli ve yapılandırması kolay hale getirebilirsiniz.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Açıklama:
#
# İçe Aktarma İfadesi: from azure.identity.aio import DefaultAzureCredential: Bu ifade, DefaultAzureCredential sınıfını azure.identity.aio modülünden içe aktarır. Modül adındaki aio kısmı, modülün asenkron işlemler için tasarlandığını gösterir.
#
# DefaultAzureCredential Amacı: DefaultAzureCredential sınıfı, Azure SDK for Python'un bir parçasıdır. Azure hizmetlerine kimlik doğrulama için varsayılan bir yol sağlar. Çevresel değişkenler, yönetilen kimlik ve Azure CLI kimlik bilgileri gibi çeşitli yöntemleri belirli bir sırayla deneyerek kimlik doğrulamaya çalışır.
#
# Asenkron İşlemler: aio modülü, DefaultAzureCredential sınıfının asenkron işlemleri desteklediğini belirtir. Bu, kimlik doğrulama isteklerini engellemeden gerçekleştirmek için asyncio ile kullanılabileceği anlamına gelir.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Açıklama:
# semantic_kernel paketinden çeşitli modüller ve sınıflar içe aktarılıyor. İşte her bir içe aktarmanın açıklaması:
#
# semantic_kernel.agents içinden AgentGroupChat: Bu sınıf, yapay zeka ajanları için grup sohbeti ile ilgili işlevleri yönetir. semantic_kernel.agents.azure_ai içinden AzureAIAgent ve AzureAIAgentSettings
#
# AzureAIAgent: Bu sınıf, Azure AI servislerini kullanan yapay zeka ajanları oluşturmak ve yönetmek için kullanılır.
#
# AzureAIAgentSettings: Bu sınıf, AzureAIAgent için ayarları yapılandırmak amacıyla kullanılır. semantic_kernel.agents.strategies.termination.termination_strategy içinden TerminationStrategy:
#
# Bu sınıf, belirli koşullar altında yapay zeka ajanlarının yürütmesini sonlandırma stratejilerini tanımlar. semantic_kernel.contents.chat_message_content içinden ChatMessageContent:
#
# Bu sınıf, sohbet mesajlarının içeriğini işlemek için kullanılır. semantic_kernel.contents.utils.author_role içinden AuthorRole:
#
# Bu sınıf, sohbet mesajları bağlamında farklı yazar rollerini tanımlar.
#
# semantic_kernel.functions.kernel_function_decorator içinden kernel_function: Bu dekoratör, semantic kernel çerçevesinde yürütülebilen çekirdek fonksiyonları tanımlamak için kullanılır.
# Bu içe aktarmalar, otel rezervasyonu veya benzeri görevler gibi faaliyetler için grup sohbeti ortamında etkileşimde bulunabilen yapay zeka ajanları oluşturmak ve yönetmek için gerekli bileşenleri kurar.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # Açıklama:
# Sonraki adımda azure.ai.projects.models modülünden CodeInterpreterTool sınıfını içe aktarıyoruz.
#
# CodeInterpreterTool: Bu sınıf Azure AI SDK'nın bir parçasıdır ve AI projeleri bağlamında kodu yorumlamak ve yürütmek için kullanılır. Kod parçacıklarını çalıştırma, kodu analiz etme veya AI iş akışları içinde kod yürütmeyi entegre etme işlevsellikleri sağlar.
# Bu içe aktarma, projenizde CodeInterpreterTool'u kullanmak için gerekli bileşeni hazırlar; bu da kodu dinamik olarak yorumlama ve yürütmeyle ilgili görevler için faydalı olabilir.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # Açıklama:
# ApprovalTerminationStrategy sınıfı, bir Yapay Zeka ajanının operasyonunu sonlandırmak için belirli bir strateji sağlar. Ajan, etkileşim geçmişindeki son mesaj "saved" kelimesini içeriyorsa sonlandırılır. Bu, bir şeyin "kaydedildiği" doğrulamasını aldıktan sonra ajanın görevinin tamamlandığı kabul edilen senaryolarda faydalı olabilir. Etkileşim yöntemini tanımlayın. Rezervasyon planı kaydedildikten sonra, kaydedildi sinyali alındığında durdurulabilir.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # Açıklama:
#
# Bu kod satırı, create() yöntemi çağrılarak varsayılan veya önceden tanımlanmış ayarlarla bir AzureAIAgentSettings nesnesi başlatır. Bu ayar nesnesi (ai_agent_settings), ardından bir AzureAIAgent örneğini yapılandırmak ve yönetmek için kullanılabilir.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # Açıklama:
# requests kütüphanesini içe aktararak, Python kodunuzda HTTP istekleri yapabilir ve web servisleriyle kolayca etkileşimde bulunabilirsiniz.

# %%
import requests

# %% [markdown]
# # Açıklama:
# Bu, bir SERP (Arama Motoru Sonuç Sayfası) API hizmetine erişim için API anahtarını saklayan bir değişkendir. Bir API anahtarı, hesabınızla ilişkili istekleri doğrulamak için kullanılan benzersiz bir tanımlayıcıdır.
#
# 'GOOGLE_SEARCH_API_KEY': Bu bir yer tutucu metindir. ''GOOGLE_SEARCH_API_KEY' ifadesini kendi gerçek SERP API anahtarınızla değiştirmeniz gerekir.
#
# Amaç: Bu satırın amacı, API anahtarını bir değişkende saklayarak SERP API hizmetine yapılan isteklerin doğrulanmasında kullanmaktır. API anahtarı, hizmete erişim sağlamak ve aramalar yapmak için gereklidir.
#
# SERP API Anahtarı Nasıl Alınır: Bir SERP API anahtarı almak için, kullandığınız belirli SERP API hizmetine bağlı olarak değişebilen genel adımları https://serpapi.com adresinde izleyin:
#
# Bir SERP API Hizmeti Seçin: SerpAPI, Google Custom Search JSON API ve diğerleri gibi çeşitli SERP API hizmetleri mevcuttur. İhtiyaçlarınıza en uygun olanı seçin.
#
# Hesap Açın:
#
# Seçtiğiniz SERP API hizmetinin web sitesine https://www.serpapi.com gidin ve bir hesap oluşturun. Bazı temel bilgileri sağlamanız ve e-posta adresinizi doğrulamanız gerekebilir.
#
# Bir API Anahtarı Oluşturun:
#
# Kayıt olduktan sonra hesabınıza giriş yapın ve API bölümüne veya gösterge tablosuna gidin. Yeni bir API anahtarı oluşturma veya üretme seçeneğini arayın.
# API Anahtarını Kopyalayın:
#
# API anahtarı oluşturulduktan sonra, anahtarı kopyalayın. Bu anahtar, SERP API hizmetine yapacağınız isteklerin doğrulanmasında kullanılacaktır.
# Yer Tutucuyu Değiştirin:
#
# .env dosyanızdaki yer tutucuyu değiştirin

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # Açıklama:
# BookingPlugin sınıfı, Serpapi.com Google Arama API'sini kullanarak otel ve uçuş rezervasyonu yapma yöntemleri sağlar. Gerekli parametreleri oluşturur, API isteklerini gönderir ve yanıtları işleyerek ilgili rezervasyon bilgilerini döner. API anahtarı (SERPAPI_SEARCH_API_KEY) ve uç noktası (SERPAPI_SEARCH_ENDPOINT), Google Arama API'sine doğrulama yapmak ve istek göndermek için kullanılır.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # Açıklama:
# SavePlugin sınıfı, Azure AI hizmetlerini kullanarak seyahat planlarını kaydetmek için saving_plan adlı bir yöntem sağlar. Azure kimlik bilgilerini ayarlar, bir AI ajanı oluşturur, kullanıcı girdilerini işleyerek seyahat planı içeriğini oluşturur ve kaydeder, dosya kaydetme ve temizlik işlemlerini yönetir. Yöntem başarılı tamamlandığında "Saved" değerini döner.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # Açıklama:
# Bu kod, kullanıcı girdilerine göre uçuş ve otel rezervasyonlarını yapmak ve seyahat planlarını kaydetmek için Azure AI ajanlarını kurar. Ajanları oluşturmak ve yapılandırmak için Azure kimlik bilgilerini kullanır, kullanıcı girdilerini bir grup sohbeti üzerinden işler ve görevler tamamlandıktan sonra uygun temizliği sağlar. Ajanlar, ilgili görevleri gerçekleştirmek için BookingPlugin ve SavePlugin adlı özel eklentileri kullanır.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Feragatname**:
# Bu belge, AI çeviri servisi [Co-op Translator](https://github.com/Azure/co-op-translator) kullanılarak çevrilmiştir. Doğruluk için çaba göstersek de, otomatik çevirilerin hatalar veya yanlışlıklar içerebileceğini lütfen unutmayın. Orijinal belge, kendi ana dilinde yetkili kaynak olarak kabul edilmelidir. Kritik bilgiler için profesyonel insan çevirisi önerilir. Bu çevirinin kullanımı nedeniyle ortaya çıkabilecek herhangi bir yanlış anlama veya yanlış yorumlamadan sorumluluk kabul edilmektedir.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
