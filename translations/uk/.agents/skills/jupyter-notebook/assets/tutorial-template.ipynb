# %% [markdown]
# # Посібник: TITLE
#
# Аудиторія:
# - Опишіть, для кого це призначено.
#
# Передумови:
# - Перерахуйте необхідні концепції або налаштування.
#
# Цілі навчання:
# - Після завершення читач зможе...

# %% [markdown]
# ## План
#
# 1. Налаштування
# 2. Мінімальний робочий приклад
# 3. Варіанти та підводні камені
# 4. Завдання

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Крок 1 - Почніть з маленького прикладу
#
# Поясніть простими словами, що робить наступна клітинка.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Вправи
#
# - Спробуйте інше введення.
# - Перед запуском коду передбачте вивід.
# - Зазначте одну поширену помилку та як її виправити.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено з використанням сервісу перекладу на основі штучного інтелекту [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, просимо врахувати, що автоматизовані переклади можуть містити помилки або неточності. Документ у його оригінальній мові слід вважати авторитетним джерелом. Для отримання критично важливої інформації рекомендується звернутися до професійного людського перекладу. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
