# %% [markdown]
# # 🔍 Корпоративний RAG з Microsoft Foundry (.NET)
#
# ## 📋 Цілі навчання
#
# У цьому ноутбуці показано, як створювати корпоративні системи Retrieval-Augmented Generation (RAG) з використанням Microsoft Agent Framework у .NET разом із Microsoft Foundry. Ви навчитесь створювати готових до виробництва агентів, які можуть шукати в документах і надавати точні, чутливі до контексту відповіді з корпоративними засобами безпеки та масштабованістю.
#
# **Можливості корпоративного RAG, які ви створите:**
# - 📚 **Аналітика документів**: Розширена обробка документів за допомогою служб Azure AI
# - 🔍 **Семантичний пошук**: Високопродуктивний векторний пошук із корпоративними функціями
# - 🛡️ **Інтеграція безпеки**: Рольовий доступ і шаблони захисту даних
# - 🏢 **Масштабована архітектура**: Готові до виробництва RAG-системи з моніторингом
#
# ## 🎯 Архітектура корпоративного RAG
#
# ### Основні корпоративні компоненти
# - **Microsoft Foundry**: Керована корпоративна платформа штучного інтелекту з можливостями безпеки та відповідності
# - **Persistent Agents**: Станові агенти з історією розмов і управлінням контекстом
# - **Vector Store Management**: Індексація та пошук документів корпоративного рівня
# - **Identity Integration**: Автентифікація Azure AD та керування доступом на основі ролей
#
# ### Переваги .NET для підприємств
# - **Type Safety**: Перевірка під час компіляції для операцій RAG та структур даних
# - **Async Performance**: Неблокуюча обробка документів та операції пошуку
# - **Memory Management**: Ефективне використання ресурсів для великих колекцій документів
# - **Integration Patterns**: Нативна інтеграція сервісів Azure з впровадженням залежностей
#
# ## 🏗️ Технічна архітектура
#
# ### Пайплайн корпоративного RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основні компоненти .NET
# - **Azure.AI.Agents.Persistent**: Управління корпоративними агентами з збереженням стану
# - **Azure.Identity**: Інтегрована автентифікація для безпечного доступу до сервісів Azure
# - **Microsoft.Agents.AI.AzureAI**: Реалізація фреймворку агентів, оптимізована для Azure
# - **System.Linq.Async**: Високопродуктивні асинхронні операції LINQ
#
# ## 🔧 Функції та переваги корпоративного рівня
#
# ### Безпека та відповідність
# - **Azure AD Integration**: Управління корпоративною ідентичністю та автентифікація
# - **Role-Based Access**: Тонке керування дозволами для доступу до документів та операцій
# - **Data Protection**: Шифрування в спокої та під час передачі для конфіденційних документів
# - **Audit Logging**: Всебічне відстеження активності для вимог відповідності
#
# ### Продуктивність та масштабованість
# - **Connection Pooling**: Ефективне управління підключеннями до сервісів Azure
# - **Async Processing**: Неблокуючі операції для сценаріїв з великою пропускною здатністю
# - **Caching Strategies**: Інтелектуальне кешування для часто використовуваних документів
# - **Load Balancing**: Розподілена обробка для розгортань великого масштабу
#
# ### Управління та моніторинг
# - **Health Checks**: Вбудований моніторинг для компонентів системи RAG
# - **Performance Metrics**: Детальна аналітика якості пошуку та часу відгуку
# - **Error Handling**: Всебічне управління виключеннями з політиками повторних спроб
# - **Configuration Management**: Налаштування, специфічні для середовища, з валідацією
#
# ## ⚙️ Вимоги та налаштування
#
# **Середовище розробки:**
# - .NET 9.0 SDK або новіший
# - Visual Studio 2022 або VS Code з розширенням C#
# - Підписка Azure з доступом до AI Foundry
#
# **Необхідні пакети NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Налаштування автентифікації Azure:**
# ```bash
# # Встановіть Azure CLI і автентифікуйтеся
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Налаштування середовища (файл .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Шаблони корпоративного RAG
#
# ### Шаблони управління документами
# - **Bulk Upload**: Ефективна обробка великих колекцій документів
# - **Incremental Updates**: Додавання та модифікація документів у реальному часі
# - **Version Control**: Версіювання документів та відстеження змін
# - **Metadata Management**: Багаті атрибути документів та таксономія
#
# ### Шаблони пошуку та отримання
# - **Hybrid Search**: Поєднання семантичного та ключового пошуку для оптимальних результатів
# - **Faceted Search**: Багатовимірне фільтрування та категоризація
# - **Relevance Tuning**: Користувацькі алгоритми оцінювання для домен-специфічних потреб
# - **Result Ranking**: Розширене ранжування з інтеграцією бізнес-логіки
#
# ### Шаблони безпеки
# - **Document-Level Security**: Тонкий контроль доступу для кожного документу
# - **Data Classification**: Автоматичне маркування чутливості та захист
# - **Audit Trails**: Всебічне журналювання всіх операцій RAG
# - **Privacy Protection**: Можливості виявлення PII та цензурування
#
# ## 🔒 Функції безпеки корпоративного рівня
#
# ### Аутентифікація та авторизація
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Захист даних
# - **Encryption**: Наскрізне шифрування для документів та індексів пошуку
# - **Access Controls**: Інтеграція з Azure AD для дозволів користувачів і груп
# - **Data Residency**: Контроль географічного розташування даних для відповідності вимогам
# - **Backup & Recovery**: Автоматизовані можливості резервного копіювання та аварійного відновлення
#
# ## 📈 Оптимізація продуктивності
#
# ### Шаблони асинхронної обробки
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управління пам'яттю
# - **Streaming Processing**: Обробка великих документів без проблем з пам'яттю
# - **Resource Pooling**: Ефективне повторне використання дорогих ресурсів
# - **Garbage Collection**: Оптимізовані шаблони виділення пам'яті
# - **Connection Management**: Правильний життєвий цикл підключень до сервісів Azure
#
# ### Стратегії кешування
# - **Query Caching**: Кешувати часто виконувані пошуки
# - **Document Caching**: Кешування в пам'яті для «гарячих» документів
# - **Index Caching**: Оптимізоване кешування векторних індексів
# - **Result Caching**: Інтелектуальне кешування згенерованих відповідей
#
# ## 📊 Сценарії використання в підприємстві
#
# ### Управління знаннями
# - **Corporate Wiki**: Інтелектуальний пошук по базах знань компанії
# - **Policy & Procedures**: Автоматизоване керівництво з відповідності та процедур
# - **Training Materials**: Інтелектуальна допомога у навчанні та розвитку
# - **Research Databases**: Системи аналізу академічних та наукових статей
#
# ### Підтримка клієнтів
# - **Support Knowledge Base**: Автоматизовані відповіді служби підтримки клієнтів
# - **Product Documentation**: Інтелектуальне отримання інформації про продукт
# - **Troubleshooting Guides**: Контекстна допомога у вирішенні проблем
# - **FAQ Systems**: Динамічне генерування FAQ із колекцій документів
#
# ### Регуляторна відповідність
# - **Legal Document Analysis**: Аналітика контрактів та юридичних документів
# - **Compliance Monitoring**: Автоматична перевірка регуляторної відповідності
# - **Risk Assessment**: Аналіз ризиків на основі документів та звітування
# - **Audit Support**: Інтелектуальний пошук документів для аудитів
#
# ## 🚀 Впровадження в продакшн
#
# ### Моніторинг та спостереження
# - **Application Insights**: Детальна телеметрія та моніторинг продуктивності
# - **Custom Metrics**: Відстеження та сповіщення бізнес-специфічних KPI
# - **Distributed Tracing**: Наскрізне відстеження запитів між сервісами
# - **Health Dashboards**: Візуалізація стану системи та продуктивності в реальному часі
#
# ### Масштабованість і надійність
# - **Auto-Scaling**: Автоматичне масштабування на основі навантаження та метрик продуктивності
# - **High Availability**: Розгортання в кількох регіонах з можливостями відновлення при відмові
# - **Load Testing**: Перевірка продуктивності в умовах корпоративного навантаження
# - **Disaster Recovery**: Автоматизовані процедури резервного копіювання та відновлення
#
# Готові створювати корпоративні RAG-системи, здатні обробляти чутливі документи в масштабі? Давайте розробляти інтелектуальні системи знань для підприємств! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено з використанням сервісу автоматичного перекладу на основі штучного інтелекту [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, врахуйте, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується звертатися до професійного людського перекладу. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
