# %% [markdown]
# # 🔍 انٹرپرائز RAG Microsoft Foundry (.NET) کے ساتھ
#
# ## 📋 سیکھنے کے مقاصد
#
# یہ نوٹ بک دکھاتی ہے کہ Microsoft Agent Framework کو .NET میں Microsoft Foundry کے ساتھ استعمال کرتے ہوئے کس طرح انٹرپرائز گریڈ Retrieval-Augmented Generation (RAG) سسٹمز بنائے جائیں۔ آپ سیکھیں گے کہ پیداواری-تیار ایجنٹس کیسے بنائے جائیں جو دستاویزات میں تلاش کر سکیں اور انٹرپرائز سکیورٹی اور اسکیل ایبلیٹی کے ساتھ درست، سیاق و سباق سے واقف جوابات فراہم کریں۔
#
# **وہ انٹرپرائز RAG صلاحیتیں جو آپ بنائیں گے:**
# - 📚 **دستاویز انٹیلیجنس**: Azure AI خدمات کے ساتھ اعلیٰ سطحی دستاویز پروسیسنگ
# - 🔍 **سیمنٹک سرچ**: انٹرپرائز خصوصیات کے ساتھ ہائی پرفارمنس ویکٹر سرچ
# - 🛡️ **سیکیورٹی انٹیگریشن**: رول-بیسڈ رسائی اور ڈیٹا پروٹیکشن پیٹرنز
# - 🏢 **اسکیل ایبل آرکیٹیکچر**: مانیٹرنگ کے ساتھ پیداواری-تیار RAG سسٹمز
#
# ## 🎯 انٹرپرائز RAG آرکیٹیکچر
#
# ### بنیادی انٹرپرائز اجزا
# - **Microsoft Foundry**: سیکیورٹی اور کمپلائنس کے ساتھ منیجد انٹرپرائز AI پلیٹ فارم
# - **Persistent Agents**: گفتگو کی تاریخ اور سیاق و سباق کے انتظام کے ساتھ ریاستی ایجنٹس
# - **Vector Store Management**: انٹرپرائز گریڈ دستاویز انڈیکسنگ اور بازیافت
# - **Identity Integration**: Azure AD توثیق اور رول-بیسڈ رسائی کنٹرول
#
# ### .NET کے انٹرپرائز فوائد
# - **Type Safety**: RAG آپریشنز اور ڈیٹا اسٹرکچرز کے لیے کمپائل-ٹائم ویلیڈیشن
# - **Async Performance**: غیر روکی جانے والی دستاویز پروسیسنگ اور سرچ آپریشنز
# - **Memory Management**: بڑی دستاویز کلیکشنز کے لیے موثر وسائل کا استعمال
# - **Integration Patterns**: dependency injection کے ساتھ نیٹیو Azure سروس انٹیگریشن
#
# ## 🏗️ ٹیکنیکل آرکیٹیکچر
#
# ### انٹرپرائز RAG پائپ لائن
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### بنیادی .NET اجزا
# - **Azure.AI.Agents.Persistent**: ریاست کے برقرار رہنے کے ساتھ انٹرپرائز ایجنٹ مینجمنٹ
# - **Azure.Identity**: محفوظ Azure سروس رسائی کے لیے مربوط توثیق
# - **Microsoft.Agents.AI.AzureAI**: Azure-آپٹمائزڈ ایجنٹ فریم ورک امپلیمینٹیشن
# - **System.Linq.Async**: ہائی پرفارمنس اسینکرونس LINQ آپریشنز
#
# ## 🔧 انٹرپرائز خصوصیات اور فوائد
#
# ### سیکیورٹی اور کمپلائنس
# - **Azure AD Integration**: انٹرپرائز شناختی مینجمنٹ اور توثیق
# - **Role-Based Access**: دستاویز تک رسائی اور آپریشنز کے لیے باریک سطحی اجازتیں
# - **Data Protection**: حساس دستاویزات کے لیے rest اور in-transit میں انکرپشن
# - **Audit Logging**: کمپلائنس تقاضوں کے لیے جامع سرگرمی ٹریکنگ
#
# ### پرفارمنس اور اسکیل ایبلیٹی
# - **Connection Pooling**: Azure سروس کنکشنز کا موثر انتظام
# - **Async Processing**: ہائی-تھروپٹ سیناریوز کے لیے غیر روکی جانے والی آپریشنز
# - **Caching Strategies**: اکثر رسائی والے دستاویزات کے لیے ذہین کیشنگ
# - **Load Balancing**: بڑے پیمانے پر ڈیپلائمنٹس کے لیے تقسیم شدہ پروسیسنگ
#
# ### منیجمنٹ اور مانیٹرنگ
# - **Health Checks**: RAG سسٹم اجزا کے لیے بلٹ-ان مانیٹرنگ
# - **Performance Metrics**: سرچ کوالٹی اور رسپانس ٹائمز پر مفصل اینالٹکس
# - **Error Handling**: ریٹری پالیسیز کے ساتھ جامع استثناء مینجمنٹ
# - **Configuration Management**: ویلیڈیشن کے ساتھ ماحولیاتی مخصوص سیٹنگز
#
# ## ⚙️ پری ریکوائرمنٹس اور سیٹ اپ
#
# **ڈیولپمنٹ ماحولیہ:**
# - .NET 9.0 SDK یا اس سے اوپر
# - Visual Studio 2022 یا VS Code کے ساتھ C# ایکسٹینشن
# - AI Foundry رسائی کے ساتھ Azure سبسکرپشن
#
# **ضروری NuGet پیکجز:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure توثیق سیٹ اپ:**
# ```bash
# # Azure CLI انسٹال کریں اور لاگ ان کریں
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **ماحول کی ترتیب (.env فائل):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 انٹرپرائز RAG پیٹرنز
#
# ### دستاویز مینجمنٹ پیٹرنز
# - **Bulk Upload**: بڑے دستاویز مجموعوں کی موثر پروسیسنگ
# - **Incremental Updates**: حقیقی وقت میں دستاویزات کا اضافہ اور ترمیم
# - **Version Control**: دستاویز ورژننگ اور تبدیلیوں کا ٹریک رکھنا
# - **Metadata Management**: متنوع دستاویز خصوصیات اور ٹیکسونومی
#
# ### سرچ اور بازیافت پیٹرنز
# - **Hybrid Search**: بہترین نتائج کے لیے سیمنٹک اور کلیدی الفاظ سرچ کا امتزاج
# - **Faceted Search**: کثیر الجہتی فلٹرنگ اور درجہ بندی
# - **Relevance Tuning**: مخصوص ڈومین ضروریات کے لیے کسٹم اسکورنگ الگورتھمز
# - **Result Ranking**: بزنس لاجک انٹیگریشن کے ساتھ ایڈوانسڈ رینکنگ
#
# ### سیکیورٹی پیٹرنز
# - **Document-Level Security**: ہر دستاویز کے لیے باریک سطحی رسائی کنٹرول
# - **Data Classification**: حساسیت کی خودکار لیبلنگ اور حفاظت
# - **Audit Trails**: تمام RAG آپریشنز کا جامع لاگنگ
# - **Privacy Protection**: PII شناخت اور ریڈیکشن صلاحیتیں
#
# ## 🔒 انٹرپرائز سیکیورٹی خصوصیات
#
# ### توثیق اور اجازت
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### ڈیٹا پروٹیکشن
# - **Encryption**: دستاویزات اور سرچ انڈیکسز کے لیے سر تو سر انکرپشن
# - **Access Controls**: صارف اور گروپ اجازتوں کے لیے Azure AD کے ساتھ انٹیگریشن
# - **Data Residency**: کمپلائنس کے لیے جغرافیائی ڈیٹا مقام کنٹرول
# - **Backup & Recovery**: خودکار بیک اپ اور ڈیزاسٹر ریکوری صلاحیتیں
#
# ## 📈 پرفارمنس آپٹیمائزیشن
#
# ### اسینکرونس پروسیسنگ پیٹرنز
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### میموری مینجمنٹ
# - **Streaming Processing**: بڑی دستاویزات کو بغیر میموری مسائل کے ہینڈل کرنا
# - **Resource Pooling**: مہنگے وسائل کا موثر دوبارہ استعمال
# - **Garbage Collection**: بہتر میموری مختص کرنے کے پیٹرنز
# - **Connection Management**: مناسب Azure سروس کنکشن لائف سائیکل
#
# ### کیشنگ حکمت عملیاں
# - **Query Caching**: اکثر چلنے والی سرچز کو کیش کریں
# - **Document Caching**: ہاٹ دستاویزات کے لیے ان-میموری کیشنگ
# - **Index Caching**: ویکٹر انڈیکس کی بہتر کیشنگ
# - **Result Caching**: تیار کردہ جوابات کی ذہین کیشنگ
#
# ## 📊 انٹرپرائز استعمال کے کیسز
#
# ### نالج مینجمنٹ
# - **Corporate Wiki**: کمپنی کے نالج بیسز میں ذہین سرچ
# - **Policy & Procedures**: خودکار کمپلائنس اور طریقہ کار کی رہنمائی
# - **Training Materials**: ذہین تربیتی اور ڈیولپمنٹ معاونت
# - **Research Databases**: اکیڈمک اور ریسرچ پیپرز کا تجزیاتی نظام
#
# ### کسٹمر سپورٹ
# - **Support Knowledge Base**: خودکار کسٹمر سروس جوابات
# - **Product Documentation**: ذہین پروڈکٹ معلومات کی بازیافت
# - **Troubleshooting Guides**: سیاق و سباق کے مطابق مسئلہ حل کرنے کی مدد
# - **FAQ Systems**: دستاویز مجموعوں سے متحرک FAQ جنریشن
#
# ### ریگولیٹری کمپلائنس
# - **Legal Document Analysis**: معاہدے اور قانونی دستاویزات کی انٹیلیجنس
# - **Compliance Monitoring**: خودکار ریگولیٹری کمپلائنس چیکنگ
# - **Risk Assessment**: دستاویزات کی بنیاد پر خطرے کا تجزیہ اور رپورٹنگ
# - **Audit Support**: آڈٹس کے لیے ذہین دستاویز تلاش
#
# ## 🚀 پروڈکشن ڈیپلائمنٹ
#
# ### مانیٹرنگ اور آبزر ویبیلٹی
# - **Application Insights**: مفصل ٹیلی میٹری اور پرفارمنس مانیٹرنگ
# - **Custom Metrics**: کاروباری مخصوص KPI ٹریکنگ اور الارٹنگ
# - **Distributed Tracing**: سروسز کے درمیان اینڈ-ٹو-اینڈ ریکویسٹ ٹریکنگ
# - **Health Dashboards**: سسٹم ہیلتھ اور پرفارمنس کی حقیقی وقت visualization
#
# ### اسکیل ایبلیٹی اور قابل اعتمادیت
# - **Auto-Scaling**: لوڈ اور پرفارمنس میٹرکس کی بنیاد پر خودکار اسکیلنگ
# - **High Availability**: فیل اوور صلاحیتوں کے ساتھ ملٹی-ریجن ڈیپلائمنٹ
# - **Load Testing**: انٹرپرائز لوڈ کنڈیشنز کے تحت پرفارمنس ویلیڈیشن
# - **Disaster Recovery**: خودکار بیک اپ اور ریکوری پروسیجرز
#
# کیا آپ حساس دستاویزات کو بڑے پیمانے پر ہینڈل کر سکنے والے انٹرپرائز-گریڈ RAG سسٹمز بنانا چاہتے ہیں؟ آئیں انٹرپرائز کے لیے ذہین نالج سسٹمز کی آرکیٹیکچر بنائیں! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# ردِ ذمہ داری:
# اس دستاویز کا ترجمہ AI ترجمہ سروس Co-op Translator (https://github.com/Azure/co-op-translator) استعمال کرتے ہوئے کیا گیا ہے۔ اگرچہ ہم درستگی کے لیے کوشاں ہیں، براہِ کرم نوٹ کریں کہ خودکار تراجم میں غلطیاں یا عدمِ درستگی ہو سکتی ہیں۔ اصل دستاویز کو اس کی مادری زبان میں حتمی ماخذ سمجھا جانا چاہیے۔ اہم معلومات کے لیے، پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ ہم اس ترجمہ کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کے لیے ذمہ دار نہیں ہیں۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
