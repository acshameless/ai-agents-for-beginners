# %% [markdown]
# ## **نمونے: ہوٹل کی بکنگ کے لیے ملٹی-اے آئی ایجنٹس**
#
# آج کی تیز رفتار دنیا میں، کاروباری سفر کی منصوبہ بندی صرف پرواز اور ہوٹل کے کمرے کی بکنگ تک محدود نہیں ہے۔ اس میں ایک ایسا درجہ کی ہم آہنگی اور کارکردگی درکار ہوتی ہے جو حاصل کرنا مشکل ہو سکتا ہے۔ یہاں ملٹی-اے آئی ایجنٹس کام میں آتے ہیں، جو ہمارے سفر کی ضروریات کو سنبھالنے کے طریقے میں انقلاب برپا کر رہے ہیں۔
#
# تصور کریں کہ آپ کے پاس ذہین ایجنٹس کی ایک ٹیم موجود ہے، جو آپ کے سفر کے ہر پہلو کو درستگی اور آسانی کے ساتھ سنبھالنے کے لیے مل کر کام کر رہی ہو۔ ہماری جدید اے آئی ٹیکنالوجی کے ساتھ، ہم نے بکنگ سروسز اور سفری منصوبہ بندی کے لیے مخصوص ایجنٹس تیار کیے ہیں، جو ایک بے جوڑ اور پریشانی سے پاک سفر کا تجربہ یقینی بناتے ہیں۔
#
# یہ ایک بنیادی منظرنامہ ہے۔ جب کاروباری سفر کی منصوبہ بندی کی جاتی ہے، تو ہمیں ہوائی ٹکٹ کی معلومات، ہوٹل کی معلومات وغیرہ حاصل کرنے کے لیے کاروباری سفر کے ایجنٹ سے مشورہ کرنا ہوتا ہے۔ اے آئی ایجنٹس کے ذریعے، ہم بکنگ سروسز کے ایجنٹس اور سفری منصوبہ بندی کے ایجنٹس تیار کر سکتے ہیں تاکہ وہ تعاون کریں اور ذہانت کی سطح کو بہتر بنائیں۔

# %% [markdown]
# # Azure AI ایجنٹ سروس کو شروع کریں اور **.env** سے ترتیب کی معلومات حاصل کریں
#
# ### **.env**
#
# ایک .env فائل بنائیں
#
# **.env** میں Azure AI ایجنٹ سروس کا کنکشن سٹرنگ، AOAI کے ذریعہ استعمال ہونے والا ماڈل، اور متعلقہ گوگل API سرچ سروس API، ENDPOINT، وغیرہ شامل ہیں۔
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "آپ کا Azure AI ایجنٹ سروس ماڈل تعیناتی کا نام"
#
# [**نوٹ**] آپ کو 100,000 ریٹ لمٹ (ٹوکنز فی منٹ) اور 600 ریٹ لمٹ (درخواستیں فی منٹ) والے ماڈل کی ضرورت ہوگی
#
#   آپ Microsoft Foundry - Model and Endpoint میں ماڈل حاصل کر سکتے ہیں۔
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "آپ کے Azure AI ایجنٹ سروس پروجیکٹ کنکشن سٹرنگ"
#
#   آپ AI ​​Foundry پورٹل اسکرین میں اپنے پروجیکٹ کے جائزے میں پروجیکٹ کنکشن سٹرنگ حاصل کر سکتے ہیں۔
#
# - **SERPAPI_SEARCH_API_KEY** = "آپ کا SERPAPI سرچ API کی"
#
# - **SERPAPI_SEARCH_ENDPOINT** = "آپ کا SERPAPI سرچ اینڈپوائنٹ"
#
# Azure AI ایجنٹ سروس کے ماڈل تعیناتی کے نام اور پروجیکٹ کنکشن سٹرنگ کو حاصل کرنے کے لیے، آپ کو Azure AI ایجنٹ سروس بنانی ہوگی۔ اسے براہ راست بنانے کے لیے [اس ٹیمپلیٹ](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) کا استعمال کرنے کی سفارش کی جاتی ہے (***نوٹ:*** Azure AI ایجنٹ سروس اس وقت محدود خطے میں سیٹ ہے۔ خطے کے تعین کے لیے آپ [اس لنک](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) کا حوالہ دے سکتے ہیں)
#
# ایجنٹ کو SERPAPI تک رسائی کی ضرورت ہے۔ رجسٹریشن کے لیے [اس لنک](https://serpapi.com/searches) کا استعمال کرنے کی سفارش کی جاتی ہے۔ رجسٹریشن کے بعد، آپ کو ایک منفرد API کی اور ENDPOINT مل سکتی ہے۔

# %% [markdown]
# # لاگ ان کریں Azure میں
#
# آپ کو اب Azure میں لاگ ان کرنا ہوگا۔ VScode میں ایک ٹرمینل کھولیں اور `az login` کمانڈ چلائیں۔

# %% [markdown]
# # Setup
#
# اس نوٹ بک کو چلانے کے لیے، آپ کو درج ذیل لائبریریز انسٹال کرنے کی ضرورت ہوگی۔ یہاں ضروری لائبریریوں کی فہرست اور متعلقہ pip انسٹال کمانڈز دی گئی ہیں:
#
# azure-identity: Azure تصدیق کے لیے۔
# requests: HTTP درخواستیں بھیجنے کے لیے۔
# semantic-kernel: سیمانٹک کرنل فریم ورک کے لیے (فرض کیا جاتا ہے کہ یہ ایک اپنی مرضی یا مخصوص لائبریری ہے، آپ کو اسے کسی مخصوص ذریعہ یا ریپوزٹری سے انسٹال کرنا پڑ سکتا ہے)۔

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # وضاحت:
# import asyncio: یہ asyncio ماڈیول کو امپورٹ کرتا ہے، جو Python میں غیر متزامن پروگرامنگ کی حمایت فراہم کرتا ہے۔ یہ آپ کو async اور await نحو استعمال کرتے ہوئے متوازی کوڈ لکھنے کی اجازت دیتا ہے۔
# from typing import Annotated: یہ typing ماڈیول سے Annotated قسم کو امپورٹ کرتا ہے۔ Annotated قسم کے اشاروں میں میٹا ڈیٹا شامل کرنے کے لیے استعمال ہوتی ہے، جو مختلف مقاصد جیسے تصدیق، دستاویزات، یا ٹولنگ کے لیے مفید ہو سکتا ہے۔

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # وضاحت:
# from dotenv import load_dotenv اور load_dotenv() استعمال کرکے، آپ آسانی سے ترتیبات کی تشکیل اور حساس معلومات (جیسے API کیز اور ڈیٹا بیس URLs) کو .env فائل میں منظم کر سکتے ہیں، انہیں اپنے سورس کوڈ سے الگ رکھتے ہوئے، اور اپنے ایپلیکیشن کو زیادہ محفوظ اور ترتیب دینے میں آسان بنا سکتے ہیں۔

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # وضاحت:
#
# درآمد کا بیان: from azure.identity.aio import DefaultAzureCredential: یہ azure.identity.aio ماڈیول سے DefaultAzureCredential کلاس کو درآمد کرتا ہے۔ ماڈیول کے نام میں aio کا مطلب ہے کہ یہ غیر متزامن عملیات کے لیے بنایا گیا ہے۔
#
# DefaultAzureCredential کا مقصد: DefaultAzureCredential کلاس Azure SDK برائے Python کا حصہ ہے۔ یہ Azure خدمات کے ساتھ تصدیق کرنے کا ایک ڈیفالٹ طریقہ فراہم کرتا ہے۔ یہ مخصوص ترتیب سے متعدد طریقوں سے تصدیق کرنے کی کوشش کرتا ہے، جیسے ماحول کے متغیرات، منیجڈ شناخت، اور Azure CLI کی سندیں۔
#
# غیر متزامن عملیات: aio ماڈیول اس بات کی نشاندہی کرتا ہے کہ DefaultAzureCredential کلاس غیر متزامن عملیات کی حمایت کرتی ہے۔ اس کا مطلب ہے کہ آپ اسے asyncio کے ساتھ استعمال کر کے غیر رکنے والی تصدیقی درخواستیں انجام دے سکتے ہیں۔

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # وضاحت:
# semantic_kernel پیکیج سے مختلف ماڈیولز اور کلاسز کو امپورٹ کرتا ہے۔ ہر امپورٹ کی تفصیل درج ذیل ہے:
#
# AgentGroupChat from semantic_kernel.agents: یہ کلاس AI ایجنٹس کے لیے گروپ چیٹ سے متعلق فنکشنلٹیز کو ہینڈل کرتی ہے۔
# AzureAIAgent اور AzureAIAgentSettings from semantic_kernel.agents.azure_ai
#
# AzureAIAgent: یہ کلاس Azure AI سروسز استعمال کرنے والے AI ایجنٹس کو بنانے اور منظم کرنے کے لیے استعمال ہوتی ہے۔
#
# AzureAIAgentSettings: یہ کلاس AzureAIAgent کے لیے سیٹنگز کنفیگر کرنے کے کام آتی ہے۔
# TerminationStrategy from semantic_kernel.agents.strategies.termination.termination_strategy:
#
# یہ کلاس AI ایجنٹس کی عملدرآمد کو مخصوص حالات میں ختم کرنے کی حکمت عملیوں کی وضاحت کرتی ہے۔
# ChatMessageContent from semantic_kernel.contents.chat_message_content:
#
# یہ کلاس چیٹ میسجز کے مواد کو ہینڈل کرنے کے لیے استعمال ہوتی ہے۔
# AuthorRole from semantic_kernel.contents.utils.author_role:
#
# یہ کلاس چیٹ میسجز کے سیاق و سباق میں مصنفین کے مختلف کرداروں کو متعین کرتی ہے۔
#
# kernel_function from semantic_kernel.functions.kernel_function_decorator: یہ ڈیکوریٹر کرنل فنکشنز کی تعریف کے لیے استعمال ہوتا ہے، جو ایسے فنکشنز ہوتے ہیں جنہیں semantic kernel فریم ورک کے اندر چلایا جا سکتا ہے۔
# یہ امپورٹس AI ایجنٹس بنانے اور منظم کرنے کے لیے ضروری اجزاء فراہم کرتے ہیں جو ممکنہ طور پر گروپ چیٹ ماحول میں بات چیت کر سکتے ہیں، جیسا کہ ہوٹل کی بکنگ یا اسی طرح کی سرگرمیوں کے لیے۔

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # وضاحت:
# اگلے مرحلے میں ہم azure.ai.projects.models ماڈیول سے CodeInterpreterTool کلاس کو درآمد کرتے ہیں۔
#
# CodeInterpreterTool: یہ کلاس Azure AI SDK کا حصہ ہے اور AI پروجیکٹس کے سیاق و سباق میں کوڈ کی تشریح اور اجرا کے لیے استعمال ہوتی ہے۔ یہ کوڈ کے چھوٹے حصے چلانے، کوڈ کا تجزیہ کرنے، یا AI ورک فلو کے اندر کوڈ کے اجرا کو مربوط کرنے کی صلاحیتیں فراہم کرتی ہے۔
# یہ درآمد آپ کے پروجیکٹ میں CodeInterpreterTool کو استعمال کرنے کے لیے ضروری جزو سیٹ اپ کرتا ہے، جو ایسے کاموں کے لیے مفید ہو سکتا ہے جن میں کوڈ کی متحرک تشریح اور اجرا شامل ہو۔

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # وضاحت:
# ApprovalTerminationStrategy کلاس اے آئی ایجنٹ کے آپریشن کو ختم کرنے کے لیے ایک مخصوص حکمت عملی فراہم کرتی ہے۔ ایجنٹ اس وقت ختم ہو جائے گا جب اس کی بات چیت کی تاریخ کا آخری پیغام لفظ "saved" پر مشتمل ہو۔ یہ ان صورتوں میں مفید ہو سکتا ہے جہاں ایجنٹ کا کام اس وقت مکمل سمجھا جائے جب اسے تصدیق مل جائے کہ کچھ "saved" کیا جا چکا ہے۔
# انٹریکشن طریقہ کار کی تعریف کریں۔ جب رزرویشن پلان محفوظ ہو جائے، تو اسے saved سگنل موصول ہونے پر روکا جا سکتا ہے۔

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # وضاحت:
#
# کوڈ کی لائن AzureAIAgentSettings آبجیکٹ کو ڈیفالٹ یا پہلے سے متعین ترتیبات کے ساتھ initialize کرتی ہے create() طریقہ کو کال کرکے۔ یہ ترتیبات کا آبجیکٹ (ai_agent_settings) پھر AzureAIAgent کی ایک مثال کو ترتیب دینے اور منظم کرنے کے لیے استعمال کیا جا سکتا ہے۔

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # وضاحت:
# requests لائبریری کو امپورٹ کرکے، آپ آسانی سے HTTP درخواستیں بھیج سکتے ہیں اور اپنے Python کوڈ میں ویب سروسز کے ساتھ بات چیت کر سکتے ہیں۔

# %%
import requests

# %% [markdown]
# # وضاحت:
# یہ ایک متغیر ہے جو SERP (سرچ انجن رزلٹ پیج) API سروس تک رسائی کے لیے API کلید محفوظ کرتا ہے۔ API کلید ایک منفرد شناختی کار ہے جو آپ کے اکاؤنٹ سے منسلک درخواستوں کی تصدیق کے لیے استعمال ہوتی ہے۔
#
# 'GOOGLE_SEARCH_API_KEY': یہ ایک عارضی سٹرنگ ہے۔ آپ کو ''GOOGLE_SEARCH_API_KEY' کو اپنی اصل SERP API کلید سے تبدیل کرنا ہوگا۔
#
# مقصد: اس لائن کا مقصد API کلید کو ایک متغیر میں ذخیرہ کرنا ہے تاکہ اسے SERP API سروس کی درخواستوں کی تصدیق کے لیے استعمال کیا جا سکے۔ API کلید سروس تک رسائی اور تلاش کرنے کے لیے ضروری ہے۔
#
# SERP API کلید کیسے حاصل کریں: SERP API کلید حاصل کرنے کے لیے، https://serpapi.com پر درج ذیل عمومی مراحل پر عمل کریں (خاص SERP API سروس کے مطابق یہ مراحل مختلف ہو سکتے ہیں):
#
# SERP API سروس کا انتخاب کریں: کئی SERP API سروسز دستیاب ہیں، جیسے SerpAPI، گوگل کسٹم سرچ JSON API، اور دیگر۔ اپنے تقاضوں کے مطابق مناسب سروس کا انتخاب کریں۔
#
# اکاؤنٹ کے لیے سائن اپ کریں:
#
# منتخب شدہ SERP API سروس کی ویب سائٹ https://www.serpapi.com پر جائیں اور اکاؤنٹ کے لیے سائن اپ کریں۔ آپ کو کچھ بنیادی معلومات فراہم کرنا اور اپنا ای میل ایڈریس تصدیق کرنا پڑ سکتا ہے۔
#
# API کلید بنائیں:
#
# سائن اپ کرنے کے بعد، اپنے اکاؤنٹ میں لاگ ان کریں اور API سیکشن یا ڈیش بورڈ پر جائیں۔ نیا API کلید بنانے یا جنریٹ کرنے کا آپشن تلاش کریں۔
# API کلید کو کاپی کریں:
#
# جب API کلید بن جائے تو اسے کاپی کریں۔ یہ کلید آپ کی درخواستوں کی تصدیق کے لیے استعمال کی جائے گی۔
# عارضی جگہ (Placeholder) کو تبدیل کریں:
#
# اپنی .env فائل میں موجود عارضی جگہ کو تبدیل کریں۔

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # وضاحت:
# BookingPlugin کلاس ہوٹلز اور پروازوں کی بکنگ کے لیے Serpapi.com گوگل سرچ API استعمال کرنے کے طریقے فراہم کرتی ہے۔ یہ ضروری پیرامیٹرز بناتی ہے، API درخواستیں بھیجتی ہے، اور جوابات کو پروسیس کرکے متعلقہ بکنگ معلومات واپس کرتی ہے۔ API کلید (SERPAPI_SEARCH_API_KEY) اور اینڈ پوائنٹ (SERPAPI_SEARCH_ENDPOINT) گوگل سرچ API کی توثیق اور درخواستیں بھیجنے کے لیے استعمال ہوتے ہیں۔

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # وضاحت:
# SavePlugin کلاس ایک طریقہ کار saving_plan فراہم کرتی ہے جو Azure AI خدمات کا استعمال کرتے ہوئے سفر کے منصوبے محفوظ کرتا ہے۔ یہ Azure اسناد مرتب کرتی ہے، ایک AI ایجنٹ بناتی ہے، صارف کی ان پٹ کو پراسیس کرکے سفر کے منصوبے کا مواد تیار اور محفوظ کرتی ہے، اور فائل کی محفوظ کاری اور صفائی کے عمل کو سنبھالتی ہے۔ کامیابی کے ساتھ مکمل ہونے پر یہ طریقہ "Saved" واپس کرتا ہے۔

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # وضاحت:
# یہ کوڈ Azure AI ایجنٹز کو فلائٹس اور ہوٹلز کی بکنگ سنبھالنے اور صارف کے ان پٹس کی بنیاد پر سفر کے منصوبے محفوظ کرنے کے لیے تیار کرتا ہے۔ یہ Azure کی اسناد استعمال کرکے ایجنٹز کو تخلیق اور ترتیب دیتا ہے، گروپ چیٹ کے ذریعے صارف کے ان پٹس کو پروسیس کرتا ہے، اور کام مکمل ہونے کے بعد مناسب صفائی یقینی بناتا ہے۔ ایجنٹ مخصوص پلگ انز (BookingPlugin اور SavePlugin) کا استعمال کرتے ہیں تاکہ اپنے متعلقہ کام انجام دے سکیں۔

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **اہم اطلاع**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ اگرچہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا غیر دقیقیاں ہو سکتی ہیں۔ اصل دستاویز اپنی مادری زبان میں معتبر ماخذ سمجھی جائے۔ اہم معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم پر نہیں ہوگی۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
