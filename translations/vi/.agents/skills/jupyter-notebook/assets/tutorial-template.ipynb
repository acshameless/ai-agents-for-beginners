# %% [markdown]
# # Hướng dẫn: TITLE
#
# Đối tượng:
# - Mô tả đối tượng mà nội dung này dành cho.
#
# Yêu cầu tiên quyết:
# - Liệt kê các khái niệm hoặc thiết lập cần thiết.
#
# Mục tiêu học tập:
# - Khi kết thúc, người đọc có thể...

# %% [markdown]
# ## Đề cương
#
# 1. Thiết lập
# 2. Một ví dụ hoạt động tối thiểu
# 3. Biến thể và những cạm bẫy
# 4. Bài tập

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## Bước 1 - Bắt đầu với một ví dụ nhỏ
#
# Giải thích ô tiếp theo làm gì bằng ngôn ngữ đơn giản.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## Bài tập
#
# - Thử một đầu vào khác.
# - Dự đoán đầu ra trước khi chạy mã.
# - Ghi lại một lỗi thường gặp và cách khắc phục.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Tuyên bố miễn trừ trách nhiệm:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi nỗ lực đảm bảo tính chính xác, xin lưu ý rằng các bản dịch tự động có thể chứa lỗi hoặc sai sót. Tài liệu gốc bằng ngôn ngữ ban đầu nên được coi là nguồn chính thức. Đối với thông tin quan trọng, nên sử dụng bản dịch chuyên nghiệp do người dịch thực hiện. Chúng tôi không chịu trách nhiệm về bất kỳ hiểu nhầm hoặc giải thích sai nào phát sinh từ việc sử dụng bản dịch này.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
