# %% [markdown]
# # 🔍 Enterprise RAG với Microsoft Foundry (.NET)
#
# ## 📋 Mục tiêu học tập
#
# Sổ tay này trình bày cách xây dựng các hệ thống Retrieval-Augmented Generation (RAG) cấp doanh nghiệp bằng cách sử dụng Microsoft Agent Framework trong .NET với Microsoft Foundry. Bạn sẽ học cách tạo các agent sẵn sàng cho sản xuất có thể tìm kiếm trong tài liệu và cung cấp các phản hồi chính xác, có ngữ cảnh với bảo mật và khả năng mở rộng cho doanh nghiệp.
#
# **Khả năng RAG doanh nghiệp bạn sẽ xây dựng:**
# - 📚 **Document Intelligence**: Xử lý tài liệu nâng cao với dịch vụ Azure AI
# - 🔍 **Semantic Search**: Tìm kiếm vector hiệu suất cao với các tính năng doanh nghiệp
# - 🛡️ **Security Integration**: Các mẫu bảo mật theo vai trò và bảo vệ dữ liệu
# - 🏢 **Scalable Architecture**: Hệ thống RAG sẵn sàng cho sản xuất với giám sát
#
# ## 🎯 Kiến trúc Enterprise RAG
#
# ### Thành phần cốt lõi cho doanh nghiệp
# - **Microsoft Foundry**: Nền tảng AI doanh nghiệp được quản lý với bảo mật và tuân thủ
# - **Persistent Agents**: Các agent có trạng thái với lịch sử hội thoại và quản lý ngữ cảnh
# - **Vector Store Management**: Lập chỉ mục và truy xuất tài liệu cấp doanh nghiệp
# - **Identity Integration**: Xác thực Azure AD và kiểm soát truy cập theo vai trò
#
# ### Lợi ích .NET cho doanh nghiệp
# - **Type Safety**: Kiểm tra tại thời gian biên dịch cho các thao tác RAG và cấu trúc dữ liệu
# - **Async Performance**: Xử lý tài liệu và tìm kiếm không chặn
# - **Memory Management**: Sử dụng tài nguyên hiệu quả cho bộ sưu tập tài liệu lớn
# - **Integration Patterns**: Tích hợp dịch vụ Azure gốc với dependency injection
#
# ## 🏗️ Kiến trúc kỹ thuật
#
# ### Pipeline Enterprise RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Core .NET Components
# - **Azure.AI.Agents.Persistent**: Quản lý agent doanh nghiệp với khả năng lưu trạng thái
# - **Azure.Identity**: Xác thực tích hợp để truy cập dịch vụ Azure an toàn
# - **Microsoft.Agents.AI.AzureAI**: Triển khai khung agent tối ưu cho Azure
# - **System.Linq.Async**: Các thao tác LINQ bất đồng bộ hiệu suất cao
#
# ## 🔧 Tính năng & Lợi ích cho doanh nghiệp
#
# ### Bảo mật & Tuân thủ
# - **Azure AD Integration**: Quản lý danh tính doanh nghiệp và xác thực
# - **Role-Based Access**: Quyền hạn chi tiết cho truy cập và thao tác tài liệu
# - **Data Protection**: Mã hóa khi lưu và khi truyền cho các tài liệu nhạy cảm
# - **Audit Logging**: Theo dõi hoạt động toàn diện cho các yêu cầu tuân thủ
#
# ### Hiệu suất & Khả năng mở rộng
# - **Connection Pooling**: Quản lý kết nối dịch vụ Azure hiệu quả
# - **Async Processing**: Các thao tác không chặn cho các kịch bản thông lượng cao
# - **Caching Strategies**: Bộ nhớ đệm thông minh cho các tài liệu truy cập thường xuyên
# - **Load Balancing**: Xử lý phân tán cho triển khai quy mô lớn
#
# ### Quản lý & Giám sát
# - **Health Checks**: Giám sát tích hợp cho các thành phần hệ thống RAG
# - **Performance Metrics**: Phân tích chi tiết về chất lượng tìm kiếm và thời gian phản hồi
# - **Error Handling**: Quản lý ngoại lệ toàn diện với chính sách thử lại
# - **Configuration Management**: Cài đặt theo môi trường với xác thực
#
# ## ⚙️ Yêu cầu & Thiết lập
#
# **Môi trường phát triển:**
# - .NET 9.0 SDK hoặc cao hơn
# - Visual Studio 2022 hoặc VS Code với phần mở rộng C#
# - Đăng ký Azure có quyền truy cập AI Foundry
#
# **Các gói NuGet bắt buộc:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Cài đặt xác thực Azure:**
# ```bash
# # Cài đặt Azure CLI và xác thực
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Cấu hình môi trường (tệp .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Mẫu RAG cho doanh nghiệp
#
# ### Mẫu quản lý tài liệu
# - **Bulk Upload**: Xử lý hiệu quả các bộ sưu tập tài liệu lớn
# - **Incremental Updates**: Thêm và sửa đổi tài liệu theo thời gian thực
# - **Version Control**: Quản lý phiên bản tài liệu và theo dõi thay đổi
# - **Metadata Management**: Thuộc tính tài liệu phong phú và hệ phân loại
#
# ### Mẫu tìm kiếm & truy xuất
# - **Hybrid Search**: Kết hợp tìm kiếm ngữ nghĩa và từ khóa để có kết quả tối ưu
# - **Faceted Search**: Lọc và phân loại đa chiều
# - **Relevance Tuning**: Thuật toán điểm tùy chỉnh cho nhu cầu theo lĩnh vực
# - **Result Ranking**: Xếp hạng nâng cao với tích hợp logic nghiệp vụ
#
# ### Mẫu bảo mật
# - **Document-Level Security**: Kiểm soát truy cập chi tiết theo từng tài liệu
# - **Data Classification**: Gán nhãn độ nhạy và bảo vệ tự động
# - **Audit Trails**: Ghi nhật ký toàn diện cho tất cả thao tác RAG
# - **Privacy Protection**: Phát hiện PII và khả năng che khuất
#
# ## 🔒 Tính năng bảo mật doanh nghiệp
#
# ### Authentication & Authorization
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Bảo vệ dữ liệu
# - **Encryption**: Mã hóa đầu-cuối cho tài liệu và chỉ mục tìm kiếm
# - **Access Controls**: Tích hợp với Azure AD cho quyền người dùng và nhóm
# - **Data Residency**: Kiểm soát vị trí dữ liệu theo vùng địa lý để tuân thủ
# - **Backup & Recovery**: Tính năng sao lưu tự động và khả năng phục hồi thảm họa
#
# ## 📈 Tối ưu hóa hiệu suất
#
# ### Mẫu xử lý bất đồng bộ
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Quản lý bộ nhớ
# - **Streaming Processing**: Xử lý tài liệu lớn mà không gây sự cố bộ nhớ
# - **Resource Pooling**: Tái sử dụng hiệu quả các tài nguyên đắt tiền
# - **Garbage Collection**: Các mẫu phân bổ bộ nhớ tối ưu
# - **Connection Management**: Vòng đời kết nối dịch vụ Azure đúng cách
#
# ### Chiến lược bộ nhớ đệm
# - **Query Caching**: Lưu bộ nhớ đệm cho các truy vấn thường thực thi
# - **Document Caching**: Bộ nhớ đệm trong RAM cho các tài liệu nóng
# - **Index Caching**: Bộ nhớ đệm chỉ mục vector được tối ưu
# - **Result Caching**: Bộ nhớ đệm thông minh cho các phản hồi tạo ra
#
# ## 📊 Trường hợp sử dụng cho doanh nghiệp
#
# ### Quản lý tri thức
# - **Corporate Wiki**: Tìm kiếm thông minh trên các cơ sở tri thức công ty
# - **Policy & Procedures**: Hướng dẫn tuân thủ và thủ tục tự động
# - **Training Materials**: Hỗ trợ học tập và phát triển thông minh
# - **Research Databases**: Hệ thống phân tích bài báo học thuật và nghiên cứu
#
# ### Hỗ trợ khách hàng
# - **Support Knowledge Base**: Phản hồi dịch vụ khách hàng tự động
# - **Product Documentation**: Truy xuất thông tin sản phẩm thông minh
# - **Troubleshooting Guides**: Hỗ trợ giải quyết vấn đề theo ngữ cảnh
# - **FAQ Systems**: Tạo FAQ động từ bộ sưu tập tài liệu
#
# ### Tuân thủ quy định
# - **Legal Document Analysis**: Phân tích hợp đồng và tài liệu pháp lý
# - **Compliance Monitoring**: Kiểm tra tuân thủ quy định tự động
# - **Risk Assessment**: Phân tích và báo cáo rủi ro dựa trên tài liệu
# - **Audit Support**: Khai phá tài liệu thông minh cho kiểm toán
#
# ## 🚀 Triển khai sản xuất
#
# ### Giám sát & Khả năng quan sát
# - **Application Insights**: Telemetry chi tiết và giám sát hiệu suất
# - **Custom Metrics**: Theo dõi KPI doanh nghiệp và cảnh báo
# - **Distributed Tracing**: Theo dõi yêu cầu đầu-cuối qua các dịch vụ
# - **Health Dashboards**: Trực quan hóa tình trạng hệ thống và hiệu suất theo thời gian thực
#
# ### Khả năng mở rộng & Độ tin cậy
# - **Auto-Scaling**: Tự động mở rộng dựa trên tải và chỉ số hiệu suất
# - **High Availability**: Triển khai đa vùng với khả năng chuyển đổi dự phòng
# - **Load Testing**: Xác thực hiệu suất dưới tải doanh nghiệp
# - **Disaster Recovery**: Thủ tục sao lưu và phục hồi tự động
#
# Sẵn sàng xây dựng các hệ thống RAG cấp doanh nghiệp có thể xử lý tài liệu nhạy cảm ở quy mô lớn? Hãy kiến trúc các hệ thống tri thức thông minh cho doanh nghiệp! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# Miễn trừ trách nhiệm:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi nỗ lực đảm bảo tính chính xác, xin lưu ý rằng bản dịch tự động có thể chứa lỗi hoặc sai sót. Văn bản gốc bằng ngôn ngữ ban đầu nên được coi là nguồn có thẩm quyền. Đối với những thông tin quan trọng, nên sử dụng dịch vụ dịch thuật chuyên nghiệp do người dịch thực hiện. Chúng tôi không chịu trách nhiệm cho bất kỳ hiểu lầm hoặc diễn giải sai nào phát sinh từ việc sử dụng bản dịch này.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
