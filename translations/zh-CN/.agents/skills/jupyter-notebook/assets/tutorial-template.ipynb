# %% [markdown]
# # 教程: TITLE
#
# 受众:
# - 描述这篇文章面向谁。
#
# 先决条件:
# - 列出所需的概念或设置。
#
# 学习目标:
# - 到本文结束时，读者将能够...

# %% [markdown]
# ## 大纲
#
# 1. 设置
# 2. 一个最小可运行示例
# 3. 变体与陷阱
# 4. 练习

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## 第 1 步 - 从一个小例子开始
#
# 用通俗的语言解释下一单元格的作用。

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## 练习
#
# - 尝试不同的输入。
# - 在运行代码之前预测输出。
# - 指出一个常见错误并说明如何修复它。

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免责声明：
# 本文件已使用 AI 翻译服务 [Co-op Translator](https://github.com/Azure/co-op-translator) 翻译。尽管我们力求准确，但请注意自动翻译可能存在错误或不准确之处。原始语言版本应被视为权威来源。对于重要信息，建议采用专业人工翻译。对于因使用本翻译而产生的任何误解或曲解，我们不承担责任。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
