# %% [markdown]
# # 教學: TITLE
#
# 目標讀者:
# - 描述這是為誰而設。
#
# 先決條件:
# - 列出所需的概念或設定。
#
# 學習目標:
# - 完成後，讀者可以...

# %% [markdown]
# ## 大綱
#
# 1. 設定
# 2. 一個最小可行的範例
# 3. 變體與陷阱
# 4. 練習

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## 第 1 步 - 從一個小例子開始
#
# 以簡單易明的語言解釋下一個單元格做什麼。

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## 練習
#
# - 嘗試不同的輸入。
# - 在執行程式之前預測輸出。
# - 注意一個常見錯誤以及如何修正它。

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免責聲明：
# 本文件已使用 AI 翻譯服務 [Co-op Translator](https://github.com/Azure/co-op-translator) 進行翻譯。儘管我們致力確保準確性，請注意自動翻譯可能包含錯誤或不準確之處。原始文件的母語版本應被視為具權威性的版本。對於關鍵資訊，建議採用專業人工翻譯。我們對因使用本翻譯而引致的任何誤解或曲解概不負責。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
