# %% [markdown]
# # 教學: TITLE
#
# 目標讀者:
# - 描述此內容適合誰。
#
# 先決條件:
# - 列出所需的概念或設定。
#
# 學習目標:
# - 完成後，讀者可以...

# %% [markdown]
# ## 大綱
#
# 1. 設定
# 2. 最小可行範例
# 3. 變體與陷阱
# 4. 練習

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## 第 1 步 - 從一個小範例開始
#
# 請以淺白的語言解釋下一個儲存格的作用。

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## 練習
#
# - 嘗試不同的輸入。
# - 在執行程式碼前預測輸出。
# - 記下一個常見錯誤以及如何修正它。

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免責聲明：
# 本文件已使用人工智能翻譯服務 Co-op Translator (https://github.com/Azure/co-op-translator) 進行翻譯。雖然我們力求準確，但請注意，自動翻譯可能包含錯誤或不準確之處。原始語言的原文應被視為具權威性的版本。若涉及重要資訊，建議使用專業人工翻譯。我們對因使用本翻譯而引起的任何誤解或曲解概不負責。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
