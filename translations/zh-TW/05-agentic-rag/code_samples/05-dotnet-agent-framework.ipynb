# %% [markdown]
# # 🔍 企業級 RAG 與 Microsoft Foundry (.NET)
#
# ## 📋 學習目標
#
# 這份筆記示範如何使用 Microsoft Agent Framework 在 .NET 中結合 Microsoft Foundry，建構企業級的檢索增強生成 (Retrieval-Augmented Generation, RAG) 系統。您將學會建立可投入生產的代理，能夠搜尋文件並提供準確、具情境感知的回應，同時具備企業級的安全性與可擴充性。
#
# **您將建立的企業級 RAG 能力：**
# - 📚 **文件智能**：使用 Azure AI 服務的進階文件處理
# - 🔍 **語意搜尋**：具有企業功能的高效能向量搜尋
# - 🛡️ **安全整合**：基於角色的存取與資料保護模式
# - 🏢 **可擴充架構**：具監控的可投入生產的 RAG 系統
#
# ## 🎯 企業級 RAG 架構
#
# ### 主要企業元件
# - **Microsoft Foundry**：受管理的企業 AI 平台，具備安全性與合規性
# - **持久化代理**：具有對話歷史與上下文管理的有狀態代理
# - **向量儲存管理**：企業級文件索引與檢索
# - **身分整合**：Azure AD 認證與基於角色的存取控制
#
# ### .NET 的企業優勢
# - **型別安全**：對 RAG 操作與資料結構進行編譯時驗證
# - **非同步效能**：非阻塞的文件處理與搜尋作業
# - **記憶體管理**：對大量文件集合的有效資源利用
# - **整合模式**：原生 Azure 服務整合與相依注入
#
# ## 🏗️ 技術架構
#
# ### 企業級 RAG 管線
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### 核心 .NET 元件
# - **Azure.AI.Agents.Persistent**：具有狀態持久化的企業代理管理
# - **Azure.Identity**：用於安全存取 Azure 服務的整合認證
# - **Microsoft.Agents.AI.AzureAI**：針對 Azure 優化的代理框架實作
# - **System.Linq.Async**：高效能的非同步 LINQ 操作
#
# ## 🔧 企業功能與優勢
#
# ### 安全與合規
# - **Azure AD 整合**：企業身分管理與驗證
# - **基於角色的存取**：針對文件存取與操作的細緻權限
# - **資料保護**：對敏感文件進行靜態與傳輸中加密
# - **稽核日誌**：為合規需求提供完整的活動追蹤
#
# ### 效能與可擴充性
# - **連線池化**：高效的 Azure 服務連線管理
# - **非同步處理**：為高吞吐情境提供非阻塞作業
# - **快取策略**：為常存取文件提供智慧快取
# - **負載平衡**：大型部署的分散式處理
#
# ### 管理與監控
# - **健康檢查**：為 RAG 系統元件提供內建監控
# - **效能指標**：關於搜尋品質與回應時間的詳細分析
# - **錯誤處理**：具重試策略的完整例外管理
# - **設定管理**：具有驗證的環境專屬設定
#
# ## ⚙️ 前置需求與設定
#
# **開發環境：**
# - .NET 9.0 SDK 或更新版本
# - Visual Studio 2022 或 安裝 C# 擴充功能的 VS Code
# - 具有 AI Foundry 存取權的 Azure 訂閱
#
# **所需的 NuGet 套件：**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure 認證設定：**
# ```bash
# # 安裝 Azure CLI 並進行身分驗證
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **環境設定（.env 檔案）：**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 企業級 RAG 模式
#
# ### 文件管理模式
# - **批次上傳**：高效率處理大量文件集合
# - **增量更新**：即時新增與修改文件
# - **版本控制**：文件版本與變更追蹤
# - **元資料管理**：豐富的文件屬性與分類
#
# ### 搜尋與檢索模式
# - **混合搜尋**：結合語意與關鍵字搜尋以取得最佳結果
# - **分面搜尋**：多維度過濾與分類
# - **相關性調校**：為特定領域需求訂製的評分演算法
# - **結果排序**：與商業邏輯整合的進階排序
#
# ### 安全模式
# - **文件層級安全**：每份文件的細緻存取控制
# - **資料分類**：自動敏感性標籤與保護
# - **稽核軌跡**：對所有 RAG 操作的完整記錄
# - **隱私保護**：PII 偵測與遮蔽能力
#
# ## 🔒 企業安全功能
#
# ### 身分驗證與授權
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### 資料保護
# - **加密**：對文件與搜尋索引提供端到端加密
# - **存取控制**：與 Azure AD 整合以管理使用者與群組權限
# - **資料駐留**：為合規性提供地理資料位置控制
# - **備份與復原**：自動備份與災難復原能力
#
# ## 📈 效能優化
#
# ### 非同步處理模式
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### 記憶體管理
# - **串流處理**：處理大型文件而不產生記憶體問題
# - **資源池化**：有效重複使用昂貴資源
# - **垃圾回收**：最佳化的記憶體配置模式
# - **連線管理**：正確的 Azure 服務連線生命週期
#
# ### 快取策略
# - **查詢快取**：快取常執行的搜尋
# - **文件快取**：對熱門文件進行記憶體快取
# - **索引快取**：最佳化的向量索引快取
# - **結果快取**：對生成回應的智慧快取
#
# ## 📊 企業使用案例
#
# ### 知識管理
# - **企業維基**：跨公司知識庫的智慧搜尋
# - **政策與流程**：自動化的合規與流程指引
# - **訓練教材**：智慧化的學習與發展協助
# - **研究資料庫**：學術與研究論文分析系統
#
# ### 客戶支援
# - **支援知識庫**：自動化的客服回應
# - **產品文件**：智慧化的產品資訊檢索
# - **故障排除指引**：具情境的問題解決協助
# - **常見問題系統**：從文件集合動態產生 FAQ
#
# ### 法規遵循
# - **法律文件分析**：合約與法律文件智能分析
# - **合規監控**：自動化的法規遵循檢查
# - **風險評估**：基於文件的風險分析與報告
# - **稽核支援**：用於稽核的智慧文件發現
#
# ## 🚀 生產部署
#
# ### 監控與可觀測性
# - **Application Insights**：詳細的遙測與效能監控
# - **自訂指標**：針對業務的 KPI 追蹤與警示
# - **分散式追蹤**：跨服務的端到端請求追蹤
# - **健康儀表板**：即時系統健康與效能可視化
#
# ### 可擴展性與可靠性
# - **自動擴展**：根據負載與效能指標自動擴展
# - **高可用性**：具備故障轉移能力的多區域部署
# - **負載測試**：在企業負載條件下的效能驗證
# - **災難復原**：自動化的備份與復原程序
#
# 準備好構建能在大規模處理敏感文件的企業級 RAG 系統了嗎？讓我們為企業設計智慧化的知識系統吧！ 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免責聲明：
# 本文件係使用 AI 翻譯服務 Co-op Translator（https://github.com/Azure/co-op-translator）翻譯而成。雖然我們力求準確，但自動翻譯可能包含錯誤或不精確之處。原始語言的文件應視為具權威性的來源。如涉及重要資訊，建議採用專業人工翻譯。我們不對因使用本翻譯而產生的任何誤解或錯誤詮釋承擔責任。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
